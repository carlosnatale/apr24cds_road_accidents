# %%
# Import libraries needed to execute the code
import os
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import scipy.cluster.hierarchy as shc
from sklearn.decomposition import PCA
from IPython.display import display, HTML
from sklearn.preprocessing import MinMaxScaler
from scipy.cluster.hierarchy import dendrogram, linkage
from pandas.plotting import andrews_curves, parallel_coordinates, lag_plot, autocorrelation_plot, radviz

# %%
# Import the clean data
data = pd.read_csv('source/data.csv', low_memory=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447670 entries, 0 to 447669
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   AccID                       447670 non-null  int64
#  1   day                         447670 non-null  int64
#  2   month                       447670 non-null  int64
#  3   year                        447670 non-null  int64
#  4   time                        447670 non-null  int64
#  5   lum                         447670 non-null  int64
#  6   atm_condition               447670 non-null  int64
#  7   collision_type              447670 non-null  int64
#  8   lat                         447670 non-null  float64
#  9   long                        447670 non-null  float64
#  10  route_category              447670 non-null  int64
#  11  traffic_regime              447670 non-null  int64
#  12  total_number_lanes          447670 non-null  int64
#  13  reserved_lane_code          447670 non-null  int64
#  14  longitudinal_profile        447670 non-null  int64
#  15  upstream_terminal_number    447670 non-null  float64
#  16  distance_upstream_terminal  447670 non-null  float64
#  17  plan                        447670 non-null  int64
#  18  surface_condition           447670 non-null  int64
#  19  infra                       447670 non-null  int64
#  20  accident_situation          447670 non-null  int64
#  21  maximum_speed               447670 non-null  int64
#  22  vehicleID                   447670 non-null  object
#  23  num_veh                     447670 non-null  object
#  24  traffic_direction           447670 non-null  int64
#  25  vehicle_category            447670 non-null  int64
#  26  fixed_obstacle              447670 non-null  int64
#  27  mobile_obstacle             447670 non-null  int64
#  28  initial_impact_point        447670 non-null  int64
#  29  manv                        447670 non-null  int64
#  30  motor                       447670 non-null  int64
#  31  seat                        447670 non-null  int64
#  32  user_category               447670 non-null  int64
#  33  gravity                     447670 non-null  int64
#  34  gender                      447670 non-null  int64
#  35  birth_year                  447670 non-null  float64
#  36  reason_travel               447670 non-null  int64
#  37  safety_equipment1           447670 non-null  int64
#  38  age                         447670 non-null  float64
# dtypes: float64(6), int64(31), object(2)
# memory usage: 133.2+ MB

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Encode the labels if they are not numeric
le = LabelEncoder()
encoded_labels = le.fit_transform(data['gravity'])

# Calculate the Gini Index
classes, counts = np.unique(encoded_labels, return_counts=True)
gini_index = 1 - sum((counts / counts.sum()) ** 2)

print(f'Gini Index: {gini_index}')
# Out:
# Gini Index: 0.6373818492920684

# %%
# Identifying correlations with the target variable 'gravity'

# Identifying non-numeric columns again
non_numeric_columns = data.select_dtypes(include=['object']).columns

# Copy the original dataframe
data_numeric = data.copy()

# Convert columns to numeric where appropriate, errors='coerce' will convert non-convertible values to NaN
for col in non_numeric_columns:
    data_numeric[col] = pd.to_numeric(data_numeric[col], errors='coerce')

# Identifying and dropping problematic columns specifically
problematic_columns = ['time', 'vehicleID', 'num_veh', 'year']

# Drop the problematic columns and recalculate the correlation matrix
data_cleaned = data_numeric.drop(columns=problematic_columns)

# Calculate correlation matrix
correlation_matrix = data_cleaned.corr()

# Extract correlations with the target variable 'gravity'
correlation_with_gravity = correlation_matrix['gravity'].sort_values(ascending=False)

correlation_with_gravity
# Out:
# gravity                       1.000000
# user_category                 0.225488
# seat                          0.213830
# vehicle_category              0.174109
# motor                         0.137000
# fixed_obstacle                0.108893
# safety_equipment1             0.095200
# birth_year                    0.092458
# gender                        0.078776
# collision_type                0.063093
# plan                          0.036741
# accident_situation            0.035035
# lum                           0.030922
# surface_condition             0.023044
# longitudinal_profile          0.013631
# maximum_speed                 0.007149
# reason_travel                 0.004505
# long                          0.004044
# route_category                0.002846
# atm_condition                 0.001014
# month                         0.000522
# day                          -0.000163
# lat                          -0.000845
# reserved_lane_code           -0.002399
# upstream_terminal_number     -0.003133
# traffic_direction            -0.004691
# traffic_regime               -0.006906
# distance_upstream_terminal   -0.007015
# AccID                        -0.007577
# infra                        -0.007659
# total_number_lanes           -0.009759
# initial_impact_point         -0.024736
# manv                         -0.068836
# age                          -0.092519
# mobile_obstacle              -0.126286
# Name: gravity, dtype: float64

# %% [markdown]
# <font size="6">
#     Visualizations Preparation
# </font>

# %%
# Set up the figure size and style
sns.set_style("darkgrid")

# %%
# Ignore specific warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn")

# %%
# Replace the values in gravity field
data['gravity'] = data['gravity'].replace({
     1: '1 - Uninjured',
     2: '2 - Fatal',
     3: '3 - Hospitalized',
     4: '4 - Minor injury'
})
# Define custom colors
custom_colors = {
    '1 - Uninjured': '#66B2FF',      
    '2 - Fatal': '#FF9999',       
    '3 - Hospitalized': '#FFCC99',   
    '4 - Minor injury': '#99FF99' 
}

# Sort gravity levels alphabetically
gravity_order = sorted(custom_colors.keys())

# %%
# Function to calculate and display percentages in a separated table 
def calculate_and_display_percentages(data, group_by_col):
    counts = data.groupby([group_by_col, 'gravity']).size().reset_index(name='count')
    total_counts = data[group_by_col].value_counts().reset_index(name='total')
    total_counts.columns = [group_by_col, 'total']
    counts = counts.merge(total_counts, on=group_by_col)
    counts['percentage'] = counts['count'] / counts['total'] * 100

    # Pivot the table to show only percentages
    percentage_table = counts.pivot(index=group_by_col, columns='gravity', values='percentage').fillna(0)
    
    styled_table = percentage_table.style.format("{:.1f}%").set_table_styles(
        [{'selector': 'th', 'props': [('font-size', '12pt'), ('font-weight', 'bold'), ('text-align', 'center')]},
         {'selector': 'td', 'props': [('font-size', '10pt'), ('text-align', 'center')]},
         {'selector': 'caption', 'props': [('caption-side', 'top')]}]
    ).set_caption(f'Percentages of Accident Gravity by {group_by_col.capitalize()}').background_gradient(cmap='Blues', axis=None)

    # Display the styled table
    html = styled_table.to_html()
    display(HTML(html))

# %% [markdown]
# <font size="6">
# Graph Visualization
# </font>

# %%
# 1. Number of accidents by Severity Category

# Calculate counts and sort them
counts = data['gravity'].value_counts().sort_values(ascending=False)

# Calculate percentages
total = counts.sum()
percentages = counts / total * 100

plt.figure(figsize=(18, 12))
ax = sns.countplot(data=data, x='gravity', order=counts.index, palette=custom_colors)

for p, percentage in zip(ax.patches, percentages):
    height = p.get_height()
    ax.annotate(f'{percentage:.1f}%', 
                (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='center', 
                xytext=(0, 8), 
                textcoords='offset points')

plt.title('Number of accidents by Severity Category')
plt.xlabel('Severity')
plt.ylabel('Number of Accidents')
plt.show()

# %%
# 2. Number of accidents by Severity vs.Year
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='year', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Year of Accident')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

# Call function to show the percentage Gravity vs. Year
calculate_and_display_percentages(data, 'year')
# Out:
# <style type="text/css">
# #T_c2b35 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_c2b35 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_c2b35 caption {
#   caption-side: top;
# }
# #T_c2b35_row0_col0 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_c2b35_row0_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_c2b35_row0_col2 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_c2b35_row0_col3, #T_c2b35_row2_col3 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_c2b35_row1_col0 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_c2b35_row1_col1, #T_c2b35_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c2b35_row1_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_c2b35_row1_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_c2b35_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c2b35_row2_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_c2b35_row3_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_c2b35_row3_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_c2b35_row3_col2 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_c2b35_row3_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c2b35">
#   <caption>Percentages of Accident Gravity by Year</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_c2b35_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_c2b35_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_c2b35_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_c2b35_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2b35_level0_row0" class="row_heading level0 row0" >2019</th>
#       <td id="T_c2b35_row0_col0" class="data row0 col0" >41.6%</td>
#       <td id="T_c2b35_row0_col1" class="data row0 col1" >2.5%</td>
#       <td id="T_c2b35_row0_col2" class="data row0 col2" >15.5%</td>
#       <td id="T_c2b35_row0_col3" class="data row0 col3" >40.4%</td>
#     </tr>
#     <tr>
#       <th id="T_c2b35_level0_row1" class="row_heading level0 row1" >2020</th>
#       <td id="T_c2b35_row1_col0" class="data row1 col0" >41.0%</td>
#       <td id="T_c2b35_row1_col1" class="data row1 col1" >2.5%</td>
#       <td id="T_c2b35_row1_col2" class="data row1 col2" >15.7%</td>
#       <td id="T_c2b35_row1_col3" class="data row1 col3" >40.7%</td>
#     </tr>
#     <tr>
#       <th id="T_c2b35_level0_row2" class="row_heading level0 row2" >2021</th>
#       <td id="T_c2b35_row2_col0" class="data row2 col0" >42.6%</td>
#       <td id="T_c2b35_row2_col1" class="data row2 col1" >2.4%</td>
#       <td id="T_c2b35_row2_col2" class="data row2 col2" >14.5%</td>
#       <td id="T_c2b35_row2_col3" class="data row2 col3" >40.5%</td>
#     </tr>
#     <tr>
#       <th id="T_c2b35_level0_row3" class="row_heading level0 row3" >2022</th>
#       <td id="T_c2b35_row3_col0" class="data row3 col0" >42.3%</td>
#       <td id="T_c2b35_row3_col1" class="data row3 col1" >2.7%</td>
#       <td id="T_c2b35_row3_col2" class="data row3 col2" >15.0%</td>
#       <td id="T_c2b35_row3_col3" class="data row3 col3" >40.0%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 2.1 Number of accidents by Severity vs.Year
years = data['year'].unique()
n_years = len(years)

fig, axes = plt.subplots(1, n_years, figsize=(18, 6))
fig.suptitle('Severity Distribution per Year', fontsize=16)

custom_colors_mat = ['#66B2FF', '#99FF99', '#FFCC99', '#FF9999']

for i, year in enumerate(years):
    yearly_data = data[data['year'] == year]['gravity'].value_counts()
    colors = custom_colors_mat[:len(yearly_data)]  
    axes[i].pie(yearly_data, labels=yearly_data.index, autopct='%1.1f%%', colors=colors)
    axes[i].set_title(f'Year {year}')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# 3. Number of accidents by Severity vs. Month
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='month', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'month')
# Out:
# <style type="text/css">
# #T_41e66 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_41e66 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_41e66 caption {
#   caption-side: top;
# }
# #T_41e66_row0_col0, #T_41e66_row10_col0, #T_41e66_row11_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_41e66_row0_col1, #T_41e66_row1_col1, #T_41e66_row10_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_41e66_row0_col2, #T_41e66_row11_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_41e66_row0_col3 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_41e66_row1_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_41e66_row1_col2, #T_41e66_row2_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_41e66_row1_col3, #T_41e66_row7_col0 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_41e66_row2_col0, #T_41e66_row9_col0 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_41e66_row2_col1, #T_41e66_row4_col1, #T_41e66_row5_col1, #T_41e66_row8_col1, #T_41e66_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_41e66_row2_col3, #T_41e66_row10_col3, #T_41e66_row11_col3 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_41e66_row3_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_41e66_row3_col1, #T_41e66_row6_col1, #T_41e66_row7_col1, #T_41e66_row11_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_41e66_row3_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_41e66_row3_col3, #T_41e66_row4_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_41e66_row4_col0, #T_41e66_row5_col0 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_41e66_row4_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_41e66_row5_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_41e66_row5_col3, #T_41e66_row8_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_41e66_row6_col0, #T_41e66_row9_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_41e66_row6_col2 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_41e66_row6_col3 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_41e66_row7_col2 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_41e66_row7_col3 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_41e66_row8_col0 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_41e66_row8_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_41e66_row9_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_41e66_row10_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# </style>
# <table id="T_41e66">
#   <caption>Percentages of Accident Gravity by Month</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_41e66_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_41e66_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_41e66_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_41e66_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41e66_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_41e66_row0_col0" class="data row0 col0" >42.4%</td>
#       <td id="T_41e66_row0_col1" class="data row0 col1" >2.6%</td>
#       <td id="T_41e66_row0_col2" class="data row0 col2" >13.7%</td>
#       <td id="T_41e66_row0_col3" class="data row0 col3" >41.4%</td>
#     </tr>
#     <tr>
#       <th id="T_41e66_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_41e66_row1_col0" class="data row1 col0" >42.8%</td>
#       <td id="T_41e66_row1_col1" class="data row1 col1" >2.5%</td>
#       <td id="T_41e66_row1_col2" class="data row1 col2" >14.2%</td>
#       <td id="T_41e66_row1_col3" class="data row1 col3" >40.4%</td>
#     </tr>
#     <tr>
#       <th id="T_41e66_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_41e66_row2_col0" class="data row2 col0" >42.2%</td>
#       <td id="T_41e66_row2_col1" class="data row2 col1" >2.4%</td>
#       <td id="T_41e66_row2_col2" class="data row2 col2" >14.3%</td>
#       <td id="T_41e66_row2_col3" class="data row2 col3" >41.1%</td>
#     </tr>
#     <tr>
#       <th id="T_41e66_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_41e66_row3_col0" class="data row3 col0" >41.9%</td>
#       <td id="T_41e66_row3_col1" class="data row3 col1" >2.7%</td>
#       <td id="T_41e66_row3_col2" class="data row3 col2" >15.3%</td>
#       <td id="T_41e66_row3_col3" class="data row3 col3" >40.1%</td>
#     </tr>
#     <tr>
#       <th id="T_41e66_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_41e66_row4_col0" class="data row4 col0" >41.7%</td>
#       <td id="T_41e66_row4_col1" class="data row4 col1" >2.4%</td>
#       <td id="T_41e66_row4_col2" class="data row4 col2" >15.8%</td>
#       <td id="T_41e66_row4_col3" class="data row4 col3" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_41e66_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_41e66_row5_col0" class="data row5 col0" >41.8%</td>
#       <td id="T_41e66_row5_col1" class="data row5 col1" >2.3%</td>
#       <td id="T_41e66_row5_col2" class="data row5 col2" >15.7%</td>
#       <td id="T_41e66_row5_col3" class="data row5 col3" >40.1%</td>
#     </tr>
#     <tr>
#       <th id="T_41e66_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_41e66_row6_col0" class="data row6 col0" >40.9%</td>
#       <td id="T_41e66_row6_col1" class="data row6 col1" >2.7%</td>
#       <td id="T_41e66_row6_col2" class="data row6 col2" >16.7%</td>
#       <td id="T_41e66_row6_col3" class="data row6 col3" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_41e66_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_41e66_row7_col0" class="data row7 col0" >40.4%</td>
#       <td id="T_41e66_row7_col1" class="data row7 col1" >2.8%</td>
#       <td id="T_41e66_row7_col2" class="data row7 col2" >18.1%</td>
#       <td id="T_41e66_row7_col3" class="data row7 col3" >38.7%</td>
#     </tr>
#     <tr>
#       <th id="T_41e66_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_41e66_row8_col0" class="data row8 col0" >42.2%</td>
#       <td id="T_41e66_row8_col1" class="data row8 col1" >2.4%</td>
#       <td id="T_41e66_row8_col2" class="data row8 col2" >15.2%</td>
#       <td id="T_41e66_row8_col3" class="data row8 col3" >40.2%</td>
#     </tr>
#     <tr>
#       <th id="T_41e66_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_41e66_row9_col0" class="data row9 col0" >42.3%</td>
#       <td id="T_41e66_row9_col1" class="data row9 col1" >2.3%</td>
#       <td id="T_41e66_row9_col2" class="data row9 col2" >14.5%</td>
#       <td id="T_41e66_row9_col3" class="data row9 col3" >40.9%</td>
#     </tr>
#     <tr>
#       <th id="T_41e66_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_41e66_row10_col0" class="data row10 col0" >42.4%</td>
#       <td id="T_41e66_row10_col1" class="data row10 col1" >2.5%</td>
#       <td id="T_41e66_row10_col2" class="data row10 col2" >14.0%</td>
#       <td id="T_41e66_row10_col3" class="data row10 col3" >41.1%</td>
#     </tr>
#     <tr>
#       <th id="T_41e66_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_41e66_row11_col0" class="data row11 col0" >42.5%</td>
#       <td id="T_41e66_row11_col1" class="data row11 col1" >2.8%</td>
#       <td id="T_41e66_row11_col2" class="data row11 col2" >13.6%</td>
#       <td id="T_41e66_row11_col3" class="data row11 col3" >41.2%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 4. Number of accidents by Severity vs. Day
aggregated_data = data.groupby(['day', 'gravity']).size().reset_index(name='count')

plt.figure(figsize=(18, 12))
sns.lineplot(data=aggregated_data, x='day', y='count', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Number of Accidents by Severity vs. Day')
plt.xlabel('Day')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'day')
# Out:
# <style type="text/css">
# #T_2a135 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_2a135 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_2a135 caption {
#   caption-side: top;
# }
# #T_2a135_row0_col0, #T_2a135_row4_col0, #T_2a135_row10_col0, #T_2a135_row11_col0, #T_2a135_row14_col0, #T_2a135_row20_col0, #T_2a135_row22_col0, #T_2a135_row24_col0, #T_2a135_row29_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_2a135_row0_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_2a135_row0_col2, #T_2a135_row9_col2, #T_2a135_row24_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_2a135_row0_col3, #T_2a135_row1_col3, #T_2a135_row4_col3, #T_2a135_row8_col3, #T_2a135_row11_col3, #T_2a135_row29_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_2a135_row1_col0, #T_2a135_row3_col0, #T_2a135_row6_col0, #T_2a135_row18_col0, #T_2a135_row23_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_2a135_row1_col1, #T_2a135_row2_col1, #T_2a135_row3_col1, #T_2a135_row4_col1, #T_2a135_row8_col1, #T_2a135_row9_col1, #T_2a135_row23_col1, #T_2a135_row28_col1, #T_2a135_row29_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2a135_row1_col2, #T_2a135_row2_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_2a135_row2_col0, #T_2a135_row5_col0, #T_2a135_row27_col0 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_2a135_row2_col3, #T_2a135_row16_col0, #T_2a135_row26_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_2a135_row3_col2, #T_2a135_row17_col2, #T_2a135_row18_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_2a135_row3_col3, #T_2a135_row7_col3, #T_2a135_row12_col3, #T_2a135_row17_col3, #T_2a135_row21_col3, #T_2a135_row28_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_2a135_row4_col2, #T_2a135_row26_col2, #T_2a135_row27_col2 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_2a135_row5_col1, #T_2a135_row7_col1, #T_2a135_row10_col1, #T_2a135_row11_col1, #T_2a135_row12_col1, #T_2a135_row14_col1, #T_2a135_row20_col1, #T_2a135_row21_col1, #T_2a135_row22_col1, #T_2a135_row24_col1, #T_2a135_row27_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_2a135_row5_col2, #T_2a135_row8_col2, #T_2a135_row11_col2, #T_2a135_row28_col2 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_2a135_row5_col3, #T_2a135_row25_col0 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_2a135_row6_col1, #T_2a135_row13_col1, #T_2a135_row15_col1, #T_2a135_row16_col1, #T_2a135_row17_col1, #T_2a135_row19_col1, #T_2a135_row25_col1, #T_2a135_row26_col1, #T_2a135_row30_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_2a135_row6_col2, #T_2a135_row15_col2, #T_2a135_row16_col2 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_2a135_row6_col3, #T_2a135_row22_col3, #T_2a135_row30_col3 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_2a135_row7_col0, #T_2a135_row17_col0 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_2a135_row7_col2, #T_2a135_row10_col2, #T_2a135_row14_col2, #T_2a135_row20_col2, #T_2a135_row21_col2, #T_2a135_row23_col2, #T_2a135_row29_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_2a135_row8_col0, #T_2a135_row12_col0, #T_2a135_row19_col0 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_2a135_row9_col0, #T_2a135_row15_col0, #T_2a135_row21_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_2a135_row9_col3, #T_2a135_row10_col3, #T_2a135_row26_col3 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_2a135_row12_col2, #T_2a135_row13_col2, #T_2a135_row19_col2, #T_2a135_row22_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_2a135_row13_col0, #T_2a135_row16_col3, #T_2a135_row30_col0 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_2a135_row13_col3, #T_2a135_row14_col3, #T_2a135_row15_col3, #T_2a135_row20_col3, #T_2a135_row25_col3, #T_2a135_row27_col3 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_2a135_row18_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_2a135_row18_col3 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_2a135_row19_col3 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_2a135_row23_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_2a135_row24_col3 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_2a135_row25_col2, #T_2a135_row30_col2 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_2a135_row28_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2a135">
#   <caption>Percentages of Accident Gravity by Day</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_2a135_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_2a135_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_2a135_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_2a135_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >day</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a135_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2a135_row0_col0" class="data row0 col0" >41.8%</td>
#       <td id="T_2a135_row0_col1" class="data row0 col1" >2.7%</td>
#       <td id="T_2a135_row0_col2" class="data row0 col2" >14.8%</td>
#       <td id="T_2a135_row0_col3" class="data row0 col3" >40.6%</td>
#     </tr>
#     <tr>
#       <th id="T_2a135_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2a135_row1_col0" class="data row1 col0" >42.4%</td>
#       <td id="T_2a135_row1_col1" class="data row1 col1" >2.3%</td>
#       <td id="T_2a135_row1_col2" class="data row1 col2" >14.6%</td>
#       <td id="T_2a135_row1_col3" class="data row1 col3" >40.7%</td>
#     </tr>
#     <tr>
#       <th id="T_2a135_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_2a135_row2_col0" class="data row2 col0" >41.6%</td>
#       <td id="T_2a135_row2_col1" class="data row2 col1" >2.4%</td>
#       <td id="T_2a135_row2_col2" class="data row2 col2" >14.5%</td>
#       <td id="T_2a135_row2_col3" class="data row2 col3" >41.5%</td>
#     </tr>
#     <tr>
#       <th id="T_2a135_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_2a135_row3_col0" class="data row3 col0" >42.5%</td>
#       <td id="T_2a135_row3_col1" class="data row3 col1" >2.4%</td>
#       <td id="T_2a135_row3_col2" class="data row3 col2" >15.1%</td>
#       <td id="T_2a135_row3_col3" class="data row3 col3" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_2a135_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_2a135_row4_col0" class="data row4 col0" >41.7%</td>
#       <td id="T_2a135_row4_col1" class="data row4 col1" >2.3%</td>
#       <td id="T_2a135_row4_col2" class="data row4 col2" >15.4%</td>
#       <td id="T_2a135_row4_col3" class="data row4 col3" >40.7%</td>
#     </tr>
#     <tr>
#       <th id="T_2a135_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_2a135_row5_col0" class="data row5 col0" >41.6%</td>
#       <td id="T_2a135_row5_col1" class="data row5 col1" >2.5%</td>
#       <td id="T_2a135_row5_col2" class="data row5 col2" >14.9%</td>
#       <td id="T_2a135_row5_col3" class="data row5 col3" >41.0%</td>
#     </tr>
#     <tr>
#       <th id="T_2a135_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_2a135_row6_col0" class="data row6 col0" >42.5%</td>
#       <td id="T_2a135_row6_col1" class="data row6 col1" >2.6%</td>
#       <td id="T_2a135_row6_col2" class="data row6 col2" >14.7%</td>
#       <td id="T_2a135_row6_col3" class="data row6 col3" >40.2%</td>
#     </tr>
#     <tr>
#       <th id="T_2a135_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_2a135_row7_col0" class="data row7 col0" >42.1%</td>
#       <td id="T_2a135_row7_col1" class="data row7 col1" >2.4%</td>
#       <td id="T_2a135_row7_col2" class

# %%
# 5. Number of accidents by Severity vs. Weather Conditions
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='atm_condition', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Weather Conditions')
plt.xlabel('Weather Condition')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'atm_condition')
# Out:
# <style type="text/css">
# #T_dc1a7 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_dc1a7 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_dc1a7 caption {
#   caption-side: top;
# }
# #T_dc1a7_row0_col0 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_dc1a7_row0_col1, #T_dc1a7_row2_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_dc1a7_row0_col2 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_dc1a7_row0_col3 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_dc1a7_row1_col0 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_dc1a7_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_dc1a7_row1_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_dc1a7_row1_col3 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_dc1a7_row2_col0 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_dc1a7_row2_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_dc1a7_row2_col3, #T_dc1a7_row7_col0 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_dc1a7_row3_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_dc1a7_row3_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_dc1a7_row3_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_dc1a7_row3_col3 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_dc1a7_row4_col0 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_dc1a7_row4_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_dc1a7_row4_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_dc1a7_row4_col3 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_dc1a7_row5_col0 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_dc1a7_row5_col1, #T_dc1a7_row8_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_dc1a7_row5_col2 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_dc1a7_row5_col3 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_dc1a7_row6_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_dc1a7_row6_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_dc1a7_row6_col2 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_dc1a7_row6_col3 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_dc1a7_row7_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_dc1a7_row7_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_dc1a7_row7_col3 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_dc1a7_row8_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_dc1a7_row8_col2 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_dc1a7_row8_col3 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dc1a7">
#   <caption>Percentages of Accident Gravity by Atm_condition</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_dc1a7_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_dc1a7_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_dc1a7_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_dc1a7_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >atm_condition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc1a7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_dc1a7_row0_col0" class="data row0 col0" >42.2%</td>
#       <td id="T_dc1a7_row0_col1" class="data row0 col1" >2.4%</td>
#       <td id="T_dc1a7_row0_col2" class="data row0 col2" >15.2%</td>
#       <td id="T_dc1a7_row0_col3" class="data row0 col3" >40.2%</td>
#     </tr>
#     <tr>
#       <th id="T_dc1a7_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_dc1a7_row1_col0" class="data row1 col0" >41.2%</td>
#       <td id="T_dc1a7_row1_col1" class="data row1 col1" >2.3%</td>
#       <td id="T_dc1a7_row1_col2" class="data row1 col2" >12.7%</td>
#       <td id="T_dc1a7_row1_col3" class="data row1 col3" >43.9%</td>
#     </tr>
#     <tr>
#       <th id="T_dc1a7_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_dc1a7_row2_col0" class="data row2 col0" >41.0%</td>
#       <td id="T_dc1a7_row2_col1" class="data row2 col1" >2.5%</td>
#       <td id="T_dc1a7_row2_col2" class="data row2 col2" >15.6%</td>
#       <td id="T_dc1a7_row2_col3" class="data row2 col3" >40.8%</td>
#     </tr>
#     <tr>
#       <th id="T_dc1a7_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_dc1a7_row3_col0" class="data row3 col0" >43.6%</td>
#       <td id="T_dc1a7_row3_col1" class="data row3 col1" >2.9%</td>
#       <td id="T_dc1a7_row3_col2" class="data row3 col2" >16.2%</td>
#       <td id="T_dc1a7_row3_col3" class="data row3 col3" >37.3%</td>
#     </tr>
#     <tr>
#       <th id="T_dc1a7_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_dc1a7_row4_col0" class="data row4 col0" >33.4%</td>
#       <td id="T_dc1a7_row4_col1" class="data row4 col1" >5.9%</td>
#       <td id="T_dc1a7_row4_col2" class="data row4 col2" >23.4%</td>
#       <td id="T_dc1a7_row4_col3" class="data row4 col3" >37.3%</td>
#     </tr>
#     <tr>
#       <th id="T_dc1a7_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_dc1a7_row5_col0" class="data row5 col0" >32.6%</td>
#       <td id="T_dc1a7_row5_col1" class="data row5 col1" >5.5%</td>
#       <td id="T_dc1a7_row5_col2" class="data row5 col2" >26.9%</td>
#       <td id="T_dc1a7_row5_col3" class="data row5 col3" >35.1%</td>
#     </tr>
#     <tr>
#       <th id="T_dc1a7_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_dc1a7_row6_col0" class="data row6 col0" >44.5%</td>
#       <td id="T_dc1a7_row6_col1" class="data row6 col1" >3.5%</td>
#       <td id="T_dc1a7_row6_col2" class="data row6 col2" >22.5%</td>
#       <td id="T_dc1a7_row6_col3" class="data row6 col3" >29.5%</td>
#     </tr>
#     <tr>
#       <th id="T_dc1a7_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_dc1a7_row7_col0" class="data row7 col0" >40.8%</td>
#       <td id="T_dc1a7_row7_col1" class="data row7 col1" >3.2%</td>
#       <td id="T_dc1a7_row7_col2" class="data row7 col2" >14.5%</td>
#       <td id="T_dc1a7_row7_col3" class="data row7 col3" >41.5%</td>
#     </tr>
#     <tr>
#       <th id="T_dc1a7_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_dc1a7_row8_col0" class="data row8 col0" >34.0%</td>
#       <td id="T_dc1a7_row8_col1" class="data row8 col1" >5.5%</td>
#       <td id="T_dc1a7_row8_col2" class="data row8 col2" >20.2%</td>
#       <td id="T_dc1a7_row8_col3" class="data row8 col3" >40.4%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 6. Number of accidents by Severity vs. Lighting Conditions
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='lum', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Lighting Conditions')
plt.xlabel('Lighting Condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'lum')
# Out:
# <style type="text/css">
# #T_6e3fc th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_6e3fc td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_6e3fc caption {
#   caption-side: top;
# }
# #T_6e3fc_row0_col0 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_6e3fc_row0_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_6e3fc_row0_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_6e3fc_row0_col3 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_6e3fc_row1_col0 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_6e3fc_row1_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_6e3fc_row1_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_6e3fc_row1_col3 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_6e3fc_row2_col0 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_6e3fc_row2_col1 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_6e3fc_row2_col2 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_6e3fc_row2_col3 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_6e3fc_row3_col0 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_6e3fc_row3_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_6e3fc_row3_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_6e3fc_row3_col3 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_6e3fc_row4_col0 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_6e3fc_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6e3fc_row4_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_6e3fc_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6e3fc">
#   <caption>Percentages of Accident Gravity by Lum</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_6e3fc_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_6e3fc_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_6e3fc_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_6e3fc_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >lum</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e3fc_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_6e3fc_row0_col0" class="data row0 col0" >43.4%</td>
#       <td id="T_6e3fc_row0_col1" class="data row0 col1" >2.2%</td>
#       <td id="T_6e3fc_row0_col2" class="data row0 col2" >14.7%</td>
#       <td id="T_6e3fc_row0_col3" class="data row0 col3" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_6e3fc_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_6e3fc_row1_col0" class="data row1 col0" >40.5%</td>
#       <td id="T_6e3fc_row1_col1" class="data row1 col1" >2.9%</td>
#       <td id="T_6e3fc_row1_col2" class="data row1 col2" >17.1%</td>
#       <td id="T_6e3fc_row1_col3" class="data row1 col3" >39.5%</td>
#     </tr>
#     <tr>
#       <th id="T_6e3fc_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_6e3fc_row2_col0" class="data row2 col0" >32.7%</td>
#       <td id="T_6e3fc_row2_col1" class="data row2 col1" >6.4%</td>
#       <td id="T_6e3fc_row2_col2" class="data row2 col2" >23.0%</td>
#       <td id="T_6e3fc_row2_col3" class="data row2 col3" >37.8%</td>
#     </tr>
#     <tr>
#       <th id="T_6e3fc_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_6e3fc_row3_col0" class="data row3 col0" >37.6%</td>
#       <td id="T_6e3fc_row3_col1" class="data row3 col1" >3.8%</td>
#       <td id="T_6e3fc_row3_col2" class="data row3 col2" >16.0%</td>
#       <td id="T_6e3fc_row3_col3" class="data row3 col3" >42.6%</td>
#     </tr>
#     <tr>
#       <th id="T_6e3fc_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_6e3fc_row4_col0" class="data row4 col0" >41.6%</td>
#       <td id="T_6e3fc_row4_col1" class="data row4 col1" >1.6%</td>
#       <td id="T_6e3fc_row4_col2" class="data row4 col2" >11.8%</td>
#       <td id="T_6e3fc_row4_col3" class="data row4 col3" >44.9%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 7. Number of accidents by Severity vs. Vehicle Category
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='vehicle_category', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Vehicle Category')
plt.xlabel('Vehicle Category')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'vehicle_category')
# Out:
# <style type="text/css">
# #T_cdb6d th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_cdb6d td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_cdb6d caption {
#   caption-side: top;
# }
# #T_cdb6d_row0_col0 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_cdb6d_row0_col1, #T_cdb6d_row14_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_cdb6d_row0_col2, #T_cdb6d_row25_col0 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_cdb6d_row0_col3 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_cdb6d_row1_col0, #T_cdb6d_row2_col0, #T_cdb6d_row5_col2, #T_cdb6d_row14_col0, #T_cdb6d_row19_col1, #T_cdb6d_row23_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_cdb6d_row1_col1, #T_cdb6d_row7_col1, #T_cdb6d_row10_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_cdb6d_row1_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_cdb6d_row1_col3 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_cdb6d_row2_col1, #T_cdb6d_row4_col1, #T_cdb6d_row9_col1, #T_cdb6d_row17_col1, #T_cdb6d_row23_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_cdb6d_row2_col2 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_cdb6d_row2_col3 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_cdb6d_row3_col0 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_cdb6d_row3_col1, #T_cdb6d_row11_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_cdb6d_row3_col2, #T_cdb6d_row19_col0 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_cdb6d_row3_col3 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_cdb6d_row4_col0 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_cdb6d_row4_col2 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_cdb6d_row4_col3 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_cdb6d_row5_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_cdb6d_row5_col1, #T_cdb6d_row6_col1, #T_cdb6d_row15_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_cdb6d_row5_col3 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_cdb6d_row6_col0 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_cdb6d_row6_col2, #T_cdb6d_row28_col0 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_cdb6d_row6_col3 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_cdb6d_row7_col0 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_cdb6d_row7_col2, #T_cdb6d_row10_col2, #T_cdb6d_row16_col0 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_cdb6d_row7_col3, #T_cdb6d_row30_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_cdb6d_row8_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_cdb6d_row8_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_cdb6d_row8_col2 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_cdb6d_row8_col3, #T_cdb6d_row15_col0, #T_cdb6d_row27_col0 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_cdb6d_row9_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_cdb6d_row9_col2, #T_cdb6d_row12_col3 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_cdb6d_row9_col3 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_cdb6d_row10_col0, #T_cdb6d_row28_col3 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_cdb6d_row10_col3 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_cdb6d_row11_col0 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_cdb6d_row11_col2, #T_cdb6d_row18_col0 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_cdb6d_row11_col3 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_cdb6d_row12_col0 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_cdb6d_row12_col1, #T_cdb6d_row20_col2, #T_cdb6d_row29_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_cdb6d_row12_col2, #T_cdb6d_row17_col0, #T_cdb6d_row22_col3 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_cdb6d_row13_col0, #T_cdb6d_row27_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_cdb6d_row13_col1, #T_cdb6d_row20_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_cdb6d_row13_col2, #T_cdb6d_row25_col2, #T_cdb6d_row26_col0, #T_cdb6d_row26_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_cdb6d_row13_col3, #T_cdb6d_row25_col3 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_cdb6d_row14_col2, #T_cdb6d_row23_col3, #T_cdb6d_row24_col2 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_cdb6d_row14_col3 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_cdb6d_row15_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_cdb6d_row15_col3 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_cdb6d_row16_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_cdb6d_row16_col2 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_cdb6d_row16_col3 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_cdb6d_row17_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_cdb6d_row17_col3 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_cdb6d_row18_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_cdb6d_row18_col2 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_cdb6d_row18_col3 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_cdb6d_row19_col2 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_cdb6d_row19_col3 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_cdb6d_row20_col0 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_cdb6d_row20_col3 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_cdb6d_row21_col0 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_cdb6d_row21_col1, #T_cdb6d_row27_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_cdb6d_row21_col2, #T_cdb6d_row22_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_cdb6d_row21_col3 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_cdb6d_row22_col0 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_cdb6d_row22_col1 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_cdb6d_row23_col0 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_cdb6d_row24_col0 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_cdb6d_row24_col1, #T_cdb6d_row25_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_cdb6d_row24_col3 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_cdb6d_row26_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_cdb6d_row26_col3 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_cdb6d_row27_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_cdb6d_row28_col1, #T_cdb6d_row30_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_cdb6d_row28_col2 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_cdb6d_row29_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_cdb6d_row29_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_cdb6d_row29_col3 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_cdb6d_row30_col0 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_cdb6d_row30_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cdb6d">
#   <caption>Percentages of Accident Gravity by Vehicle_category</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_cdb6d_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_cdb6d_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_cdb6d_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_cdb6d_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >vehicle_category</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdb6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cdb6d_row0_col0" class="data row0 col0" >44.0%</td>
#       <td id="T_cdb6d_row0_col1" class="data row0 col1" >3.2%</td>
#       <td id="T_cdb6d_row0_col2" class="data row0 col2" >14.7%</td>
#       <td id="T_cdb6d_row0_col3" class="data row0

# %%
# 7.1 Number of accidents by Severity vs.Year
genders = data['gender'].unique()
n_genders = len(genders)

fig, axes = plt.subplots(1, n_genders, figsize=(18, 6))
fig.suptitle('Severity Distribution per gender', fontsize=16)

custom_colors_mat = ['#66B2FF', '#99FF99', '#FFCC99', '#FF9999']

for i, gender in enumerate(genders):
    genderly_data = data[data['gender'] == gender]['gravity'].value_counts()
    colors = custom_colors_mat[:len(genderly_data)]  
    axes[i].pie(genderly_data, labels=genderly_data.index, autopct='%1.1f%%', colors=colors)
    axes[i].set_title(f'gender {gender}')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# 8. Number of accidents by Severity vs. Gender
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='gender', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.show()

calculate_and_display_percentages(data, 'gender')
# Out:
# <style type="text/css">
# #T_0a2c5 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_0a2c5 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_0a2c5 caption {
#   caption-side: top;
# }
# #T_0a2c5_row0_col0 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_0a2c5_row0_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_0a2c5_row0_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_0a2c5_row0_col3 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_0a2c5_row1_col0 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_0a2c5_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0a2c5_row1_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_0a2c5_row1_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0a2c5">
#   <caption>Percentages of Accident Gravity by Gender</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_0a2c5_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_0a2c5_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_0a2c5_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_0a2c5_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a2c5_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_0a2c5_row0_col0" class="data row0 col0" >43.9%</td>
#       <td id="T_0a2c5_row0_col1" class="data row0 col1" >2.9%</td>
#       <td id="T_0a2c5_row0_col2" class="data row0 col2" >15.7%</td>
#       <td id="T_0a2c5_row0_col3" class="data row0 col3" >37.4%</td>
#     </tr>
#     <tr>
#       <th id="T_0a2c5_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_0a2c5_row1_col0" class="data row1 col0" >37.6%</td>
#       <td id="T_0a2c5_row1_col1" class="data row1 col1" >1.7%</td>
#       <td id="T_0a2c5_row1_col2" class="data row1 col2" >13.9%</td>
#       <td id="T_0a2c5_row1_col3" class="data row1 col3" >46.8%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 9. Number of accidents by Severity vs. Surface Condition
plt.figure(figsize=(18,12))
sns.countplot(data=data, x='surface_condition', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Surface Condition')
plt.xlabel('Surface Condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'surface_condition')
# Out:
# <style type="text/css">
# #T_21427 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_21427 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_21427 caption {
#   caption-side: top;
# }
# #T_21427_row0_col0 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_21427_row0_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_21427_row0_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_21427_row0_col3, #T_21427_row2_col3, #T_21427_row6_col3 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_21427_row1_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_21427_row1_col1, #T_21427_row4_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_21427_row1_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_21427_row1_col3 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_21427_row2_col0, #T_21427_row3_col0 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_21427_row2_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_21427_row2_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_21427_row3_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_21427_row3_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_21427_row3_col3 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_21427_row4_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_21427_row4_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_21427_row4_col3 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_21427_row5_col0 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_21427_row5_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_21427_row5_col2 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_21427_row5_col3 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_21427_row6_col0 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_21427_row6_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_21427_row6_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_21427_row7_col0 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_21427_row7_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_21427_row7_col2 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_21427_row7_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_21427_row8_col0 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_21427_row8_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_21427_row8_col2 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_21427_row8_col3 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_21427">
#   <caption>Percentages of Accident Gravity by Surface_condition</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_21427_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_21427_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_21427_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_21427_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >surface_condition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21427_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_21427_row0_col0" class="data row0 col0" >42.4%</td>
#       <td id="T_21427_row0_col1" class="data row0 col1" >2.5%</td>
#       <td id="T_21427_row0_col2" class="data row0 col2" >15.3%</td>
#       <td id="T_21427_row0_col3" class="data row0 col3" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_21427_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_21427_row1_col0" class="data row1 col0" >40.6%</td>
#       <td id="T_21427_row1_col1" class="data row1 col1" >2.7%</td>
#       <td id="T_21427_row1_col2" class="data row1 col2" >13.8%</td>
#       <td id="T_21427_row1_col3" class="data row1 col3" >43.0%</td>
#     </tr>
#     <tr>
#       <th id="T_21427_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_21427_row2_col0" class="data row2 col0" >37.8%</td>
#       <td id="T_21427_row2_col1" class="data row2 col1" >3.1%</td>
#       <td id="T_21427_row2_col2" class="data row2 col2" >19.1%</td>
#       <td id="T_21427_row2_col3" class="data row2 col3" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_21427_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_21427_row3_col0" class="data row3 col0" >37.9%</td>
#       <td id="T_21427_row3_col1" class="data row3 col1" >2.4%</td>
#       <td id="T_21427_row3_col2" class="data row3 col2" >17.8%</td>
#       <td id="T_21427_row3_col3" class="data row3 col3" >42.0%</td>
#     </tr>
#     <tr>
#       <th id="T_21427_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_21427_row4_col0" class="data row4 col0" >44.2%</td>
#       <td id="T_21427_row4_col1" class="data row4 col1" >2.7%</td>
#       <td id="T_21427_row4_col2" class="data row4 col2" >16.4%</td>
#       <td id="T_21427_row4_col3" class="data row4 col3" >36.6%</td>
#     </tr>
#     <tr>
#       <th id="T_21427_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_21427_row5_col0" class="data row5 col0" >24.1%</td>
#       <td id="T_21427_row5_col1" class="data row5 col1" >8.9%</td>
#       <td id="T_21427_row5_col2" class="data row5 col2" >36.6%</td>
#       <td id="T_21427_row5_col3" class="data row5 col3" >30.4%</td>
#     </tr>
#     <tr>
#       <th id="T_21427_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_21427_row6_col0" class="data row6 col0" >30.7%</td>
#       <td id="T_21427_row6_col1" class="data row6 col1" >5.1%</td>
#       <td id="T_21427_row6_col2" class="data row6 col2" >24.4%</td>
#       <td id="T_21427_row6_col3" class="data row6 col3" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_21427_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_21427_row7_col0" class="data row7 col0" >25.2%</td>
#       <td id="T_21427_row7_col1" class="data row7 col1" >1.7%</td>
#       <td id="T_21427_row7_col2" class="data row7 col2" >22.9%</td>
#       <td id="T_21427_row7_col3" class="data row7 col3" >50.3%</td>
#     </tr>
#     <tr>
#       <th id="T_21427_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_21427_row8_col0" class="data row8 col0" >28.1%</td>
#       <td id="T_21427_row8_col1" class="data row8 col1" >5.2%</td>
#       <td id="T_21427_row8_col2" class="data row8 col2" >29.9%</td>
#       <td id="T_21427_row8_col3" class="data row8 col3" >36.9%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 10. Number of accidents by Severity vs. Maximum Speed
# Define the bins and corresponding labels
bins = [0, 49, 59, 69, 79, 89, 99, 109, float('inf')]
labels = ['0-49', '50-59', '60-69', '70-79', '80-89', '90-99', '100-109', '110-119']

# Create a new column for the binned speeds
data['speed_group'] = pd.cut(data['maximum_speed'], bins=bins, labels=labels, right=False)

plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='speed_group', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Maximum Speed')
plt.xlabel('Maximum Speed Group')
plt.ylabel('Gravity')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'maximum_speed')
# Out:
# <style type="text/css">
# #T_4cbef th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_4cbef td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_4cbef caption {
#   caption-side: top;
# }
# #T_4cbef_row0_col0, #T_4cbef_row15_col0 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_4cbef_row0_col1, #T_4cbef_row15_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_4cbef_row0_col2, #T_4cbef_row1_col2, #T_4cbef_row15_col2 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_4cbef_row0_col3, #T_4cbef_row8_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_4cbef_row1_col0, #T_4cbef_row5_col3 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_4cbef_row1_col1, #T_4cbef_row2_col1, #T_4cbef_row3_col0, #T_4cbef_row3_col1, #T_4cbef_row3_col2, #T_4cbef_row4_col1, #T_4cbef_row4_col2, #T_4cbef_row6_col1, #T_4cbef_row6_col2, #T_4cbef_row11_col1, #T_4cbef_row13_col1, #T_4cbef_row13_col2, #T_4cbef_row16_col1, #T_4cbef_row18_col1, #T_4cbef_row18_col3, #T_4cbef_row20_col1, #T_4cbef_row20_col3, #T_4cbef_row25_col1, #T_4cbef_row25_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_4cbef_row1_col3 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_4cbef_row2_col0, #T_4cbef_row25_col0, #T_4cbef_row25_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_4cbef_row2_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_4cbef_row2_col3, #T_4cbef_row4_col3, #T_4cbef_row16_col0, #T_4cbef_row16_col2, #T_4cbef_row16_col3, #T_4cbef_row20_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_4cbef_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4cbef_row4_col0, #T_4cbef_row20_col2 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_4cbef_row5_col0 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_4cbef_row5_col1, #T_4cbef_row8_col1, #T_4cbef_row22_col1, #T_4cbef_row24_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_4cbef_row5_col2 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_4cbef_row6_col0, #T_4cbef_row18_col2 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_4cbef_row6_col3, #T_4cbef_row17_col0, #T_4cbef_row18_col0, #T_4cbef_row19_col3 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_4cbef_row7_col0 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_4cbef_row7_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_4cbef_row7_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_4cbef_row7_col3, #T_4cbef_row8_col3 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_4cbef_row8_col2 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_4cbef_row9_col0, #T_4cbef_row12_col3 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_4cbef_row9_col1, #T_4cbef_row17_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_4cbef_row9_col2, #T_4cbef_row21_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_4cbef_row9_col3 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_4cbef_row10_col0 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_4cbef_row10_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_4cbef_row10_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_4cbef_row10_col3, #T_4cbef_row24_col0 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_4cbef_row11_col0, #T_4cbef_row13_col3 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_4cbef_row11_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_4cbef_row11_col3 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_4cbef_row12_col0, #T_4cbef_row19_col0 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_4cbef_row12_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_4cbef_row12_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_4cbef_row13_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_4cbef_row14_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_4cbef_row14_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_4cbef_row14_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_4cbef_row14_col3 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_4cbef_row15_col3 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_4cbef_row17_col2, #T_4cbef_row24_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_4cbef_row17_col3 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_4cbef_row19_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_4cbef_row19_col2 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_4cbef_row21_col0 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_4cbef_row21_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_4cbef_row21_col3 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_4cbef_row22_col0, #T_4cbef_row22_col3, #T_4cbef_row24_col3 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_4cbef_row22_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_4cbef_row23_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_4cbef_row23_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_4cbef_row23_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_4cbef_row23_col3 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# </style>
# <table id="T_4cbef">
#   <caption>Percentages of Accident Gravity by Maximum_speed</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_4cbef_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_4cbef_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_4cbef_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_4cbef_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >maximum_speed</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4cbef_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_4cbef_row0_col0" class="data row0 col0" >44.1%</td>
#       <td id="T_4cbef_row0_col1" class="data row0 col1" >1.5%</td>
#       <td id="T_4cbef_row0_col2" class="data row0 col2" >12.3%</td>
#       <td id="T_4cbef_row0_col3" class="data row0 col3" >42.2%</td>
#     </tr>
#     <tr>
#       <th id="T_4cbef_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_4cbef_row1_col0" class="data row1 col0" >38.8%</td>
#       <td id="T_4cbef_row1_col1" class="data row1 col1" >0.0%</td>
#       <td id="T_4cbef_row1_col2" class="data row1 col2" >12.2%</td>
#       <td id="T_4cbef_row1_col3" class="data row1 col3" >49.0%</td>
#     </tr>
#     <tr>
#       <th id="T_4cbef_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_4cbef_row2_col0" class="data row2 col0" >50.0%</td>
#       <td id="T_4cbef_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_4cbef_row2_col2" class="data row2 col2" >16.7%</td>
#       <td id="T_4cbef_row2_col3" class="data row2 col3" >33.3%</td>
#     </tr>
#     <tr>
#       <th id="T_4cbef_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_4cbef_row3_col0" class="data row3 col0" >0.0%</td>
#       <td id="T_4cbef_row3_col1" class="data row3 col1" >0.0%</td>
#       <td id="T_4cbef_row3_col2" class="data row3 col2" >0.0%</td>
#       <td id="T_4cbef_row3_col3" class="data row3 col3" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_4cbef_level0_row4" class="row_heading level0 row4" >9</th>
#       <td id="T_4cbef_row4_col0" class="data row4 col0" >66.7%</td>
#       <td id="T_4cbef_row4_col1" class="data row4 col1" >0.0%</td>
#       <td id="T_4cbef_row4_col2" class="data row4 col2" >0.0%</td>
#       <td id="T_4cbef_row4_col3" class="data row4 col3" >33.3%</td>
#     </tr>
#     <tr>
#       <th id="T_4cbef_level0_row5" class="row_heading level0 row5" >10</th>
#       <td id="T_4cbef_row5_col0" class="data row5 col0" >44.9%</td>
#       <td id="T_4cbef_row5_col1" class="data row5 col1" >2.6%</td>
#       <td id="T_4cbef_row5_col2" class="data row5 col2" >13.5%</td>

# %%
# 11. Number of accidents by Severity vs. Maximum Speed
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='gravity', y='maximum_speed', hue_order=gravity_order, palette=custom_colors)
plt.title('Maximum Speed Distribution by Accident Gravity Category')
plt.show()

calculate_and_display_percentages(data, 'maximum_speed')
# Out:
# <style type="text/css">
# #T_3c0ed th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_3c0ed td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_3c0ed caption {
#   caption-side: top;
# }
# #T_3c0ed_row0_col0, #T_3c0ed_row15_col0 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_3c0ed_row0_col1, #T_3c0ed_row15_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_3c0ed_row0_col2, #T_3c0ed_row1_col2, #T_3c0ed_row15_col2 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_3c0ed_row0_col3, #T_3c0ed_row8_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_3c0ed_row1_col0, #T_3c0ed_row5_col3 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_3c0ed_row1_col1, #T_3c0ed_row2_col1, #T_3c0ed_row3_col0, #T_3c0ed_row3_col1, #T_3c0ed_row3_col2, #T_3c0ed_row4_col1, #T_3c0ed_row4_col2, #T_3c0ed_row6_col1, #T_3c0ed_row6_col2, #T_3c0ed_row11_col1, #T_3c0ed_row13_col1, #T_3c0ed_row13_col2, #T_3c0ed_row16_col1, #T_3c0ed_row18_col1, #T_3c0ed_row18_col3, #T_3c0ed_row20_col1, #T_3c0ed_row20_col3, #T_3c0ed_row25_col1, #T_3c0ed_row25_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3c0ed_row1_col3 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_3c0ed_row2_col0, #T_3c0ed_row25_col0, #T_3c0ed_row25_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_3c0ed_row2_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_3c0ed_row2_col3, #T_3c0ed_row4_col3, #T_3c0ed_row16_col0, #T_3c0ed_row16_col2, #T_3c0ed_row16_col3, #T_3c0ed_row20_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_3c0ed_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3c0ed_row4_col0, #T_3c0ed_row20_col2 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_3c0ed_row5_col0 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_3c0ed_row5_col1, #T_3c0ed_row8_col1, #T_3c0ed_row22_col1, #T_3c0ed_row24_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_3c0ed_row5_col2 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_3c0ed_row6_col0, #T_3c0ed_row18_col2 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_3c0ed_row6_col3, #T_3c0ed_row17_col0, #T_3c0ed_row18_col0, #T_3c0ed_row19_col3 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_3c0ed_row7_col0 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_3c0ed_row7_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_3c0ed_row7_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_3c0ed_row7_col3, #T_3c0ed_row8_col3 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_3c0ed_row8_col2 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_3c0ed_row9_col0, #T_3c0ed_row12_col3 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_3c0ed_row9_col1, #T_3c0ed_row17_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_3c0ed_row9_col2, #T_3c0ed_row21_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_3c0ed_row9_col3 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_3c0ed_row10_col0 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_3c0ed_row10_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_3c0ed_row10_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_3c0ed_row10_col3, #T_3c0ed_row24_col0 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_3c0ed_row11_col0, #T_3c0ed_row13_col3 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_3c0ed_row11_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_3c0ed_row11_col3 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_3c0ed_row12_col0, #T_3c0ed_row19_col0 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_3c0ed_row12_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_3c0ed_row12_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_3c0ed_row13_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_3c0ed_row14_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_3c0ed_row14_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_3c0ed_row14_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_3c0ed_row14_col3 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_3c0ed_row15_col3 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_3c0ed_row17_col2, #T_3c0ed_row24_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_3c0ed_row17_col3 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_3c0ed_row19_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_3c0ed_row19_col2 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_3c0ed_row21_col0 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_3c0ed_row21_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_3c0ed_row21_col3 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_3c0ed_row22_col0, #T_3c0ed_row22_col3, #T_3c0ed_row24_col3 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_3c0ed_row22_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_3c0ed_row23_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_3c0ed_row23_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_3c0ed_row23_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_3c0ed_row23_col3 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# </style>
# <table id="T_3c0ed">
#   <caption>Percentages of Accident Gravity by Maximum_speed</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_3c0ed_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_3c0ed_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_3c0ed_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_3c0ed_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >maximum_speed</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c0ed_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_3c0ed_row0_col0" class="data row0 col0" >44.1%</td>
#       <td id="T_3c0ed_row0_col1" class="data row0 col1" >1.5%</td>
#       <td id="T_3c0ed_row0_col2" class="data row0 col2" >12.3%</td>
#       <td id="T_3c0ed_row0_col3" class="data row0 col3" >42.2%</td>
#     </tr>
#     <tr>
#       <th id="T_3c0ed_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_3c0ed_row1_col0" class="data row1 col0" >38.8%</td>
#       <td id="T_3c0ed_row1_col1" class="data row1 col1" >0.0%</td>
#       <td id="T_3c0ed_row1_col2" class="data row1 col2" >12.2%</td>
#       <td id="T_3c0ed_row1_col3" class="data row1 col3" >49.0%</td>
#     </tr>
#     <tr>
#       <th id="T_3c0ed_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_3c0ed_row2_col0" class="data row2 col0" >50.0%</td>
#       <td id="T_3c0ed_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_3c0ed_row2_col2" class="data row2 col2" >16.7%</td>
#       <td id="T_3c0ed_row2_col3" class="data row2 col3" >33.3%</td>
#     </tr>
#     <tr>
#       <th id="T_3c0ed_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_3c0ed_row3_col0" class="data row3 col0" >0.0%</td>
#       <td id="T_3c0ed_row3_col1" class="data row3 col1" >0.0%</td>
#       <td id="T_3c0ed_row3_col2" class="data row3 col2" >0.0%</td>
#       <td id="T_3c0ed_row3_col3" class="data row3 col3" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_3c0ed_level0_row4" class="row_heading level0 row4" >9</th>
#       <td id="T_3c0ed_row4_col0" class="data row4 col0" >66.7%</td>
#       <td id="T_3c0ed_row4_col1" class="data row4 col1" >0.0%</td>
#       <td id="T_3c0ed_row4_col2" class="data row4 col2" >0.0%</td>
#       <td id="T_3c0ed_row4_col3" class="data row4 col3" >33.3%</td>
#     </tr>
#     <tr>
#       <th id="T_3c0ed_level0_row5" class="row_heading level0 row5" >10</th>
#       <td id="T_3c0ed_row5_col0" class="data row5 col0" >44.9%</td>
#       <td id="T_3c0ed_row5_col1" class="data row5 col1" >2.6%</td>
#       <td id="T_3c0ed_row5_col2" class="data row5 col2" >13.5%</td>

# %%
# 11. Number of accidents by Severity vs. Age
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='gravity', y='age', hue_order=gravity_order, palette=custom_colors)
plt.title('Age Distribution by Accident Gravity Category')
plt.show()

calculate_and_display_percentages(data, 'age')
# Out:
# <style type="text/css">
# #T_83f60 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_83f60 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_83f60 caption {
#   caption-side: top;
# }
# #T_83f60_row0_col0, #T_83f60_row47_col3, #T_83f60_row49_col3, #T_83f60_row80_col0, #T_83f60_row85_col0 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_83f60_row0_col1, #T_83f60_row2_col1, #T_83f60_row15_col1, #T_83f60_row16_col1, #T_83f60_row35_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_83f60_row0_col2, #T_83f60_row86_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_83f60_row0_col3, #T_83f60_row17_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_83f60_row1_col0, #T_83f60_row31_col0, #T_83f60_row65_col0 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_83f60_row1_col1, #T_83f60_row17_col1, #T_83f60_row23_col1, #T_83f60_row27_col1, #T_83f60_row30_col1, #T_83f60_row34_col1, #T_83f60_row37_col1, #T_83f60_row39_col1, #T_83f60_row40_col1, #T_83f60_row41_col1, #T_83f60_row45_col1, #T_83f60_row46_col1, #T_83f60_row48_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_83f60_row1_col2, #T_83f60_row76_col1 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_83f60_row1_col3, #T_83f60_row36_col0, #T_83f60_row56_col0, #T_83f60_row57_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_83f60_row2_col0, #T_83f60_row27_col0, #T_83f60_row64_col0, #T_83f60_row74_col0 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_83f60_row2_col2, #T_83f60_row82_col1 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_83f60_row2_col3, #T_83f60_row35_col0, #T_83f60_row49_col0, #T_83f60_row59_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_83f60_row3_col0, #T_83f60_row57_col3 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_83f60_row3_col1, #T_83f60_row9_col1, #T_83f60_row11_col1, #T_83f60_row13_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_83f60_row3_col2, #T_83f60_row44_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_83f60_row3_col3 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_83f60_row4_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_83f60_row4_col1, #T_83f60_row6_col1, #T_83f60_row10_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_83f60_row4_col2, #T_83f60_row40_col2, #T_83f60_row42_col2, #T_83f60_row43_col2, #T_83f60_row88_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_83f60_row4_col3 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_83f60_row5_col0, #T_83f60_row89_col0, #T_83f60_row91_col3 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_83f60_row5_col1, #T_83f60_row7_col1, #T_83f60_row8_col1, #T_83f60_row12_col1, #T_83f60_row14_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_83f60_row5_col2, #T_83f60_row24_col2, #T_83f60_row46_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_83f60_row5_col3, #T_83f60_row6_col3 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_83f60_row6_col0, #T_83f60_row71_col3, #T_83f60_row79_col3, #T_83f60_row84_col3, #T_83f60_row86_col3 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_83f60_row6_col2, #T_83f60_row50_col2, #T_83f60_row52_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_83f60_row7_col0, #T_83f60_row68_col3, #T_83f60_row83_col3, #T_83f60_row87_col3, #T_83f60_row91_col0 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_83f60_row7_col2, #T_83f60_row9_col2 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_83f60_row7_col3 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_83f60_row8_col0 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_83f60_row8_col2, #T_83f60_row51_col2 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_83f60_row8_col3 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_83f60_row9_col0, #T_83f60_row67_col3, #T_83f60_row76_col3, #T_83f60_row90_col0 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_83f60_row9_col3, #T_83f60_row16_col3 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_83f60_row10_col0 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_83f60_row10_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_83f60_row10_col3 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_83f60_row11_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_83f60_row11_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_83f60_row11_col3 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_83f60_row12_col0, #T_83f60_row13_col0 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_83f60_row12_col2, #T_83f60_row20_col2, #T_83f60_row53_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_83f60_row12_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_83f60_row13_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_83f60_row13_col3 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_83f60_row14_col0, #T_83f60_row64_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_83f60_row14_col2, #T_83f60_row71_col2, #T_83f60_row73_col2, #T_83f60_row76_col2, #T_83f60_row77_col2 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_83f60_row14_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_83f60_row15_col0, #T_83f60_row65_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_83f60_row15_col2, #T_83f60_row17_col2, #T_83f60_row84_col2, #T_83f60_row90_col2 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_83f60_row15_col3 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_83f60_row16_col0 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_83f60_row16_col2, #T_83f60_row87_col2 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_83f60_row17_col0, #T_83f60_row69_col2 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_83f60_row18_col0 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_83f60_row18_col1, #T_83f60_row19_col1, #T_83f60_row21_col1, #T_83f60_row22_col1, #T_83f60_row24_col1, #T_83f60_row25_col1, #T_83f60_row43_col1, #T_83f60_row50_col1, #T_83f60_row51_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_83f60_row18_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_83f60_row18_col3 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_83f60_row19_col0, #T_83f60_row50_col3, #T_83f60_row51_col3 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_83f60_row19_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_83f60_row19_col3, #T_83f60_row60_col0 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_83f60_row20_col0, #T_83f60_row40_col3 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_83f60_row20_col1, #T_83f60_row49_col1, #T_83f60_row52_col1, #T_83f60_row53_col1, #T_83f60_row55_col1, #T_83f60_row56_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_83f60_row20_col3, #T_83f60_row22_col3, #T_83f60_row29_col0, #T_83f60_row29_col3, #T_83f60_row30_col0, #T_83f60_row30_col3 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_83f60_row21_col0 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_83f60_row21_col2, #T_83f60_row91_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_83f60_row21_col3, #T_83f60_row24_col3, #T_83f60_row26_col3, #T_83f60_row27_col3, #T_83f60_row67_col0, #T_83f60_row70_col0 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_83f60_row22_col0 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_83f60_row22_col2, #T_83f60_row23_col2, #T_83f60_row48_col2, #T_83f60_row49_col2 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_83f60_row23_col0 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_83f60_row23_col3, #T_83f60_row32_col3 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_83f60_row24_col0, #T_83f60_row25_col0, #T_83f60_row33_col3, #T_83f60_row72_col0, #T_83f60_row77_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_83f60_row25_col2, #T_83f60_row92_col1 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_83f60_row25_col3, #T_83f60_row28_col0, #T_83f60_row66_col0, #T_83f60_row69_col0 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_83f60_row26_col0, #T_83f60_r

# %%
# 12. Number of accidents by Severity vs. Age
plt.figure(figsize=(10, 6))
sns.kdeplot(data=data, x='age', hue='gravity', fill=True, hue_order=gravity_order, palette=custom_colors)
plt.title('Density of Age Distribution by Accident Gravity Category')
plt.show()

# %%
# 13. Number of accidents by Severity vs. Age
plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='age', y='maximum_speed', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Age vs. Maximum Speed by Accident Gravity')
plt.show()

# %%
# 14. Number of accidents by Severity vs. motor
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='motor', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. motor')
plt.xlabel('motor')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'motor')
# Out:
# <style type="text/css">
# #T_48fc3 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_48fc3 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_48fc3 caption {
#   caption-side: top;
# }
# #T_48fc3_row0_col0 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_48fc3_row0_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_48fc3_row0_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_48fc3_row0_col3 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_48fc3_row1_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_48fc3_row1_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_48fc3_row1_col2 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_48fc3_row1_col3 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_48fc3_row2_col0 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_48fc3_row2_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_48fc3_row2_col2 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_48fc3_row2_col3 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_48fc3_row3_col0 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_48fc3_row3_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_48fc3_row3_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_48fc3_row3_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_48fc3_row4_col0 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_48fc3_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_48fc3_row4_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_48fc3_row4_col3 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_48fc3_row5_col0 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_48fc3_row5_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_48fc3_row5_col2 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_48fc3_row5_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_48fc3_row6_col0 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_48fc3_row6_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_48fc3_row6_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_48fc3_row6_col3 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_48fc3">
#   <caption>Percentages of Accident Gravity by Motor</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_48fc3_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_48fc3_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_48fc3_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_48fc3_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >motor</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48fc3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48fc3_row0_col0" class="data row0 col0" >44.7%</td>
#       <td id="T_48fc3_row0_col1" class="data row0 col1" >1.8%</td>
#       <td id="T_48fc3_row0_col2" class="data row0 col2" >13.8%</td>
#       <td id="T_48fc3_row0_col3" class="data row0 col3" >39.7%</td>
#     </tr>
#     <tr>
#       <th id="T_48fc3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_48fc3_row1_col0" class="data row1 col0" >43.8%</td>
#       <td id="T_48fc3_row1_col1" class="data row1 col1" >2.6%</td>
#       <td id="T_48fc3_row1_col2" class="data row1 col2" >15.1%</td>
#       <td id="T_48fc3_row1_col3" class="data row1 col3" >38.6%</td>
#     </tr>
#     <tr>
#       <th id="T_48fc3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_48fc3_row2_col0" class="data row2 col0" >60.5%</td>
#       <td id="T_48fc3_row2_col1" class="data row2 col1" >1.1%</td>
#       <td id="T_48fc3_row2_col2" class="data row2 col2" >6.7%</td>
#       <td id="T_48fc3_row2_col3" class="data row2 col3" >31.8%</td>
#     </tr>
#     <tr>
#       <th id="T_48fc3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_48fc3_row3_col0" class="data row3 col0" >23.9%</td>
#       <td id="T_48fc3_row3_col1" class="data row3 col1" >2.0%</td>
#       <td id="T_48fc3_row3_col2" class="data row3 col2" >12.8%</td>
#       <td id="T_48fc3_row3_col3" class="data row3 col3" >61.4%</td>
#     </tr>
#     <tr>
#       <th id="T_48fc3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_48fc3_row4_col0" class="data row4 col0" >43.6%</td>
#       <td id="T_48fc3_row4_col1" class="data row4 col1" >0.7%</td>
#       <td id="T_48fc3_row4_col2" class="data row4 col2" >12.5%</td>
#       <td id="T_48fc3_row4_col3" class="data row4 col3" >43.3%</td>
#     </tr>
#     <tr>
#       <th id="T_48fc3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_48fc3_row5_col0" class="data row5 col0" >8.1%</td>
#       <td id="T_48fc3_row5_col1" class="data row5 col1" >3.3%</td>
#       <td id="T_48fc3_row5_col2" class="data row5 col2" >23.0%</td>
#       <td id="T_48fc3_row5_col3" class="data row5 col3" >65.6%</td>
#     </tr>
#     <tr>
#       <th id="T_48fc3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_48fc3_row6_col0" class="data row6 col0" >39.9%</td>
#       <td id="T_48fc3_row6_col1" class="data row6 col1" >3.0%</td>
#       <td id="T_48fc3_row6_col2" class="data row6 col2" >19.0%</td>
#       <td id="T_48fc3_row6_col3" class="data row6 col3" >38.2%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 15. Number of accidents by Severity vs. Impact point
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='initial_impact_point', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Impact point')
plt.xlabel('Impact point')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'initial_impact_point')
# Out:
# <style type="text/css">
# #T_51a06 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_51a06 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_51a06 caption {
#   caption-side: top;
# }
# #T_51a06_row0_col0 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_51a06_row0_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_51a06_row0_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_51a06_row0_col3, #T_51a06_row1_col3 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_51a06_row1_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_51a06_row1_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_51a06_row1_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_51a06_row2_col0 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_51a06_row2_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_51a06_row2_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_51a06_row2_col3 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_51a06_row3_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_51a06_row3_col1, #T_51a06_row8_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_51a06_row3_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_51a06_row3_col3 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_51a06_row4_col0 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_51a06_row4_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_51a06_row4_col2 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_51a06_row4_col3 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_51a06_row5_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_51a06_row5_col1, #T_51a06_row6_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_51a06_row5_col2, #T_51a06_row9_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_51a06_row5_col3 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_51a06_row6_col0 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_51a06_row6_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_51a06_row6_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_51a06_row7_col0, #T_51a06_row8_col0 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_51a06_row7_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_51a06_row7_col2, #T_51a06_row8_col2, #T_51a06_row9_col0 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_51a06_row7_col3 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_51a06_row8_col3 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_51a06_row9_col2 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_51a06_row9_col3 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_51a06">
#   <caption>Percentages of Accident Gravity by Initial_impact_point</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_51a06_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_51a06_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_51a06_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_51a06_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >initial_impact_point</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51a06_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51a06_row0_col0" class="data row0 col0" >33.1%</td>
#       <td id="T_51a06_row0_col1" class="data row0 col1" >3.8%</td>
#       <td id="T_51a06_row0_col2" class="data row0 col2" >19.9%</td>
#       <td id="T_51a06_row0_col3" class="data row0 col3" >43.2%</td>
#     </tr>
#     <tr>
#       <th id="T_51a06_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_51a06_row1_col0" class="data row1 col0" >34.6%</td>
#       <td id="T_51a06_row1_col1" class="data row1 col1" >3.1%</td>
#       <td id="T_51a06_row1_col2" class="data row1 col2" >19.3%</td>
#       <td id="T_51a06_row1_col3" class="data row1 col3" >43.0%</td>
#     </tr>
#     <tr>
#       <th id="T_51a06_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_51a06_row2_col0" class="data row2 col0" >50.7%</td>
#       <td id="T_51a06_row2_col1" class="data row2 col1" >2.1%</td>
#       <td id="T_51a06_row2_col2" class="data row2 col2" >12.7%</td>
#       <td id="T_51a06_row2_col3" class="data row2 col3" >34.5%</td>
#     </tr>
#     <tr>
#       <th id="T_51a06_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_51a06_row3_col0" class="data row3 col0" >50.2%</td>
#       <td id="T_51a06_row3_col1" class="data row3 col1" >2.4%</td>
#       <td id="T_51a06_row3_col2" class="data row3 col2" >13.4%</td>
#       <td id="T_51a06_row3_col3" class="data row3 col3" >34.0%</td>
#     </tr>
#     <tr>
#       <th id="T_51a06_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_51a06_row4_col0" class="data row4 col0" >46.8%</td>
#       <td id="T_51a06_row4_col1" class="data row4 col1" >1.1%</td>
#       <td id="T_51a06_row4_col2" class="data row4 col2" >6.0%</td>
#       <td id="T_51a06_row4_col3" class="data row4 col3" >46.2%</td>
#     </tr>
#     <tr>
#       <th id="T_51a06_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_51a06_row5_col0" class="data row5 col0" >62.2%</td>
#       <td id="T_51a06_row5_col1" class="data row5 col1" >0.9%</td>
#       <td id="T_51a06_row5_col2" class="data row5 col2" >6.5%</td>
#       <td id="T_51a06_row5_col3" class="data row5 col3" >30.4%</td>
#     </tr>
#     <tr>
#       <th id="T_51a06_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_51a06_row6_col0" class="data row6 col0" >59.3%</td>
#       <td id="T_51a06_row6_col1" class="data row6 col1" >0.7%</td>
#       <td id="T_51a06_row6_col2" class="data row6 col2" >5.7%</td>
#       <td id="T_51a06_row6_col3" class="data row6 col3" >34.2%</td>
#     </tr>
#     <tr>
#       <th id="T_51a06_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_51a06_row7_col0" class="data row7 col0" >38.4%</td>
#       <td id="T_51a06_row7_col1" class="data row7 col1" >2.5%</td>
#       <td id="T_51a06_row7_col2" class="data row7 col2" >15.7%</td>
#       <td id="T_51a06_row7_col3" class="data row7 col3" >43.4%</td>
#     </tr>
#     <tr>
#       <th id="T_51a06_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_51a06_row8_col0" class="data row8 col0" >38.3%</td>
#       <td id="T_51a06_row8_col1" class="data row8 col1" >2.4%</td>
#       <td id="T_51a06_row8_col2" class="data row8 col2" >15.6%</td>
#       <td id="T_51a06_row8_col3" class="data row8 col3" >43.7%</td>
#     </tr>
#     <tr>
#       <th id="T_51a06_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_51a06_row9_col0" class="data row9 col0" >15.7%</td>
#       <td id="T_51a06_row9_col1" class="data row9 col1" >6.3%</td>
#       <td id="T_51a06_row9_col2" class="data row9 col2" >28.7%</td>
#       <td id="T_51a06_row9_col3" class="data row9 col3" >49.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 16. Number of accidents by Severity vs. Safety equipment
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='safety_equipment1', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Safety equipment')
plt.xlabel('Safety equipment')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'safety_equipment1')
# Out:
# <style type="text/css">
# #T_aecf8 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_aecf8 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_aecf8 caption {
#   caption-side: top;
# }
# #T_aecf8_row0_col0, #T_aecf8_row3_col2 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_aecf8_row0_col1, #T_aecf8_row7_col0 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_aecf8_row0_col2, #T_aecf8_row9_col2 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_aecf8_row0_col3 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_aecf8_row1_col0, #T_aecf8_row6_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_aecf8_row1_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_aecf8_row1_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_aecf8_row1_col3 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_aecf8_row2_col0, #T_aecf8_row5_col1 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_aecf8_row2_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_aecf8_row2_col2 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_aecf8_row2_col3 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_aecf8_row3_col0 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_aecf8_row3_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_aecf8_row3_col3 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_aecf8_row4_col0 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_aecf8_row4_col1 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_aecf8_row4_col2 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_aecf8_row4_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_aecf8_row5_col0 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_aecf8_row5_col2 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_aecf8_row5_col3 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_aecf8_row6_col0 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_aecf8_row6_col1 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_aecf8_row6_col3 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_aecf8_row7_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_aecf8_row7_col2 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_aecf8_row7_col3 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_aecf8_row8_col0 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_aecf8_row8_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_aecf8_row8_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_aecf8_row8_col3 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_aecf8_row9_col0 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_aecf8_row9_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_aecf8_row9_col3 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# </style>
# <table id="T_aecf8">
#   <caption>Percentages of Accident Gravity by Safety_equipment1</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_aecf8_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_aecf8_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_aecf8_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_aecf8_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >safety_equipment1</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aecf8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aecf8_row0_col0" class="data row0 col0" >8.2%</td>
#       <td id="T_aecf8_row0_col1" class="data row0 col1" >7.2%</td>
#       <td id="T_aecf8_row0_col2" class="data row0 col2" >30.8%</td>
#       <td id="T_aecf8_row0_col3" class="data row0 col3" >53.7%</td>
#     </tr>
#     <tr>
#       <th id="T_aecf8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aecf8_row1_col0" class="data row1 col0" >58.8%</td>
#       <td id="T_aecf8_row1_col1" class="data row1 col1" >1.5%</td>
#       <td id="T_aecf8_row1_col2" class="data row1 col2" >8.5%</td>
#       <td id="T_aecf8_row1_col3" class="data row1 col3" >31.3%</td>
#     </tr>
#     <tr>
#       <th id="T_aecf8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_aecf8_row2_col0" class="data row2 col0" >9.6%</td>
#       <td id="T_aecf8_row2_col1" class="data row2 col1" >3.4%</td>
#       <td id="T_aecf8_row2_col2" class="data row2 col2" >28.9%</td>
#       <td id="T_aecf8_row2_col3" class="data row2 col3" >58.1%</td>
#     </tr>
#     <tr>
#       <th id="T_aecf8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_aecf8_row3_col0" class="data row3 col0" >46.3%</td>
#       <td id="T_aecf8_row3_col1" class="data row3 col1" >1.2%</td>
#       <td id="T_aecf8_row3_col2" class="data row3 col2" >8.2%</td>
#       <td id="T_aecf8_row3_col3" class="data row3 col3" >44.4%</td>
#     </tr>
#     <tr>
#       <th id="T_aecf8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_aecf8_row4_col0" class="data row4 col0" >16.1%</td>
#       <td id="T_aecf8_row4_col1" class="data row4 col1" >10.7%</td>
#       <td id="T_aecf8_row4_col2" class="data row4 col2" >43.6%</td>
#       <td id="T_aecf8_row4_col3" class="data row4 col3" >29.6%</td>
#     </tr>
#     <tr>
#       <th id="T_aecf8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_aecf8_row5_col0" class="data row5 col0" >24.9%</td>
#       <td id="T_aecf8_row5_col1" class="data row5 col1" >9.6%</td>
#       <td id="T_aecf8_row5_col2" class="data row5 col2" >36.8%</td>
#       <td id="T_aecf8_row5_col3" class="data row5 col3" >28.7%</td>
#     </tr>
#     <tr>
#       <th id="T_aecf8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_aecf8_row6_col0" class="data row6 col0" >5.3%</td>
#       <td id="T_aecf8_row6_col1" class="data row6 col1" >8.0%</td>
#       <td id="T_aecf8_row6_col2" class="data row6 col2" >58.9%</td>
#       <td id="T_aecf8_row6_col3" class="data row6 col3" >27.7%</td>
#     </tr>
#     <tr>
#       <th id="T_aecf8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_aecf8_row7_col0" class="data row7 col0" >7.1%</td>
#       <td id="T_aecf8_row7_col1" class="data row7 col1" >0.0%</td>
#       <td id="T_aecf8_row7_col2" class="data row7 col2" >50.0%</td>
#       <td id="T_aecf8_row7_col3" class="data row7 col3" >42.9%</td>
#     </tr>
#     <tr>
#       <th id="T_aecf8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_aecf8_row8_col0" class="data row8 col0" >33.4%</td>
#       <td id="T_aecf8_row8_col1" class="data row8 col1" >2.9%</td>
#       <td id="T_aecf8_row8_col2" class="data row8 col2" >15.4%</td>
#       <td id="T_aecf8_row8_col3" class="data row8 col3" >48.3%</td>
#     </tr>
#     <tr>
#       <th id="T_aecf8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_aecf8_row9_col0" class="data row9 col0" >36.3%</td>
#       <td id="T_aecf8_row9_col1" class="data row9 col1" >4.9%</td>
#       <td id="T_aecf8_row9_col2" class="data row9 col2" >30.8%</td>
#       <td id="T_aecf8_row9_col3" class="data row9 col3" >28.0%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 17. Number of accidents by Severity vs. Manv
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='manv', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. manv')
plt.xlabel('manv')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'manv')
# Out:
# <style type="text/css">
# #T_48e25 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_48e25 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_48e25 caption {
#   caption-side: top;
# }
# #T_48e25_row0_col0 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_48e25_row0_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_48e25_row0_col2, #T_48e25_row18_col0 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_48e25_row0_col3 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_48e25_row1_col0 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_48e25_row1_col1, #T_48e25_row4_col1, #T_48e25_row19_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_48e25_row1_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_48e25_row1_col3 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_48e25_row2_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_48e25_row2_col1, #T_48e25_row3_col1, #T_48e25_row11_col1, #T_48e25_row16_col1, #T_48e25_row20_col1, #T_48e25_row24_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_48e25_row2_col2, #T_48e25_row13_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_48e25_row2_col3, #T_48e25_row5_col3 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_48e25_row3_col0 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_48e25_row3_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_48e25_row3_col3 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_48e25_row4_col0, #T_48e25_row25_col3 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_48e25_row4_col2 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_48e25_row4_col3, #T_48e25_row13_col0, #T_48e25_row13_col2 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_48e25_row5_col0 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_48e25_row5_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_48e25_row5_col2, #T_48e25_row8_col0 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_48e25_row6_col0 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_48e25_row6_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_48e25_row6_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_48e25_row6_col3 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_48e25_row7_col0 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_48e25_row7_col1, #T_48e25_row25_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_48e25_row7_col2, #T_48e25_row20_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_48e25_row7_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_48e25_row8_col1, #T_48e25_row22_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_48e25_row8_col2, #T_48e25_row19_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_48e25_row8_col3, #T_48e25_row20_col0 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_48e25_row9_col0 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_48e25_row9_col1, #T_48e25_row10_col1, #T_48e25_row12_col1, #T_48e25_row15_col1, #T_48e25_row22_col2, #T_48e25_row23_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_48e25_row9_col2, #T_48e25_row15_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_48e25_row9_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_48e25_row10_col0 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_48e25_row10_col2, #T_48e25_row24_col2 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_48e25_row10_col3 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_48e25_row11_col0 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_48e25_row11_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_48e25_row11_col3, #T_48e25_row20_col3 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_48e25_row12_col0 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_48e25_row12_col2, #T_48e25_row23_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_48e25_row12_col3 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_48e25_row13_col3 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_48e25_row14_col0, #T_48e25_row15_col3, #T_48e25_row25_col0 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_48e25_row14_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_48e25_row14_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_48e25_row14_col3, #T_48e25_row17_col3 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_48e25_row15_col0 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_48e25_row16_col0 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_48e25_row16_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_48e25_row16_col3 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_48e25_row17_col0 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_48e25_row17_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_48e25_row17_col2 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_48e25_row18_col1, #T_48e25_row21_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_48e25_row18_col2 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_48e25_row18_col3 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_48e25_row19_col0 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_48e25_row19_col3, #T_48e25_row23_col3 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_48e25_row21_col0 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_48e25_row21_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_48e25_row21_col3 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_48e25_row22_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_48e25_row22_col3 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_48e25_row23_col0 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_48e25_row24_col0 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_48e25_row24_col3 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_48e25_row25_col2 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_48e25_row26_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_48e25_row26_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_48e25_row26_col2 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_48e25_row26_col3 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# </style>
# <table id="T_48e25">
#   <caption>Percentages of Accident Gravity by Manv</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_48e25_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_48e25_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_48e25_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_48e25_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manv</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48e25_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48e25_row0_col0" class="data row0 col0" >34.8%</td>
#       <td id="T_48e25_row0_col1" class="data row0 col1" >4.0%</td>
#       <td id="T_48e25_row0_col2" class="data row0 col2" >19.7%</td>
#       <td id="T_48e25_row0_col3" class="data row0 col3" >41.5%</td>
#     </tr>
#     <tr>
#       <th id="T_48e25_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_48e25_row1_col0" class="data row1 col0" >36.7%</td>
#       <td id="T_48e25_row1_col1" class="data row1 col1" >2.7%</td>
#       <td id="T_48e25_row1_col2" class="data row1 col2" >17.8%</td>
#       <td id="T_48e25_row1_col3" class="data row1 col3" >42.9%</td>
#     </tr>
#     <tr>
#       <th id="T_48e25_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_48e25_row2_col0" class="data row2 col0" >48.3%</td>
#       <td id="T_48e25_row2_col1" class="data row2 col1" >1.1%</td>
#       <td id="T_48e25_row2_col2" class="data row2 col2" >8.3%</td>
#       <td id="T_48e25_row2_col

# %%
# 18. Number of accidents by Severity vs. user_category
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='user_category', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. user_category')
plt.xlabel('user_category')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'user_category')
# Out:
# <style type="text/css">
# #T_50e52 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_50e52 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_50e52 caption {
#   caption-side: top;
# }
# #T_50e52_row0_col0, #T_50e52_row1_col3 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_50e52_row0_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_50e52_row0_col2, #T_50e52_row1_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_50e52_row0_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_50e52_row1_col0 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_50e52_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_50e52_row2_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_50e52_row2_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_50e52_row2_col2 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_50e52_row2_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_50e52">
#   <caption>Percentages of Accident Gravity by User_category</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_50e52_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_50e52_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_50e52_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_50e52_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >user_category</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50e52_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_50e52_row0_col0" class="data row0 col0" >47.3%</td>
#       <td id="T_50e52_row0_col1" class="data row0 col1" >2.4%</td>
#       <td id="T_50e52_row0_col2" class="data row0 col2" >14.1%</td>
#       <td id="T_50e52_row0_col3" class="data row0 col3" >36.2%</td>
#     </tr>
#     <tr>
#       <th id="T_50e52_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_50e52_row1_col0" class="data row1 col0" >36.4%</td>
#       <td id="T_50e52_row1_col1" class="data row1 col1" >2.0%</td>
#       <td id="T_50e52_row1_col2" class="data row1 col2" >14.1%</td>
#       <td id="T_50e52_row1_col3" class="data row1 col3" >47.5%</td>
#     </tr>
#     <tr>
#       <th id="T_50e52_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_50e52_row2_col0" class="data row2 col0" >2.9%</td>
#       <td id="T_50e52_row2_col1" class="data row2 col1" >4.6%</td>
#       <td id="T_50e52_row2_col2" class="data row2 col2" >27.8%</td>
#       <td id="T_50e52_row2_col3" class="data row2 col3" >64.7%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 2.1 Number of accidents by Severity vs.Year
user_category = data['user_category'].unique()
n_user_category = len(user_category)

fig, axes = plt.subplots(1, n_user_category, figsize=(18, 6))
fig.suptitle('Severity Distribution per Usercategory', fontsize=16)

custom_colors_mat = ['#66B2FF', '#99FF99', '#FFCC99', '#FF9999']

for i, user_category in enumerate(user_categories):
    yearly_data = data[data['user_category'] == user_category]['gravity'].value_counts()
    colors = custom_colors_mat[:len(user_category_data)]  
    axes[i].pie(user_category_data, labels=user_category_data.index, autopct='%1.1f%%', colors=colors)
    axes[i].set_title(f'User category {user_category}')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# 19. Number of accidents by Severity vs. seat
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='seat', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. seat')
plt.xlabel('seat')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'seat')
# Out:
# <style type="text/css">
# #T_fac06 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_fac06 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_fac06 caption {
#   caption-side: top;
# }
# #T_fac06_row0_col0, #T_fac06_row7_col3 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_fac06_row0_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_fac06_row0_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_fac06_row0_col3 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_fac06_row1_col0 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_fac06_row1_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_fac06_row1_col2 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_fac06_row1_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_fac06_row2_col0, #T_fac06_row3_col0 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_fac06_row2_col1, #T_fac06_row3_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_fac06_row2_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_fac06_row2_col3, #T_fac06_row4_col3 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_fac06_row3_col2 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_fac06_row3_col3 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_fac06_row4_col0 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_fac06_row4_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_fac06_row4_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_fac06_row5_col0 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_fac06_row5_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_fac06_row5_col2 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_fac06_row5_col3 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_fac06_row6_col0 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_fac06_row6_col1, #T_fac06_row8_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_fac06_row6_col2 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_fac06_row6_col3 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_fac06_row7_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_fac06_row7_col1, #T_fac06_row9_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_fac06_row7_col2 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_fac06_row8_col0 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_fac06_row8_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_fac06_row8_col3 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_fac06_row9_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_fac06_row9_col2 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_fac06_row9_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fac06">
#   <caption>Percentages of Accident Gravity by Seat</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_fac06_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_fac06_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_fac06_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_fac06_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >seat</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fac06_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_fac06_row0_col0" class="data row0 col0" >47.4%</td>
#       <td id="T_fac06_row0_col1" class="data row0 col1" >2.4%</td>
#       <td id="T_fac06_row0_col2" class="data row0 col2" >14.1%</td>
#       <td id="T_fac06_row0_col3" class="data row0 col3" >36.1%</td>
#     </tr>
#     <tr>
#       <th id="T_fac06_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_fac06_row1_col0" class="data row1 col0" >34.6%</td>
#       <td id="T_fac06_row1_col1" class="data row1 col1" >2.0%</td>
#       <td id="T_fac06_row1_col2" class="data row1 col2" >15.0%</td>
#       <td id="T_fac06_row1_col3" class="data row1 col3" >48.4%</td>
#     </tr>
#     <tr>
#       <th id="T_fac06_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_fac06_row2_col0" class="data row2 col0" >38.7%</td>
#       <td id="T_fac06_row2_col1" class="data row2 col1" >1.4%</td>
#       <td id="T_fac06_row2_col2" class="data row2 col2" >8.7%</td>
#       <td id="T_fac06_row2_col3" class="data row2 col3" >51.3%</td>
#     </tr>
#     <tr>
#       <th id="T_fac06_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_fac06_row3_col0" class="data row3 col0" >38.8%</td>
#       <td id="T_fac06_row3_col1" class="data row3 col1" >1.3%</td>
#       <td id="T_fac06_row3_col2" class="data row3 col2" >8.4%</td>
#       <td id="T_fac06_row3_col3" class="data row3 col3" >51.6%</td>
#     </tr>
#     <tr>
#       <th id="T_fac06_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_fac06_row4_col0" class="data row4 col0" >36.7%</td>
#       <td id="T_fac06_row4_col1" class="data row4 col1" >1.8%</td>
#       <td id="T_fac06_row4_col2" class="data row4 col2" >10.3%</td>
#       <td id="T_fac06_row4_col3" class="data row4 col3" >51.2%</td>
#     </tr>
#     <tr>
#       <th id="T_fac06_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_fac06_row5_col0" class="data row5 col0" >44.3%</td>
#       <td id="T_fac06_row5_col1" class="data row5 col1" >1.6%</td>
#       <td id="T_fac06_row5_col2" class="data row5 col2" >10.7%</td>
#       <td id="T_fac06_row5_col3" class="data row5 col3" >43.3%</td>
#     </tr>
#     <tr>
#       <th id="T_fac06_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_fac06_row6_col0" class="data row6 col0" >40.1%</td>
#       <td id="T_fac06_row6_col1" class="data row6 col1" >2.7%</td>
#       <td id="T_fac06_row6_col2" class="data row6 col2" >19.8%</td>
#       <td id="T_fac06_row6_col3" class="data row6 col3" >37.4%</td>
#     </tr>
#     <tr>
#       <th id="T_fac06_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_fac06_row7_col0" class="data row7 col0" >33.8%</td>
#       <td id="T_fac06_row7_col1" class="data row7 col1" >2.9%</td>
#       <td id="T_fac06_row7_col2" class="data row7 col2" >15.9%</td>
#       <td id="T_fac06_row7_col3" class="data row7 col3" >47.4%</td>
#     </tr>
#     <tr>
#       <th id="T_fac06_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_fac06_row8_col0" class="data row8 col0" >42.4%</td>
#       <td id="T_fac06_row8_col1" class="data row8 col1" >2.8%</td>
#       <td id="T_fac06_row8_col2" class="data row8 col2" >20.0%</td>
#       <td id="T_fac06_row8_col3" class="data row8 col3" >34.9%</td>
#     </tr>
#     <tr>
#       <th id="T_fac06_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_fac06_row9_col0" class="data row9 col0" >2.9%</td>
#       <td id="T_fac06_row9_col1" class="data row9 col1" >4.6%</td>
#       <td id="T_fac06_row9_col2" class="data row9 col2" >27.8%</td>
#       <td id="T_fac06_row9_col3" class="data row9 col3" >64.7%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 20. Number of accidents by Severity vs. fixed_obstacle
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='fixed_obstacle', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. fixed_obstacle')
plt.xlabel('fixed_obstacle')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'fixed_obstacle')
# Out:
# <style type="text/css">
# #T_8d6a0 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_8d6a0 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_8d6a0 caption {
#   caption-side: top;
# }
# #T_8d6a0_row0_col0, #T_8d6a0_row5_col3 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_8d6a0_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8d6a0_row0_col2, #T_8d6a0_row2_col0 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_8d6a0_row0_col3 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_8d6a0_row1_col0 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_8d6a0_row1_col1, #T_8d6a0_row4_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_8d6a0_row1_col2, #T_8d6a0_row2_col1 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_8d6a0_row1_col3 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_8d6a0_row2_col2 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_8d6a0_row2_col3 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_8d6a0_row3_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_8d6a0_row3_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_8d6a0_row3_col2 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_8d6a0_row3_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_8d6a0_row4_col0 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_8d6a0_row4_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_8d6a0_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8d6a0_row5_col0, #T_8d6a0_row16_col0 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_8d6a0_row5_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_8d6a0_row5_col2 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_8d6a0_row6_col0 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_8d6a0_row6_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_8d6a0_row6_col2, #T_8d6a0_row16_col2 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_8d6a0_row6_col3 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_8d6a0_row7_col0 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_8d6a0_row7_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_8d6a0_row7_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_8d6a0_row7_col3 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_8d6a0_row8_col0, #T_8d6a0_row10_col0 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_8d6a0_row8_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_8d6a0_row8_col2 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_8d6a0_row8_col3 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_8d6a0_row9_col0 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_8d6a0_row9_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_8d6a0_row9_col2, #T_8d6a0_row14_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_8d6a0_row9_col3 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_8d6a0_row10_col1 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_8d6a0_row10_col2 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_8d6a0_row10_col3 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_8d6a0_row11_col0, #T_8d6a0_row13_col0 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_8d6a0_row11_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_8d6a0_row11_col2 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_8d6a0_row11_col3, #T_8d6a0_row17_col2 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_8d6a0_row12_col0 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_8d6a0_row12_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_8d6a0_row12_col2 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_8d6a0_row12_col3 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_8d6a0_row13_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_8d6a0_row13_col2 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_8d6a0_row13_col3 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_8d6a0_row14_col0 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_8d6a0_row14_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_8d6a0_row14_col3 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_8d6a0_row15_col0 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_8d6a0_row15_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_8d6a0_row15_col2 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_8d6a0_row15_col3 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_8d6a0_row16_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_8d6a0_row16_col3 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_8d6a0_row17_col0 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_8d6a0_row17_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_8d6a0_row17_col3 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# </style>
# <table id="T_8d6a0">
#   <caption>Percentages of Accident Gravity by Fixed_obstacle</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_8d6a0_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_8d6a0_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_8d6a0_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_8d6a0_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >fixed_obstacle</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d6a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d6a0_row0_col0" class="data row0 col0" >45.9%</td>
#       <td id="T_8d6a0_row0_col1" class="data row0 col1" >1.8%</td>
#       <td id="T_8d6a0_row0_col2" class="data row0 col2" >12.8%</td>
#       <td id="T_8d6a0_row0_col3" class="data row0 col3" >39.6%</td>
#     </tr>
#     <tr>
#       <th id="T_8d6a0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8d6a0_row1_col0" class="data row1 col0" >30.6%</td>
#       <td id="T_8d6a0_row1_col1" class="data row1 col1" >2.4%</td>
#       <td id="T_8d6a0_row1_col2" class="data row1 col2" >14.8%</td>
#       <td id="T_8d6a0_row1_col3" class="data row1 col3" >52.2%</td>
#     </tr>
#     <tr>
#       <th id="T_8d6a0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8d6a0_row2_col0" class="data row2 col0" >12.7%</td>
#       <td id="T_8d6a0_row2_col1" class="data row2 col1" >14.8%</td>
#       <td id="T_8d6a0_row2_col2" class="data row2 col2" >41.6%</td>
#       <td id="T_8d6a0_row2_col3" class="data row2 col3" >30.8%</td>
#     </tr>
#     <tr>
#       <th id="T_8d6a0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8d6a0_row3_col0" class="data row3 col0" >21.0%</td>
#       <td id="T_8d6a0_row3_col1" class="data row3 col1" >6.7%</td>
#       <td id="T_8d6a0_row3_col2" class="data row3 col2" >23.4%</td>
#       <td id="T_8d6a0_row3_col3" class="data row3 col3" >48.9%</td>
#     </tr>
#     <tr>
#       <th id="T_8d6a0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8d6a0_row4_col0" class="data row4 col0" >18.9%</td>
#       <td id="T_8d6a0_row4_col1" class="data row4 col1" >2.4%</td>
#       <td id="T_8d6a0_row4_col2" class="data row4 col2" >13.5%</td>
#       <td id="T_8d6a0_row4_col3" class="data row4 col3" >65.2%</td>
#     </tr>
#     <tr>
#       <th id="T_8d6a0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8d6a0_row5_col0" class="data row5 col0" >18.4%</td>
#       <td id="T_8d6a0_row5_col1" class="data row5 col1" >6.5%</td>
#       <td id="T_8d6a0_row5_col2" class="data row5 col2" >29.4%</td>
#       <td id="T_8d6a0_row5_col3" class="data row5 col3" >45.7%</td>
#     </tr>
#     <tr>
#       <th id="T_8d6a0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8d6a0_row6_col0" class="data row6 col0" >16.3%</td>
#       <td id="T_8d6a0_row6_col1" class="data row6 col1" >9.0%</td>
#       <td id="T_8d6a0_

# %%
# 21. Number of accidents by Severity vs. Collision type
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='collision_type', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Collision type')
plt.xlabel('collision_type')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'collision_type')
# Out:
# <style type="text/css">
# #T_502d2 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_502d2 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_502d2 caption {
#   caption-side: top;
# }
# #T_502d2_row0_col0 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_502d2_row0_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_502d2_row0_col2 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_502d2_row0_col3 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_502d2_row1_col0 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_502d2_row1_col1, #T_502d2_row2_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_502d2_row1_col2 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_502d2_row1_col3 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_502d2_row2_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_502d2_row2_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_502d2_row2_col3 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_502d2_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_502d2_row3_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_502d2_row3_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_502d2_row3_col3 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_502d2_row4_col0 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_502d2_row4_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_502d2_row4_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_502d2_row4_col3 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_502d2_row5_col0 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_502d2_row5_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_502d2_row5_col2 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_502d2_row5_col3 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_502d2_row6_col0 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_502d2_row6_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_502d2_row6_col2 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_502d2_row6_col3 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_502d2">
#   <caption>Percentages of Accident Gravity by Collision_type</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_502d2_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_502d2_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_502d2_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_502d2_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >collision_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_502d2_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_502d2_row0_col0" class="data row0 col0" >36.2%</td>
#       <td id="T_502d2_row0_col1" class="data row0 col1" >4.2%</td>
#       <td id="T_502d2_row0_col2" class="data row0 col2" >22.7%</td>
#       <td id="T_502d2_row0_col3" class="data row0 col3" >36.9%</td>
#     </tr>
#     <tr>
#       <th id="T_502d2_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_502d2_row1_col0" class="data row1 col0" >47.0%</td>
#       <td id="T_502d2_row1_col1" class="data row1 col1" >1.0%</td>
#       <td id="T_502d2_row1_col2" class="data row1 col2" >7.7%</td>
#       <td id="T_502d2_row1_col3" class="data row1 col3" >44.3%</td>
#     </tr>
#     <tr>
#       <th id="T_502d2_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_502d2_row2_col0" class="data row2 col0" >46.8%</td>
#       <td id="T_502d2_row2_col1" class="data row2 col1" >1.0%</td>
#       <td id="T_502d2_row2_col2" class="data row2 col2" >11.6%</td>
#       <td id="T_502d2_row2_col3" class="data row2 col3" >40.6%</td>
#     </tr>
#     <tr>
#       <th id="T_502d2_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_502d2_row3_col0" class="data row3 col0" >57.8%</td>
#       <td id="T_502d2_row3_col1" class="data row3 col1" >0.5%</td>
#       <td id="T_502d2_row3_col2" class="data row3 col2" >3.7%</td>
#       <td id="T_502d2_row3_col3" class="data row3 col3" >37.9%</td>
#     </tr>
#     <tr>
#       <th id="T_502d2_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_502d2_row4_col0" class="data row4 col0" >51.9%</td>
#       <td id="T_502d2_row4_col1" class="data row4 col1" >2.1%</td>
#       <td id="T_502d2_row4_col2" class="data row4 col2" >10.7%</td>
#       <td id="T_502d2_row4_col3" class="data row4 col3" >35.3%</td>
#     </tr>
#     <tr>
#       <th id="T_502d2_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_502d2_row5_col0" class="data row5 col0" >35.6%</td>
#       <td id="T_502d2_row5_col1" class="data row5 col1" >4.5%</td>
#       <td id="T_502d2_row5_col2" class="data row5 col2" >20.4%</td>
#       <td id="T_502d2_row5_col3" class="data row5 col3" >39.5%</td>
#     </tr>
#     <tr>
#       <th id="T_502d2_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_502d2_row6_col0" class="data row6 col0" >15.5%</td>
#       <td id="T_502d2_row6_col1" class="data row6 col1" >5.2%</td>
#       <td id="T_502d2_row6_col2" class="data row6 col2" >31.6%</td>
#       <td id="T_502d2_row6_col3" class="data row6 col3" >47.7%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 22. Number of accidents by Severity vs. plan
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='plan', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. plan')
plt.xlabel('plan')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'plan')
# Out:
# <style type="text/css">
# #T_297ae th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_297ae td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_297ae caption {
#   caption-side: top;
# }
# #T_297ae_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_297ae_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_297ae_row0_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_297ae_row0_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_297ae_row1_col0 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_297ae_row1_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_297ae_row1_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_297ae_row1_col3 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_297ae_row2_col0 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_297ae_row2_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_297ae_row2_col2 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_297ae_row2_col3 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_297ae_row3_col0 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_297ae_row3_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_297ae_row3_col2 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_297ae_row3_col3 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_297ae">
#   <caption>Percentages of Accident Gravity by Plan</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_297ae_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_297ae_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_297ae_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_297ae_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >plan</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_297ae_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_297ae_row0_col0" class="data row0 col0" >43.7%</td>
#       <td id="T_297ae_row0_col1" class="data row0 col1" >2.1%</td>
#       <td id="T_297ae_row0_col2" class="data row0 col2" >13.3%</td>
#       <td id="T_297ae_row0_col3" class="data row0 col3" >40.9%</td>
#     </tr>
#     <tr>
#       <th id="T_297ae_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_297ae_row1_col0" class="data row1 col0" >33.9%</td>
#       <td id="T_297ae_row1_col1" class="data row1 col1" >4.2%</td>
#       <td id="T_297ae_row1_col2" class="data row1 col2" >23.0%</td>
#       <td id="T_297ae_row1_col3" class="data row1 col3" >38.9%</td>
#     </tr>
#     <tr>
#       <th id="T_297ae_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_297ae_row2_col0" class="data row2 col0" >34.4%</td>
#       <td id="T_297ae_row2_col1" class="data row2 col1" >4.6%</td>
#       <td id="T_297ae_row2_col2" class="data row2 col2" >23.3%</td>
#       <td id="T_297ae_row2_col3" class="data row2 col3" >37.7%</td>
#     </tr>
#     <tr>
#       <th id="T_297ae_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_297ae_row3_col0" class="data row3 col0" >30.9%</td>
#       <td id="T_297ae_row3_col1" class="data row3 col1" >4.8%</td>
#       <td id="T_297ae_row3_col2" class="data row3 col2" >28.1%</td>
#       <td id="T_297ae_row3_col3" class="data row3 col3" >36.2%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 23. Number of accidents by Severity vs. accident situation
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='accident_situation', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. accident situation')
plt.xlabel('accident situation')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'accident_situation')
# Out:
# <style type="text/css">
# #T_5f1dc th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_5f1dc td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_5f1dc caption {
#   caption-side: top;
# }
# #T_5f1dc_row0_col0 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_5f1dc_row0_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_5f1dc_row0_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_5f1dc_row0_col3 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_5f1dc_row1_col0 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_5f1dc_row1_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_5f1dc_row1_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_5f1dc_row1_col3 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_5f1dc_row2_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_5f1dc_row2_col1 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_5f1dc_row2_col2 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_5f1dc_row2_col3 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_5f1dc_row3_col0 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_5f1dc_row3_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_5f1dc_row3_col2 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_5f1dc_row3_col3 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_5f1dc_row4_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_5f1dc_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5f1dc_row4_col2 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_5f1dc_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5f1dc_row5_col0 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_5f1dc_row5_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_5f1dc_row5_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_5f1dc_row5_col3 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_5f1dc_row6_col0 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_5f1dc_row6_col1 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_5f1dc_row6_col2 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_5f1dc_row6_col3 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5f1dc">
#   <caption>Percentages of Accident Gravity by Accident_situation</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_5f1dc_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_5f1dc_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_5f1dc_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_5f1dc_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >accident_situation</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f1dc_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_5f1dc_row0_col0" class="data row0 col0" >43.8%</td>
#       <td id="T_5f1dc_row0_col1" class="data row0 col1" >1.9%</td>
#       <td id="T_5f1dc_row0_col2" class="data row0 col2" >13.5%</td>
#       <td id="T_5f1dc_row0_col3" class="data row0 col3" >40.8%</td>
#     </tr>
#     <tr>
#       <th id="T_5f1dc_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_5f1dc_row1_col0" class="data row1 col0" >37.9%</td>
#       <td id="T_5f1dc_row1_col1" class="data row1 col1" >2.8%</td>
#       <td id="T_5f1dc_row1_col2" class="data row1 col2" >14.2%</td>
#       <td id="T_5f1dc_row1_col3" class="data row1 col3" >45.1%</td>
#     </tr>
#     <tr>
#       <th id="T_5f1dc_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_5f1dc_row2_col0" class="data row2 col0" >18.5%</td>
#       <td id="T_5f1dc_row2_col1" class="data row2 col1" >10.2%</td>
#       <td id="T_5f1dc_row2_col2" class="data row2 col2" >39.8%</td>
#       <td id="T_5f1dc_row2_col3" class="data row2 col3" >31.5%</td>
#     </tr>
#     <tr>
#       <th id="T_5f1dc_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_5f1dc_row3_col0" class="data row3 col0" >28.9%</td>
#       <td id="T_5f1dc_row3_col1" class="data row3 col1" >4.9%</td>
#       <td id="T_5f1dc_row3_col2" class="data row3 col2" >22.6%</td>
#       <td id="T_5f1dc_row3_col3" class="data row3 col3" >43.6%</td>
#     </tr>
#     <tr>
#       <th id="T_5f1dc_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_5f1dc_row4_col0" class="data row4 col0" >42.8%</td>
#       <td id="T_5f1dc_row4_col1" class="data row4 col1" >0.9%</td>
#       <td id="T_5f1dc_row4_col2" class="data row4 col2" >7.5%</td>
#       <td id="T_5f1dc_row4_col3" class="data row4 col3" >48.8%</td>
#     </tr>
#     <tr>
#       <th id="T_5f1dc_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_5f1dc_row5_col0" class="data row5 col0" >44.9%</td>
#       <td id="T_5f1dc_row5_col1" class="data row5 col1" >1.8%</td>
#       <td id="T_5f1dc_row5_col2" class="data row5 col2" >10.1%</td>
#       <td id="T_5f1dc_row5_col3" class="data row5 col3" >43.3%</td>
#     </tr>
#     <tr>
#       <th id="T_5f1dc_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_5f1dc_row6_col0" class="data row6 col0" >31.2%</td>
#       <td id="T_5f1dc_row6_col1" class="data row6 col1" >7.3%</td>
#       <td id="T_5f1dc_row6_col2" class="data row6 col2" >27.6%</td>
#       <td id="T_5f1dc_row6_col3" class="data row6 col3" >33.9%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 24. Number of accidents by Severity vs. surface condition
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='surface_condition', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. surface condition')
plt.xlabel('surface condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'surface_condition')
# Out:
# <style type="text/css">
# #T_96839 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_96839 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_96839 caption {
#   caption-side: top;
# }
# #T_96839_row0_col0 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_96839_row0_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_96839_row0_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_96839_row0_col3, #T_96839_row2_col3, #T_96839_row6_col3 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_96839_row1_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_96839_row1_col1, #T_96839_row4_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_96839_row1_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_96839_row1_col3 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_96839_row2_col0, #T_96839_row3_col0 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_96839_row2_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_96839_row2_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_96839_row3_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_96839_row3_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_96839_row3_col3 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_96839_row4_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_96839_row4_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_96839_row4_col3 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_96839_row5_col0 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_96839_row5_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_96839_row5_col2 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_96839_row5_col3 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_96839_row6_col0 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_96839_row6_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_96839_row6_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_96839_row7_col0 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_96839_row7_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_96839_row7_col2 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_96839_row7_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_96839_row8_col0 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_96839_row8_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_96839_row8_col2 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_96839_row8_col3 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_96839">
#   <caption>Percentages of Accident Gravity by Surface_condition</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_96839_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_96839_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_96839_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_96839_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >surface_condition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96839_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_96839_row0_col0" class="data row0 col0" >42.4%</td>
#       <td id="T_96839_row0_col1" class="data row0 col1" >2.5%</td>
#       <td id="T_96839_row0_col2" class="data row0 col2" >15.3%</td>
#       <td id="T_96839_row0_col3" class="data row0 col3" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_96839_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_96839_row1_col0" class="data row1 col0" >40.6%</td>
#       <td id="T_96839_row1_col1" class="data row1 col1" >2.7%</td>
#       <td id="T_96839_row1_col2" class="data row1 col2" >13.8%</td>
#       <td id="T_96839_row1_col3" class="data row1 col3" >43.0%</td>
#     </tr>
#     <tr>
#       <th id="T_96839_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_96839_row2_col0" class="data row2 col0" >37.8%</td>
#       <td id="T_96839_row2_col1" class="data row2 col1" >3.1%</td>
#       <td id="T_96839_row2_col2" class="data row2 col2" >19.1%</td>
#       <td id="T_96839_row2_col3" class="data row2 col3" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_96839_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_96839_row3_col0" class="data row3 col0" >37.9%</td>
#       <td id="T_96839_row3_col1" class="data row3 col1" >2.4%</td>
#       <td id="T_96839_row3_col2" class="data row3 col2" >17.8%</td>
#       <td id="T_96839_row3_col3" class="data row3 col3" >42.0%</td>
#     </tr>
#     <tr>
#       <th id="T_96839_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_96839_row4_col0" class="data row4 col0" >44.2%</td>
#       <td id="T_96839_row4_col1" class="data row4 col1" >2.7%</td>
#       <td id="T_96839_row4_col2" class="data row4 col2" >16.4%</td>
#       <td id="T_96839_row4_col3" class="data row4 col3" >36.6%</td>
#     </tr>
#     <tr>
#       <th id="T_96839_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_96839_row5_col0" class="data row5 col0" >24.1%</td>
#       <td id="T_96839_row5_col1" class="data row5 col1" >8.9%</td>
#       <td id="T_96839_row5_col2" class="data row5 col2" >36.6%</td>
#       <td id="T_96839_row5_col3" class="data row5 col3" >30.4%</td>
#     </tr>
#     <tr>
#       <th id="T_96839_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_96839_row6_col0" class="data row6 col0" >30.7%</td>
#       <td id="T_96839_row6_col1" class="data row6 col1" >5.1%</td>
#       <td id="T_96839_row6_col2" class="data row6 col2" >24.4%</td>
#       <td id="T_96839_row6_col3" class="data row6 col3" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_96839_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_96839_row7_col0" class="data row7 col0" >25.2%</td>
#       <td id="T_96839_row7_col1" class="data row7 col1" >1.7%</td>
#       <td id="T_96839_row7_col2" class="data row7 col2" >22.9%</td>
#       <td id="T_96839_row7_col3" class="data row7 col3" >50.3%</td>
#     </tr>
#     <tr>
#       <th id="T_96839_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_96839_row8_col0" class="data row8 col0" >28.1%</td>
#       <td id="T_96839_row8_col1" class="data row8 col1" >5.2%</td>
#       <td id="T_96839_row8_col2" class="data row8 col2" >29.9%</td>
#       <td id="T_96839_row8_col3" class="data row8 col3" >36.9%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 25. Number of accidents by Severity vs. longitudinal profile
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='longitudinal_profile', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. longitudinal profile')
plt.xlabel('longitudinal profile')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'longitudinal_profile')
# Out:
# <style type="text/css">
# #T_53738 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_53738 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_53738 caption {
#   caption-side: top;
# }
# #T_53738_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_53738_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_53738_row0_col2 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_53738_row0_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_53738_row1_col0 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_53738_row1_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_53738_row1_col2 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_53738_row1_col3 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_53738_row2_col0 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_53738_row2_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_53738_row2_col2 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_53738_row2_col3, #T_53738_row3_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_53738_row3_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_53738_row3_col2 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_53738_row3_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_53738">
#   <caption>Percentages of Accident Gravity by Longitudinal_profile</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_53738_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_53738_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_53738_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_53738_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >longitudinal_profile</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53738_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_53738_row0_col0" class="data row0 col0" >42.8%</td>
#       <td id="T_53738_row0_col1" class="data row0 col1" >2.3%</td>
#       <td id="T_53738_row0_col2" class="data row0 col2" >14.1%</td>
#       <td id="T_53738_row0_col3" class="data row0 col3" >40.8%</td>
#     </tr>
#     <tr>
#       <th id="T_53738_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_53738_row1_col0" class="data row1 col0" >38.2%</td>
#       <td id="T_53738_row1_col1" class="data row1 col1" >3.5%</td>
#       <td id="T_53738_row1_col2" class="data row1 col2" >19.6%</td>
#       <td id="T_53738_row1_col3" class="data row1 col3" >38.7%</td>
#     </tr>
#     <tr>
#       <th id="T_53738_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_53738_row2_col0" class="data row2 col0" >37.5%</td>
#       <td id="T_53738_row2_col1" class="data row2 col1" >4.5%</td>
#       <td id="T_53738_row2_col2" class="data row2 col2" >20.1%</td>
#       <td id="T_53738_row2_col3" class="data row2 col3" >37.9%</td>
#     </tr>
#     <tr>
#       <th id="T_53738_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_53738_row3_col0" class="data row3 col0" >37.8%</td>
#       <td id="T_53738_row3_col1" class="data row3 col1" >4.2%</td>
#       <td id="T_53738_row3_col2" class="data row3 col2" >20.7%</td>
#       <td id="T_53738_row3_col3" class="data row3 col3" >37.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 26. Number of accidents by Severity vs. route_category
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='route_category', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. route category')
plt.xlabel('route category')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'route_category')
# Out:
# <style type="text/css">
# #T_a7ceb th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_a7ceb td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_a7ceb caption {
#   caption-side: top;
# }
# #T_a7ceb_row0_col0 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_a7ceb_row0_col1, #T_a7ceb_row3_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a7ceb_row0_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_a7ceb_row0_col3 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_a7ceb_row1_col0 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_a7ceb_row1_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_a7ceb_row1_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_a7ceb_row1_col3, #T_a7ceb_row6_col0 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_a7ceb_row2_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_a7ceb_row2_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_a7ceb_row2_col2 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_a7ceb_row2_col3 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_a7ceb_row3_col0 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_a7ceb_row3_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_a7ceb_row3_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_a7ceb_row4_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_a7ceb_row4_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_a7ceb_row4_col2 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_a7ceb_row4_col3 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_a7ceb_row5_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a7ceb_row5_col1, #T_a7ceb_row6_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_a7ceb_row5_col2 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_a7ceb_row5_col3 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_a7ceb_row6_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_a7ceb_row6_col3 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_a7ceb_row7_col0, #T_a7ceb_row7_col3 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_a7ceb_row7_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_a7ceb_row7_col2 {
#   background-color: #92c4de;
#   color: #000000;
# }
# </style>
# <table id="T_a7ceb">
#   <caption>Percentages of Accident Gravity by Route_category</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_a7ceb_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_a7ceb_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_a7ceb_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_a7ceb_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >route_category</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7ceb_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a7ceb_row0_col0" class="data row0 col0" >46.6%</td>
#       <td id="T_a7ceb_row0_col1" class="data row0 col1" >1.1%</td>
#       <td id="T_a7ceb_row0_col2" class="data row0 col2" >5.6%</td>
#       <td id="T_a7ceb_row0_col3" class="data row0 col3" >46.7%</td>
#     </tr>
#     <tr>
#       <th id="T_a7ceb_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a7ceb_row1_col0" class="data row1 col0" >41.2%</td>
#       <td id="T_a7ceb_row1_col1" class="data row1 col1" >3.3%</td>
#       <td id="T_a7ceb_row1_col2" class="data row1 col2" >13.8%</td>
#       <td id="T_a7ceb_row1_col3" class="data row1 col3" >41.6%</td>
#     </tr>
#     <tr>
#       <th id="T_a7ceb_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a7ceb_row2_col0" class="data row2 col0" >38.3%</td>
#       <td id="T_a7ceb_row2_col1" class="data row2 col1" >4.2%</td>
#       <td id="T_a7ceb_row2_col2" class="data row2 col2" >22.8%</td>
#       <td id="T_a7ceb_row2_col3" class="data row2 col3" >34.7%</td>
#     </tr>
#     <tr>
#       <th id="T_a7ceb_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_a7ceb_row3_col0" class="data row3 col0" >44.3%</td>
#       <td id="T_a7ceb_row3_col1" class="data row3 col1" >1.2%</td>
#       <td id="T_a7ceb_row3_col2" class="data row3 col2" >10.5%</td>
#       <td id="T_a7ceb_row3_col3" class="data row3 col3" >44.0%</td>
#     </tr>
#     <tr>
#       <th id="T_a7ceb_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_a7ceb_row4_col0" class="data row4 col0" >36.1%</td>
#       <td id="T_a7ceb_row4_col1" class="data row4 col1" >4.4%</td>
#       <td id="T_a7ceb_row4_col2" class="data row4 col2" >23.7%</td>
#       <td id="T_a7ceb_row4_col3" class="data row4 col3" >35.7%</td>
#     </tr>
#     <tr>
#       <th id="T_a7ceb_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_a7ceb_row5_col0" class="data row5 col0" >47.2%</td>
#       <td id="T_a7ceb_row5_col1" class="data row5 col1" >2.2%</td>
#       <td id="T_a7ceb_row5_col2" class="data row5 col2" >17.1%</td>
#       <td id="T_a7ceb_row5_col3" class="data row5 col3" >33.4%</td>
#     </tr>
#     <tr>
#       <th id="T_a7ceb_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_a7ceb_row6_col0" class="data row6 col0" >41.6%</td>
#       <td id="T_a7ceb_row6_col1" class="data row6 col1" >2.2%</td>
#       <td id="T_a7ceb_row6_col2" class="data row6 col2" >14.2%</td>
#       <td id="T_a7ceb_row6_col3" class="data row6 col3" >41.9%</td>
#     </tr>
#     <tr>
#       <th id="T_a7ceb_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_a7ceb_row7_col0" class="data row7 col0" >38.8%</td>
#       <td id="T_a7ceb_row7_col1" class="data row7 col1" >2.7%</td>
#       <td id="T_a7ceb_row7_col2" class="data row7 col2" >19.7%</td>
#       <td id="T_a7ceb_row7_col3" class="data row7 col3" >38.8%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 27. Number of accidents by Severity vs. reason travel
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='reason_travel', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. reason_travel')
plt.xlabel('reason_travel')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'reason_travel')
# Out:
# <style type="text/css">
# #T_74bc2 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_74bc2 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_74bc2 caption {
#   caption-side: top;
# }
# #T_74bc2_row0_col0, #T_74bc2_row0_col3 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_74bc2_row0_col1, #T_74bc2_row1_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_74bc2_row0_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_74bc2_row1_col0 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_74bc2_row1_col2 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_74bc2_row1_col3 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_74bc2_row2_col0 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_74bc2_row2_col1, #T_74bc2_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_74bc2_row2_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_74bc2_row2_col3 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_74bc2_row3_col0 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_74bc2_row3_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_74bc2_row3_col2, #T_74bc2_row5_col2 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_74bc2_row3_col3 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_74bc2_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_74bc2_row4_col2 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_74bc2_row4_col3 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_74bc2_row5_col0 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_74bc2_row5_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_74bc2_row5_col3 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_74bc2_row6_col0 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_74bc2_row6_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_74bc2_row6_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_74bc2_row6_col3 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_74bc2">
#   <caption>Percentages of Accident Gravity by Reason_travel</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_74bc2_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_74bc2_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_74bc2_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_74bc2_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >reason_travel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74bc2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_74bc2_row0_col0" class="data row0 col0" >42.9%</td>
#       <td id="T_74bc2_row0_col1" class="data row0 col1" >1.9%</td>
#       <td id="T_74bc2_row0_col2" class="data row0 col2" >12.4%</td>
#       <td id="T_74bc2_row0_col3" class="data row0 col3" >42.8%</td>
#     </tr>
#     <tr>
#       <th id="T_74bc2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_74bc2_row1_col0" class="data row1 col0" >40.8%</td>
#       <td id="T_74bc2_row1_col1" class="data row1 col1" >1.9%</td>
#       <td id="T_74bc2_row1_col2" class="data row1 col2" >13.6%</td>
#       <td id="T_74bc2_row1_col3" class="data row1 col3" >43.7%</td>
#     </tr>
#     <tr>
#       <th id="T_74bc2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_74bc2_row2_col0" class="data row2 col0" >28.6%</td>
#       <td id="T_74bc2_row2_col1" class="data row2 col1" >1.1%</td>
#       <td id="T_74bc2_row2_col2" class="data row2 col2" >16.0%</td>
#       <td id="T_74bc2_row2_col3" class="data row2 col3" >54.3%</td>
#     </tr>
#     <tr>
#       <th id="T_74bc2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_74bc2_row3_col0" class="data row3 col0" >43.1%</td>
#       <td id="T_74bc2_row3_col1" class="data row3 col1" >4.2%</td>
#       <td id="T_74bc2_row3_col2" class="data row3 col2" >20.4%</td>
#       <td id="T_74bc2_row3_col3" class="data row3 col3" >32.4%</td>
#     </tr>
#     <tr>
#       <th id="T_74bc2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_74bc2_row4_col0" class="data row4 col0" >64.6%</td>
#       <td id="T_74bc2_row4_col1" class="data row4 col1" >1.0%</td>
#       <td id="T_74bc2_row4_col2" class="data row4 col2" >5.7%</td>
#       <td id="T_74bc2_row4_col3" class="data row4 col3" >28.7%</td>
#     </tr>
#     <tr>
#       <th id="T_74bc2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_74bc2_row5_col0" class="data row5 col0" >36.8%</td>
#       <td id="T_74bc2_row5_col1" class="data row5 col1" >3.6%</td>
#       <td id="T_74bc2_row5_col2" class="data row5 col2" >20.5%</td>
#       <td id="T_74bc2_row5_col3" class="data row5 col3" >39.1%</td>
#     </tr>
#     <tr>
#       <th id="T_74bc2_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_74bc2_row6_col0" class="data row6 col0" >40.1%</td>
#       <td id="T_74bc2_row6_col1" class="data row6 col1" >2.2%</td>
#       <td id="T_74bc2_row6_col2" class="data row6 col2" >11.8%</td>
#       <td id="T_74bc2_row6_col3" class="data row6 col3" >46.0%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 28. Accidents Severity vs. geographical location
fig = px.scatter_mapbox(
    data, 
    lat="lat", 
    lon="long", 
    color="gravity", 
    color_continuous_scale=px.colors.cyclical.IceFire, 
    zoom=3, 
    height=1000, 
    width=2000, 
    labels={"gravity": "Severity"}
)

# Update the layout for mapbox style
fig.update_layout(
    mapbox_style="open-street-map",
    mapbox_center={"lat": data["lat"].mean(), "lon": data["long"].mean()}, 
    title={'x': 0.5} 
)

# Add hover data for more information on each point
fig.update_traces(marker=dict(size=8), 
                  hovertemplate="<br>".join([
                      "Latitude: %{lat}",
                      "Longitude: %{lon}",
                      "Severity: %{marker.color}"
                  ])
)

# Save the map as an HTML file
fig.write_html("accidents_severity_map.html")
