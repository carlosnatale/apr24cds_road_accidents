# %%
import os
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import scipy.cluster.hierarchy as shc
from sklearn.decomposition import PCA
from IPython.display import display, HTML
from scipy.cluster.hierarchy import dendrogram, linkage
from pandas.plotting import andrews_curves, parallel_coordinates, lag_plot, autocorrelation_plot, radviz

#import geopandas as gpd
#from shapely.geometry import Point

# %%
# Function to load and process files based on the given conditions
def process_files(file_list, column_order, rename_dict, drop_column=None):
    dfs = []
    for file in file_list:
        df = pd.read_csv(file, delimiter=';', on_bad_lines='skip', dtype=str)
        if "Accident_Id" in df.columns:
            df.rename(columns={"Accident_Id": "Num_Acc"}, inplace=True)
        if drop_column and drop_column in df.columns:
            df.drop(columns=[drop_column], inplace=True)
        df = df.reindex(columns=column_order)
        dfs.append(df)
    combined_df = pd.concat(dfs, ignore_index=True)
    combined_df.rename(columns=rename_dict, inplace=True)
    return combined_df

# %%
# Define file paths
source_folder = "source/"
caracteristiques_files = [os.path.join(source_folder, f) for f in os.listdir(source_folder) if f.startswith("caracteristiques")]
lieux_files = [os.path.join(source_folder, f) for f in os.listdir(source_folder) if f.startswith("lieux")]
usagers_files = [os.path.join(source_folder, f) for f in os.listdir(source_folder) if f.startswith("usagers")]
vehicules_files = [os.path.join(source_folder, f) for f in os.listdir(source_folder) if f.startswith("vehicules")]

# %%
# Define column orders and rename dictionaries
caracteristiques_columns = ["Num_Acc", "jour", "mois", "an", "hrmn", "lum", "dep", "com", "agg", "int", "atm", "col", "adr", "lat", "long"]
caracteristiques_rename = {"Num_Acc": "AccID", "jour": "day", "mois": "month", "an": "year", "hrmn": "time", "lum": "lum", 
                           "dep": "dep_code", "com": "com_code", "agg": "location", "int": "int", "atm": "atm_condition", 
                           "col": "collision_type", "adr": "address", "lat": "lat", "long": "long"}

lieux_columns = ["Num_Acc", "catr", "voie", "v1", "v2", "circ", "nbv", "vosp", "prof", "pr", "pr1", "plan", "lartpc", 
                 "larrout", "surf", "infra", "situ", "vma"]
lieux_rename = {"Num_Acc": "AccID", "catr": "route_category", "voie": "route_number", "v1": "route_number_index1", 
                "v2": "alph_route_index", "circ": "traffic_regime", "nbv": "total_number_lanes", "vosp": "reserved_lane_code", 
                "prof": "longitudinal_profile", "pr": "upstream_terminal_number", "pr1": "distance_upstream_terminal", 
                "plan": "plan", "lartpc": "width_central_reservation", "larrout": "width_roadway", "surf": "surface_condition", 
                "infra": "infra", "situ": "accident_situation", "vma": "maximum_speed"}

usagers_columns = ["Num_Acc", "id_vehicule", "num_veh", "place", "catu", "grav", "sexe", "an_nais", "trajet", "secu1", 
                   "secu2", "secu3", "locp", "actp", "etatp"]
usagers_rename = {"Num_Acc": "AccID", "id_vehicule": "vehicleID", "num_veh": "num_veh", "place": "seat", "catu": "user_category", 
                  "grav": "gravity", "sexe": "gender", "an_nais": "birth_year", "trajet": "reason_travel", "secu1": "safety_equipment1", 
                  "secu2": "safety_equipment2", "secu3": "safety_equipment3", "locp": "pedestrian_location", "actp": "pedestrian_action", 
                  "etatp": "pedestrian_involved"}

vehicules_columns = ["Num_Acc", "id_vehicule", "num_veh", "senc", "catv", "obs", "obsm", "choc", "manv", "motor", "occutc"]
vehicules_rename = {"Num_Acc": "AccID", "id_vehicule": "vehicleID", "num_veh": "num_veh", "senc": "traffic_direction", 
                    "catv": "vehicle_category", "obs": "fixed_obstacle", "obsm": "mobile_obstacle", "choc": "initial_impact_point", 
                    "manv": "manv", "motor": "motor", "occutc": "number_occupants_publictransport"}

# %%
# Process each group of files
characteristics = process_files(caracteristiques_files, caracteristiques_columns, caracteristiques_rename)
locations = process_files(lieux_files, lieux_columns, lieux_rename)
users = process_files(usagers_files, usagers_columns, usagers_rename, drop_column="id_usager")
vehicles = process_files(vehicules_files, vehicules_columns, vehicules_rename)

# %%
# Convert 'lat' and 'long' fields to float in the 'characteristics' dataframe
characteristics['lat'] = characteristics['lat'].str.replace(',', '.').astype(float)
characteristics['long'] = characteristics['long'].str.replace(',', '.').astype(float)

# %%
# Convert 'time' field to proper time format in the 'characteristics' dataframe
characteristics['time'] = pd.to_datetime(characteristics['time'], format='%H:%M').dt.time

# %%
# Convert 'day', 'month', and 'year' fields to integer in the 'characteristics' dataframe
characteristics['day'] = pd.to_numeric(characteristics['day'], errors='coerce').astype(pd.Int32Dtype())
characteristics['month'] = pd.to_numeric(characteristics['month'], errors='coerce').astype(pd.Int32Dtype())
characteristics['year'] = pd.to_numeric(characteristics['year'], errors='coerce').astype(pd.Int32Dtype())

# %%
# Replace invalid literals with NaN and convert specified columns in 'locations' dataframe
locations['total_number_lanes'] = pd.to_numeric(locations['total_number_lanes'].replace('#ERREUR', np.nan), errors='coerce').astype(pd.Int32Dtype())
locations['distance_upstream_terminal'] = pd.to_numeric(locations['distance_upstream_terminal'].str.replace(',', '.').replace('#ERREUR', np.nan), errors='coerce')
locations['width_central_reservation'] = pd.to_numeric(locations['width_central_reservation'].str.replace(',', '.').replace('#ERREUR', np.nan), errors='coerce')
locations['width_roadway'] = pd.to_numeric(locations['width_roadway'].str.replace(',', '.').replace('#ERREUR', np.nan), errors='coerce')
locations['maximum_speed'] = pd.to_numeric(locations['maximum_speed'].replace('#ERREUR', np.nan), errors='coerce').astype(pd.Int32Dtype())

# %%
#Replace '#ERREUR' with NaN
users['birth_year'] = users['birth_year'].replace('#ERREUR', np.nan)

#Convert 'birth_year' to numeric with coercion
users['birth_year'] = pd.to_numeric(users['birth_year'], errors='coerce')

#Calculate the average birth year, ignoring NaN values
average_birth_year = int(users['birth_year'].mean())

# Replace NaN values in 'birth_year' with the average
users['birth_year'] = users['birth_year'].fillna(average_birth_year).astype(int)

#Calculate 'age'
current_year = datetime.now().year
users['age'] = current_year - users['birth_year']

# %%
# Convert 'number_occupants_publictransport' field to integer in the 'vehicles' dataframe
vehicles['number_occupants_publictransport'] = pd.to_numeric(
    vehicles['number_occupants_publictransport'].replace('#ERREUR', np.nan), errors='coerce').astype(pd.Int32Dtype())

# %%
# Drop fields with a large number of missing values and outliers
vehicles = vehicles.drop(['number_occupants_publictransport'], axis=1)
locations = locations.drop(['alph_route_index', 'distance_upstream_terminal', 'width_central_reservation', 'width_roadway', 'route_number', 'route_number_index1'], axis=1)
locations = locations[(locations['maximum_speed'] >= 6) & (locations['maximum_speed'] <= 120)]
users = users[users['birth_year'] > 1930]
users = users[users['gravity'] != -1]

# %% [markdown]
# <font size="6">
#     Merge and Export Dataframes
# </font>

# %%
# Merge dataframes on AccID
data = characteristics.merge(locations, on='AccID').merge(users, on='AccID').merge(vehicles, on='AccID')

# %%
# Drop rows with missing values in numeric columns
cleaned_data = data.dropna(subset=numeric_columns)

# Create a boxplot for each numeric column to identify outliers
plt.figure(figsize=(15, 10))
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(len(numeric_columns) // 3 + 1, 3, i)
    sns.boxplot(x=cleaned_data[column])
    plt.title(column)

plt.tight_layout()
plt.show()

# %%
#characteristics.to_csv('characteristics.csv', index=False)
#locations.to_csv('locations.csv', index=False)
#users.to_csv('users.csv', index=False)
#vehicles.to_csv('vehicles.csv', index=False)
#data.to_csv('data.csv', index=False)

# %% [markdown]
# <font size="6">
#     Visualizations
# </font>

# %%
# Set up the figure size and style
sns.set_style("darkgrid")
plt.figure(figsize=(12, 8))

# %%
# Ignore specific warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn")

# %%
# Replace the values
data['gravity'] = data['gravity'].replace({
     '1': '1 - Unharmed',
     '2': '2 - Killed',
     '3': '3 - Hospitalized',
     '4': '4 - Slightly injured'
})

# %%
# Function to calculate and display percentages
def calculate_and_display_percentages(data, group_by_col):
    counts = data.groupby([group_by_col, 'gravity']).size().reset_index(name='count')
    total_counts = data[group_by_col].value_counts().reset_index(name='total')
    total_counts.columns = [group_by_col, 'total']
    counts = counts.merge(total_counts, on=group_by_col)
    counts['percentage'] = counts['count'] / counts['total'] * 100
    
    # Pivot the table to show only percentages
    percentage_table = counts.pivot(index=group_by_col, columns='gravity', values='percentage').fillna(0)
    
    # Improve table visualization
    styled_table = percentage_table.style.format("{:.1f}%").set_table_styles(
        [{'selector': 'th', 'props': [('font-size', '12pt'), ('font-weight', 'bold'), ('text-align', 'center')]},
         {'selector': 'td', 'props': [('font-size', '10pt'), ('text-align', 'center')]},
         {'selector': 'caption', 'props': [('caption-side', 'top')]}]
    ).set_caption(f'Percentages of Accident Gravity by {group_by_col.capitalize()}').background_gradient(cmap='Blues', axis=None)
    
    # Display the styled table
    html = styled_table.to_html()
    display(HTML(html))

# %%
data.head()
# Out:
#           AccID  day  month  year      time lum dep_code com_code location  \
# 0  201900000001   30     11  2019  01:30:00   4       93    93053        1
# 1  201900000001   30     11  2019  01:30:00   4       93    93053        1
# 2  201900000001   30     11  2019  01:30:00   4       93    93053        1
# 3  201900000001   30     11  2019  01:30:00   4       93    93053        1
# 4  201900000001   30     11  2019  01:30:00   4       93    93053        1
#
#   int  ... age  vehicleID_y num_veh_y  traffic_direction  vehicle_category  \
# 0   1  ...  22  138 306 524       B01                  2                 7
# 1   1  ...  22  138 306 525       A01                  2                17
# 2   1  ...  31  138 306 524       B01                  2                 7
# 3   1  ...  31  138 306 525       A01                  2                17
# 4   1  ...  65  138 306 524       B01                  2                 7
#
#   fixed_obstacle mobile_obstacle  initial_impact_point manv motor
# 0              0               2                     5   23     1
# 1              1               0                     3   11     1
# 2              0               2                     5   23     1
# 3              1               0                     3   11     1
# 4              0               2                     5   23     1
#
# [5 rows x 50 columns]

# %%
# Gravity vs. Year
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='year', hue='gravity')
plt.title('Gravity vs. Year of Accident')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.show()

# Gravity vs. Year
calculate_and_display_percentages(data, 'year')
# Out:
# <style type="text/css">
# #T_8e402 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_8e402 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_8e402 caption {
#   caption-side: top;
# }
# #T_8e402_row0_col0, #T_8e402_row1_col0, #T_8e402_row2_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8e402_row0_col1 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_8e402_row0_col2, #T_8e402_row1_col2, #T_8e402_row2_col2, #T_8e402_row3_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_8e402_row0_col3 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_8e402_row0_col4, #T_8e402_row1_col4 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_8e402_row1_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_8e402_row1_col3 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_8e402_row2_col1, #T_8e402_row3_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8e402_row2_col3 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_8e402_row2_col4 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_8e402_row3_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_8e402_row3_col3 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_8e402_row3_col4 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8e402">
#   <caption>Percentages of Accident Gravity by Year</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_8e402_level0_col0" class="col_heading level0 col0" > -1</th>
#       <th id="T_8e402_level0_col1" class="col_heading level0 col1" >1 - Unharmed</th>
#       <th id="T_8e402_level0_col2" class="col_heading level0 col2" >2 - Killed</th>
#       <th id="T_8e402_level0_col3" class="col_heading level0 col3" >3 - Hospitalized</th>
#       <th id="T_8e402_level0_col4" class="col_heading level0 col4" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e402_level0_row0" class="row_heading level0 row0" >2019</th>
#       <td id="T_8e402_row0_col0" class="data row0 col0" >0.0%</td>
#       <td id="T_8e402_row0_col1" class="data row0 col1" >45.0%</td>
#       <td id="T_8e402_row0_col2" class="data row0 col2" >2.1%</td>
#       <td id="T_8e402_row0_col3" class="data row0 col3" >13.4%</td>
#       <td id="T_8e402_row0_col4" class="data row0 col4" >39.5%</td>
#     </tr>
#     <tr>
#       <th id="T_8e402_level0_row1" class="row_heading level0 row1" >2020</th>
#       <td id="T_8e402_row1_col0" class="data row1 col0" >0.0%</td>
#       <td id="T_8e402_row1_col1" class="data row1 col1" >44.7%</td>
#       <td id="T_8e402_row1_col2" class="data row1 col2" >2.1%</td>
#       <td id="T_8e402_row1_col3" class="data row1 col3" >13.7%</td>
#       <td id="T_8e402_row1_col4" class="data row1 col4" >39.6%</td>
#     </tr>
#     <tr>
#       <th id="T_8e402_level0_row2" class="row_heading level0 row2" >2021</th>
#       <td id="T_8e402_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_8e402_row2_col1" class="data row2 col1" >45.9%</td>
#       <td id="T_8e402_row2_col2" class="data row2 col2" >2.0%</td>
#       <td id="T_8e402_row2_col3" class="data row2 col3" >12.7%</td>
#       <td id="T_8e402_row2_col4" class="data row2 col4" >39.4%</td>
#     </tr>
#     <tr>
#       <th id="T_8e402_level0_row3" class="row_heading level0 row3" >2022</th>
#       <td id="T_8e402_row3_col0" class="data row3 col0" >0.2%</td>
#       <td id="T_8e402_row3_col1" class="data row3 col1" >45.8%</td>
#       <td id="T_8e402_row3_col2" class="data row3 col2" >2.3%</td>
#       <td id="T_8e402_row3_col3" class="data row3 col3" >13.1%</td>
#       <td id="T_8e402_row3_col4" class="data row3 col4" >38.6%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Gravity vs. Month
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='month', hue='gravity')
plt.title('Gravity vs. Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.show()

# Gravity vs. Month
calculate_and_display_percentages(data, 'month')
# Out:
# <style type="text/css">
# #T_8d5c5 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_8d5c5 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_8d5c5 caption {
#   caption-side: top;
# }
# #T_8d5c5_row0_col0, #T_8d5c5_row1_col0, #T_8d5c5_row2_col0, #T_8d5c5_row3_col0, #T_8d5c5_row4_col0, #T_8d5c5_row5_col0, #T_8d5c5_row6_col0, #T_8d5c5_row7_col0, #T_8d5c5_row8_col0, #T_8d5c5_row9_col0, #T_8d5c5_row10_col0, #T_8d5c5_row11_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8d5c5_row0_col1, #T_8d5c5_row3_col1 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_8d5c5_row0_col2, #T_8d5c5_row1_col2, #T_8d5c5_row2_col2, #T_8d5c5_row3_col2, #T_8d5c5_row4_col2, #T_8d5c5_row5_col2, #T_8d5c5_row6_col2, #T_8d5c5_row7_col2, #T_8d5c5_row8_col2, #T_8d5c5_row10_col2, #T_8d5c5_row11_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_8d5c5_row0_col3, #T_8d5c5_row10_col3 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_8d5c5_row0_col4 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_8d5c5_row1_col1, #T_8d5c5_row10_col1, #T_8d5c5_row11_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8d5c5_row1_col3, #T_8d5c5_row2_col3 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_8d5c5_row1_col4 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_8d5c5_row2_col1, #T_8d5c5_row8_col1 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_8d5c5_row2_col4 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_8d5c5_row3_col3 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_8d5c5_row3_col4 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_8d5c5_row4_col1 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_8d5c5_row4_col3 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_8d5c5_row4_col4, #T_8d5c5_row6_col4 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_8d5c5_row5_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_8d5c5_row5_col3 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_8d5c5_row5_col4, #T_8d5c5_row8_col4 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_8d5c5_row6_col1 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_8d5c5_row6_col3 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_8d5c5_row7_col1 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_8d5c5_row7_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_8d5c5_row7_col4 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_8d5c5_row8_col3 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_8d5c5_row9_col1 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_8d5c5_row9_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_8d5c5_row9_col3 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_8d5c5_row9_col4, #T_8d5c5_row10_col4 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_8d5c5_row11_col3 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_8d5c5_row11_col4 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8d5c5">
#   <caption>Percentages of Accident Gravity by Month</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_8d5c5_level0_col0" class="col_heading level0 col0" > -1</th>
#       <th id="T_8d5c5_level0_col1" class="col_heading level0 col1" >1 - Unharmed</th>
#       <th id="T_8d5c5_level0_col2" class="col_heading level0 col2" >2 - Killed</th>
#       <th id="T_8d5c5_level0_col3" class="col_heading level0 col3" >3 - Hospitalized</th>
#       <th id="T_8d5c5_level0_col4" class="col_heading level0 col4" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d5c5_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8d5c5_row0_col0" class="data row0 col0" >0.0%</td>
#       <td id="T_8d5c5_row0_col1" class="data row0 col1" >45.5%</td>
#       <td id="T_8d5c5_row0_col2" class="data row0 col2" >2.2%</td>
#       <td id="T_8d5c5_row0_col3" class="data row0 col3" >12.0%</td>
#       <td id="T_8d5c5_row0_col4" class="data row0 col4" >40.2%</td>
#     </tr>
#     <tr>
#       <th id="T_8d5c5_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_8d5c5_row1_col0" class="data row1 col0" >0.1%</td>
#       <td id="T_8d5c5_row1_col1" class="data row1 col1" >46.1%</td>
#       <td id="T_8d5c5_row1_col2" class="data row1 col2" >2.1%</td>
#       <td id="T_8d5c5_row1_col3" class="data row1 col3" >12.4%</td>
#       <td id="T_8d5c5_row1_col4" class="data row1 col4" >39.4%</td>
#     </tr>
#     <tr>
#       <th id="T_8d5c5_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_8d5c5_row2_col0" class="data row2 col0" >0.1%</td>
#       <td id="T_8d5c5_row2_col1" class="data row2 col1" >45.4%</td>
#       <td id="T_8d5c5_row2_col2" class="data row2 col2" >2.0%</td>
#       <td id="T_8d5c5_row2_col3" class="data row2 col3" >12.4%</td>
#       <td id="T_8d5c5_row2_col4" class="data row2 col4" >40.1%</td>
#     </tr>
#     <tr>
#       <th id="T_8d5c5_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_8d5c5_row3_col0" class="data row3 col0" >0.0%</td>
#       <td id="T_8d5c5_row3_col1" class="data row3 col1" >45.5%</td>
#       <td id="T_8d5c5_row3_col2" class="data row3 col2" >2.2%</td>
#       <td id="T_8d5c5_row3_col3" class="data row3 col3" >13.1%</td>
#       <td id="T_8d5c5_row3_col4" class="data row3 col4" >39.1%</td>
#     </tr>
#     <tr>
#       <th id="T_8d5c5_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_8d5c5_row4_col0" class="data row4 col0" >0.0%</td>
#       <td id="T_8d5c5_row4_col1" class="data row4 col1" >45.1%</td>
#       <td id="T_8d5c5_row4_col2" class="data row4 col2" >2.1%</td>
#       <td id="T_8d5c5_row4_col3" class="data row4 col3" >14.0%</td>
#       <td id="T_8d5c5_row4_col4" class="data row4 col4" >38.8%</td>
#     </tr>
#     <tr>
#       <th id="T_8d5c5_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_8d5c5_row5_col0" class="data row5 col0" >0.1%</td>
#       <td id="T_8d5c5_row5_col1" class="data row5 col1" >44.9%</td>
#       <td id="T_8d5c5_row5_col2" class="data row5 col2" >2.0%</td>
#       <td id="T_8d5c5_row5_col3" class="data row5 col3" >13.8%</td>
#       <td id="T_8d5c5_row5_col4" class="data row5 col4" >39.2%</td>
#     </tr>
#     <tr>
#       <th id="T_8d5c5_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_8d5c5_row6_col0" class="data row6 col0" >0.1%</td>
#       <td id="T_8d5c5_row6_col1" class="data row6 col1" >44.4%</td>
#       <td id="T_8d5c5_row6_col2" class="data row6 col2" >2.3%</td>
#       <td id="T_8d5c5_row6_col3" class="data row6 col3" >14.4%</td>
#       <td id="T_8d5c5_row6_col4" class="data row6 col4" >38.8%</td>
#     </tr>
#     <tr>
#       <th id="T_8d5c5_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_8d5c5_row7_col0" class="data row7 col0" >0.0%</td>
#       <td id="T_8d5c5_row7_col1" class="data row7 col1" >44.8%</td>
#       <td id="T_8d5c5_row7_col2" class="data row7 col2" >2.3%</td>
#       <td id="T_8d5c5_row7_col3" class="data row7 col3" >15.4%</td>
#       <td id="T_8d5c5_row7_col4" class="data row7 col4" >37.5%</td>
#     </tr>
#     <tr>
#       <th id="T_8d5c5_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_8d5c5_row8_col0" class="data row8 col0" >0.1%</td>
#       <td id="T_8d5c5_row8_col1" class="data row8 col1" >45.3%</td>
#       <td id="T_8d5c5_row8_col2" class="data row8 col2" >2.1%</td>
#       <td id="T_8d5c5_row8_col3" class="data row8 col3" >13.4%</td>
#       <td id="T_8d5c5_row8_col4" class="data row8 col4" >39.2%</td>
#     </tr>
#     <tr>
#       <th id="T_8d5c5_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_8d5c5_row9_col0" class="data row9 col0" >0.1%</td>
#       <td id="T_8d5c5_row9_col1" class="data row9 col1" >45.6%</td>
#       <td id="T_8d5c5_row9_col2" class="data row9 col2" >1.9%</td>
#       <td id="

# %%
# Aggregate the data by vehicle_category and gravity
agg_dataday = data.groupby(['day', 'gravity']).size().unstack(fill_value=0)

# Gravity vs. Day
plt.figure(figsize=(18, 12))
for gravity in agg_dataday.columns:
    plt.plot(agg_dataday.index, agg_dataday[gravity], marker='o', label=f'Gravity: {gravity}')

plt.title('Gravity vs. day')
plt.xlabel('day')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Gravity vs. Day
calculate_and_display_percentages(data, 'day')
# Out:
# <style type="text/css">
# #T_f389d th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_f389d td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_f389d caption {
#   caption-side: top;
# }
# #T_f389d_row0_col0, #T_f389d_row1_col0, #T_f389d_row2_col0, #T_f389d_row3_col0, #T_f389d_row4_col0, #T_f389d_row5_col0, #T_f389d_row6_col0, #T_f389d_row7_col0, #T_f389d_row8_col0, #T_f389d_row9_col0, #T_f389d_row10_col0, #T_f389d_row11_col0, #T_f389d_row12_col0, #T_f389d_row13_col0, #T_f389d_row14_col0, #T_f389d_row15_col0, #T_f389d_row16_col0, #T_f389d_row17_col0, #T_f389d_row18_col0, #T_f389d_row19_col0, #T_f389d_row20_col0, #T_f389d_row21_col0, #T_f389d_row22_col0, #T_f389d_row23_col0, #T_f389d_row24_col0, #T_f389d_row25_col0, #T_f389d_row26_col0, #T_f389d_row27_col0, #T_f389d_row28_col0, #T_f389d_row29_col0, #T_f389d_row30_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f389d_row0_col1, #T_f389d_row2_col1, #T_f389d_row7_col1, #T_f389d_row9_col1, #T_f389d_row23_col1 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_f389d_row0_col2, #T_f389d_row1_col2, #T_f389d_row2_col2, #T_f389d_row3_col2, #T_f389d_row5_col2, #T_f389d_row6_col2, #T_f389d_row7_col2, #T_f389d_row8_col2, #T_f389d_row9_col2, #T_f389d_row10_col2, #T_f389d_row11_col2, #T_f389d_row12_col2, #T_f389d_row13_col2, #T_f389d_row14_col2, #T_f389d_row15_col2, #T_f389d_row16_col2, #T_f389d_row17_col2, #T_f389d_row19_col2, #T_f389d_row20_col2, #T_f389d_row21_col2, #T_f389d_row22_col2, #T_f389d_row23_col2, #T_f389d_row24_col2, #T_f389d_row25_col2, #T_f389d_row26_col2, #T_f389d_row27_col2, #T_f389d_row30_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_f389d_row0_col3, #T_f389d_row4_col3, #T_f389d_row11_col3, #T_f389d_row28_col3 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_f389d_row0_col4, #T_f389d_row3_col4, #T_f389d_row14_col4, #T_f389d_row21_col4, #T_f389d_row26_col4 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_f389d_row1_col1, #T_f389d_row3_col1, #T_f389d_row17_col1 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_f389d_row1_col3, #T_f389d_row2_col3 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_f389d_row1_col4, #T_f389d_row10_col4, #T_f389d_row24_col4 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_f389d_row2_col4 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_f389d_row3_col3, #T_f389d_row14_col3, #T_f389d_row15_col3, #T_f389d_row17_col3, #T_f389d_row18_col3 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_f389d_row4_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_f389d_row4_col2, #T_f389d_row28_col2, #T_f389d_row29_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_f389d_row4_col4, #T_f389d_row17_col4 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_f389d_row5_col1, #T_f389d_row29_col1 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_f389d_row5_col3, #T_f389d_row6_col3, #T_f389d_row9_col3, #T_f389d_row24_col3 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_f389d_row5_col4 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_f389d_row6_col1, #T_f389d_row18_col1 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_f389d_row6_col4, #T_f389d_row7_col4, #T_f389d_row12_col4, #T_f389d_row13_col4, #T_f389d_row23_col4 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_f389d_row7_col3, #T_f389d_row8_col3, #T_f389d_row10_col3, #T_f389d_row19_col3, #T_f389d_row21_col3 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_f389d_row8_col1, #T_f389d_row12_col1, #T_f389d_row26_col1, #T_f389d_row27_col1 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_f389d_row8_col4, #T_f389d_row15_col4, #T_f389d_row20_col4, #T_f389d_row27_col4 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_f389d_row9_col4, #T_f389d_row11_col4, #T_f389d_row22_col4, #T_f389d_row25_col4, #T_f389d_row29_col4, #T_f389d_row30_col4 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_f389d_row10_col1, #T_f389d_row13_col1, #T_f389d_row16_col1, #T_f389d_row20_col1, #T_f389d_row22_col1, #T_f389d_row30_col1 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_f389d_row11_col1, #T_f389d_row14_col1, #T_f389d_row15_col1, #T_f389d_row21_col1, #T_f389d_row24_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_f389d_row12_col3, #T_f389d_row20_col3, #T_f389d_row22_col3, #T_f389d_row23_col3, #T_f389d_row25_col3, #T_f389d_row26_col3, #T_f389d_row27_col3, #T_f389d_row29_col3, #T_f389d_row30_col3 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_f389d_row13_col3 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_f389d_row16_col3 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_f389d_row16_col4 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_f389d_row18_col2 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_f389d_row18_col4 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_f389d_row19_col1 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_f389d_row19_col4, #T_f389d_row28_col4 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_f389d_row25_col1 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_f389d_row28_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f389d">
#   <caption>Percentages of Accident Gravity by Day</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_f389d_level0_col0" class="col_heading level0 col0" > -1</th>
#       <th id="T_f389d_level0_col1" class="col_heading level0 col1" >1 - Unharmed</th>
#       <th id="T_f389d_level0_col2" class="col_heading level0 col2" >2 - Killed</th>
#       <th id="T_f389d_level0_col3" class="col_heading level0 col3" >3 - Hospitalized</th>
#       <th id="T_f389d_level0_col4" class="col_heading level0 col4" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >day</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f389d_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f389d_row0_col0" class="data row0 col0" >0.1%</td>
#       <td id="T_f389d_row0_col1" class="data row0 col1" >45.5%</td>
#       <td id="T_f389d_row0_col2" class="data row0 col2" >2.3%</td>
#       <td id="T_f389d_row0_col3" class="data row0 col3" >13.0%</td>
#       <td id="T_f389d_row0_col4" class="data row0 col4" >39.1%</td>
#     </tr>
#     <tr>
#       <th id="T_f389d_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_f389d_row1_col0" class="data row1 col0" >0.1%</td>
#       <td id="T_f389d_row1_col1" class="data row1 col1" >45.7%</td>
#       <td id="T_f389d_row1_col2" class="data row1 col2" >2.1%</td>
#       <td id="T_f389d_row1_col3" class="data row1 col3" >12.5%</td>
#       <td id="T_f389d_row1_col4" class="data row1 col4" >39.7%</td>
#     </tr>
#     <tr>
#       <th id="T_f389d_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_f389d_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_f389d_row2_col1" class="data row2 col1" >45.5%</td>
#       <td id="T_f389d_row2_col2" class="data row2 col2" >2.0%</td>
#       <td id="T_f389d_row2_col3" class="data row2 col3" >12.5%</td>
#       <td id="T_f389d_row2_col4" class="data row2 col4" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_f389d_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_f389d_row3_col0" class="data row3 col0" >0.1%</td>
#       <td id="T_f389d_row3_col1" class="data row3 col1" >45.6%</td>
#       <td id="T_f389d_row3_col2" class="data row3 col2" >2.1%</td>
#       <td id="T_f389d_row3_col3" class="data row3 col3" >13.1%</td>
#       <td id="T_f389d_row3_col4" class="data row3 col4" >39.1%</td>
#     </tr>
#     <tr>
#       <th id="T_f389d_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_f389d_row4_col0" class="data row4 col0" >0.0%</td>
#       <td id="T_f389d_row4_col1" class="data row4 col1" >46.2%</td>
#       <td id="T_f389d_row4_col2" class="data row4 c

# %%
# Gravity vs. Weather Conditions (atm_condition)
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='atm_condition', hue='gravity')
plt.title('Gravity vs. Weather Conditions')
plt.xlabel('Weather Condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

# Gravity vs. Weather Conditions (atm_condition)
calculate_and_display_percentages(data, 'atm_condition')
# Out:
# <style type="text/css">
# #T_d1f6b th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_d1f6b td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_d1f6b caption {
#   caption-side: top;
# }
# #T_d1f6b_row0_col0, #T_d1f6b_row3_col2, #T_d1f6b_row4_col2, #T_d1f6b_row8_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_d1f6b_row0_col1 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_d1f6b_row0_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_d1f6b_row0_col3 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_d1f6b_row0_col4 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_d1f6b_row1_col0, #T_d1f6b_row2_col0, #T_d1f6b_row3_col0, #T_d1f6b_row4_col0, #T_d1f6b_row5_col0, #T_d1f6b_row6_col0, #T_d1f6b_row7_col0, #T_d1f6b_row8_col0, #T_d1f6b_row9_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d1f6b_row1_col1 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_d1f6b_row1_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_d1f6b_row1_col3, #T_d1f6b_row3_col3 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_d1f6b_row1_col4, #T_d1f6b_row3_col4 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_d1f6b_row2_col1, #T_d1f6b_row5_col1 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_d1f6b_row2_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_d1f6b_row2_col3 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_d1f6b_row2_col4 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_d1f6b_row3_col1 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_d1f6b_row4_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d1f6b_row4_col3 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_d1f6b_row4_col4 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_d1f6b_row5_col2 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_d1f6b_row5_col3 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_d1f6b_row5_col4 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_d1f6b_row6_col1 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_d1f6b_row6_col2, #T_d1f6b_row9_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_d1f6b_row6_col3 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_d1f6b_row6_col4 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_d1f6b_row7_col1 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_d1f6b_row7_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_d1f6b_row7_col3 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_d1f6b_row7_col4 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_d1f6b_row8_col1 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_d1f6b_row8_col3 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_d1f6b_row8_col4 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_d1f6b_row9_col1 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_d1f6b_row9_col3 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_d1f6b_row9_col4 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d1f6b">
#   <caption>Percentages of Accident Gravity by Atm_condition</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_d1f6b_level0_col0" class="col_heading level0 col0" > -1</th>
#       <th id="T_d1f6b_level0_col1" class="col_heading level0 col1" >1 - Unharmed</th>
#       <th id="T_d1f6b_level0_col2" class="col_heading level0 col2" >2 - Killed</th>
#       <th id="T_d1f6b_level0_col3" class="col_heading level0 col3" >3 - Hospitalized</th>
#       <th id="T_d1f6b_level0_col4" class="col_heading level0 col4" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >atm_condition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1f6b_level0_row0" class="row_heading level0 row0" > -1</th>
#       <td id="T_d1f6b_row0_col0" class="data row0 col0" >2.4%</td>
#       <td id="T_d1f6b_row0_col1" class="data row0 col1" >29.3%</td>
#       <td id="T_d1f6b_row0_col2" class="data row0 col2" >9.8%</td>
#       <td id="T_d1f6b_row0_col3" class="data row0 col3" >4.9%</td>
#       <td id="T_d1f6b_row0_col4" class="data row0 col4" >53.7%</td>
#     </tr>
#     <tr>
#       <th id="T_d1f6b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d1f6b_row1_col0" class="data row1 col0" >0.1%</td>
#       <td id="T_d1f6b_row1_col1" class="data row1 col1" >45.4%</td>
#       <td id="T_d1f6b_row1_col2" class="data row1 col2" >2.1%</td>
#       <td id="T_d1f6b_row1_col3" class="data row1 col3" >13.2%</td>
#       <td id="T_d1f6b_row1_col4" class="data row1 col4" >39.2%</td>
#     </tr>
#     <tr>
#       <th id="T_d1f6b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d1f6b_row2_col0" class="data row2 col0" >0.1%</td>
#       <td id="T_d1f6b_row2_col1" class="data row2 col1" >44.9%</td>
#       <td id="T_d1f6b_row2_col2" class="data row2 col2" >1.9%</td>
#       <td id="T_d1f6b_row2_col3" class="data row2 col3" >11.1%</td>
#       <td id="T_d1f6b_row2_col4" class="data row2 col4" >42.1%</td>
#     </tr>
#     <tr>
#       <th id="T_d1f6b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d1f6b_row3_col0" class="data row3 col0" >0.0%</td>
#       <td id="T_d1f6b_row3_col1" class="data row3 col1" >45.1%</td>
#       <td id="T_d1f6b_row3_col2" class="data row3 col2" >2.4%</td>
#       <td id="T_d1f6b_row3_col3" class="data row3 col3" >13.4%</td>
#       <td id="T_d1f6b_row3_col4" class="data row3 col4" >39.1%</td>
#     </tr>
#     <tr>
#       <th id="T_d1f6b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d1f6b_row4_col0" class="data row4 col0" >0.1%</td>
#       <td id="T_d1f6b_row4_col1" class="data row4 col1" >54.5%</td>
#       <td id="T_d1f6b_row4_col2" class="data row4 col2" >2.4%</td>
#       <td id="T_d1f6b_row4_col3" class="data row4 col3" >12.5%</td>
#       <td id="T_d1f6b_row4_col4" class="data row4 col4" >30.5%</td>
#     </tr>
#     <tr>
#       <th id="T_d1f6b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d1f6b_row5_col0" class="data row5 col0" >0.1%</td>
#       <td id="T_d1f6b_row5_col1" class="data row5 col1" >44.8%</td>
#       <td id="T_d1f6b_row5_col2" class="data row5 col2" >4.6%</td>
#       <td id="T_d1f6b_row5_col3" class="data row5 col3" >17.9%</td>
#       <td id="T_d1f6b_row5_col4" class="data row5 col4" >32.6%</td>
#     </tr>
#     <tr>
#       <th id="T_d1f6b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d1f6b_row6_col0" class="data row6 col0" >0.0%</td>
#       <td id="T_d1f6b_row6_col1" class="data row6 col1" >37.0%</td>
#       <td id="T_d1f6b_row6_col2" class="data row6 col2" >4.2%</td>
#       <td id="T_d1f6b_row6_col3" class="data row6 col3" >23.6%</td>
#       <td id="T_d1f6b_row6_col4" class="data row6 col4" >35.1%</td>
#     </tr>
#     <tr>
#       <th id="T_d1f6b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d1f6b_row7_col0" class="data row7 col0" >0.0%</td>
#       <td id="T_d1f6b_row7_col1" class="data row7 col1" >46.3%</td>
#       <td id="T_d1f6b_row7_col2" class="data row7 col2" >3.1%</td>
#       <td id="T_d1f6b_row7_col3" class="data row7 col3" >20.4%</td>
#       <td id="T_d1f6b_row7_col4" class="data row7 col4" >30.1%</td>
#     </tr>
#     <tr>
#       <th id="T_d1f6b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d1f6b_row8_col0" class="data row8 col0" >0.0%</td>
#       <td id="T_d1f6b_row8_col1" class="data row8 col1" >44.2%</td>
#       <td id="T_d1f6b_row8_col2" class="data row8 col2" >2.8%</td>
#       <td id="T_d1f6b_row8_col3" class="data row8 col3" >12.6%</td>
#       <td id="T_d1f6b_row8_col4" class="data row8 col4" >40.4%</td>
#     </tr>
#     <tr>
#       <th id="T_d1f6b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d1f6b_row9_col0" class="data row9 col0" >0.1%</td>
#       <td id="T_d1f6b_row9_col1" class="data row9 col1" >40.8%</td>
#       <td id="T_d1f6b_row

# %%
# Gravity vs. Lighting Conditions (lum)
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='lum', hue='gravity')
plt.title('Gravity vs. Lighting Conditions')
plt.xlabel('Lighting Condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

# Gravity vs. Lighting Conditions (lum)
calculate_and_display_percentages(data, 'lum')
# Out:
# <style type="text/css">
# #T_3fdfe th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_3fdfe td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_3fdfe caption {
#   caption-side: top;
# }
# #T_3fdfe_row0_col0, #T_3fdfe_row0_col2 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_3fdfe_row0_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_3fdfe_row0_col3, #T_3fdfe_row1_col0, #T_3fdfe_row2_col0, #T_3fdfe_row3_col0, #T_3fdfe_row4_col0, #T_3fdfe_row5_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3fdfe_row0_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3fdfe_row1_col1 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_3fdfe_row1_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_3fdfe_row1_col3 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_3fdfe_row1_col4 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_3fdfe_row2_col1, #T_3fdfe_row5_col1 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_3fdfe_row2_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_3fdfe_row2_col3 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_3fdfe_row2_col4 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_3fdfe_row3_col1 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_3fdfe_row3_col2 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_3fdfe_row3_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_3fdfe_row3_col4 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_3fdfe_row4_col1 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_3fdfe_row4_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_3fdfe_row4_col3 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_3fdfe_row4_col4 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_3fdfe_row5_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_3fdfe_row5_col3 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_3fdfe_row5_col4 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3fdfe">
#   <caption>Percentages of Accident Gravity by Lum</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_3fdfe_level0_col0" class="col_heading level0 col0" > -1</th>
#       <th id="T_3fdfe_level0_col1" class="col_heading level0 col1" >1 - Unharmed</th>
#       <th id="T_3fdfe_level0_col2" class="col_heading level0 col2" >2 - Killed</th>
#       <th id="T_3fdfe_level0_col3" class="col_heading level0 col3" >3 - Hospitalized</th>
#       <th id="T_3fdfe_level0_col4" class="col_heading level0 col4" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >lum</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3fdfe_level0_row0" class="row_heading level0 row0" > -1</th>
#       <td id="T_3fdfe_row0_col0" class="data row0 col0" >7.1%</td>
#       <td id="T_3fdfe_row0_col1" class="data row0 col1" >28.6%</td>
#       <td id="T_3fdfe_row0_col2" class="data row0 col2" >7.1%</td>
#       <td id="T_3fdfe_row0_col3" class="data row0 col3" >0.0%</td>
#       <td id="T_3fdfe_row0_col4" class="data row0 col4" >57.1%</td>
#     </tr>
#     <tr>
#       <th id="T_3fdfe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3fdfe_row1_col0" class="data row1 col0" >0.1%</td>
#       <td id="T_3fdfe_row1_col1" class="data row1 col1" >46.4%</td>
#       <td id="T_3fdfe_row1_col2" class="data row1 col2" >1.8%</td>
#       <td id="T_3fdfe_row1_col3" class="data row1 col3" >12.9%</td>
#       <td id="T_3fdfe_row1_col4" class="data row1 col4" >38.9%</td>
#     </tr>
#     <tr>
#       <th id="T_3fdfe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3fdfe_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_3fdfe_row2_col1" class="data row2 col1" >44.3%</td>
#       <td id="T_3fdfe_row2_col2" class="data row2 col2" >2.5%</td>
#       <td id="T_3fdfe_row2_col3" class="data row2 col3" >14.9%</td>
#       <td id="T_3fdfe_row2_col4" class="data row2 col4" >38.3%</td>
#     </tr>
#     <tr>
#       <th id="T_3fdfe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3fdfe_row3_col0" class="data row3 col0" >0.0%</td>
#       <td id="T_3fdfe_row3_col1" class="data row3 col1" >40.7%</td>
#       <td id="T_3fdfe_row3_col2" class="data row3 col2" >5.1%</td>
#       <td id="T_3fdfe_row3_col3" class="data row3 col3" >18.1%</td>
#       <td id="T_3fdfe_row3_col4" class="data row3 col4" >36.1%</td>
#     </tr>
#     <tr>
#       <th id="T_3fdfe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3fdfe_row4_col0" class="data row4 col0" >0.1%</td>
#       <td id="T_3fdfe_row4_col1" class="data row4 col1" >44.0%</td>
#       <td id="T_3fdfe_row4_col2" class="data row4 col2" >3.2%</td>
#       <td id="T_3fdfe_row4_col3" class="data row4 col3" >12.6%</td>
#       <td id="T_3fdfe_row4_col4" class="data row4 col4" >40.1%</td>
#     </tr>
#     <tr>
#       <th id="T_3fdfe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3fdfe_row5_col0" class="data row5 col0" >0.1%</td>
#       <td id="T_3fdfe_row5_col1" class="data row5 col1" >44.3%</td>
#       <td id="T_3fdfe_row5_col2" class="data row5 col2" >1.3%</td>
#       <td id="T_3fdfe_row5_col3" class="data row5 col3" >10.6%</td>
#       <td id="T_3fdfe_row5_col4" class="data row5 col4" >43.6%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Gravity vs. Vehicle Category
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='vehicle_category', hue='gravity')
plt.title('Gravity vs. Vehicle Category')
plt.xlabel('Vehicle Category')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

# Gravity vs. Vehicle Category
calculate_and_display_percentages(data, 'vehicle_category')
# Out:
# <style type="text/css">
# #T_f29b2 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_f29b2 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_f29b2 caption {
#   caption-side: top;
# }
# #T_f29b2_row0_col0, #T_f29b2_row2_col0, #T_f29b2_row3_col0, #T_f29b2_row4_col0, #T_f29b2_row5_col0, #T_f29b2_row6_col0, #T_f29b2_row8_col0, #T_f29b2_row9_col0, #T_f29b2_row10_col0, #T_f29b2_row11_col0, #T_f29b2_row12_col0, #T_f29b2_row13_col0, #T_f29b2_row14_col0, #T_f29b2_row15_col0, #T_f29b2_row16_col0, #T_f29b2_row17_col0, #T_f29b2_row19_col0, #T_f29b2_row20_col0, #T_f29b2_row21_col0, #T_f29b2_row22_col0, #T_f29b2_row23_col0, #T_f29b2_row24_col0, #T_f29b2_row25_col0, #T_f29b2_row25_col2, #T_f29b2_row26_col0, #T_f29b2_row27_col0, #T_f29b2_row29_col0, #T_f29b2_row30_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f29b2_row0_col1, #T_f29b2_row12_col1, #T_f29b2_row30_col1 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_f29b2_row0_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_f29b2_row0_col3 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_f29b2_row0_col4 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_f29b2_row1_col0, #T_f29b2_row4_col2 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_f29b2_row1_col1 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_f29b2_row1_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_f29b2_row1_col3, #T_f29b2_row6_col3 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_f29b2_row1_col4, #T_f29b2_row9_col1 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_f29b2_row2_col1 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_f29b2_row2_col2, #T_f29b2_row3_col2, #T_f29b2_row14_col2, #T_f29b2_row29_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_f29b2_row2_col3 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_f29b2_row2_col4 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_f29b2_row3_col1 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_f29b2_row3_col3 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_f29b2_row3_col4 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_f29b2_row4_col1, #T_f29b2_row13_col4 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_f29b2_row4_col3, #T_f29b2_row31_col3 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_f29b2_row4_col4, #T_f29b2_row10_col4 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_f29b2_row5_col1 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_f29b2_row5_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_f29b2_row5_col3 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_f29b2_row5_col4 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_f29b2_row6_col1 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_f29b2_row6_col2, #T_f29b2_row19_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_f29b2_row6_col4 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_f29b2_row7_col0, #T_f29b2_row28_col0, #T_f29b2_row28_col2, #T_f29b2_row31_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_f29b2_row7_col1, #T_f29b2_row10_col1 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_f29b2_row7_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_f29b2_row7_col3, #T_f29b2_row22_col4 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_f29b2_row7_col4 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_f29b2_row8_col1 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_f29b2_row8_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_f29b2_row8_col3 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_f29b2_row8_col4 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_f29b2_row9_col2, #T_f29b2_row17_col2, #T_f29b2_row20_col2 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_f29b2_row9_col3 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_f29b2_row9_col4 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_f29b2_row10_col2, #T_f29b2_row16_col2 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_f29b2_row10_col3 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_f29b2_row11_col1 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_f29b2_row11_col2, #T_f29b2_row20_col3, #T_f29b2_row27_col3 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_f29b2_row11_col3 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_f29b2_row11_col4 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_f29b2_row12_col2, #T_f29b2_row23_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_f29b2_row12_col3, #T_f29b2_row29_col3 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_f29b2_row12_col4 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_f29b2_row13_col1 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_f29b2_row13_col2 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_f29b2_row13_col3 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_f29b2_row14_col1, #T_f29b2_row15_col4, #T_f29b2_row17_col1, #T_f29b2_row25_col4 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_f29b2_row14_col3 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_f29b2_row14_col4 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_f29b2_row15_col1, #T_f29b2_row20_col4, #T_f29b2_row23_col4 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_f29b2_row15_col2, #T_f29b2_row18_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_f29b2_row15_col3 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_f29b2_row16_col1 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_f29b2_row16_col3 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_f29b2_row16_col4 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_f29b2_row17_col3 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_f29b2_row17_col4 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_f29b2_row18_col1, #T_f29b2_row18_col4 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_f29b2_row18_col2 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_f29b2_row18_col3 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_f29b2_row19_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_f29b2_row19_col3 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_f29b2_row19_col4 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_f29b2_row20_col1, #T_f29b2_row26_col1 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_f29b2_row21_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f29b2_row21_col2, #T_f29b2_row30_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_f29b2_row21_col3, #T_f29b2_row28_col3 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_f29b2_row21_col4 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_f29b2_row22_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_f29b2_row22_col2 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_f29b2_row22_col3 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_f29b2_row23_col1, #T_f29b2_row29_col1 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_f29b2_row23_col3 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_f29b2_row24_col1, #T_f29b2_row24_col4 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_f29b2_row24_col2, #T_f29b2_row27_col2 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_f29b2_row24_col3 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_f29b2_row25_col1 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_f29b2_row25_col3 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_f29b2_row26_col2, #T_f29b2_row31_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_f29b2_row26_col3 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_f29b2_row26_col4 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_f29b2_row27_col1 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_f29b2_row27_col4 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_f29b2_row28_col1, #T_f29b2_row31_col1 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_f29b2_row28_col4 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_f29b2_row29_col4 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T

# %%
# Gravity vs. Gender
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='gender', hue='gravity')
plt.title('Gravity vs. Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.show()

# Gravity vs. Gender
calculate_and_display_percentages(data, 'gender')
# Out:
# <style type="text/css">
# #T_f9796 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_f9796 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_f9796 caption {
#   caption-side: top;
# }
# #T_f9796_row0_col0 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_f9796_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f9796_row0_col2, #T_f9796_row0_col3, #T_f9796_row0_col4, #T_f9796_row1_col0, #T_f9796_row2_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f9796_row1_col1 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_f9796_row1_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_f9796_row1_col3 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_f9796_row1_col4 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_f9796_row2_col1 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_f9796_row2_col2 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_f9796_row2_col3 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_f9796_row2_col4 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f9796">
#   <caption>Percentages of Accident Gravity by Gender</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_f9796_level0_col0" class="col_heading level0 col0" > -1</th>
#       <th id="T_f9796_level0_col1" class="col_heading level0 col1" >1 - Unharmed</th>
#       <th id="T_f9796_level0_col2" class="col_heading level0 col2" >2 - Killed</th>
#       <th id="T_f9796_level0_col3" class="col_heading level0 col3" >3 - Hospitalized</th>
#       <th id="T_f9796_level0_col4" class="col_heading level0 col4" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9796_level0_row0" class="row_heading level0 row0" > -1</th>
#       <td id="T_f9796_row0_col0" class="data row0 col0" >5.3%</td>
#       <td id="T_f9796_row0_col1" class="data row0 col1" >94.7%</td>
#       <td id="T_f9796_row0_col2" class="data row0 col2" >0.0%</td>
#       <td id="T_f9796_row0_col3" class="data row0 col3" >0.0%</td>
#       <td id="T_f9796_row0_col4" class="data row0 col4" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_f9796_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f9796_row1_col0" class="data row1 col0" >0.0%</td>
#       <td id="T_f9796_row1_col1" class="data row1 col1" >47.0%</td>
#       <td id="T_f9796_row1_col2" class="data row1 col2" >2.5%</td>
#       <td id="T_f9796_row1_col3" class="data row1 col3" >14.0%</td>
#       <td id="T_f9796_row1_col4" class="data row1 col4" >36.6%</td>
#     </tr>
#     <tr>
#       <th id="T_f9796_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f9796_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_f9796_row2_col1" class="data row2 col1" >40.0%</td>
#       <td id="T_f9796_row2_col2" class="data row2 col2" >1.5%</td>
#       <td id="T_f9796_row2_col3" class="data row2 col3" >12.0%</td>
#       <td id="T_f9796_row2_col4" class="data row2 col4" >46.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Gravity vs. Surface Condition
plt.figure(figsize=(18,12))
sns.countplot(data=data, x='surface_condition', hue='gravity')
plt.title('Gravity vs. Surface Condition')
plt.xlabel('Surface Condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

# Gravity vs. Surface Condition
calculate_and_display_percentages(data, 'surface_condition')
# Out:
# <style type="text/css">
# #T_7df40 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_7df40 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_7df40 caption {
#   caption-side: top;
# }
# #T_7df40_row0_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_7df40_row0_col1 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_7df40_row0_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_7df40_row0_col3 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_7df40_row0_col4, #T_7df40_row1_col4 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_7df40_row1_col0, #T_7df40_row2_col0, #T_7df40_row3_col0, #T_7df40_row4_col0, #T_7df40_row6_col0, #T_7df40_row7_col0, #T_7df40_row8_col0, #T_7df40_row9_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7df40_row1_col1 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_7df40_row1_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_7df40_row1_col3 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_7df40_row2_col1 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_7df40_row2_col2, #T_7df40_row3_col2, #T_7df40_row5_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_7df40_row2_col3 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_7df40_row2_col4 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_7df40_row3_col1, #T_7df40_row4_col1 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_7df40_row3_col3 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_7df40_row3_col4, #T_7df40_row4_col4 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_7df40_row4_col2 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_7df40_row4_col3 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_7df40_row5_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_7df40_row5_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7df40_row5_col3 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_7df40_row5_col4 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_7df40_row6_col1 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_7df40_row6_col2 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_7df40_row6_col3 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_7df40_row6_col4 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_7df40_row7_col1 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_7df40_row7_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_7df40_row7_col3 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_7df40_row7_col4 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_7df40_row8_col1 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_7df40_row8_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_7df40_row8_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_7df40_row8_col4 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_7df40_row9_col1 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_7df40_row9_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_7df40_row9_col3 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_7df40_row9_col4 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7df40">
#   <caption>Percentages of Accident Gravity by Surface_condition</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_7df40_level0_col0" class="col_heading level0 col0" > -1</th>
#       <th id="T_7df40_level0_col1" class="col_heading level0 col1" >1 - Unharmed</th>
#       <th id="T_7df40_level0_col2" class="col_heading level0 col2" >2 - Killed</th>
#       <th id="T_7df40_level0_col3" class="col_heading level0 col3" >3 - Hospitalized</th>
#       <th id="T_7df40_level0_col4" class="col_heading level0 col4" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >surface_condition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7df40_level0_row0" class="row_heading level0 row0" > -1</th>
#       <td id="T_7df40_row0_col0" class="data row0 col0" >0.6%</td>
#       <td id="T_7df40_row0_col1" class="data row0 col1" >40.8%</td>
#       <td id="T_7df40_row0_col2" class="data row0 col2" >5.2%</td>
#       <td id="T_7df40_row0_col3" class="data row0 col3" >14.4%</td>
#       <td id="T_7df40_row0_col4" class="data row0 col4" >39.1%</td>
#     </tr>
#     <tr>
#       <th id="T_7df40_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7df40_row1_col0" class="data row1 col0" >0.1%</td>
#       <td id="T_7df40_row1_col1" class="data row1 col1" >45.5%</td>
#       <td id="T_7df40_row1_col2" class="data row1 col2" >2.1%</td>
#       <td id="T_7df40_row1_col3" class="data row1 col3" >13.4%</td>
#       <td id="T_7df40_row1_col4" class="data row1 col4" >38.9%</td>
#     </tr>
#     <tr>
#       <th id="T_7df40_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7df40_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_7df40_row2_col1" class="data row2 col1" >44.6%</td>
#       <td id="T_7df40_row2_col2" class="data row2 col2" >2.3%</td>
#       <td id="T_7df40_row2_col3" class="data row2 col3" >11.9%</td>
#       <td id="T_7df40_row2_col4" class="data row2 col4" >41.2%</td>
#     </tr>
#     <tr>
#       <th id="T_7df40_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7df40_row3_col0" class="data row3 col0" >0.0%</td>
#       <td id="T_7df40_row3_col1" class="data row3 col1" >43.4%</td>
#       <td id="T_7df40_row3_col2" class="data row3 col2" >2.4%</td>
#       <td id="T_7df40_row3_col3" class="data row3 col3" >16.5%</td>
#       <td id="T_7df40_row3_col4" class="data row3 col4" >37.7%</td>
#     </tr>
#     <tr>
#       <th id="T_7df40_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7df40_row4_col0" class="data row4 col0" >0.0%</td>
#       <td id="T_7df40_row4_col1" class="data row4 col1" >43.5%</td>
#       <td id="T_7df40_row4_col2" class="data row4 col2" >3.0%</td>
#       <td id="T_7df40_row4_col3" class="data row4 col3" >15.9%</td>
#       <td id="T_7df40_row4_col4" class="data row4 col4" >37.6%</td>
#     </tr>
#     <tr>
#       <th id="T_7df40_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7df40_row5_col0" class="data row5 col0" >0.2%</td>
#       <td id="T_7df40_row5_col1" class="data row5 col1" >50.8%</td>
#       <td id="T_7df40_row5_col2" class="data row5 col2" >2.6%</td>
#       <td id="T_7df40_row5_col3" class="data row5 col3" >12.9%</td>
#       <td id="T_7df40_row5_col4" class="data row5 col4" >33.5%</td>
#     </tr>
#     <tr>
#       <th id="T_7df40_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7df40_row6_col0" class="data row6 col0" >0.0%</td>
#       <td id="T_7df40_row6_col1" class="data row6 col1" >28.8%</td>
#       <td id="T_7df40_row6_col2" class="data row6 col2" >6.8%</td>
#       <td id="T_7df40_row6_col3" class="data row6 col3" >32.5%</td>
#       <td id="T_7df40_row6_col4" class="data row6 col4" >31.9%</td>
#     </tr>
#     <tr>
#       <th id="T_7df40_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7df40_row7_col0" class="data row7 col0" >0.1%</td>
#       <td id="T_7df40_row7_col1" class="data row7 col1" >48.8%</td>
#       <td id="T_7df40_row7_col2" class="data row7 col2" >3.9%</td>
#       <td id="T_7df40_row7_col3" class="data row7 col3" >16.7%</td>
#       <td id="T_7df40_row7_col4" class="data row7 col4" >30.5%</td>
#     </tr>
#     <tr>
#       <th id="T_7df40_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7df40_row8_col0" class="data row8 col0" >0.0%</td>
#       <td id="T_7df40_row8_col1" class="data row8 col1" >39.7%</td>
#       <td id="T_7df40_row8_col2" class="data row8 col2" >1.3%</td>
#       <td id="T_7df40_row8_col3" class="data row8 col3" >17.4%</td>
#       <td id="T_7df40_row8_col4" class="data row8 col4" >41.6%</td>
#     </tr>
#     <tr>
#       <th id="T_7df40_level0_row9" class="row_heading level0 row9" >9</th>

# %%
# Define the bins and corresponding labels
bins = [0, 49, 59, 69, 79, 89, 99, 109, 119, 129, 139, 149, float('inf')]
labels = ['0-49', '50-59', '60-69', '70-79', '80-89', '90-99', '100-109', '110-119', '120-129', '130-139', '140-149', '+150']

# Create a new column for the binned speeds
data['speed_group'] = pd.cut(data['maximum_speed'], bins=bins, labels=labels, right=False)

# Gravity vs. Maximum Speed
plt.figure(figsize=(10, 6))
#sns.scatterplot(data=data, x='speed_group', y='gravity', hue='gravity', palette='viridis')
sns.countplot(data=data, x='speed_group', hue='gravity')

plt.title('Gravity vs. Maximum Speed')
plt.xlabel('Maximum Speed Group')
plt.ylabel('Gravity')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

# Gravity vs. Maximum Speed
calculate_and_display_percentages(data, 'speed_group')
# Out:
# C:\Users\sd10725\AppData\Local\Temp\ipykernel_18992\2009690530.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   counts = data.groupby([group_by_col, 'gravity']).size().reset_index(name='count')
# <style type="text/css">
# #T_0dfb7 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_0dfb7 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_0dfb7 caption {
#   caption-side: top;
# }
# #T_0dfb7_row0_col0, #T_0dfb7_row1_col0, #T_0dfb7_row2_col0, #T_0dfb7_row3_col0, #T_0dfb7_row4_col0, #T_0dfb7_row5_col0, #T_0dfb7_row6_col0, #T_0dfb7_row7_col0, #T_0dfb7_row8_col0, #T_0dfb7_row8_col2, #T_0dfb7_row8_col3, #T_0dfb7_row9_col0, #T_0dfb7_row10_col0, #T_0dfb7_row10_col3, #T_0dfb7_row10_col4, #T_0dfb7_row11_col0, #T_0dfb7_row11_col1, #T_0dfb7_row11_col2, #T_0dfb7_row11_col3, #T_0dfb7_row11_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0dfb7_row0_col1 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_0dfb7_row0_col2 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_0dfb7_row0_col3, #T_0dfb7_row5_col3 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_0dfb7_row0_col4 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_0dfb7_row1_col1, #T_0dfb7_row3_col1 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_0dfb7_row1_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_0dfb7_row1_col3 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_0dfb7_row1_col4 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_0dfb7_row2_col1 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_0dfb7_row2_col2 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_0dfb7_row2_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_0dfb7_row2_col4 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_0dfb7_row3_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_0dfb7_row3_col3 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_0dfb7_row3_col4 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_0dfb7_row4_col1 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_0dfb7_row4_col2 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_0dfb7_row4_col3 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_0dfb7_row4_col4, #T_0dfb7_row9_col4 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_0dfb7_row5_col1 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_0dfb7_row5_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_0dfb7_row5_col4 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_0dfb7_row6_col1 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_0dfb7_row6_col2 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_0dfb7_row6_col3 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_0dfb7_row6_col4 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_0dfb7_row7_col1 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_0dfb7_row7_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_0dfb7_row7_col3 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_0dfb7_row7_col4 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_0dfb7_row8_col1, #T_0dfb7_row8_col4, #T_0dfb7_row10_col1, #T_0dfb7_row10_col2 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_0dfb7_row9_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0dfb7_row9_col2 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_0dfb7_row9_col3 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# </style>
# <table id="T_0dfb7">
#   <caption>Percentages of Accident Gravity by Speed_group</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_0dfb7_level0_col0" class="col_heading level0 col0" > -1</th>
#       <th id="T_0dfb7_level0_col1" class="col_heading level0 col1" >1 - Unharmed</th>
#       <th id="T_0dfb7_level0_col2" class="col_heading level0 col2" >2 - Killed</th>
#       <th id="T_0dfb7_level0_col3" class="col_heading level0 col3" >3 - Hospitalized</th>
#       <th id="T_0dfb7_level0_col4" class="col_heading level0 col4" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >speed_group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0dfb7_level0_row0" class="row_heading level0 row0" >0-49</th>
#       <td id="T_0dfb7_row0_col0" class="data row0 col0" >0.1%</td>
#       <td id="T_0dfb7_row0_col1" class="data row0 col1" >46.7%</td>
#       <td id="T_0dfb7_row0_col2" class="data row0 col2" >1.0%</td>
#       <td id="T_0dfb7_row0_col3" class="data row0 col3" >8.7%</td>
#       <td id="T_0dfb7_row0_col4" class="data row0 col4" >43.6%</td>
#     </tr>
#     <tr>
#       <th id="T_0dfb7_level0_row1" class="row_heading level0 row1" >50-59</th>
#       <td id="T_0dfb7_row1_col0" class="data row1 col0" >0.1%</td>
#       <td id="T_0dfb7_row1_col1" class="data row1 col1" >46.0%</td>
#       <td id="T_0dfb7_row1_col2" class="data row1 col2" >1.1%</td>
#       <td id="T_0dfb7_row1_col3" class="data row1 col3" >10.9%</td>
#       <td id="T_0dfb7_row1_col4" class="data row1 col4" >41.9%</td>
#     </tr>
#     <tr>
#       <th id="T_0dfb7_level0_row2" class="row_heading level0 row2" >60-69</th>
#       <td id="T_0dfb7_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_0dfb7_row2_col1" class="data row2 col1" >41.5%</td>
#       <td id="T_0dfb7_row2_col2" class="data row2 col2" >4.9%</td>
#       <td id="T_0dfb7_row2_col3" class="data row2 col3" >17.2%</td>
#       <td id="T_0dfb7_row2_col4" class="data row2 col4" >36.5%</td>
#     </tr>
#     <tr>
#       <th id="T_0dfb7_level0_row3" class="row_heading level0 row3" >70-79</th>
#       <td id="T_0dfb7_row3_col0" class="data row3 col0" >0.0%</td>
#       <td id="T_0dfb7_row3_col1" class="data row3 col1" >46.2%</td>
#       <td id="T_0dfb7_row3_col2" class="data row3 col2" >2.5%</td>
#       <td id="T_0dfb7_row3_col3" class="data row3 col3" >12.8%</td>
#       <td id="T_0dfb7_row3_col4" class="data row3 col4" >38.4%</td>
#     </tr>
#     <tr>
#       <th id="T_0dfb7_level0_row4" class="row_heading level0 row4" >80-89</th>
#       <td id="T_0dfb7_row4_col0" class="data row4 col0" >0.0%</td>
#       <td id="T_0dfb7_row4_col1" class="data row4 col1" >36.0%</td>
#       <td id="T_0dfb7_row4_col2" class="data row4 col2" >6.0%</td>
#       <td id="T_0dfb7_row4_col3" class="data row4 col3" >28.3%</td>
#       <td id="T_0dfb7_row4_col4" class="data row4 col4" >29.7%</td>
#     </tr>
#     <tr>
#       <th id="T_0dfb7_level0_row5" class="row_heading level0 row5" >90-99</th>
#       <td id="T_0dfb7_row5_col0" class="data row5 col0" >0.0%</td>
#       <td id="T_0dfb7_row5_col1" class="data row5 col1" >48.3%</td>
#       <td id="T_0dfb7_row5_col2" class="data row5 col2" >1.9%</td>
#       <td id="T_0dfb7_row5_col3" class="data row5 col3" >8.8%</td>
#       <td id="T_0dfb7_row5_col4" class="data row5 col4" >41.0%</td>
#     </tr>
#     <tr>
#       <th id="T_0dfb7_level0_row6" class="row_heading level0 row6" >100-109</th>
#       <td id="T_0dfb7_row6_col0" class="data row6 col0" >0.0%</td>
#       <td id="T_0dfb7_row6_col1" class="data row6 col1" >37.3%</td>
#       <td id="T_0dfb7_row6_col2" class="data row6 col2" >1.5%</td>
#       <td id="T_0dfb7_row6_col3" class="data row6 col3" >18.7%</td>
#       <td id="T_0dfb7_row6_col4" class="data row6 col4" >42.5%</td>
#     </tr>
#     <tr>
#       <th id="T_0dfb7_level0_row7" class="row_heading level0 row7" >110-119</th>
#       <td id="T_0dfb7_row7_col0" class="data row7 col0" >0.0%</td>
#       <td id="T_0dfb7_row7_col1" class="data row7 col1" >50.7%</td>
#       <td id="T_0dfb7_row7_col2" class="data row7 col2" >2.0%</td>
#       <td id="T_0dfb7_row7_col3" class="data row7 col3" >7.7%</td>
#       <td id="T_0dfb7_row7_col4" class="data row7 col4" >39.6%</td>
#     </tr>
#     <tr>
#       <th id="T_0dfb7_level0_row8" class="row_heading level0 row8" >120-129</th>
#       <td id="T_0dfb7_row8_col0" class="data row8 col0" >0.0%</td>
#       <td id="T_0dfb7_row8_col1" class="data row8 col1" >50.0%</td>
#       <td id="T_0dfb7_row8_col2" class="data row8 col2" >0.0%</td>
#       <td id="T_0dfb7_row8_col3" class="data row8 col3" >0.0%</td>
#       <td id="T_0dfb7_row8_col4" class="data row8 col4" >50.0%</td>
#     </tr>

# %%
# Out:
# 498

# %%
# Out:
# 286
