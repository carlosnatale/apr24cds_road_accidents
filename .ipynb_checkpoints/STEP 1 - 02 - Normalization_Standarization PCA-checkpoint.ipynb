# %%
# Import libraries needed to execute the code
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# To avoid warning messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Import the clean data
data = pd.read_csv('source/data.csv', low_memory=False)

# %%
data.drop('vehicleID', axis=1, inplace=True)
data.drop('num_veh', axis=1, inplace=True)
data.drop('AccID', axis=1, inplace=True)

# %%
# Insert your code here
plt.figure(figsize=(20, 20))
sns.heatmap(data.corr(), annot=True, cmap='viridis');

# %%
# Target variable: 'gravity'
target = data['gravity']

# Deletion of 'diagnosis'
data.drop('gravity', axis=1, inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
Z = sc.fit_transform(data)
Z
# Out:
# array([[ 1.635754  ,  1.27308923, -1.31856076, ..., -1.17778001,
#         -0.42596313, -1.14151193],
#        [ 1.635754  ,  1.27308923, -1.31856076, ...,  0.6570552 ,
#         -0.42596313, -0.66382879],
#        [ 1.635754  ,  1.27308923, -1.31856076, ..., -1.17778001,
#         -0.42596313,  1.14075195],
#        ...,
#        [-1.67843418, -1.70626763,  1.31357483, ...,  0.6570552 ,
#         -0.42596313,  1.61843509],
#        [-1.67843418, -1.11039626,  1.31357483, ..., -0.81081297,
#          0.00495926, -0.45152517],
#        [-1.67843418, -1.11039626,  1.31357483, ..., -1.17778001,
#         -0.42596313, -0.87613241]])

# %%
from sklearn.decomposition import PCA

pca = PCA()

# Contains the coordinates of the ACP on the lines.
Coord = pca.fit_transform(Z)

# %%
print('Explained variance ratio :', pca.explained_variance_)

# plt.figure(figsize=(10, 10))
plt.plot(range(0, 35), pca.explained_variance_)
plt.xlabel('Factor number')
plt.ylabel('Eigenvalues');
# Out:
# Explained variance ratio : [2.53432719 2.16561468 2.0164646  1.73255604 1.46504577 1.28708551
#  1.21715926 1.17784008 1.14644828 1.10357607 1.06396241 1.04078682
#  1.01358488 1.00090701 0.99480286 0.98218586 0.97225856 0.94495765
#  0.9279143  0.91006011 0.88812516 0.85307087 0.84008966 0.79430583
#  0.78134096 0.76065977 0.7333238  0.72191456 0.69429127 0.63500897
#  0.54742983 0.52389516 0.42174152 0.09510102 0.01224185]

# %%
print('Ratios are :', pca.explained_variance_ratio_)


# Cumulative sum of explained variance plot
plt.plot(np.arange(1, 36), np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Factor number')
plt.ylabel('Cumsum');
# Out:
# Ratios are : [0.07240919 0.06187457 0.05761315 0.04950149 0.04185836 0.03677379
#  0.0347759  0.0336525  0.03275559 0.03153067 0.03039886 0.0297367
#  0.0289595  0.02859728 0.02842288 0.02806239 0.02777875 0.02699873
#  0.02651178 0.02600166 0.02537495 0.0243734  0.02400251 0.0226944
#  0.02232398 0.02173309 0.02095206 0.02062608 0.01983685 0.01814307
#  0.01564082 0.0149684  0.01204973 0.00271717 0.00034977]

# %%
# Pie chart of the distribution of the explained variance ratio by each axis.
L1 = list(pca.explained_variance_ratio_[0:6])
L1.append(sum(pca.explained_variance_ratio_[6:31]))

plt.pie(L1, labels=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'Others'], 
        autopct='%1.3f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1c53d391990>,
#   <matplotlib.patches.Wedge at 0x1c53bcbf910>,
#   <matplotlib.patches.Wedge at 0x1c53bcace90>,
#   <matplotlib.patches.Wedge at 0x1c53e6ea3d0>,
#   <matplotlib.patches.Wedge at 0x1c53cfe39d0>,
#   <matplotlib.patches.Wedge at 0x1c53d6c1650>,
#   <matplotlib.patches.Wedge at 0x1c53d392950>],
#  [Text(1.0698844470709894, 0.25563112078853656, 'PC1'),
#   Text(0.8625544146736224, 0.6826418400061961, 'PC2'),
#   Text(0.5411030605472721, 0.9577094955498642, 'PC3'),
#   Text(0.18321155528538557, 1.0846352041169927, 'PC4'),
#   Text(-0.1410511488209606, 1.0909191415573785, 'PC5'),
#   Text(-0.4113557993246272, 1.0201893972993432, 'PC6'),
#   Text(-0.5600724119514762, -0.9467411966165074, 'Others')],
#  [Text(0.5835733347659942, 0.1394351567937472, '7.466%'),
#   Text(0.47048422618561214, 0.37235009454883417, '6.379%'),
#   Text(0.2951471239348757, 0.5223869975726532, '5.940%'),
#   Text(0.0999335756102103, 0.5916192022456322, '5.104%'),
#   Text(-0.07693699026597849, 0.5950468044858427, '4.316%'),
#   Text(-0.2243758905407057, 0.5564669439814599, '3.791%'),
#   Text(-0.30549404288262333, -0.5164042890635494, '67.004%')])

# %%
Comp_PCA = pd.DataFrame({'PC1': pca.components_[:, 0], 'PC2': pca.components_[:, 1]})

plt.figure(figsize=(20, 20))

sns.heatmap(Comp_PCA, annot=True, cmap='viridis');

# %%
racine_valeurs_propres = np.sqrt(pca.explained_variance_)
corvar = np.zeros((35, 35))
for k in range(35):
    corvar[:, k] = pca.components_[:, k] * racine_valeurs_propres[k]

# Define the figure
fig, axes = plt.subplots(figsize=(10, 10))
axes.set_xlim(-1, 1)
axes.set_ylim(-1, 1)

# Display variables
for j in range(30):
    plt.annotate(data.columns[j], (corvar[j, 0], corvar[j, 1]), color='#091158')
    plt.arrow(0, 0, corvar[j, 0]*0.6, corvar[j, 1]*0.6, alpha=0.5, head_width=0.03, color='b')

# Add axes
plt.plot([-1, 1], [0, 0], color='silver', linestyle='-', linewidth=1)
plt.plot([0, 0], [-1, 1], color='silver', linestyle='-', linewidth=1)

# Circle and legends
cercle = plt.Circle((0, 0), 1, color='#16E4CA', fill=False)
axes.add_artist(cercle)
plt.xlabel('AXE 1')
plt.ylabel('AXE 2');

# %%
PCA_mat = pd.DataFrame({'AXE 1': Coord[:, 0], 'AXE 2': Coord[:, 1], 'target': target})
plt.figure(figsize=(10, 10))

sns.scatterplot(x='AXE 1', y='AXE 2', hue=target, data=PCA_mat);
