# %%
# Import libraries needed to execute the code
import os
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import scipy.cluster.hierarchy as shc
from sklearn.decomposition import PCA
from IPython.display import display, HTML
from scipy.cluster.hierarchy import dendrogram, linkage
from pandas.plotting import andrews_curves, parallel_coordinates, lag_plot, autocorrelation_plot, radviz

# %%
# Import the clean data
data = pd.read_csv('source/data.csv')

# %%
# List of columns to convert to object type
columns_to_convert = [
    'AccID', 'accident_situation', 'atm_condition', 'collision_type', 'com_code', 'dep_code', 
    'fixed_obstacle', 'gender', 'gravity', 'infra', 'initial_impact_point', 'int', 'location', 
    'longitudinal_profile', 'lum', 'manv', 'mobile_obstacle', 'motor', 'num_veh_x', 'num_veh_y',
    'pedestrian_action', 'pedestrian_location', 'plan', 'reason_travel', 'reserved_lane_code', 
    'route_category', 'safety_equipment1', 'safety_equipment2', 'safety_equipment3', 'seat', 
    'surface_condition', 'time', 'traffic_direction', 'traffic_regime', 'upstream_terminal_number', 
    'user_category', 'vehicle_category', 'vehicleID_x', 'vehicleID_y'
]

# Convert specified columns to object type
data[columns_to_convert] = data[columns_to_convert].astype('object')

# Convert 'time' field to proper time format in the 'data' dataframe
data['time'] = pd.to_datetime(data['time'], format='%H:%M:%S').dt.time

# %% [markdown]
# <font size="6">
#     Exploratory analysis
# </font>

# %%
# Basic Statistics about data
data.describe()
# Out:
#                  day          month           year            lat  \
# count  882583.000000  882583.000000  882583.000000  882583.000000
# mean       15.661863       6.737335    2020.496611      44.323137
# std         8.743861       3.356068       1.139034      12.217143
# min         1.000000       1.000000    2019.000000     -61.425660
# 25%         8.000000       4.000000    2019.000000      44.582586
# 50%        16.000000       7.000000    2021.000000      47.871709
# 75%        23.000000      10.000000    2022.000000      48.858557
# max        31.000000      12.000000    2022.000000      63.568066
#
#                 long  total_number_lanes  maximum_speed     birth_year  \
# count  882583.000000       882581.000000  882583.000000  882583.000000
# mean        2.502246            2.556675      61.867994    1982.281042
# std        19.234755            1.498044      20.864863      18.118216
# min      -178.158090           -1.000000       6.000000    1931.000000
# 25%         1.434420            2.000000      50.000000    1970.000000
# 50%         2.402060            2.000000      50.000000    1985.000000
# 75%         4.837080            3.000000      80.000000    1997.000000
# max       174.023438           12.000000     120.000000    2022.000000
#
#        pedestrian_involved            age
# count        882583.000000  882583.000000
# mean             -0.901336      41.718958
# std               0.477423      18.118216
# min              -1.000000       2.000000
# 25%              -1.000000      27.000000
# 50%              -1.000000      39.000000
# 75%              -1.000000      54.000000
# max               3.000000      93.000000

# %%
# Basic info about data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 882583 entries, 0 to 882582
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   AccID                     882583 non-null  object
#  1   day                       882583 non-null  int64
#  2   month                     882583 non-null  int64
#  3   year                      882583 non-null  int64
#  4   time                      882583 non-null  object
#  5   lum                       882583 non-null  object
#  6   dep_code                  882583 non-null  object
#  7   com_code                  882583 non-null  object
#  8   location                  882583 non-null  object
#  9   int                       882583 non-null  object
#  10  atm_condition             882583 non-null  object
#  11  collision_type            882583 non-null  object
#  12  lat                       882583 non-null  float64
#  13  long                      882583 non-null  float64
#  14  route_category            882583 non-null  object
#  15  traffic_regime            882583 non-null  object
#  16  total_number_lanes        882581 non-null  float64
#  17  reserved_lane_code        882583 non-null  object
#  18  longitudinal_profile      882583 non-null  object
#  19  upstream_terminal_number  882583 non-null  object
#  20  plan                      882583 non-null  object
#  21  surface_condition         882583 non-null  object
#  22  infra                     882583 non-null  object
#  23  accident_situation        882583 non-null  object
#  24  maximum_speed             882583 non-null  int64
#  25  vehicleID_x               882583 non-null  object
#  26  num_veh_x                 882583 non-null  object
#  27  seat                      882583 non-null  object
#  28  user_category             882583 non-null  object
#  29  gravity                   882583 non-null  object
#  30  gender                    882583 non-null  object
#  31  birth_year                882583 non-null  int64
#  32  reason_travel             882583 non-null  object
#  33  safety_equipment1         882583 non-null  object
#  34  safety_equipment2         882583 non-null  object
#  35  safety_equipment3         882583 non-null  object
#  36  pedestrian_location       882583 non-null  object
#  37  pedestrian_action         882583 non-null  object
#  38  pedestrian_involved       882583 non-null  int64
#  39  age                       882583 non-null  int64
#  40  vehicleID_y               882583 non-null  object
#  41  num_veh_y                 882583 non-null  object
#  42  traffic_direction         882583 non-null  object
#  43  vehicle_category          882583 non-null  object
#  44  fixed_obstacle            882583 non-null  object
#  45  mobile_obstacle           882583 non-null  object
#  46  initial_impact_point      882583 non-null  object
#  47  manv                      882583 non-null  object
#  48  motor                     882583 non-null  object
# dtypes: float64(3), int64(7), object(39)
# memory usage: 329.9+ MB

# %%
# Counting duplicates
duplicate_count = data.duplicated().sum()
duplicate_count
# Out:
# 0

# %%
# Counting NaN values in each column
nan_count_per_column = data.isna().sum()
nan_count_per_column
# Out:
# AccID                       0
# day                         0
# month                       0
# year                        0
# time                        0
# lum                         0
# dep_code                    0
# com_code                    0
# location                    0
# int                         0
# atm_condition               0
# collision_type              0
# lat                         0
# long                        0
# route_category              0
# traffic_regime              0
# total_number_lanes          2
# reserved_lane_code          0
# longitudinal_profile        0
# upstream_terminal_number    0
# plan                        0
# surface_condition           0
# infra                       0
# accident_situation          0
# maximum_speed               0
# vehicleID_x                 0
# num_veh_x                   0
# seat                        0
# user_category               0
# gravity                     0
# gender                      0
# birth_year                  0
# reason_travel               0
# safety_equipment1           0
# safety_equipment2           0
# safety_equipment3           0
# pedestrian_location         0
# pedestrian_action           0
# pedestrian_involved         0
# age                         0
# vehicleID_y                 0
# num_veh_y                   0
# traffic_direction           0
# vehicle_category            0
# fixed_obstacle              0
# mobile_obstacle             0
# initial_impact_point        0
# manv                        0
# motor                       0
# dtype: int64

# %%
# Counting total NaN values in the DataFrame
total_nan_count = data.isna().sum().sum()
total_nan_count
# Out:
# 2

# %%
# Visualize 10 first rows
data.head(10)
# Out:
#           AccID  day  month  year      time lum dep_code com_code location  \
# 0  201900000001   30     11  2019  01:30:00   4       93    93053        1
# 1  201900000001   30     11  2019  01:30:00   4       93    93053        1
# 2  201900000001   30     11  2019  01:30:00   4       93    93053        1
# 3  201900000001   30     11  2019  01:30:00   4       93    93053        1
# 4  201900000001   30     11  2019  01:30:00   4       93    93053        1
# 5  201900000001   30     11  2019  01:30:00   4       93    93053        1
# 6  201900000002   30     11  2019  02:50:00   3       93    93066        1
# 7  201900000003   28     11  2019  15:15:00   1       92    92036        1
# 8  201900000003   28     11  2019  15:15:00   1       92    92036        1
# 9  201900000003   28     11  2019  15:15:00   1       92    92036        1
#
#   int  ... age  vehicleID_y  num_veh_y  traffic_direction vehicle_category  \
# 0   1  ...  22  138 306 524        B01                  2                7
# 1   1  ...  22  138 306 525        A01                  2               17
# 2   1  ...  31  138 306 524        B01                  2                7
# 3   1  ...  31  138 306 525        A01                  2               17
# 4   1  ...  65  138 306 524        B01                  2                7
# 5   1  ...  65  138 306 525        A01                  2               17
# 6   1  ...  30  138 306 523        A01                  1                7
# 7   1  ...  28  138 306 520        A01                  1                7
# 8   1  ...  28  138 306 521        B01                  1                7
# 9   1  ...  28  138 306 522        C01                  1                7
#
#   fixed_obstacle  mobile_obstacle initial_impact_point manv motor
# 0              0                2                    5   23     1
# 1              1                0                    3   11     1
# 2              0                2                    5   23     1
# 3              1                0                    3   11     1
# 4              0                2                    5   23     1
# 5              1                0                    3   11     1
# 6              4                0                    1    0     1
# 7              0                2                    1    2     1
# 8              1                0                    4    2     1
# 9              0                2                    4   23     6
#
# [10 rows x 49 columns]

# %% [markdown]
# <font size="6">
#     Visualizations Preparation
# </font>

# %%
# Set up the figure size and style
sns.set_style("darkgrid")

# %%
# Ignore specific warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn")

# %%
# Replace the values in gravity field
data['gravity'] = data['gravity'].replace({
     1: '1 - Unharmed',
     2: '2 - Killed',
     3: '3 - Hospitalized',
     4: '4 - Slightly injured'
})

# Define custom colors
custom_colors = {
    '1 - Unharmed': '#66B2FF',      
    '2 - Killed': '#FF9999',       
    '3 - Hospitalized': '#FFCC99',   
    '4 - Slightly injured': '#99FF99' 
}

# Sort gravity levels alphabetically
gravity_order = sorted(custom_colors.keys())

# %%
# Function to calculate and display percentages in a separated table 
def calculate_and_display_percentages(data, group_by_col):
    counts = data.groupby([group_by_col, 'gravity']).size().reset_index(name='count')
    total_counts = data[group_by_col].value_counts().reset_index(name='total')
    total_counts.columns = [group_by_col, 'total']
    counts = counts.merge(total_counts, on=group_by_col)
    counts['percentage'] = counts['count'] / counts['total'] * 100

    # Pivot the table to show only percentages
    percentage_table = counts.pivot(index=group_by_col, columns='gravity', values='percentage').fillna(0)
    
    styled_table = percentage_table.style.format("{:.1f}%").set_table_styles(
        [{'selector': 'th', 'props': [('font-size', '12pt'), ('font-weight', 'bold'), ('text-align', 'center')]},
         {'selector': 'td', 'props': [('font-size', '10pt'), ('text-align', 'center')]},
         {'selector': 'caption', 'props': [('caption-side', 'top')]}]
    ).set_caption(f'Percentages of Accident Gravity by {group_by_col.capitalize()}').background_gradient(cmap='Blues', axis=None)

    # Display the styled table
    html = styled_table.to_html()
    display(HTML(html))

# %% [markdown]
# <font size="6">
# Graph Visualization
# </font>

# %%
# 1. Number of accidents by Severity Category

# Calculate counts and sort them
counts = data['gravity'].value_counts().sort_values(ascending=False)

# Calculate percentages
total = counts.sum()
percentages = counts / total * 100

plt.figure(figsize=(18, 12))
ax = sns.countplot(data=data, x='gravity', order=counts.index, palette=custom_colors)

for p, percentage in zip(ax.patches, percentages):
    height = p.get_height()
    ax.annotate(f'{percentage:.1f}%', 
                (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='center', 
                xytext=(0, 8), 
                textcoords='offset points')

plt.title('Number of accidents by Severity Category')
plt.xlabel('Severity')
plt.ylabel('Number of Accidents')
plt.show()

# %%
# 2. Number of accidents by Severity vs.Year
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='year', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Year of Accident')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

# Call function to show the percentage Gravity vs. Year
calculate_and_display_percentages(data, 'year')
# Out:
# <style type="text/css">
# #T_7ae53 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_7ae53 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_7ae53 caption {
#   caption-side: top;
# }
# #T_7ae53_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7ae53_row0_col1, #T_7ae53_row1_col1, #T_7ae53_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7ae53_row0_col2, #T_7ae53_row3_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_7ae53_row0_col3 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_7ae53_row1_col0, #T_7ae53_row3_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_7ae53_row1_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_7ae53_row1_col3, #T_7ae53_row3_col3 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_7ae53_row2_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_7ae53_row2_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_7ae53_row2_col3 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_7ae53_row3_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# </style>
# <table id="T_7ae53">
#   <caption>Percentages of Accident Gravity by Year</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_7ae53_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_7ae53_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_7ae53_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_7ae53_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ae53_level0_row0" class="row_heading level0 row0" >2019</th>
#       <td id="T_7ae53_row0_col0" class="data row0 col0" >44.8%</td>
#       <td id="T_7ae53_row0_col1" class="data row0 col1" >2.0%</td>
#       <td id="T_7ae53_row0_col2" class="data row0 col2" >13.3%</td>
#       <td id="T_7ae53_row0_col3" class="data row0 col3" >39.9%</td>
#     </tr>
#     <tr>
#       <th id="T_7ae53_level0_row1" class="row_heading level0 row1" >2020</th>
#       <td id="T_7ae53_row1_col0" class="data row1 col0" >44.4%</td>
#       <td id="T_7ae53_row1_col1" class="data row1 col1" >2.0%</td>
#       <td id="T_7ae53_row1_col2" class="data row1 col2" >13.5%</td>
#       <td id="T_7ae53_row1_col3" class="data row1 col3" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_7ae53_level0_row2" class="row_heading level0 row2" >2021</th>
#       <td id="T_7ae53_row2_col0" class="data row2 col0" >44.5%</td>
#       <td id="T_7ae53_row2_col1" class="data row2 col1" >2.0%</td>
#       <td id="T_7ae53_row2_col2" class="data row2 col2" >12.7%</td>
#       <td id="T_7ae53_row2_col3" class="data row2 col3" >40.8%</td>
#     </tr>
#     <tr>
#       <th id="T_7ae53_level0_row3" class="row_heading level0 row3" >2022</th>
#       <td id="T_7ae53_row3_col0" class="data row3 col0" >44.4%</td>
#       <td id="T_7ae53_row3_col1" class="data row3 col1" >2.2%</td>
#       <td id="T_7ae53_row3_col2" class="data row3 col2" >13.2%</td>
#       <td id="T_7ae53_row3_col3" class="data row3 col3" >40.1%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 2.1 Number of accidents by Severity vs.Year
years = data['year'].unique()
n_years = len(years)

fig, axes = plt.subplots(1, n_years, figsize=(18, 6))
fig.suptitle('Severity Distribution per Year', fontsize=16)

custom_colors_mat = ['#66B2FF', '#99FF99', '#FFCC99', '#FF9999']

for i, year in enumerate(years):
    yearly_data = data[data['year'] == year]['gravity'].value_counts()
    colors = custom_colors_mat[:len(yearly_data)]  
    axes[i].pie(yearly_data, labels=yearly_data.index, autopct='%1.1f%%', colors=colors)
    axes[i].set_title(f'Year {year}')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# 3. Number of accidents by Severity vs. Month
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='month', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'month')
# Out:
# <style type="text/css">
# #T_2c267 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_2c267 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_2c267 caption {
#   caption-side: top;
# }
# #T_2c267_row0_col0, #T_2c267_row2_col0, #T_2c267_row3_col0, #T_2c267_row9_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_2c267_row0_col1, #T_2c267_row1_col1, #T_2c267_row10_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_2c267_row0_col2, #T_2c267_row10_col2, #T_2c267_row11_col2 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_2c267_row0_col3 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_2c267_row1_col0, #T_2c267_row10_col0, #T_2c267_row11_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2c267_row1_col2, #T_2c267_row2_col2 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_2c267_row1_col3 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_2c267_row2_col1, #T_2c267_row4_col1, #T_2c267_row5_col1, #T_2c267_row8_col1, #T_2c267_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2c267_row2_col3 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_2c267_row3_col1, #T_2c267_row6_col1, #T_2c267_row7_col1, #T_2c267_row11_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_2c267_row3_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_2c267_row3_col3, #T_2c267_row8_col3 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_2c267_row4_col0, #T_2c267_row5_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_2c267_row4_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_2c267_row4_col3, #T_2c267_row6_col3 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_2c267_row5_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_2c267_row5_col3 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_2c267_row6_col0 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_2c267_row6_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_2c267_row7_col0 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_2c267_row7_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_2c267_row7_col3 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_2c267_row8_col0 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_2c267_row8_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_2c267_row9_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_2c267_row9_col3, #T_2c267_row10_col3, #T_2c267_row11_col3 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2c267">
#   <caption>Percentages of Accident Gravity by Month</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_2c267_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_2c267_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_2c267_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_2c267_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c267_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2c267_row0_col0" class="data row0 col0" >44.8%</td>
#       <td id="T_2c267_row0_col1" class="data row0 col1" >2.1%</td>
#       <td id="T_2c267_row0_col2" class="data row0 col2" >12.0%</td>
#       <td id="T_2c267_row0_col3" class="data row0 col3" >41.1%</td>
#     </tr>
#     <tr>
#       <th id="T_2c267_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2c267_row1_col0" class="data row1 col0" >45.2%</td>
#       <td id="T_2c267_row1_col1" class="data row1 col1" >2.0%</td>
#       <td id="T_2c267_row1_col2" class="data row1 col2" >12.4%</td>
#       <td id="T_2c267_row1_col3" class="data row1 col3" >40.4%</td>
#     </tr>
#     <tr>
#       <th id="T_2c267_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_2c267_row2_col0" class="data row2 col0" >44.8%</td>
#       <td id="T_2c267_row2_col1" class="data row2 col1" >2.0%</td>
#       <td id="T_2c267_row2_col2" class="data row2 col2" >12.4%</td>
#       <td id="T_2c267_row2_col3" class="data row2 col3" >40.8%</td>
#     </tr>
#     <tr>
#       <th id="T_2c267_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_2c267_row3_col0" class="data row3 col0" >44.8%</td>
#       <td id="T_2c267_row3_col1" class="data row3 col1" >2.2%</td>
#       <td id="T_2c267_row3_col2" class="data row3 col2" >13.1%</td>
#       <td id="T_2c267_row3_col3" class="data row3 col3" >39.9%</td>
#     </tr>
#     <tr>
#       <th id="T_2c267_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_2c267_row4_col0" class="data row4 col0" >44.3%</td>
#       <td id="T_2c267_row4_col1" class="data row4 col1" >2.0%</td>
#       <td id="T_2c267_row4_col2" class="data row4 col2" >14.0%</td>
#       <td id="T_2c267_row4_col3" class="data row4 col3" >39.7%</td>
#     </tr>
#     <tr>
#       <th id="T_2c267_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_2c267_row5_col0" class="data row5 col0" >44.3%</td>
#       <td id="T_2c267_row5_col1" class="data row5 col1" >2.0%</td>
#       <td id="T_2c267_row5_col2" class="data row5 col2" >13.7%</td>
#       <td id="T_2c267_row5_col3" class="data row5 col3" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_2c267_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_2c267_row6_col0" class="data row6 col0" >43.6%</td>
#       <td id="T_2c267_row6_col1" class="data row6 col1" >2.2%</td>
#       <td id="T_2c267_row6_col2" class="data row6 col2" >14.4%</td>
#       <td id="T_2c267_row6_col3" class="data row6 col3" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_2c267_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_2c267_row7_col0" class="data row7 col0" >43.5%</td>
#       <td id="T_2c267_row7_col1" class="data row7 col1" >2.3%</td>
#       <td id="T_2c267_row7_col2" class="data row7 col2" >15.6%</td>
#       <td id="T_2c267_row7_col3" class="data row7 col3" >38.6%</td>
#     </tr>
#     <tr>
#       <th id="T_2c267_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_2c267_row8_col0" class="data row8 col0" >44.7%</td>
#       <td id="T_2c267_row8_col1" class="data row8 col1" >2.0%</td>
#       <td id="T_2c267_row8_col2" class="data row8 col2" >13.3%</td>
#       <td id="T_2c267_row8_col3" class="data row8 col3" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_2c267_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_2c267_row9_col0" class="data row9 col0" >44.8%</td>
#       <td id="T_2c267_row9_col1" class="data row9 col1" >1.8%</td>
#       <td id="T_2c267_row9_col2" class="data row9 col2" >12.6%</td>
#       <td id="T_2c267_row9_col3" class="data row9 col3" >40.8%</td>
#     </tr>
#     <tr>
#       <th id="T_2c267_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_2c267_row10_col0" class="data row10 col0" >45.1%</td>
#       <td id="T_2c267_row10_col1" class="data row10 col1" >2.1%</td>
#       <td id="T_2c267_row10_col2" class="data row10 col2" >12.0%</td>
#       <td id="T_2c267_row10_col3" class="data row10 col3" >40.8%</td>
#     </tr>
#     <tr>
#       <th id="T_2c267_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_2c267_row11_col0" class="data row11 col0" >45.1%</td>
#       <td id="T_2c267_row11_col1" class="data row11 col1" >2.2%</td>
#       <td id="T_2c267_row11_col2" class="data row11 col2" >12.0%</td>
#       <td id="T_2c267_row11_col3" class="data row11 col3" >40.7%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 4. Number of accidents by Severity vs. Day
aggregated_data = data.groupby(['day', 'gravity']).size().reset_index(name='count')

plt.figure(figsize=(18, 12))
sns.lineplot(data=aggregated_data, x='day', y='count', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Number of Accidents by Severity vs. Day')
plt.xlabel('Day')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'day')
# Out:
# <style type="text/css">
# #T_fa610 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_fa610 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_fa610 caption {
#   caption-side: top;
# }
# #T_fa610_row0_col0, #T_fa610_row7_col0, #T_fa610_row11_col0, #T_fa610_row14_col0, #T_fa610_row15_col0, #T_fa610_row17_col0 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_fa610_row0_col1, #T_fa610_row13_col1, #T_fa610_row14_col1, #T_fa610_row16_col1, #T_fa610_row19_col1, #T_fa610_row25_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_fa610_row0_col2, #T_fa610_row3_col2, #T_fa610_row4_col2, #T_fa610_row14_col2, #T_fa610_row15_col2, #T_fa610_row28_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_fa610_row0_col3, #T_fa610_row13_col3, #T_fa610_row15_col3, #T_fa610_row20_col3, #T_fa610_row27_col3 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_fa610_row1_col0, #T_fa610_row9_col0, #T_fa610_row23_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_fa610_row1_col1, #T_fa610_row5_col1, #T_fa610_row6_col1, #T_fa610_row7_col1, #T_fa610_row8_col1, #T_fa610_row10_col1, #T_fa610_row11_col1, #T_fa610_row12_col1, #T_fa610_row15_col1, #T_fa610_row17_col1, #T_fa610_row20_col1, #T_fa610_row21_col1, #T_fa610_row22_col1, #T_fa610_row24_col1, #T_fa610_row26_col1, #T_fa610_row27_col1, #T_fa610_row30_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_fa610_row1_col2, #T_fa610_row16_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_fa610_row1_col3, #T_fa610_row9_col3, #T_fa610_row11_col3, #T_fa610_row22_col3 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_fa610_row2_col0, #T_fa610_row4_col0 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_fa610_row2_col1, #T_fa610_row3_col1, #T_fa610_row4_col1, #T_fa610_row9_col1, #T_fa610_row23_col1, #T_fa610_row28_col1, #T_fa610_row29_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_fa610_row2_col2 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_fa610_row2_col3, #T_fa610_row16_col3 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_fa610_row3_col0, #T_fa610_row6_col0, #T_fa610_row18_col0, #T_fa610_row28_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fa610_row3_col3, #T_fa610_row6_col3, #T_fa610_row7_col3, #T_fa610_row12_col3, #T_fa610_row14_col3, #T_fa610_row17_col3, #T_fa610_row21_col3 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_fa610_row4_col3, #T_fa610_row10_col3, #T_fa610_row25_col3, #T_fa610_row29_col3 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_fa610_row5_col0, #T_fa610_row16_col0, #T_fa610_row26_col0 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_fa610_row5_col2, #T_fa610_row11_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_fa610_row5_col3, #T_fa610_row24_col3 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_fa610_row6_col2, #T_fa610_row9_col2, #T_fa610_row24_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_fa610_row7_col2, #T_fa610_row8_col2, #T_fa610_row10_col2, #T_fa610_row17_col2, #T_fa610_row18_col2, #T_fa610_row21_col2, #T_fa610_row23_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_fa610_row8_col0, #T_fa610_row12_col0, #T_fa610_row20_col0, #T_fa610_row24_col0, #T_fa610_row27_col0, #T_fa610_row29_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_fa610_row8_col3, #T_fa610_row26_col3, #T_fa610_row30_col3 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_fa610_row10_col0, #T_fa610_row13_col0, #T_fa610_row22_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_fa610_row12_col2, #T_fa610_row22_col2, #T_fa610_row27_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_fa610_row13_col2, #T_fa610_row30_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_fa610_row18_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_fa610_row18_col3 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_fa610_row19_col0, #T_fa610_row21_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_fa610_row19_col2, #T_fa610_row20_col2, #T_fa610_row25_col2, #T_fa610_row26_col2, #T_fa610_row29_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_fa610_row19_col3, #T_fa610_row28_col3 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_fa610_row23_col3 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_fa610_row25_col0 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_fa610_row30_col0 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fa610">
#   <caption>Percentages of Accident Gravity by Day</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_fa610_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_fa610_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_fa610_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_fa610_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >day</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa610_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_fa610_row0_col0" class="data row0 col0" >44.7%</td>
#       <td id="T_fa610_row0_col1" class="data row0 col1" >2.2%</td>
#       <td id="T_fa610_row0_col2" class="data row0 col2" >13.1%</td>
#       <td id="T_fa610_row0_col3" class="data row0 col3" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_fa610_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_fa610_row1_col0" class="data row1 col0" >45.0%</td>
#       <td id="T_fa610_row1_col1" class="data row1 col1" >2.0%</td>
#       <td id="T_fa610_row1_col2" class="data row1 col2" >12.5%</td>
#       <td id="T_fa610_row1_col3" class="data row1 col3" >40.4%</td>
#     </tr>
#     <tr>
#       <th id="T_fa610_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_fa610_row2_col0" class="data row2 col0" >44.4%</td>
#       <td id="T_fa610_row2_col1" class="data row2 col1" >2.0%</td>
#       <td id="T_fa610_row2_col2" class="data row2 col2" >12.5%</td>
#       <td id="T_fa610_row2_col3" class="data row2 col3" >41.1%</td>
#     </tr>
#     <tr>
#       <th id="T_fa610_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_fa610_row3_col0" class="data row3 col0" >45.1%</td>
#       <td id="T_fa610_row3_col1" class="data row3 col1" >1.9%</td>
#       <td id="T_fa610_row3_col2" class="data row3 col2" >13.1%</td>
#       <td id="T_fa610_row3_col3" class="data row3 col3" >39.9%</td>
#     </tr>
#     <tr>
#       <th id="T_fa610_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_fa610_row4_col0" class="data row4 col0" >44.4%</td>
#       <td id="T_fa610_row4_col1" class="data row4 col1" >1.8%</td>
#       <td id="T_fa610_row4_col2" class="data row4 col2" >13.2%</td>
#       <td id="T_fa610_row4_col3" class="data row4 col3" >40.6%</td>
#     </tr>
#     <tr>
#       <th id="T_fa610_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_fa610_row5_col0" class="data row5 col0" >44.2%</td>
#       <td id="T_fa610_row5_col1" class="data row5 col1" >2.0%</td>
#       <td id="T_fa610_row5_col2" class="data row5 col2" >12.9%</td>
#       <td id="T_fa610_row5_col3" class="data row5 col3" >40.9%</td>
#     </tr>
#     <tr>
#       <th id="T_fa610_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_fa610_row6_col0" class="data row6 col0" >45.2%</td>
#       <td id="T_fa610_row6_col1" class="data row6 col1" >2.1%</td>
#       <td id="T_fa610_row6_col2" class="data row6 col2" >12.8%</td>
#       <td id="T_fa610_row6_col3" class="data row6 col3" >39.9%</td>
#     </tr>
#     <tr>
#       <th id="T_fa610_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_fa610_row7_col0" class="data row7 col0" >44.7%</td>
#       <td id="T_fa610_row7_col1" class="data row7 col1" >2.1%</td>
#       <td id="T_fa610_row7_col2" c

# %%
# 5. Number of accidents by Severity vs. Weather Conditions
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='atm_condition', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Weather Conditions')
plt.xlabel('Weather Condition')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'atm_condition')
# Out:
# <style type="text/css">
# #T_7f173 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_7f173 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_7f173 caption {
#   caption-side: top;
# }
# #T_7f173_row0_col0 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_7f173_row0_col1, #T_7f173_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7f173_row0_col2 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_7f173_row0_col3 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_7f173_row1_col0, #T_7f173_row2_col0 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_7f173_row1_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_7f173_row1_col3 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_7f173_row2_col1, #T_7f173_row3_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_7f173_row2_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_7f173_row2_col3, #T_7f173_row8_col3 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_7f173_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7f173_row3_col2, #T_7f173_row7_col2 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_7f173_row3_col3 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_7f173_row4_col0 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_7f173_row4_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_7f173_row4_col2 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_7f173_row4_col3 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_7f173_row5_col0, #T_7f173_row5_col3 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_7f173_row5_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_7f173_row5_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_7f173_row6_col0 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_7f173_row6_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_7f173_row6_col2 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_7f173_row6_col3 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_7f173_row7_col0 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_7f173_row7_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_7f173_row7_col3 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_7f173_row8_col0 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_7f173_row8_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_7f173_row8_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# </style>
# <table id="T_7f173">
#   <caption>Percentages of Accident Gravity by Atm_condition</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_7f173_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_7f173_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_7f173_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_7f173_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >atm_condition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f173_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_7f173_row0_col0" class="data row0 col0" >44.7%</td>
#       <td id="T_7f173_row0_col1" class="data row0 col1" >2.0%</td>
#       <td id="T_7f173_row0_col2" class="data row0 col2" >13.2%</td>
#       <td id="T_7f173_row0_col3" class="data row0 col3" >40.1%</td>
#     </tr>
#     <tr>
#       <th id="T_7f173_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_7f173_row1_col0" class="data row1 col0" >44.1%</td>
#       <td id="T_7f173_row1_col1" class="data row1 col1" >1.8%</td>
#       <td id="T_7f173_row1_col2" class="data row1 col2" >11.0%</td>
#       <td id="T_7f173_row1_col3" class="data row1 col3" >43.0%</td>
#     </tr>
#     <tr>
#       <th id="T_7f173_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_7f173_row2_col0" class="data row2 col0" >44.1%</td>
#       <td id="T_7f173_row2_col1" class="data row2 col1" >2.2%</td>
#       <td id="T_7f173_row2_col2" class="data row2 col2" >13.5%</td>
#       <td id="T_7f173_row2_col3" class="data row2 col3" >40.2%</td>
#     </tr>
#     <tr>
#       <th id="T_7f173_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_7f173_row3_col0" class="data row3 col0" >51.6%</td>
#       <td id="T_7f173_row3_col1" class="data row3 col1" >2.2%</td>
#       <td id="T_7f173_row3_col2" class="data row3 col2" >12.6%</td>
#       <td id="T_7f173_row3_col3" class="data row3 col3" >33.6%</td>
#     </tr>
#     <tr>
#       <th id="T_7f173_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_7f173_row4_col0" class="data row4 col0" >38.2%</td>
#       <td id="T_7f173_row4_col1" class="data row4 col1" >5.0%</td>
#       <td id="T_7f173_row4_col2" class="data row4 col2" >20.1%</td>
#       <td id="T_7f173_row4_col3" class="data row4 col3" >36.7%</td>
#     </tr>
#     <tr>
#       <th id="T_7f173_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_7f173_row5_col0" class="data row5 col0" >35.9%</td>
#       <td id="T_7f173_row5_col1" class="data row5 col1" >4.1%</td>
#       <td id="T_7f173_row5_col2" class="data row5 col2" >24.1%</td>
#       <td id="T_7f173_row5_col3" class="data row5 col3" >35.9%</td>
#     </tr>
#     <tr>
#       <th id="T_7f173_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_7f173_row6_col0" class="data row6 col0" >46.1%</td>
#       <td id="T_7f173_row6_col1" class="data row6 col1" >3.1%</td>
#       <td id="T_7f173_row6_col2" class="data row6 col2" >20.8%</td>
#       <td id="T_7f173_row6_col3" class="data row6 col3" >30.0%</td>
#     </tr>
#     <tr>
#       <th id="T_7f173_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_7f173_row7_col0" class="data row7 col0" >43.5%</td>
#       <td id="T_7f173_row7_col1" class="data row7 col1" >2.7%</td>
#       <td id="T_7f173_row7_col2" class="data row7 col2" >12.6%</td>
#       <td id="T_7f173_row7_col3" class="data row7 col3" >41.3%</td>
#     </tr>
#     <tr>
#       <th id="T_7f173_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_7f173_row8_col0" class="data row8 col0" >37.6%</td>
#       <td id="T_7f173_row8_col1" class="data row8 col1" >4.6%</td>
#       <td id="T_7f173_row8_col2" class="data row8 col2" >17.7%</td>
#       <td id="T_7f173_row8_col3" class="data row8 col3" >40.1%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 6. Number of accidents by Severity vs. Lighting Conditions
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='lum', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Lighting Conditions')
plt.xlabel('Lighting Condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'lum')
# Out:
# <style type="text/css">
# #T_79170 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_79170 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_79170 caption {
#   caption-side: top;
# }
# #T_79170_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_79170_row0_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_79170_row0_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_79170_row0_col3 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_79170_row1_col0 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_79170_row1_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_79170_row1_col2 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_79170_row1_col3 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_79170_row2_col0 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_79170_row2_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_79170_row2_col2 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_79170_row2_col3 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_79170_row3_col0, #T_79170_row3_col3 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_79170_row3_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_79170_row3_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_79170_row4_col0 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_79170_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_79170_row4_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_79170_row4_col3 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_79170">
#   <caption>Percentages of Accident Gravity by Lum</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_79170_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_79170_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_79170_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_79170_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >lum</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79170_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_79170_row0_col0" class="data row0 col0" >45.8%</td>
#       <td id="T_79170_row0_col1" class="data row0 col1" >1.8%</td>
#       <td id="T_79170_row0_col2" class="data row0 col2" >12.8%</td>
#       <td id="T_79170_row0_col3" class="data row0 col3" >39.6%</td>
#     </tr>
#     <tr>
#       <th id="T_79170_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_79170_row1_col0" class="data row1 col0" >43.1%</td>
#       <td id="T_79170_row1_col1" class="data row1 col1" >2.4%</td>
#       <td id="T_79170_row1_col2" class="data row1 col2" >15.0%</td>
#       <td id="T_79170_row1_col3" class="data row1 col3" >39.5%</td>
#     </tr>
#     <tr>
#       <th id="T_79170_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_79170_row2_col0" class="data row2 col0" >38.4%</td>
#       <td id="T_79170_row2_col1" class="data row2 col1" >5.2%</td>
#       <td id="T_79170_row2_col2" class="data row2 col2" >18.7%</td>
#       <td id="T_79170_row2_col3" class="data row2 col3" >37.7%</td>
#     </tr>
#     <tr>
#       <th id="T_79170_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_79170_row3_col0" class="data row3 col0" >41.7%</td>
#       <td id="T_79170_row3_col1" class="data row3 col1" >3.1%</td>
#       <td id="T_79170_row3_col2" class="data row3 col2" >13.5%</td>
#       <td id="T_79170_row3_col3" class="data row3 col3" >41.8%</td>
#     </tr>
#     <tr>
#       <th id="T_79170_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_79170_row4_col0" class="data row4 col0" >43.2%</td>
#       <td id="T_79170_row4_col1" class="data row4 col1" >1.4%</td>
#       <td id="T_79170_row4_col2" class="data row4 col2" >10.8%</td>
#       <td id="T_79170_row4_col3" class="data row4 col3" >44.7%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 7. Number of accidents by Severity vs. Vehicle Category
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='vehicle_category', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Vehicle Category')
plt.xlabel('Vehicle Category')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'vehicle_category')
# Out:
# <style type="text/css">
# #T_d46bc th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_d46bc td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_d46bc caption {
#   caption-side: top;
# }
# #T_d46bc_row0_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_d46bc_row0_col1, #T_d46bc_row29_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_d46bc_row0_col2, #T_d46bc_row12_col3 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_d46bc_row0_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d46bc_row1_col0, #T_d46bc_row25_col3, #T_d46bc_row26_col3 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_d46bc_row1_col1, #T_d46bc_row5_col1, #T_d46bc_row14_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_d46bc_row1_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_d46bc_row1_col3 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_d46bc_row2_col0, #T_d46bc_row27_col0 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_d46bc_row2_col1, #T_d46bc_row17_col1, #T_d46bc_row20_col1, #T_d46bc_row23_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_d46bc_row2_col2 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_d46bc_row2_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_d46bc_row3_col0, #T_d46bc_row30_col0 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_d46bc_row3_col1, #T_d46bc_row4_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_d46bc_row3_col2, #T_d46bc_row4_col2 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_d46bc_row3_col3, #T_d46bc_row14_col0, #T_d46bc_row15_col0, #T_d46bc_row17_col0 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_d46bc_row4_col0, #T_d46bc_row9_col0 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_d46bc_row4_col3 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_d46bc_row5_col0, #T_d46bc_row25_col0 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_d46bc_row5_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_d46bc_row5_col3 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_d46bc_row6_col0 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_d46bc_row6_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_d46bc_row6_col2 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_d46bc_row6_col3 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_d46bc_row7_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_d46bc_row7_col1 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_d46bc_row7_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_d46bc_row7_col3 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_d46bc_row8_col0, #T_d46bc_row13_col3, #T_d46bc_row27_col3 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_d46bc_row8_col1, #T_d46bc_row19_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_d46bc_row8_col2, #T_d46bc_row17_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_d46bc_row8_col3 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_d46bc_row9_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_d46bc_row9_col2 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_d46bc_row9_col3 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_d46bc_row10_col0, #T_d46bc_row11_col0 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_d46bc_row10_col1 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_d46bc_row10_col2, #T_d46bc_row30_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_d46bc_row10_col3 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_d46bc_row11_col1, #T_d46bc_row16_col1, #T_d46bc_row21_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_d46bc_row11_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_d46bc_row11_col3 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_d46bc_row12_col0, #T_d46bc_row23_col0, #T_d46bc_row26_col0 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_d46bc_row12_col1, #T_d46bc_row27_col2 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_d46bc_row12_col2 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_d46bc_row13_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_d46bc_row13_col1, #T_d46bc_row27_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_d46bc_row13_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_d46bc_row14_col2 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_d46bc_row14_col3 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_d46bc_row15_col1, #T_d46bc_row26_col1, #T_d46bc_row30_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_d46bc_row15_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_d46bc_row15_col3 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_d46bc_row16_col0 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_d46bc_row16_col2, #T_d46bc_row24_col2 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_d46bc_row16_col3 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_d46bc_row17_col3, #T_d46bc_row19_col2 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_d46bc_row18_col0, #T_d46bc_row18_col3 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_d46bc_row18_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_d46bc_row18_col2 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_d46bc_row19_col0 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_d46bc_row19_col3 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_d46bc_row20_col0 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_d46bc_row20_col2 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_d46bc_row20_col3, #T_d46bc_row23_col3 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_d46bc_row21_col0 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_d46bc_row21_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_d46bc_row21_col3 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_d46bc_row22_col0 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_d46bc_row22_col1 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_d46bc_row22_col2 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_d46bc_row22_col3 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_d46bc_row23_col2 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_d46bc_row24_col0 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_d46bc_row24_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_d46bc_row24_col3 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_d46bc_row25_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d46bc_row25_col2 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_d46bc_row26_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_d46bc_row28_col0 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_d46bc_row28_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_d46bc_row28_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_d46bc_row28_col3 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_d46bc_row29_col0 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_d46bc_row29_col2 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_d46bc_row29_col3 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_d46bc_row30_col3 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d46bc">
#   <caption>Percentages of Accident Gravity by Vehicle_category</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_d46bc_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_d46bc_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_d46bc_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_d46bc_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >vehicle_category</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d46bc_l

# %%
# 2.1 Number of accidents by Severity vs.Year
genders = data['gender'].unique()
n_genders = len(genders)

fig, axes = plt.subplots(1, n_genders, figsize=(18, 6))
fig.suptitle('Severity Distribution per gender', fontsize=16)

custom_colors_mat = ['#66B2FF', '#99FF99', '#FFCC99', '#FF9999']

for i, gender in enumerate(genders):
    genderly_data = data[data['gender'] == gender]['gravity'].value_counts()
    colors = custom_colors_mat[:len(genderly_data)]  
    axes[i].pie(genderly_data, labels=genderly_data.index, autopct='%1.1f%%', colors=colors)
    axes[i].set_title(f'gender {gender}')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# 8. Number of accidents by Severity vs. Gender
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='gender', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.show()

calculate_and_display_percentages(data, 'gender')
# Out:
# <style type="text/css">
# #T_6062a th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_6062a td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_6062a caption {
#   caption-side: top;
# }
# #T_6062a_row0_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_6062a_row0_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_6062a_row0_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_6062a_row0_col3 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_6062a_row1_col0 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_6062a_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6062a_row1_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_6062a_row1_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6062a">
#   <caption>Percentages of Accident Gravity by Gender</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_6062a_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_6062a_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_6062a_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_6062a_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6062a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_6062a_row0_col0" class="data row0 col0" >46.7%</td>
#       <td id="T_6062a_row0_col1" class="data row0 col1" >2.4%</td>
#       <td id="T_6062a_row0_col2" class="data row0 col2" >13.9%</td>
#       <td id="T_6062a_row0_col3" class="data row0 col3" >37.1%</td>
#     </tr>
#     <tr>
#       <th id="T_6062a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_6062a_row1_col0" class="data row1 col0" >39.9%</td>
#       <td id="T_6062a_row1_col1" class="data row1 col1" >1.4%</td>
#       <td id="T_6062a_row1_col2" class="data row1 col2" >11.6%</td>
#       <td id="T_6062a_row1_col3" class="data row1 col3" >47.1%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 9. Number of accidents by Severity vs. Surface Condition
plt.figure(figsize=(18,12))
sns.countplot(data=data, x='surface_condition', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Surface Condition')
plt.xlabel('Surface Condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'surface_condition')
# Out:
# <style type="text/css">
# #T_83c7e th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_83c7e td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_83c7e caption {
#   caption-side: top;
# }
# #T_83c7e_row0_col0 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_83c7e_row0_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_83c7e_row0_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_83c7e_row0_col3 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_83c7e_row1_col0 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_83c7e_row1_col1, #T_83c7e_row4_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_83c7e_row1_col2 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_83c7e_row1_col3 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_83c7e_row2_col0 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_83c7e_row2_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_83c7e_row2_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_83c7e_row2_col3 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_83c7e_row3_col0 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_83c7e_row3_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_83c7e_row3_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_83c7e_row3_col3 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_83c7e_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_83c7e_row4_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_83c7e_row4_col3 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_83c7e_row5_col0 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_83c7e_row5_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_83c7e_row5_col2 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_83c7e_row5_col3 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_83c7e_row6_col0 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_83c7e_row6_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_83c7e_row6_col2 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_83c7e_row6_col3, #T_83c7e_row8_col0 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_83c7e_row7_col0 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_83c7e_row7_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_83c7e_row7_col2 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_83c7e_row7_col3 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_83c7e_row8_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_83c7e_row8_col2 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_83c7e_row8_col3 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_83c7e">
#   <caption>Percentages of Accident Gravity by Surface_condition</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_83c7e_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_83c7e_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_83c7e_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_83c7e_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >surface_condition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83c7e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_83c7e_row0_col0" class="data row0 col0" >44.8%</td>
#       <td id="T_83c7e_row0_col1" class="data row0 col1" >2.0%</td>
#       <td id="T_83c7e_row0_col2" class="data row0 col2" >13.4%</td>
#       <td id="T_83c7e_row0_col3" class="data row0 col3" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_83c7e_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_83c7e_row1_col0" class="data row1 col0" >43.8%</td>
#       <td id="T_83c7e_row1_col1" class="data row1 col1" >2.2%</td>
#       <td id="T_83c7e_row1_col2" class="data row1 col2" >11.8%</td>
#       <td id="T_83c7e_row1_col3" class="data row1 col3" >42.2%</td>
#     </tr>
#     <tr>
#       <th id="T_83c7e_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_83c7e_row2_col0" class="data row2 col0" >43.4%</td>
#       <td id="T_83c7e_row2_col1" class="data row2 col1" >2.3%</td>
#       <td id="T_83c7e_row2_col2" class="data row2 col2" >16.5%</td>
#       <td id="T_83c7e_row2_col3" class="data row2 col3" >37.8%</td>
#     </tr>
#     <tr>
#       <th id="T_83c7e_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_83c7e_row3_col0" class="data row3 col0" >42.0%</td>
#       <td id="T_83c7e_row3_col1" class="data row3 col1" >3.7%</td>
#       <td id="T_83c7e_row3_col2" class="data row3 col2" >15.7%</td>
#       <td id="T_83c7e_row3_col3" class="data row3 col3" >38.6%</td>
#     </tr>
#     <tr>
#       <th id="T_83c7e_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_83c7e_row4_col0" class="data row4 col0" >49.0%</td>
#       <td id="T_83c7e_row4_col1" class="data row4 col1" >2.1%</td>
#       <td id="T_83c7e_row4_col2" class="data row4 col2" >13.5%</td>
#       <td id="T_83c7e_row4_col3" class="data row4 col3" >35.3%</td>
#     </tr>
#     <tr>
#       <th id="T_83c7e_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_83c7e_row5_col0" class="data row5 col0" >28.4%</td>
#       <td id="T_83c7e_row5_col1" class="data row5 col1" >5.2%</td>
#       <td id="T_83c7e_row5_col2" class="data row5 col2" >30.3%</td>
#       <td id="T_83c7e_row5_col3" class="data row5 col3" >36.2%</td>
#     </tr>
#     <tr>
#       <th id="T_83c7e_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_83c7e_row6_col0" class="data row6 col0" >36.9%</td>
#       <td id="T_83c7e_row6_col1" class="data row6 col1" >4.4%</td>
#       <td id="T_83c7e_row6_col2" class="data row6 col2" >20.8%</td>
#       <td id="T_83c7e_row6_col3" class="data row6 col3" >37.9%</td>
#     </tr>
#     <tr>
#       <th id="T_83c7e_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_83c7e_row7_col0" class="data row7 col0" >40.0%</td>
#       <td id="T_83c7e_row7_col1" class="data row7 col1" >1.3%</td>
#       <td id="T_83c7e_row7_col2" class="data row7 col2" >16.9%</td>
#       <td id="T_83c7e_row7_col3" class="data row7 col3" >41.8%</td>
#     </tr>
#     <tr>
#       <th id="T_83c7e_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_83c7e_row8_col0" class="data row8 col0" >38.0%</td>
#       <td id="T_83c7e_row8_col1" class="data row8 col1" >4.2%</td>
#       <td id="T_83c7e_row8_col2" class="data row8 col2" >22.8%</td>
#       <td id="T_83c7e_row8_col3" class="data row8 col3" >34.9%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 10. Number of accidents by Severity vs. Maximum Speed
# Define the bins and corresponding labels
bins = [0, 49, 59, 69, 79, 89, 99, 109, float('inf')]
labels = ['0-49', '50-59', '60-69', '70-79', '80-89', '90-99', '100-109', '110-119']

# Create a new column for the binned speeds
data['speed_group'] = pd.cut(data['maximum_speed'], bins=bins, labels=labels, right=False)

plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='speed_group', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Maximum Speed')
plt.xlabel('Maximum Speed Group')
plt.ylabel('Gravity')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'maximum_speed')
# Out:
# <style type="text/css">
# #T_19f38 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_19f38 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_19f38 caption {
#   caption-side: top;
# }
# #T_19f38_row0_col0, #T_19f38_row15_col0, #T_19f38_row15_col3, #T_19f38_row19_col0, #T_19f38_row23_col3 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_19f38_row0_col1, #T_19f38_row1_col1, #T_19f38_row2_col0, #T_19f38_row2_col1, #T_19f38_row2_col2, #T_19f38_row3_col1, #T_19f38_row3_col2, #T_19f38_row5_col1, #T_19f38_row5_col2, #T_19f38_row10_col1, #T_19f38_row12_col1, #T_19f38_row12_col2, #T_19f38_row15_col1, #T_19f38_row17_col1, #T_19f38_row17_col3, #T_19f38_row19_col1, #T_19f38_row19_col3, #T_19f38_row24_col1, #T_19f38_row24_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_19f38_row0_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_19f38_row0_col3, #T_19f38_row21_col0 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_19f38_row1_col0 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_19f38_row1_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_19f38_row1_col3 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_19f38_row2_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_19f38_row3_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_19f38_row3_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_19f38_row4_col0, #T_19f38_row9_col3 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_19f38_row4_col1, #T_19f38_row13_col1, #T_19f38_row23_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_19f38_row4_col2 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_19f38_row4_col3 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_19f38_row5_col0 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_19f38_row5_col3 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_19f38_row6_col0, #T_19f38_row14_col0, #T_19f38_row18_col0 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_19f38_row6_col1, #T_19f38_row9_col1, #T_19f38_row14_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_19f38_row6_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_19f38_row6_col3 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_19f38_row7_col0, #T_19f38_row7_col3, #T_19f38_row14_col3, #T_19f38_row22_col3 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_19f38_row7_col1, #T_19f38_row21_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_19f38_row7_col2 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_19f38_row8_col0, #T_19f38_row16_col3 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_19f38_row8_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_19f38_row8_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_19f38_row8_col3 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_19f38_row9_col0 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_19f38_row9_col2 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_19f38_row10_col0, #T_19f38_row11_col3, #T_19f38_row20_col3 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_19f38_row10_col2 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_19f38_row10_col3 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_19f38_row11_col0 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_19f38_row11_col1, #T_19f38_row16_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_19f38_row11_col2 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_19f38_row12_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_19f38_row12_col3 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_19f38_row13_col0, #T_19f38_row17_col0 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_19f38_row13_col2 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_19f38_row13_col3, #T_19f38_row18_col3 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_19f38_row14_col2 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_19f38_row15_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_19f38_row16_col0, #T_19f38_row21_col3 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_19f38_row16_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_19f38_row17_col2 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_19f38_row18_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_19f38_row18_col2 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_19f38_row19_col2 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_19f38_row20_col0 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_19f38_row20_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_19f38_row20_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_19f38_row21_col2 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_19f38_row22_col0 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_19f38_row22_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_19f38_row22_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_19f38_row23_col0, #T_19f38_row24_col0, #T_19f38_row24_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_19f38_row23_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# </style>
# <table id="T_19f38">
#   <caption>Percentages of Accident Gravity by Maximum_speed</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_19f38_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_19f38_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_19f38_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_19f38_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >maximum_speed</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19f38_level0_row0" class="row_heading level0 row0" >6</th>
#       <td id="T_19f38_row0_col0" class="data row0 col0" >40.0%</td>
#       <td id="T_19f38_row0_col1" class="data row0 col1" >0.0%</td>
#       <td id="T_19f38_row0_col2" class="data row0 col2" >12.0%</td>
#       <td id="T_19f38_row0_col3" class="data row0 col3" >48.0%</td>
#     </tr>
#     <tr>
#       <th id="T_19f38_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_19f38_row1_col0" class="data row1 col0" >54.5%</td>
#       <td id="T_19f38_row1_col1" class="data row1 col1" >0.0%</td>
#       <td id="T_19f38_row1_col2" class="data row1 col2" >18.2%</td>
#       <td id="T_19f38_row1_col3" class="data row1 col3" >27.3%</td>
#     </tr>
#     <tr>
#       <th id="T_19f38_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_19f38_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_19f38_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_19f38_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_19f38_row2_col3" class="data row2 col3" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_19f38_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_19f38_row3_col0" class="data row3 col0" >66.7%</td>
#       <td id="T_19f38_row3_col1" class="data row3 col1" >0.0%</td>
#       <td id="T_19f38_row3_col2" class="data row3 col2" >0.0%</td>
#       <td id="T_19f38_row3_col3" class="data row3 col3" >33.3%</td>
#     </tr>
#     <tr>
#       <th id="T_19f38_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_19f38_row4_col0" class="data row4 col0" >44.6%</td>
#       <td id="T_19f38_row4_col1" class="data row4 col1" >2.3%</td>
#       <td id="T_19f38_row4_col2" class="data row4 col2" >12.2%</td>
#       <td id="T_19f38_row4_col3" class="data row4 col3" >40.9%</td>
#     </tr>
#     <tr>
#       <th id="T_19f38_level0_row5" class="row_heading level0 row5" >12</th>
#       <td id="T_19f38_row5_col0" class="data row5 col0" >62.5%</td>
#       <td id="T_19f38_row5_col1" class="data row5 col1" >0.0%</td>
#       <td id="T_19f38_row5_col2" class="data row

# %%
# 11. Number of accidents by Severity vs. Age
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='gravity', y='age', hue_order=gravity_order, palette=custom_colors)
plt.title('Age Distribution by Accident Gravity Category')
plt.show()

calculate_and_display_percentages(data, 'age')
# Out:
# <style type="text/css">
# #T_6ea37 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_6ea37 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_6ea37 caption {
#   caption-side: top;
# }
# #T_6ea37_row0_col0, #T_6ea37_row22_col0, #T_6ea37_row22_col3, #T_6ea37_row79_col0, #T_6ea37_row82_col0 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_6ea37_row0_col1, #T_6ea37_row17_col1, #T_6ea37_row27_col1, #T_6ea37_row28_col1, #T_6ea37_row29_col1, #T_6ea37_row30_col1, #T_6ea37_row31_col1, #T_6ea37_row33_col1, #T_6ea37_row34_col1, #T_6ea37_row36_col1, #T_6ea37_row38_col1, #T_6ea37_row40_col1, #T_6ea37_row42_col1, #T_6ea37_row44_col1, #T_6ea37_row46_col1, #T_6ea37_row47_col1, #T_6ea37_row48_col1, #T_6ea37_row50_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_6ea37_row0_col2, #T_6ea37_row76_col1, #T_6ea37_row79_col1, #T_6ea37_row80_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_6ea37_row0_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_6ea37_row1_col0, #T_6ea37_row34_col3, #T_6ea37_row35_col3 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_6ea37_row1_col1, #T_6ea37_row4_col1, #T_6ea37_row8_col1, #T_6ea37_row16_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_6ea37_row1_col2, #T_6ea37_row5_col2 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_6ea37_row1_col3, #T_6ea37_row5_col3, #T_6ea37_row41_col0 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_6ea37_row2_col0, #T_6ea37_row29_col0 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_6ea37_row2_col1, #T_6ea37_row3_col1, #T_6ea37_row19_col1, #T_6ea37_row20_col1, #T_6ea37_row22_col1, #T_6ea37_row24_col1, #T_6ea37_row25_col1, #T_6ea37_row51_col1, #T_6ea37_row52_col1, #T_6ea37_row55_col1, #T_6ea37_row56_col1, #T_6ea37_row57_col1, #T_6ea37_row58_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_6ea37_row2_col2, #T_6ea37_row78_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_6ea37_row2_col3, #T_6ea37_row19_col3, #T_6ea37_row37_col0, #T_6ea37_row39_col0, #T_6ea37_row49_col0 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_6ea37_row3_col0, #T_6ea37_row81_col0 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_6ea37_row3_col2, #T_6ea37_row4_col2 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_6ea37_row3_col3, #T_6ea37_row36_col0 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_6ea37_row4_col0, #T_6ea37_row76_col0 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_6ea37_row4_col3, #T_6ea37_row32_col0, #T_6ea37_row66_col0, #T_6ea37_row68_col0 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_6ea37_row5_col0 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_6ea37_row5_col1, #T_6ea37_row12_col1, #T_6ea37_row14_col1, #T_6ea37_row15_col1, #T_6ea37_row35_col1, #T_6ea37_row39_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_6ea37_row6_col0, #T_6ea37_row50_col3, #T_6ea37_row91_col0 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_6ea37_row6_col1, #T_6ea37_row7_col1, #T_6ea37_row10_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6ea37_row6_col2, #T_6ea37_row30_col2, #T_6ea37_row31_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_6ea37_row6_col3, #T_6ea37_row44_col0 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_6ea37_row7_col0, #T_6ea37_row52_col3 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_6ea37_row7_col2, #T_6ea37_row48_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_6ea37_row7_col3, #T_6ea37_row47_col0 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_6ea37_row8_col0 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_6ea37_row8_col2, #T_6ea37_row39_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_6ea37_row8_col3, #T_6ea37_row17_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_6ea37_row9_col0 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_6ea37_row9_col1, #T_6ea37_row11_col1, #T_6ea37_row13_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_6ea37_row9_col2, #T_6ea37_row26_col2, #T_6ea37_row52_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_6ea37_row9_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_6ea37_row10_col0, #T_6ea37_row65_col3 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_6ea37_row10_col2, #T_6ea37_row57_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_6ea37_row10_col3 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_6ea37_row11_col0, #T_6ea37_row84_col3, #T_6ea37_row87_col3 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_6ea37_row11_col2, #T_6ea37_row55_col2, #T_6ea37_row56_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_6ea37_row11_col3 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_6ea37_row12_col0 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_6ea37_row12_col2, #T_6ea37_row49_col2, #T_6ea37_row91_col1 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_6ea37_row12_col3, #T_6ea37_row13_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6ea37_row13_col0 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_6ea37_row13_col2 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_6ea37_row14_col0 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_6ea37_row14_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_6ea37_row14_col3 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_6ea37_row15_col0, #T_6ea37_row80_col2, #T_6ea37_row87_col2 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_6ea37_row15_col2, #T_6ea37_row70_col2, #T_6ea37_row74_col2 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_6ea37_row15_col3 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_6ea37_row16_col0, #T_6ea37_row81_col2 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_6ea37_row16_col2, #T_6ea37_row18_col0, #T_6ea37_row83_col2, #T_6ea37_row88_col2 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_6ea37_row16_col3 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_6ea37_row17_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_6ea37_row17_col2 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_6ea37_row18_col1, #T_6ea37_row23_col1, #T_6ea37_row26_col1, #T_6ea37_row32_col1, #T_6ea37_row37_col1, #T_6ea37_row41_col1, #T_6ea37_row43_col1, #T_6ea37_row45_col1, #T_6ea37_row49_col1, #T_6ea37_row54_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_6ea37_row18_col2 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_6ea37_row18_col3 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_6ea37_row19_col0, #T_6ea37_row74_col3, #T_6ea37_row76_col3 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_6ea37_row19_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_6ea37_row20_col0, #T_6ea37_row62_col3 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_6ea37_row20_col2, #T_6ea37_row68_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_6ea37_row20_col3 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_6ea37_row21_col0, #T_6ea37_row42_col3 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_6ea37_row21_col1, #T_6ea37_row60_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_6ea37_row21_col2, #T_6ea37_row58_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_6ea37_row21_col3 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_6ea37_row22_col2, #T_6ea37_row54_col2 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_6ea37_row23_col0, #T_6ea37_row24_col3 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_6ea37_row23_col2, #T_6ea37_row24_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_6ea37_row23_col3, #T_6ea37_row25_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_6ea37_row24_col0, #T_6ea37_row26_col3, #T_6ea37_row29_col3 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_6ea37_row25_col0, #T_6ea37_row28_col3, #T_6ea37_row31_col3 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_6ea37_row25_col2, #T_6ea37_row50_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_6ea37_row26_col0, #T_6ea37_row27_col0, #T_6ea37_row27_col3 {

# %%
# 12. Number of accidents by Severity vs. Age
plt.figure(figsize=(10, 6))
sns.kdeplot(data=data, x='age', hue='gravity', fill=True, hue_order=gravity_order, palette=custom_colors)
plt.title('Density of Age Distribution by Accident Gravity Category')
plt.show()

# %%
# 13. Number of accidents by Severity vs. Age
plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='age', y='maximum_speed', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Age vs. Maximum Speed by Accident Gravity')
plt.show()
