# %%
# Import libraries needed to execute the code
import os
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import scipy.cluster.hierarchy as shc
from sklearn.decomposition import PCA
from IPython.display import display, HTML
from scipy.cluster.hierarchy import dendrogram, linkage
from pandas.plotting import andrews_curves, parallel_coordinates, lag_plot, autocorrelation_plot, radviz

# %%
# Import the clean data
data = pd.read_csv('source/data.csv')
# Out:
# C:\Users\sd10725\AppData\Local\Temp\ipykernel_28980\2749963071.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('source/data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 469506 entries, 0 to 469505
# Data columns (total 46 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   AccID                       469506 non-null  int64
#  1   day                         469506 non-null  int64
#  2   month                       469506 non-null  int64
#  3   year                        469506 non-null  int64
#  4   time                        469506 non-null  object
#  5   lum                         469506 non-null  int64
#  6   dep_code                    469506 non-null  float64
#  7   com_code                    469506 non-null  object
#  8   location                    469506 non-null  int64
#  9   int                         469506 non-null  int64
#  10  atm_condition               469506 non-null  int64
#  11  collision_type              469506 non-null  int64
#  12  address                     469506 non-null  object
#  13  lat                         469506 non-null  float64
#  14  long                        469506 non-null  float64
#  15  route_category              469506 non-null  int64
#  16  route_number                469506 non-null  object
#  17  route_number_index1         469506 non-null  int64
#  18  traffic_regime              469506 non-null  int64
#  19  total_number_lanes          469506 non-null  int64
#  20  reserved_lane_code          469506 non-null  int64
#  21  longitudinal_profile        469506 non-null  int64
#  22  upstream_terminal_number    469506 non-null  int64
#  23  distance_upstream_terminal  469506 non-null  object
#  24  plan                        469506 non-null  int64
#  25  surface_condition           469506 non-null  int64
#  26  infra                       469506 non-null  int64
#  27  accident_situation          469506 non-null  int64
#  28  maximum_speed               469506 non-null  int64
#  29  vehicleID                   469506 non-null  object
#  30  num_veh                     469506 non-null  object
#  31  traffic_direction           469506 non-null  int64
#  32  vehicle_category            469506 non-null  int64
#  33  fixed_obstacle              469506 non-null  int64
#  34  mobile_obstacle             469506 non-null  int64
#  35  initial_impact_point        469506 non-null  int64
#  36  manv                        469506 non-null  int64
#  37  motor                       469506 non-null  int64
#  38  seat                        469506 non-null  int64
#  39  user_category               469506 non-null  int64
#  40  gravity                     469506 non-null  int64
#  41  gender                      469506 non-null  int64
#  42  birth_year                  469506 non-null  float64
#  43  reason_travel               469506 non-null  int64
#  44  safety_equipment1           469506 non-null  int64
#  45  age                         469506 non-null  float64
# dtypes: float64(5), int64(34), object(7)
# memory usage: 164.8+ MB

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Encode the labels if they are not numeric
le = LabelEncoder()
encoded_labels = le.fit_transform(data['gravity'])

# Calculate the Gini Index
classes, counts = np.unique(encoded_labels, return_counts=True)
gini_index = 1 - sum((counts / counts.sum()) ** 2)

print(f'Gini Index: {gini_index}')
# Out:
# Gini Index: 0.6378703504327665

# %%
# Identifying correlations with the target variable 'gravity'

# Identifying non-numeric columns again
non_numeric_columns = data.select_dtypes(include=['object']).columns

# Copy the original dataframe
data_numeric = data.copy()

# Convert columns to numeric where appropriate, errors='coerce' will convert non-convertible values to NaN
for col in non_numeric_columns:
    data_numeric[col] = pd.to_numeric(data_numeric[col], errors='coerce')

# Identifying and dropping problematic columns specifically
problematic_columns = ['time', 'vehicleID', 'num_veh', 'year']

# Drop the problematic columns and recalculate the correlation matrix
data_cleaned = data_numeric.drop(columns=problematic_columns)

# Calculate correlation matrix
correlation_matrix = data_cleaned.corr()

# Extract correlations with the target variable 'gravity'
correlation_with_gravity = correlation_matrix['gravity'].sort_values(ascending=False)

correlation_with_gravity
# Out:
# gravity                       1.000000
# user_category                 0.227025
# seat                          0.214538
# vehicle_category              0.173912
# motor                         0.134646
# Cluster                       0.113109
# fixed_obstacle                0.108537
# safety_equipment1             0.096664
# birth_year                    0.094124
# gender                        0.077617
# collision_type                0.062923
# plan                          0.036249
# accident_situation            0.035091
# lum                           0.030846
# surface_condition             0.023362
# longitudinal_profile          0.013228
# address                       0.006161
# maximum_speed                 0.005792
# lat                           0.003995
# reason_travel                 0.003662
# route_category                0.003642
# atm_condition                 0.001320
# route_number                  0.000780
# route_number_index1           0.000617
# month                         0.000095
# day                          -0.000338
# long                         -0.000365
# upstream_terminal_number     -0.001111
# reserved_lane_code           -0.002381
# com_code                     -0.002946
# dep_code                     -0.003894
# traffic_direction            -0.004119
# traffic_regime               -0.006335
# infra                        -0.007408
# AccID                        -0.007643
# total_number_lanes           -0.010112
# distance_upstream_terminal   -0.010372
# int                          -0.013773
# location                     -0.016413
# initial_impact_point         -0.026517
# manv                         -0.067745
# age                          -0.094166
# mobile_obstacle              -0.125325
# Name: gravity, dtype: float64

# %% [markdown]
# <font size="6">
#     Visualizations Preparation
# </font>

# %%
# Set up the figure size and style
sns.set_style("darkgrid")

# %%
# Ignore specific warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn")

# %%
# Replace the values in gravity field
data['gravity'] = data['gravity'].replace({
     1: '1 - Uninjured',
     2: '2 - Fatal',
     3: '3 - Hospitalized',
     4: '4 - Minor injury'
})
# Define custom colors
custom_colors = {
    '1 - Uninjured': '#66B2FF',      
    '2 - Fatal': '#FF9999',       
    '3 - Hospitalized': '#FFCC99',   
    '4 - Minor injury': '#99FF99' 
}

# Sort gravity levels alphabetically
gravity_order = sorted(custom_colors.keys())

# %%
# Function to calculate and display percentages in a separated table 
def calculate_and_display_percentages(data, group_by_col):
    counts = data.groupby([group_by_col, 'gravity']).size().reset_index(name='count')
    total_counts = data[group_by_col].value_counts().reset_index(name='total')
    total_counts.columns = [group_by_col, 'total']
    counts = counts.merge(total_counts, on=group_by_col)
    counts['percentage'] = counts['count'] / counts['total'] * 100

    # Pivot the table to show only percentages
    percentage_table = counts.pivot(index=group_by_col, columns='gravity', values='percentage').fillna(0)
    
    styled_table = percentage_table.style.format("{:.1f}%").set_table_styles(
        [{'selector': 'th', 'props': [('font-size', '12pt'), ('font-weight', 'bold'), ('text-align', 'center')]},
         {'selector': 'td', 'props': [('font-size', '10pt'), ('text-align', 'center')]},
         {'selector': 'caption', 'props': [('caption-side', 'top')]}]
    ).set_caption(f'Percentages of Accident Gravity by {group_by_col.capitalize()}').background_gradient(cmap='Blues', axis=None)

    # Display the styled table
    html = styled_table.to_html()
    display(HTML(html))

# %% [markdown]
# <font size="6">
# Graph Visualization
# </font>

# %%
# 1. Number of accidents by Severity Category

# Calculate counts and sort them
counts = data['gravity'].value_counts().sort_values(ascending=False)

# Calculate percentages
total = counts.sum()
percentages = counts / total * 100

plt.figure(figsize=(18, 12))
ax = sns.countplot(data=data, x='gravity', order=counts.index, palette=custom_colors)

for p, percentage in zip(ax.patches, percentages):
    height = p.get_height()
    ax.annotate(f'{percentage:.1f}%', 
                (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='center', 
                xytext=(0, 8), 
                textcoords='offset points')

plt.title('Number of accidents by Severity Category')
plt.xlabel('Severity')
plt.ylabel('Number of Accidents')
plt.show()

# %%
# 2. Number of accidents by Severity vs.Year
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='year', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Year of Accident')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

# Call function to show the percentage Gravity vs. Year
calculate_and_display_percentages(data, 'year')
# Out:
# <style type="text/css">
# #T_5294c th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_5294c td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_5294c caption {
#   caption-side: top;
# }
# #T_5294c_row0_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_5294c_row0_col1, #T_5294c_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5294c_row0_col2 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_5294c_row0_col3, #T_5294c_row2_col3 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_5294c_row1_col0 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_5294c_row1_col1, #T_5294c_row3_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_5294c_row1_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_5294c_row1_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_5294c_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5294c_row2_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_5294c_row3_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_5294c_row3_col2 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_5294c_row3_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5294c">
#   <caption>Percentages of Accident Gravity by Year</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_5294c_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_5294c_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_5294c_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_5294c_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5294c_level0_row0" class="row_heading level0 row0" >2019</th>
#       <td id="T_5294c_row0_col0" class="data row0 col0" >41.6%</td>
#       <td id="T_5294c_row0_col1" class="data row0 col1" >2.5%</td>
#       <td id="T_5294c_row0_col2" class="data row0 col2" >15.5%</td>
#       <td id="T_5294c_row0_col3" class="data row0 col3" >40.4%</td>
#     </tr>
#     <tr>
#       <th id="T_5294c_level0_row1" class="row_heading level0 row1" >2020</th>
#       <td id="T_5294c_row1_col0" class="data row1 col0" >41.0%</td>
#       <td id="T_5294c_row1_col1" class="data row1 col1" >2.6%</td>
#       <td id="T_5294c_row1_col2" class="data row1 col2" >15.8%</td>
#       <td id="T_5294c_row1_col3" class="data row1 col3" >40.6%</td>
#     </tr>
#     <tr>
#       <th id="T_5294c_level0_row2" class="row_heading level0 row2" >2021</th>
#       <td id="T_5294c_row2_col0" class="data row2 col0" >42.7%</td>
#       <td id="T_5294c_row2_col1" class="data row2 col1" >2.4%</td>
#       <td id="T_5294c_row2_col2" class="data row2 col2" >14.6%</td>
#       <td id="T_5294c_row2_col3" class="data row2 col3" >40.4%</td>
#     </tr>
#     <tr>
#       <th id="T_5294c_level0_row3" class="row_heading level0 row3" >2022</th>
#       <td id="T_5294c_row3_col0" class="data row3 col0" >42.3%</td>
#       <td id="T_5294c_row3_col1" class="data row3 col1" >2.7%</td>
#       <td id="T_5294c_row3_col2" class="data row3 col2" >15.1%</td>
#       <td id="T_5294c_row3_col3" class="data row3 col3" >40.0%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 2.1 Number of accidents by Severity vs.Year
years = data['year'].unique()
n_years = len(years)

fig, axes = plt.subplots(1, n_years, figsize=(18, 6))
fig.suptitle('Severity Distribution per Year', fontsize=16)

custom_colors_mat = ['#66B2FF', '#99FF99', '#FFCC99', '#FF9999']

for i, year in enumerate(years):
    yearly_data = data[data['year'] == year]['gravity'].value_counts()
    colors = custom_colors_mat[:len(yearly_data)]  
    axes[i].pie(yearly_data, labels=yearly_data.index, autopct='%1.1f%%', colors=colors)
    axes[i].set_title(f'Year {year}')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# 3. Number of accidents by Severity vs. Month
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='month', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'month')
# Out:
# <style type="text/css">
# #T_d7ec0 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_d7ec0 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_d7ec0 caption {
#   caption-side: top;
# }
# #T_d7ec0_row0_col0, #T_d7ec0_row10_col0, #T_d7ec0_row11_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_d7ec0_row0_col1, #T_d7ec0_row1_col1, #T_d7ec0_row3_col1, #T_d7ec0_row10_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_d7ec0_row0_col2, #T_d7ec0_row11_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_d7ec0_row0_col3 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_d7ec0_row1_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d7ec0_row1_col2, #T_d7ec0_row2_col2 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_d7ec0_row1_col3 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_d7ec0_row2_col0, #T_d7ec0_row8_col0 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_d7ec0_row2_col1, #T_d7ec0_row4_col1, #T_d7ec0_row5_col1, #T_d7ec0_row8_col1, #T_d7ec0_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d7ec0_row2_col3, #T_d7ec0_row10_col3, #T_d7ec0_row11_col3 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_d7ec0_row3_col0 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_d7ec0_row3_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_d7ec0_row3_col3, #T_d7ec0_row5_col3, #T_d7ec0_row8_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_d7ec0_row4_col0 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_d7ec0_row4_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_d7ec0_row4_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_d7ec0_row5_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_d7ec0_row5_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_d7ec0_row6_col0, #T_d7ec0_row9_col3 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_d7ec0_row6_col1, #T_d7ec0_row7_col1, #T_d7ec0_row11_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_d7ec0_row6_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_d7ec0_row6_col3 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_d7ec0_row7_col0 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_d7ec0_row7_col2 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_d7ec0_row7_col3 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_d7ec0_row8_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_d7ec0_row9_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_d7ec0_row9_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_d7ec0_row10_col2 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# </style>
# <table id="T_d7ec0">
#   <caption>Percentages of Accident Gravity by Month</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_d7ec0_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_d7ec0_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_d7ec0_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_d7ec0_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7ec0_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d7ec0_row0_col0" class="data row0 col0" >42.4%</td>
#       <td id="T_d7ec0_row0_col1" class="data row0 col1" >2.6%</td>
#       <td id="T_d7ec0_row0_col2" class="data row0 col2" >13.8%</td>
#       <td id="T_d7ec0_row0_col3" class="data row0 col3" >41.2%</td>
#     </tr>
#     <tr>
#       <th id="T_d7ec0_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d7ec0_row1_col0" class="data row1 col0" >42.7%</td>
#       <td id="T_d7ec0_row1_col1" class="data row1 col1" >2.6%</td>
#       <td id="T_d7ec0_row1_col2" class="data row1 col2" >14.4%</td>
#       <td id="T_d7ec0_row1_col3" class="data row1 col3" >40.4%</td>
#     </tr>
#     <tr>
#       <th id="T_d7ec0_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d7ec0_row2_col0" class="data row2 col0" >42.1%</td>
#       <td id="T_d7ec0_row2_col1" class="data row2 col1" >2.4%</td>
#       <td id="T_d7ec0_row2_col2" class="data row2 col2" >14.4%</td>
#       <td id="T_d7ec0_row2_col3" class="data row2 col3" >41.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d7ec0_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_d7ec0_row3_col0" class="data row3 col0" >41.9%</td>
#       <td id="T_d7ec0_row3_col1" class="data row3 col1" >2.7%</td>
#       <td id="T_d7ec0_row3_col2" class="data row3 col2" >15.3%</td>
#       <td id="T_d7ec0_row3_col3" class="data row3 col3" >40.1%</td>
#     </tr>
#     <tr>
#       <th id="T_d7ec0_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_d7ec0_row4_col0" class="data row4 col0" >41.7%</td>
#       <td id="T_d7ec0_row4_col1" class="data row4 col1" >2.4%</td>
#       <td id="T_d7ec0_row4_col2" class="data row4 col2" >15.9%</td>
#       <td id="T_d7ec0_row4_col3" class="data row4 col3" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d7ec0_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_d7ec0_row5_col0" class="data row5 col0" >41.8%</td>
#       <td id="T_d7ec0_row5_col1" class="data row5 col1" >2.4%</td>
#       <td id="T_d7ec0_row5_col2" class="data row5 col2" >15.7%</td>
#       <td id="T_d7ec0_row5_col3" class="data row5 col3" >40.1%</td>
#     </tr>
#     <tr>
#       <th id="T_d7ec0_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_d7ec0_row6_col0" class="data row6 col0" >40.9%</td>
#       <td id="T_d7ec0_row6_col1" class="data row6 col1" >2.7%</td>
#       <td id="T_d7ec0_row6_col2" class="data row6 col2" >16.7%</td>
#       <td id="T_d7ec0_row6_col3" class="data row6 col3" >39.7%</td>
#     </tr>
#     <tr>
#       <th id="T_d7ec0_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_d7ec0_row7_col0" class="data row7 col0" >40.5%</td>
#       <td id="T_d7ec0_row7_col1" class="data row7 col1" >2.8%</td>
#       <td id="T_d7ec0_row7_col2" class="data row7 col2" >18.0%</td>
#       <td id="T_d7ec0_row7_col3" class="data row7 col3" >38.7%</td>
#     </tr>
#     <tr>
#       <th id="T_d7ec0_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_d7ec0_row8_col0" class="data row8 col0" >42.2%</td>
#       <td id="T_d7ec0_row8_col1" class="data row8 col1" >2.5%</td>
#       <td id="T_d7ec0_row8_col2" class="data row8 col2" >15.3%</td>
#       <td id="T_d7ec0_row8_col3" class="data row8 col3" >40.1%</td>
#     </tr>
#     <tr>
#       <th id="T_d7ec0_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_d7ec0_row9_col0" class="data row9 col0" >42.3%</td>
#       <td id="T_d7ec0_row9_col1" class="data row9 col1" >2.4%</td>
#       <td id="T_d7ec0_row9_col2" class="data row9 col2" >14.6%</td>
#       <td id="T_d7ec0_row9_col3" class="data row9 col3" >40.8%</td>
#     </tr>
#     <tr>
#       <th id="T_d7ec0_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_d7ec0_row10_col0" class="data row10 col0" >42.5%</td>
#       <td id="T_d7ec0_row10_col1" class="data row10 col1" >2.5%</td>
#       <td id="T_d7ec0_row10_col2" class="data row10 col2" >14.0%</td>
#       <td id="T_d7ec0_row10_col3" class="data row10 col3" >41.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d7ec0_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_d7ec0_row11_col0" class="data row11 col0" >42.4%</td>
#       <td id="T_d7ec0_row11_col1" class="data row11 col1" >2.8%</td>
#       <td id="T_d7ec0_row11_col2" class="data row11 col2" >13.8%</td>
#       <td id="T_d7ec0_row11_col3" class="data row11 col3" >41.0%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 4. Number of accidents by Severity vs. Day
aggregated_data = data.groupby(['day', 'gravity']).size().reset_index(name='count')

plt.figure(figsize=(18, 12))
sns.lineplot(data=aggregated_data, x='day', y='count', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Number of Accidents by Severity vs. Day')
plt.xlabel('Day')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'day')
# Out:
# <style type="text/css">
# #T_abaab th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_abaab td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_abaab caption {
#   caption-side: top;
# }
# #T_abaab_row0_col0, #T_abaab_row11_col0, #T_abaab_row12_col0, #T_abaab_row14_col0, #T_abaab_row19_col0, #T_abaab_row20_col0, #T_abaab_row29_col0 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_abaab_row0_col1, #T_abaab_row13_col1, #T_abaab_row19_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_abaab_row0_col2, #T_abaab_row5_col2, #T_abaab_row8_col2, #T_abaab_row11_col2, #T_abaab_row24_col2, #T_abaab_row28_col2 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_abaab_row0_col3, #T_abaab_row8_col3, #T_abaab_row9_col3, #T_abaab_row10_col3, #T_abaab_row26_col3, #T_abaab_row29_col3 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_abaab_row1_col0, #T_abaab_row6_col0, #T_abaab_row23_col0, #T_abaab_row28_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_abaab_row1_col1, #T_abaab_row2_col1, #T_abaab_row4_col1, #T_abaab_row7_col1, #T_abaab_row8_col1, #T_abaab_row9_col1, #T_abaab_row21_col1, #T_abaab_row28_col1, #T_abaab_row29_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_abaab_row1_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_abaab_row1_col3, #T_abaab_row4_col3, #T_abaab_row24_col3 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_abaab_row2_col0, #T_abaab_row5_col0, #T_abaab_row22_col0 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_abaab_row2_col2 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_abaab_row2_col3, #T_abaab_row13_col0, #T_abaab_row16_col0, #T_abaab_row26_col0, #T_abaab_row30_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_abaab_row3_col0, #T_abaab_row9_col0, #T_abaab_row18_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_abaab_row3_col1, #T_abaab_row5_col1, #T_abaab_row10_col1, #T_abaab_row11_col1, #T_abaab_row12_col1, #T_abaab_row14_col1, #T_abaab_row22_col1, #T_abaab_row23_col1, #T_abaab_row24_col1, #T_abaab_row27_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_abaab_row3_col2, #T_abaab_row4_col2, #T_abaab_row14_col2, #T_abaab_row17_col2, #T_abaab_row18_col2, #T_abaab_row21_col2, #T_abaab_row23_col2, #T_abaab_row29_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_abaab_row3_col3, #T_abaab_row12_col3, #T_abaab_row13_col3, #T_abaab_row20_col3 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_abaab_row4_col0, #T_abaab_row10_col0, #T_abaab_row24_col0, #T_abaab_row27_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_abaab_row5_col3 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_abaab_row6_col1, #T_abaab_row15_col1, #T_abaab_row16_col1, #T_abaab_row17_col1, #T_abaab_row20_col1, #T_abaab_row25_col1, #T_abaab_row26_col1, #T_abaab_row30_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_abaab_row6_col2, #T_abaab_row9_col2, #T_abaab_row15_col2, #T_abaab_row16_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_abaab_row6_col3, #T_abaab_row7_col3, #T_abaab_row17_col3, #T_abaab_row21_col3, #T_abaab_row28_col3, #T_abaab_row30_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_abaab_row7_col0, #T_abaab_row15_col0, #T_abaab_row21_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_abaab_row7_col2, #T_abaab_row10_col2, #T_abaab_row20_col2, #T_abaab_row22_col2, #T_abaab_row26_col2, #T_abaab_row27_col2 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_abaab_row8_col0, #T_abaab_row17_col0 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_abaab_row11_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_abaab_row12_col2, #T_abaab_row19_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_abaab_row13_col2, #T_abaab_row25_col2, #T_abaab_row30_col2 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_abaab_row14_col3, #T_abaab_row15_col3, #T_abaab_row22_col3, #T_abaab_row25_col3, #T_abaab_row27_col3 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_abaab_row16_col3 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_abaab_row18_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_abaab_row18_col3 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_abaab_row19_col3 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_abaab_row23_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_abaab_row25_col0 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_abaab">
#   <caption>Percentages of Accident Gravity by Day</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_abaab_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_abaab_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_abaab_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_abaab_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >day</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abaab_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_abaab_row0_col0" class="data row0 col0" >41.8%</td>
#       <td id="T_abaab_row0_col1" class="data row0 col1" >2.8%</td>
#       <td id="T_abaab_row0_col2" class="data row0 col2" >14.9%</td>
#       <td id="T_abaab_row0_col3" class="data row0 col3" >40.5%</td>
#     </tr>
#     <tr>
#       <th id="T_abaab_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_abaab_row1_col0" class="data row1 col0" >42.5%</td>
#       <td id="T_abaab_row1_col1" class="data row1 col1" >2.4%</td>
#       <td id="T_abaab_row1_col2" class="data row1 col2" >14.4%</td>
#       <td id="T_abaab_row1_col3" class="data row1 col3" >40.7%</td>
#     </tr>
#     <tr>
#       <th id="T_abaab_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_abaab_row2_col0" class="data row2 col0" >41.6%</td>
#       <td id="T_abaab_row2_col1" class="data row2 col1" >2.4%</td>
#       <td id="T_abaab_row2_col2" class="data row2 col2" >14.7%</td>
#       <td id="T_abaab_row2_col3" class="data row2 col3" >41.4%</td>
#     </tr>
#     <tr>
#       <th id="T_abaab_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_abaab_row3_col0" class="data row3 col0" >42.3%</td>
#       <td id="T_abaab_row3_col1" class="data row3 col1" >2.4%</td>
#       <td id="T_abaab_row3_col2" class="data row3 col2" >15.2%</td>
#       <td id="T_abaab_row3_col3" class="data row3 col3" >40.1%</td>
#     </tr>
#     <tr>
#       <th id="T_abaab_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_abaab_row4_col0" class="data row4 col0" >41.7%</td>
#       <td id="T_abaab_row4_col1" class="data row4 col1" >2.3%</td>
#       <td id="T_abaab_row4_col2" class="data row4 col2" >15.3%</td>
#       <td id="T_abaab_row4_col3" class="data row4 col3" >40.7%</td>
#     </tr>
#     <tr>
#       <th id="T_abaab_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_abaab_row5_col0" class="data row5 col0" >41.6%</td>
#       <td id="T_abaab_row5_col1" class="data row5 col1" >2.5%</td>
#       <td id="T_abaab_row5_col2" class="data row5 col2" >15.0%</td>
#       <td id="T_abaab_row5_col3" class="data row5 col3" >40.9%</td>
#     </tr>
#     <tr>
#       <th id="T_abaab_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_abaab_row6_col0" class="data row6 col0" >42.5%</td>
#       <td id="T_abaab_row6_col1" class="data row6 col1" >2.6%</td>
#       <td id="T_abaab_row6_col2" class="data row6 col2" >14.8%</td>
#       <td id="T_abaab_row6_col3" class="data row6 col3" >40.1%</td>
#     </tr>
#     <tr>
#       <th id="T_abaab_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_abaab_row7_col0" class="data row7 col0" >42.2%</td>
#       <td id="T_abaab_row7_col1" class="data row7 col1" >2.4%</td>
#       <td id="T_abaab_row7_col2" class

# %%
# 5. Number of accidents by Severity vs. Weather Conditions
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='atm_condition', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Weather Conditions')
plt.xlabel('Weather Condition')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'atm_condition')
# Out:
# <style type="text/css">
# #T_67169 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_67169 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_67169 caption {
#   caption-side: top;
# }
# #T_67169_row0_col0 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_67169_row0_col1, #T_67169_row2_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_67169_row0_col2 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_67169_row0_col3, #T_67169_row8_col3 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_67169_row1_col0, #T_67169_row2_col0 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_67169_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_67169_row1_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_67169_row1_col3 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_67169_row2_col2 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_67169_row2_col3, #T_67169_row7_col0 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_67169_row3_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_67169_row3_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_67169_row3_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_67169_row3_col3, #T_67169_row4_col3 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_67169_row4_col0 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_67169_row4_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_67169_row4_col2 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_67169_row5_col0 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_67169_row5_col1, #T_67169_row8_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_67169_row5_col2 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_67169_row5_col3 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_67169_row6_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_67169_row6_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_67169_row6_col2 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_67169_row6_col3 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_67169_row7_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_67169_row7_col2 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_67169_row7_col3 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_67169_row8_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_67169_row8_col2 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# </style>
# <table id="T_67169">
#   <caption>Percentages of Accident Gravity by Atm_condition</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_67169_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_67169_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_67169_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_67169_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >atm_condition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67169_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_67169_row0_col0" class="data row0 col0" >42.2%</td>
#       <td id="T_67169_row0_col1" class="data row0 col1" >2.5%</td>
#       <td id="T_67169_row0_col2" class="data row0 col2" >15.2%</td>
#       <td id="T_67169_row0_col3" class="data row0 col3" >40.1%</td>
#     </tr>
#     <tr>
#       <th id="T_67169_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_67169_row1_col0" class="data row1 col0" >41.1%</td>
#       <td id="T_67169_row1_col1" class="data row1 col1" >2.3%</td>
#       <td id="T_67169_row1_col2" class="data row1 col2" >12.8%</td>
#       <td id="T_67169_row1_col3" class="data row1 col3" >43.9%</td>
#     </tr>
#     <tr>
#       <th id="T_67169_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_67169_row2_col0" class="data row2 col0" >41.0%</td>
#       <td id="T_67169_row2_col1" class="data row2 col1" >2.6%</td>
#       <td id="T_67169_row2_col2" class="data row2 col2" >15.6%</td>
#       <td id="T_67169_row2_col3" class="data row2 col3" >40.7%</td>
#     </tr>
#     <tr>
#       <th id="T_67169_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_67169_row3_col0" class="data row3 col0" >43.7%</td>
#       <td id="T_67169_row3_col1" class="data row3 col1" >2.9%</td>
#       <td id="T_67169_row3_col2" class="data row3 col2" >16.2%</td>
#       <td id="T_67169_row3_col3" class="data row3 col3" >37.2%</td>
#     </tr>
#     <tr>
#       <th id="T_67169_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_67169_row4_col0" class="data row4 col0" >33.3%</td>
#       <td id="T_67169_row4_col1" class="data row4 col1" >6.0%</td>
#       <td id="T_67169_row4_col2" class="data row4 col2" >23.4%</td>
#       <td id="T_67169_row4_col3" class="data row4 col3" >37.3%</td>
#     </tr>
#     <tr>
#       <th id="T_67169_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_67169_row5_col0" class="data row5 col0" >32.6%</td>
#       <td id="T_67169_row5_col1" class="data row5 col1" >5.4%</td>
#       <td id="T_67169_row5_col2" class="data row5 col2" >27.0%</td>
#       <td id="T_67169_row5_col3" class="data row5 col3" >34.9%</td>
#     </tr>
#     <tr>
#       <th id="T_67169_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_67169_row6_col0" class="data row6 col0" >44.6%</td>
#       <td id="T_67169_row6_col1" class="data row6 col1" >3.5%</td>
#       <td id="T_67169_row6_col2" class="data row6 col2" >22.3%</td>
#       <td id="T_67169_row6_col3" class="data row6 col3" >29.5%</td>
#     </tr>
#     <tr>
#       <th id="T_67169_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_67169_row7_col0" class="data row7 col0" >40.8%</td>
#       <td id="T_67169_row7_col1" class="data row7 col1" >3.2%</td>
#       <td id="T_67169_row7_col2" class="data row7 col2" >14.5%</td>
#       <td id="T_67169_row7_col3" class="data row7 col3" >41.5%</td>
#     </tr>
#     <tr>
#       <th id="T_67169_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_67169_row8_col0" class="data row8 col0" >34.1%</td>
#       <td id="T_67169_row8_col1" class="data row8 col1" >5.5%</td>
#       <td id="T_67169_row8_col2" class="data row8 col2" >20.3%</td>
#       <td id="T_67169_row8_col3" class="data row8 col3" >40.1%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 6. Number of accidents by Severity vs. Lighting Conditions
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='lum', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Lighting Conditions')
plt.xlabel('Lighting Condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'lum')
# Out:
# <style type="text/css">
# #T_391d0 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_391d0 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_391d0 caption {
#   caption-side: top;
# }
# #T_391d0_row0_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_391d0_row0_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_391d0_row0_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_391d0_row0_col3 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_391d0_row1_col0 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_391d0_row1_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_391d0_row1_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_391d0_row1_col3 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_391d0_row2_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_391d0_row2_col1 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_391d0_row2_col2 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_391d0_row2_col3 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_391d0_row3_col0 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_391d0_row3_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_391d0_row3_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_391d0_row3_col3 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_391d0_row4_col0 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_391d0_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_391d0_row4_col2 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_391d0_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_391d0">
#   <caption>Percentages of Accident Gravity by Lum</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_391d0_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_391d0_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_391d0_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_391d0_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >lum</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_391d0_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_391d0_row0_col0" class="data row0 col0" >43.4%</td>
#       <td id="T_391d0_row0_col1" class="data row0 col1" >2.2%</td>
#       <td id="T_391d0_row0_col2" class="data row0 col2" >14.7%</td>
#       <td id="T_391d0_row0_col3" class="data row0 col3" >39.7%</td>
#     </tr>
#     <tr>
#       <th id="T_391d0_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_391d0_row1_col0" class="data row1 col0" >40.5%</td>
#       <td id="T_391d0_row1_col1" class="data row1 col1" >2.9%</td>
#       <td id="T_391d0_row1_col2" class="data row1 col2" >17.1%</td>
#       <td id="T_391d0_row1_col3" class="data row1 col3" >39.4%</td>
#     </tr>
#     <tr>
#       <th id="T_391d0_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_391d0_row2_col0" class="data row2 col0" >32.9%</td>
#       <td id="T_391d0_row2_col1" class="data row2 col1" >6.5%</td>
#       <td id="T_391d0_row2_col2" class="data row2 col2" >23.0%</td>
#       <td id="T_391d0_row2_col3" class="data row2 col3" >37.5%</td>
#     </tr>
#     <tr>
#       <th id="T_391d0_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_391d0_row3_col0" class="data row3 col0" >37.9%</td>
#       <td id="T_391d0_row3_col1" class="data row3 col1" >3.9%</td>
#       <td id="T_391d0_row3_col2" class="data row3 col2" >16.0%</td>
#       <td id="T_391d0_row3_col3" class="data row3 col3" >42.2%</td>
#     </tr>
#     <tr>
#       <th id="T_391d0_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_391d0_row4_col0" class="data row4 col0" >41.4%</td>
#       <td id="T_391d0_row4_col1" class="data row4 col1" >1.7%</td>
#       <td id="T_391d0_row4_col2" class="data row4 col2" >12.2%</td>
#       <td id="T_391d0_row4_col3" class="data row4 col3" >44.7%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 7. Number of accidents by Severity vs. Vehicle Category
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='vehicle_category', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Vehicle Category')
plt.xlabel('Vehicle Category')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'vehicle_category')
# Out:
# <style type="text/css">
# #T_3ce2e th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_3ce2e td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_3ce2e caption {
#   caption-side: top;
# }
# #T_3ce2e_row0_col0 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_3ce2e_row0_col1, #T_3ce2e_row14_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_3ce2e_row0_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_3ce2e_row0_col3 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_3ce2e_row1_col0, #T_3ce2e_row5_col2, #T_3ce2e_row10_col2, #T_3ce2e_row14_col0, #T_3ce2e_row23_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_3ce2e_row1_col1, #T_3ce2e_row7_col1, #T_3ce2e_row10_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_3ce2e_row1_col2 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_3ce2e_row1_col3 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_3ce2e_row2_col0, #T_3ce2e_row19_col1 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_3ce2e_row2_col1, #T_3ce2e_row3_col1, #T_3ce2e_row17_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_3ce2e_row2_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_3ce2e_row2_col3 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_3ce2e_row3_col0 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_3ce2e_row3_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_3ce2e_row3_col3 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_3ce2e_row4_col0 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_3ce2e_row4_col1, #T_3ce2e_row9_col1, #T_3ce2e_row11_col1, #T_3ce2e_row23_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_3ce2e_row4_col2, #T_3ce2e_row8_col3, #T_3ce2e_row15_col0, #T_3ce2e_row27_col0 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_3ce2e_row4_col3 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_3ce2e_row5_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_3ce2e_row5_col1, #T_3ce2e_row6_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_3ce2e_row5_col3 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_3ce2e_row6_col0 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_3ce2e_row6_col2, #T_3ce2e_row7_col2 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_3ce2e_row6_col3 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_3ce2e_row7_col0 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_3ce2e_row7_col3, #T_3ce2e_row25_col0, #T_3ce2e_row30_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_3ce2e_row8_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3ce2e_row8_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_3ce2e_row8_col2 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_3ce2e_row9_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_3ce2e_row9_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_3ce2e_row9_col3 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_3ce2e_row10_col0 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_3ce2e_row10_col3 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_3ce2e_row11_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_3ce2e_row11_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_3ce2e_row11_col3, #T_3ce2e_row14_col2 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_3ce2e_row12_col0 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_3ce2e_row12_col1, #T_3ce2e_row29_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_3ce2e_row12_col2, #T_3ce2e_row17_col0, #T_3ce2e_row22_col3 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_3ce2e_row12_col3 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_3ce2e_row13_col0, #T_3ce2e_row22_col1, #T_3ce2e_row27_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_3ce2e_row13_col1, #T_3ce2e_row20_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_3ce2e_row13_col2, #T_3ce2e_row26_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_3ce2e_row13_col3, #T_3ce2e_row22_col0 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_3ce2e_row14_col3 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_3ce2e_row15_col1, #T_3ce2e_row26_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_3ce2e_row15_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_3ce2e_row15_col3, #T_3ce2e_row25_col3 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_3ce2e_row16_col0, #T_3ce2e_row28_col0 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_3ce2e_row16_col1, #T_3ce2e_row18_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_3ce2e_row16_col2 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_3ce2e_row16_col3 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_3ce2e_row17_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_3ce2e_row17_col3 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_3ce2e_row18_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_3ce2e_row18_col2 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_3ce2e_row18_col3 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_3ce2e_row19_col0 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_3ce2e_row19_col2 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_3ce2e_row19_col3 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_3ce2e_row20_col0 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_3ce2e_row20_col2, #T_3ce2e_row24_col0 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_3ce2e_row20_col3 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_3ce2e_row21_col0 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_3ce2e_row21_col1, #T_3ce2e_row27_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_3ce2e_row21_col2, #T_3ce2e_row22_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_3ce2e_row21_col3 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_3ce2e_row23_col0 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_3ce2e_row23_col3 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_3ce2e_row24_col1, #T_3ce2e_row25_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3ce2e_row24_col2 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_3ce2e_row24_col3 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_3ce2e_row25_col2, #T_3ce2e_row26_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_3ce2e_row26_col3 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_3ce2e_row27_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_3ce2e_row28_col1, #T_3ce2e_row30_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_3ce2e_row28_col2 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_3ce2e_row28_col3 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_3ce2e_row29_col0 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_3ce2e_row29_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_3ce2e_row29_col3 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_3ce2e_row30_col0 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_3ce2e_row30_col3 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3ce2e">
#   <caption>Percentages of Accident Gravity by Vehicle_category</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_3ce2e_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_3ce2e_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_3ce2e_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_3ce2e_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >vehicle_category</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ce2e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ce2e_row0_col0" class="data row0 col0" >41.9%</td>
#       <td id="T_3ce2e_row0_col1" c

# %%
# 7.1 Number of accidents by Severity vs.Year
genders = data['gender'].unique()
n_genders = len(genders)

fig, axes = plt.subplots(1, n_genders, figsize=(18, 6))
fig.suptitle('Severity Distribution per gender', fontsize=16)

custom_colors_mat = ['#66B2FF', '#99FF99', '#FFCC99', '#FF9999']

for i, gender in enumerate(genders):
    genderly_data = data[data['gender'] == gender]['gravity'].value_counts()
    colors = custom_colors_mat[:len(genderly_data)]  
    axes[i].pie(genderly_data, labels=genderly_data.index, autopct='%1.1f%%', colors=colors)
    axes[i].set_title(f'gender {gender}')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# 8. Number of accidents by Severity vs. Gender
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='gender', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.show()

calculate_and_display_percentages(data, 'gender')
# Out:
# <style type="text/css">
# #T_2012b th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_2012b td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_2012b caption {
#   caption-side: top;
# }
# #T_2012b_row0_col0 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_2012b_row0_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_2012b_row0_col2 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_2012b_row0_col3 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_2012b_row1_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_2012b_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2012b_row1_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_2012b_row1_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2012b">
#   <caption>Percentages of Accident Gravity by Gender</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_2012b_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_2012b_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_2012b_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_2012b_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2012b_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2012b_row0_col0" class="data row0 col0" >43.9%</td>
#       <td id="T_2012b_row0_col1" class="data row0 col1" >2.9%</td>
#       <td id="T_2012b_row0_col2" class="data row0 col2" >15.9%</td>
#       <td id="T_2012b_row0_col3" class="data row0 col3" >37.3%</td>
#     </tr>
#     <tr>
#       <th id="T_2012b_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2012b_row1_col0" class="data row1 col0" >37.7%</td>
#       <td id="T_2012b_row1_col1" class="data row1 col1" >1.7%</td>
#       <td id="T_2012b_row1_col2" class="data row1 col2" >13.8%</td>
#       <td id="T_2012b_row1_col3" class="data row1 col3" >46.8%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 9. Number of accidents by Severity vs. Surface Condition
plt.figure(figsize=(18,12))
sns.countplot(data=data, x='surface_condition', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Surface Condition')
plt.xlabel('Surface Condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'surface_condition')
# Out:
# <style type="text/css">
# #T_4d043 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_4d043 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_4d043 caption {
#   caption-side: top;
# }
# #T_4d043_row0_col0 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_4d043_row0_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_4d043_row0_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_4d043_row0_col3, #T_4d043_row2_col3, #T_4d043_row6_col3 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_4d043_row1_col0 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_4d043_row1_col1, #T_4d043_row4_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_4d043_row1_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_4d043_row1_col3 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_4d043_row2_col0 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_4d043_row2_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_4d043_row2_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_4d043_row3_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_4d043_row3_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_4d043_row3_col2 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_4d043_row3_col3 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_4d043_row4_col0 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_4d043_row4_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_4d043_row4_col3 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_4d043_row5_col0 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_4d043_row5_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_4d043_row5_col2 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_4d043_row5_col3, #T_4d043_row6_col0 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_4d043_row6_col1, #T_4d043_row8_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_4d043_row6_col2 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_4d043_row7_col0 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_4d043_row7_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_4d043_row7_col2 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_4d043_row7_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4d043_row8_col0 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_4d043_row8_col2 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_4d043_row8_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4d043">
#   <caption>Percentages of Accident Gravity by Surface_condition</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_4d043_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_4d043_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_4d043_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_4d043_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >surface_condition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d043_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_4d043_row0_col0" class="data row0 col0" >42.4%</td>
#       <td id="T_4d043_row0_col1" class="data row0 col1" >2.5%</td>
#       <td id="T_4d043_row0_col2" class="data row0 col2" >15.3%</td>
#       <td id="T_4d043_row0_col3" class="data row0 col3" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_4d043_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_4d043_row1_col0" class="data row1 col0" >40.5%</td>
#       <td id="T_4d043_row1_col1" class="data row1 col1" >2.7%</td>
#       <td id="T_4d043_row1_col2" class="data row1 col2" >13.9%</td>
#       <td id="T_4d043_row1_col3" class="data row1 col3" >42.9%</td>
#     </tr>
#     <tr>
#       <th id="T_4d043_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_4d043_row2_col0" class="data row2 col0" >37.9%</td>
#       <td id="T_4d043_row2_col1" class="data row2 col1" >3.3%</td>
#       <td id="T_4d043_row2_col2" class="data row2 col2" >19.0%</td>
#       <td id="T_4d043_row2_col3" class="data row2 col3" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_4d043_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_4d043_row3_col0" class="data row3 col0" >38.4%</td>
#       <td id="T_4d043_row3_col1" class="data row3 col1" >2.8%</td>
#       <td id="T_4d043_row3_col2" class="data row3 col2" >17.5%</td>
#       <td id="T_4d043_row3_col3" class="data row3 col3" >41.2%</td>
#     </tr>
#     <tr>
#       <th id="T_4d043_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_4d043_row4_col0" class="data row4 col0" >44.3%</td>
#       <td id="T_4d043_row4_col1" class="data row4 col1" >2.7%</td>
#       <td id="T_4d043_row4_col2" class="data row4 col2" >16.4%</td>
#       <td id="T_4d043_row4_col3" class="data row4 col3" >36.6%</td>
#     </tr>
#     <tr>
#       <th id="T_4d043_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_4d043_row5_col0" class="data row5 col0" >24.1%</td>
#       <td id="T_4d043_row5_col1" class="data row5 col1" >8.8%</td>
#       <td id="T_4d043_row5_col2" class="data row5 col2" >36.4%</td>
#       <td id="T_4d043_row5_col3" class="data row5 col3" >30.7%</td>
#     </tr>
#     <tr>
#       <th id="T_4d043_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_4d043_row6_col0" class="data row6 col0" >30.8%</td>
#       <td id="T_4d043_row6_col1" class="data row6 col1" >5.1%</td>
#       <td id="T_4d043_row6_col2" class="data row6 col2" >24.5%</td>
#       <td id="T_4d043_row6_col3" class="data row6 col3" >39.7%</td>
#     </tr>
#     <tr>
#       <th id="T_4d043_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_4d043_row7_col0" class="data row7 col0" >25.7%</td>
#       <td id="T_4d043_row7_col1" class="data row7 col1" >1.8%</td>
#       <td id="T_4d043_row7_col2" class="data row7 col2" >22.4%</td>
#       <td id="T_4d043_row7_col3" class="data row7 col3" >50.1%</td>
#     </tr>
#     <tr>
#       <th id="T_4d043_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_4d043_row8_col0" class="data row8 col0" >28.0%</td>
#       <td id="T_4d043_row8_col1" class="data row8 col1" >5.0%</td>
#       <td id="T_4d043_row8_col2" class="data row8 col2" >29.2%</td>
#       <td id="T_4d043_row8_col3" class="data row8 col3" >37.8%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 10. Number of accidents by Severity vs. Maximum Speed
# Define the bins and corresponding labels
bins = [0, 49, 59, 69, 79, 89, 99, 109, float('inf')]
labels = ['0-49', '50-59', '60-69', '70-79', '80-89', '90-99', '100-109', '110-119']

# Create a new column for the binned speeds
data['speed_group'] = pd.cut(data['maximum_speed'], bins=bins, labels=labels, right=False)

plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='speed_group', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Maximum Speed')
plt.xlabel('Maximum Speed Group')
plt.ylabel('Gravity')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'maximum_speed')
# Out:
# <style type="text/css">
# #T_49cb9 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_49cb9 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_49cb9 caption {
#   caption-side: top;
# }
# #T_49cb9_row0_col0, #T_49cb9_row5_col0 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_49cb9_row0_col1, #T_49cb9_row7_col1, #T_49cb9_row9_col1, #T_49cb9_row10_col1, #T_49cb9_row15_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_49cb9_row0_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_49cb9_row0_col3, #T_49cb9_row8_col0 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_49cb9_row1_col0, #T_49cb9_row14_col0, #T_49cb9_row15_col3 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_49cb9_row1_col1, #T_49cb9_row2_col1, #T_49cb9_row3_col0, #T_49cb9_row3_col1, #T_49cb9_row3_col2, #T_49cb9_row4_col1, #T_49cb9_row4_col2, #T_49cb9_row6_col1, #T_49cb9_row6_col2, #T_49cb9_row11_col1, #T_49cb9_row13_col1, #T_49cb9_row16_col1, #T_49cb9_row18_col1, #T_49cb9_row18_col3, #T_49cb9_row20_col1, #T_49cb9_row20_col3, #T_49cb9_row25_col1, #T_49cb9_row25_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_49cb9_row1_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_49cb9_row1_col3 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_49cb9_row2_col0 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_49cb9_row2_col2, #T_49cb9_row8_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_49cb9_row2_col3, #T_49cb9_row11_col0 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_49cb9_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_49cb9_row4_col0, #T_49cb9_row20_col2 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_49cb9_row4_col3, #T_49cb9_row16_col0, #T_49cb9_row16_col2, #T_49cb9_row16_col3, #T_49cb9_row20_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_49cb9_row5_col1, #T_49cb9_row22_col1, #T_49cb9_row23_col1, #T_49cb9_row24_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_49cb9_row5_col2 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_49cb9_row5_col3 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_49cb9_row6_col0, #T_49cb9_row13_col0, #T_49cb9_row18_col2 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_49cb9_row6_col3, #T_49cb9_row17_col0, #T_49cb9_row18_col0 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_49cb9_row7_col0, #T_49cb9_row10_col0 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_49cb9_row7_col2, #T_49cb9_row15_col2 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_49cb9_row7_col3, #T_49cb9_row8_col3 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_49cb9_row8_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_49cb9_row9_col0 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_49cb9_row9_col2 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_49cb9_row9_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_49cb9_row10_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_49cb9_row10_col3, #T_49cb9_row24_col0 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_49cb9_row11_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_49cb9_row11_col3 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_49cb9_row12_col0, #T_49cb9_row19_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_49cb9_row12_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_49cb9_row12_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_49cb9_row12_col3 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_49cb9_row13_col2, #T_49cb9_row13_col3 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_49cb9_row14_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_49cb9_row14_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_49cb9_row14_col3 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_49cb9_row15_col0 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_49cb9_row17_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_49cb9_row17_col2, #T_49cb9_row24_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_49cb9_row17_col3 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_49cb9_row19_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_49cb9_row19_col2 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_49cb9_row19_col3 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_49cb9_row21_col0, #T_49cb9_row21_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_49cb9_row21_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_49cb9_row21_col3 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_49cb9_row22_col0 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_49cb9_row22_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_49cb9_row22_col3, #T_49cb9_row24_col3 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_49cb9_row23_col0 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_49cb9_row23_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_49cb9_row23_col3 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_49cb9_row25_col0, #T_49cb9_row25_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_49cb9">
#   <caption>Percentages of Accident Gravity by Maximum_speed</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_49cb9_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_49cb9_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_49cb9_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_49cb9_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >maximum_speed</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49cb9_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_49cb9_row0_col0" class="data row0 col0" >44.6%</td>
#       <td id="T_49cb9_row0_col1" class="data row0 col1" >1.4%</td>
#       <td id="T_49cb9_row0_col2" class="data row0 col2" >11.7%</td>
#       <td id="T_49cb9_row0_col3" class="data row0 col3" >42.3%</td>
#     </tr>
#     <tr>
#       <th id="T_49cb9_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_49cb9_row1_col0" class="data row1 col0" >42.0%</td>
#       <td id="T_49cb9_row1_col1" class="data row1 col1" >0.0%</td>
#       <td id="T_49cb9_row1_col2" class="data row1 col2" >10.0%</td>
#       <td id="T_49cb9_row1_col3" class="data row1 col3" >48.0%</td>
#     </tr>
#     <tr>
#       <th id="T_49cb9_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_49cb9_row2_col0" class="data row2 col0" >57.1%</td>
#       <td id="T_49cb9_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_49cb9_row2_col2" class="data row2 col2" >14.3%</td>
#       <td id="T_49cb9_row2_col3" class="data row2 col3" >28.6%</td>
#     </tr>
#     <tr>
#       <th id="T_49cb9_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_49cb9_row3_col0" class="data row3 col0" >0.0%</td>
#       <td id="T_49cb9_row3_col1" class="data row3 col1" >0.0%</td>
#       <td id="T_49cb9_row3_col2" class="data row3 col2" >0.0%</td>
#       <td id="T_49cb9_row3_col3" class="data row3 col3" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_49cb9_level0_row4" class="row_heading level0 row4" >9</th>
#       <td id="T_49cb9_row4_col0" class="data row4 col0" >66.7%</td>
#       <td id="T_49cb9_row4_col1" class="data row4 col1" >0.0%</td>
#       <td id="T_49cb9_row4_col2" class="data row4 col2" >0.0%</td>
#       <td id="T_49cb9_row4_col3" class="data row4 col3" >33.3%</td>
#     </tr>
#     <tr>
#       <th id="T_49cb9_level0_row5" class="row_heading level0 row5" >10</th>
#       <td id="T_49cb9_row5_col0" class="data row5 col0" >44.7%</td>
#       <td id="T_49cb9_row5_col1" class="data row5 col1" >2.5%</td>
#       <td id="T_49cb9_row5_col2" class="data row5 col2" >13.7%</td>

# %%
# 11. Number of accidents by Severity vs. Age
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='gravity', y='age', hue_order=gravity_order, palette=custom_colors)
plt.title('Age Distribution by Accident Gravity Category')
plt.show()

calculate_and_display_percentages(data, 'age')
# Out:
# <style type="text/css">
# #T_da3c1 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_da3c1 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_da3c1 caption {
#   caption-side: top;
# }
# #T_da3c1_row0_col0, #T_da3c1_row27_col0, #T_da3c1_row33_col3, #T_da3c1_row76_col0, #T_da3c1_row78_col0 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_da3c1_row0_col1, #T_da3c1_row1_col1, #T_da3c1_row14_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_da3c1_row0_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_da3c1_row0_col3, #T_da3c1_row4_col3, #T_da3c1_row47_col0 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_da3c1_row1_col0, #T_da3c1_row37_col3, #T_da3c1_row38_col3, #T_da3c1_row43_col3 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_da3c1_row1_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_da3c1_row1_col3 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_da3c1_row2_col0, #T_da3c1_row23_col3, #T_da3c1_row25_col3, #T_da3c1_row67_col0, #T_da3c1_row77_col0 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_da3c1_row2_col1, #T_da3c1_row20_col1, #T_da3c1_row22_col1, #T_da3c1_row23_col1, #T_da3c1_row24_col1, #T_da3c1_row25_col1, #T_da3c1_row26_col1, #T_da3c1_row37_col1, #T_da3c1_row43_col1, #T_da3c1_row52_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_da3c1_row2_col2, #T_da3c1_row78_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_da3c1_row2_col3, #T_da3c1_row19_col3 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_da3c1_row3_col0, #T_da3c1_row86_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_da3c1_row3_col1, #T_da3c1_row21_col1, #T_da3c1_row51_col1, #T_da3c1_row56_col1, #T_da3c1_row57_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_da3c1_row3_col2, #T_da3c1_row89_col1 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_da3c1_row3_col3 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_da3c1_row4_col0, #T_da3c1_row80_col0, #T_da3c1_row81_col0 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_da3c1_row4_col1, #T_da3c1_row8_col1, #T_da3c1_row12_col1, #T_da3c1_row16_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_da3c1_row4_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_da3c1_row5_col0, #T_da3c1_row61_col3 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_da3c1_row5_col1, #T_da3c1_row18_col1, #T_da3c1_row28_col1, #T_da3c1_row29_col1, #T_da3c1_row38_col1, #T_da3c1_row39_col1, #T_da3c1_row45_col1, #T_da3c1_row48_col1, #T_da3c1_row50_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_da3c1_row5_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_da3c1_row5_col3 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_da3c1_row6_col0, #T_da3c1_row68_col3, #T_da3c1_row94_col3 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_da3c1_row6_col1, #T_da3c1_row7_col1, #T_da3c1_row9_col1, #T_da3c1_row10_col1, #T_da3c1_row11_col1, #T_da3c1_row13_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_da3c1_row6_col2, #T_da3c1_row48_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_da3c1_row6_col3 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_da3c1_row7_col0, #T_da3c1_row75_col3, #T_da3c1_row80_col3, #T_da3c1_row92_col0 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_da3c1_row7_col2, #T_da3c1_row12_col2, #T_da3c1_row50_col2, #T_da3c1_row52_col2, #T_da3c1_row93_col1 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_da3c1_row7_col3, #T_da3c1_row17_col3 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_da3c1_row8_col0 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_da3c1_row8_col2 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_da3c1_row8_col3 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_da3c1_row9_col0 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_da3c1_row9_col2, #T_da3c1_row54_col2 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_da3c1_row9_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_da3c1_row10_col0, #T_da3c1_row95_col0 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_da3c1_row10_col2, #T_da3c1_row56_col2, #T_da3c1_row95_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_da3c1_row10_col3 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_da3c1_row11_col0, #T_da3c1_row93_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_da3c1_row11_col2, #T_da3c1_row13_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_da3c1_row11_col3, #T_da3c1_row16_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_da3c1_row12_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_da3c1_row12_col3 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_da3c1_row13_col0 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_da3c1_row13_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_da3c1_row14_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_da3c1_row14_col2, #T_da3c1_row65_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_da3c1_row14_col3 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_da3c1_row15_col0, #T_da3c1_row71_col2, #T_da3c1_row77_col2 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_da3c1_row15_col1, #T_da3c1_row17_col1, #T_da3c1_row35_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_da3c1_row15_col2, #T_da3c1_row19_col2, #T_da3c1_row72_col2, #T_da3c1_row75_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_da3c1_row15_col3 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_da3c1_row16_col0, #T_da3c1_row17_col0 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_da3c1_row16_col2, #T_da3c1_row79_col2 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_da3c1_row17_col2 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_da3c1_row18_col0 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_da3c1_row18_col2, #T_da3c1_row73_col2, #T_da3c1_row78_col2 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_da3c1_row18_col3 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_da3c1_row19_col0, #T_da3c1_row91_col3 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_da3c1_row19_col1, #T_da3c1_row27_col1, #T_da3c1_row30_col1, #T_da3c1_row31_col1, #T_da3c1_row32_col1, #T_da3c1_row33_col1, #T_da3c1_row34_col1, #T_da3c1_row36_col1, #T_da3c1_row40_col1, #T_da3c1_row41_col1, #T_da3c1_row42_col1, #T_da3c1_row44_col1, #T_da3c1_row46_col1, #T_da3c1_row47_col1, #T_da3c1_row49_col1, #T_da3c1_row54_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_da3c1_row20_col0, #T_da3c1_row72_col3 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_da3c1_row20_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_da3c1_row20_col3, #T_da3c1_row35_col0, #T_da3c1_row53_col0, #T_da3c1_row58_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_da3c1_row21_col0, #T_da3c1_row87_col0 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_da3c1_row21_col2, #T_da3c1_row60_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_da3c1_row21_col3, #T_da3c1_row69_col0 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_da3c1_row22_col0, #T_da3c1_row35_col3 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_da3c1_row22_col2, #T_da3c1_row94_col1 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_da3c1_row22_col3, #T_da3c1_row28_col0, #T_da3c1_row29_col0 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_da3c1_row23_col0, #T_da3c1_row36_col3, #T_da3c1_row79_col0 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_da3c1_row23_col2, #T_da3c1_row24_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_da3c1_row24_col0 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_da3c1_row24_col3, #T_da3c1_row30_col0, #T_da3c1_row31_col3, #T_da3c1_row73_col0 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_da3c1_row25_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_da3c1_row25_col2, #T_da3c1_row26_col2, #T_da3c1_row49_col2 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_da3c1_row26_col0, #T_da3c1_row34_col3 {
#   background-color: #3484bf;
#   colo

# %%
# 12. Number of accidents by Severity vs. Age
plt.figure(figsize=(10, 6))
sns.kdeplot(data=data, x='age', hue='gravity', fill=True, hue_order=gravity_order, palette=custom_colors)
plt.title('Density of Age Distribution by Accident Gravity Category')
plt.show()

# %%
# 13. Number of accidents by Severity vs. Age
plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='age', y='maximum_speed', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Age vs. Maximum Speed by Accident Gravity')
plt.show()

# %%
# 14. Number of accidents by Severity vs. motor
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='motor', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. motor')
plt.xlabel('motor')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'motor')
# Out:
# <style type="text/css">
# #T_f47c7 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_f47c7 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_f47c7 caption {
#   caption-side: top;
# }
# #T_f47c7_row0_col0 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_f47c7_row0_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_f47c7_row0_col2 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_f47c7_row0_col3, #T_f47c7_row6_col0 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_f47c7_row1_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_f47c7_row1_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_f47c7_row1_col2 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_f47c7_row1_col3, #T_f47c7_row6_col3 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_f47c7_row2_col0 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_f47c7_row2_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_f47c7_row2_col2 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_f47c7_row2_col3 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_f47c7_row3_col0 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_f47c7_row3_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_f47c7_row3_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_f47c7_row3_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_f47c7_row4_col0, #T_f47c7_row4_col3 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_f47c7_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f47c7_row4_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_f47c7_row5_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_f47c7_row5_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_f47c7_row5_col2 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_f47c7_row5_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f47c7_row6_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_f47c7_row6_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# </style>
# <table id="T_f47c7">
#   <caption>Percentages of Accident Gravity by Motor</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_f47c7_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_f47c7_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_f47c7_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_f47c7_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >motor</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f47c7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f47c7_row0_col0" class="data row0 col0" >44.4%</td>
#       <td id="T_f47c7_row0_col1" class="data row0 col1" >1.9%</td>
#       <td id="T_f47c7_row0_col2" class="data row0 col2" >14.1%</td>
#       <td id="T_f47c7_row0_col3" class="data row0 col3" >39.6%</td>
#     </tr>
#     <tr>
#       <th id="T_f47c7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f47c7_row1_col0" class="data row1 col0" >43.8%</td>
#       <td id="T_f47c7_row1_col1" class="data row1 col1" >2.6%</td>
#       <td id="T_f47c7_row1_col2" class="data row1 col2" >15.1%</td>
#       <td id="T_f47c7_row1_col3" class="data row1 col3" >38.5%</td>
#     </tr>
#     <tr>
#       <th id="T_f47c7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f47c7_row2_col0" class="data row2 col0" >60.2%</td>
#       <td id="T_f47c7_row2_col1" class="data row2 col1" >1.1%</td>
#       <td id="T_f47c7_row2_col2" class="data row2 col2" >6.6%</td>
#       <td id="T_f47c7_row2_col3" class="data row2 col3" >32.1%</td>
#     </tr>
#     <tr>
#       <th id="T_f47c7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f47c7_row3_col0" class="data row3 col0" >24.0%</td>
#       <td id="T_f47c7_row3_col1" class="data row3 col1" >2.0%</td>
#       <td id="T_f47c7_row3_col2" class="data row3 col2" >12.8%</td>
#       <td id="T_f47c7_row3_col3" class="data row3 col3" >61.2%</td>
#     </tr>
#     <tr>
#       <th id="T_f47c7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f47c7_row4_col0" class="data row4 col0" >43.5%</td>
#       <td id="T_f47c7_row4_col1" class="data row4 col1" >0.7%</td>
#       <td id="T_f47c7_row4_col2" class="data row4 col2" >12.2%</td>
#       <td id="T_f47c7_row4_col3" class="data row4 col3" >43.5%</td>
#     </tr>
#     <tr>
#       <th id="T_f47c7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f47c7_row5_col0" class="data row5 col0" >7.9%</td>
#       <td id="T_f47c7_row5_col1" class="data row5 col1" >3.4%</td>
#       <td id="T_f47c7_row5_col2" class="data row5 col2" >23.2%</td>
#       <td id="T_f47c7_row5_col3" class="data row5 col3" >65.5%</td>
#     </tr>
#     <tr>
#       <th id="T_f47c7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f47c7_row6_col0" class="data row6 col0" >39.5%</td>
#       <td id="T_f47c7_row6_col1" class="data row6 col1" >3.0%</td>
#       <td id="T_f47c7_row6_col2" class="data row6 col2" >19.1%</td>
#       <td id="T_f47c7_row6_col3" class="data row6 col3" >38.4%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 15. Number of accidents by Severity vs. Impact point
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='initial_impact_point', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Impact point')
plt.xlabel('Impact point')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'initial_impact_point')
# Out:
# <style type="text/css">
# #T_9f475 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_9f475 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_9f475 caption {
#   caption-side: top;
# }
# #T_9f475_row0_col0 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_9f475_row0_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_9f475_row0_col2 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_9f475_row0_col3 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_9f475_row1_col0 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_9f475_row1_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_9f475_row1_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_9f475_row1_col3 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_9f475_row2_col0 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_9f475_row2_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_9f475_row2_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_9f475_row2_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_9f475_row3_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_9f475_row3_col1, #T_9f475_row8_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_9f475_row3_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_9f475_row3_col3, #T_9f475_row6_col3 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_9f475_row4_col0 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_9f475_row4_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_9f475_row4_col2 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_9f475_row4_col3 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_9f475_row5_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9f475_row5_col1, #T_9f475_row6_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9f475_row5_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_9f475_row5_col3 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_9f475_row6_col0 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_9f475_row6_col2 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_9f475_row7_col0, #T_9f475_row8_col0 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_9f475_row7_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_9f475_row7_col2, #T_9f475_row9_col0 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_9f475_row7_col3 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_9f475_row8_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_9f475_row8_col3 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_9f475_row9_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_9f475_row9_col2 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_9f475_row9_col3 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9f475">
#   <caption>Percentages of Accident Gravity by Initial_impact_point</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_9f475_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_9f475_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_9f475_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_9f475_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >initial_impact_point</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f475_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9f475_row0_col0" class="data row0 col0" >32.9%</td>
#       <td id="T_9f475_row0_col1" class="data row0 col1" >3.9%</td>
#       <td id="T_9f475_row0_col2" class="data row0 col2" >20.1%</td>
#       <td id="T_9f475_row0_col3" class="data row0 col3" >43.0%</td>
#     </tr>
#     <tr>
#       <th id="T_9f475_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9f475_row1_col0" class="data row1 col0" >34.5%</td>
#       <td id="T_9f475_row1_col1" class="data row1 col1" >3.1%</td>
#       <td id="T_9f475_row1_col2" class="data row1 col2" >19.4%</td>
#       <td id="T_9f475_row1_col3" class="data row1 col3" >43.0%</td>
#     </tr>
#     <tr>
#       <th id="T_9f475_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9f475_row2_col0" class="data row2 col0" >50.7%</td>
#       <td id="T_9f475_row2_col1" class="data row2 col1" >2.2%</td>
#       <td id="T_9f475_row2_col2" class="data row2 col2" >12.7%</td>
#       <td id="T_9f475_row2_col3" class="data row2 col3" >34.4%</td>
#     </tr>
#     <tr>
#       <th id="T_9f475_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9f475_row3_col0" class="data row3 col0" >50.4%</td>
#       <td id="T_9f475_row3_col1" class="data row3 col1" >2.4%</td>
#       <td id="T_9f475_row3_col2" class="data row3 col2" >13.3%</td>
#       <td id="T_9f475_row3_col3" class="data row3 col3" >33.9%</td>
#     </tr>
#     <tr>
#       <th id="T_9f475_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9f475_row4_col0" class="data row4 col0" >46.8%</td>
#       <td id="T_9f475_row4_col1" class="data row4 col1" >1.1%</td>
#       <td id="T_9f475_row4_col2" class="data row4 col2" >6.1%</td>
#       <td id="T_9f475_row4_col3" class="data row4 col3" >46.1%</td>
#     </tr>
#     <tr>
#       <th id="T_9f475_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9f475_row5_col0" class="data row5 col0" >62.3%</td>
#       <td id="T_9f475_row5_col1" class="data row5 col1" >1.0%</td>
#       <td id="T_9f475_row5_col2" class="data row5 col2" >6.6%</td>
#       <td id="T_9f475_row5_col3" class="data row5 col3" >30.2%</td>
#     </tr>
#     <tr>
#       <th id="T_9f475_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9f475_row6_col0" class="data row6 col0" >59.6%</td>
#       <td id="T_9f475_row6_col1" class="data row6 col1" >0.8%</td>
#       <td id="T_9f475_row6_col2" class="data row6 col2" >5.8%</td>
#       <td id="T_9f475_row6_col3" class="data row6 col3" >33.8%</td>
#     </tr>
#     <tr>
#       <th id="T_9f475_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9f475_row7_col0" class="data row7 col0" >38.5%</td>
#       <td id="T_9f475_row7_col1" class="data row7 col1" >2.5%</td>
#       <td id="T_9f475_row7_col2" class="data row7 col2" >15.7%</td>
#       <td id="T_9f475_row7_col3" class="data row7 col3" >43.3%</td>
#     </tr>
#     <tr>
#       <th id="T_9f475_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9f475_row8_col0" class="data row8 col0" >38.5%</td>
#       <td id="T_9f475_row8_col1" class="data row8 col1" >2.4%</td>
#       <td id="T_9f475_row8_col2" class="data row8 col2" >15.5%</td>
#       <td id="T_9f475_row8_col3" class="data row8 col3" >43.6%</td>
#     </tr>
#     <tr>
#       <th id="T_9f475_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9f475_row9_col0" class="data row9 col0" >15.7%</td>
#       <td id="T_9f475_row9_col1" class="data row9 col1" >6.3%</td>
#       <td id="T_9f475_row9_col2" class="data row9 col2" >28.6%</td>
#       <td id="T_9f475_row9_col3" class="data row9 col3" >49.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 16. Number of accidents by Severity vs. Safety equipment
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='safety_equipment1', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Safety equipment')
plt.xlabel('Safety equipment')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'safety_equipment1')
# Out:
# <style type="text/css">
# #T_0ee2d th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_0ee2d td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_0ee2d caption {
#   caption-side: top;
# }
# #T_0ee2d_row0_col0, #T_0ee2d_row3_col2 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_0ee2d_row0_col1 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_0ee2d_row0_col2, #T_0ee2d_row1_col3 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_0ee2d_row0_col3 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_0ee2d_row1_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0ee2d_row1_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_0ee2d_row1_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_0ee2d_row2_col0 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_0ee2d_row2_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_0ee2d_row2_col2 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_0ee2d_row2_col3 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_0ee2d_row3_col0 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_0ee2d_row3_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_0ee2d_row3_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_0ee2d_row4_col0 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_0ee2d_row4_col1 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_0ee2d_row4_col2 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_0ee2d_row4_col3 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_0ee2d_row5_col0 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_0ee2d_row5_col1 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_0ee2d_row5_col2 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_0ee2d_row5_col3 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_0ee2d_row6_col0 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_0ee2d_row6_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_0ee2d_row6_col2 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_0ee2d_row6_col3 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_0ee2d_row7_col0 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_0ee2d_row7_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0ee2d_row7_col2 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_0ee2d_row7_col3 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_0ee2d_row8_col0 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_0ee2d_row8_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_0ee2d_row8_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_0ee2d_row8_col3 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_0ee2d_row9_col0 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_0ee2d_row9_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_0ee2d_row9_col2 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_0ee2d_row9_col3 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# </style>
# <table id="T_0ee2d">
#   <caption>Percentages of Accident Gravity by Safety_equipment1</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_0ee2d_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_0ee2d_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_0ee2d_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_0ee2d_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >safety_equipment1</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ee2d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0ee2d_row0_col0" class="data row0 col0" >8.2%</td>
#       <td id="T_0ee2d_row0_col1" class="data row0 col1" >7.4%</td>
#       <td id="T_0ee2d_row0_col2" class="data row0 col2" >31.1%</td>
#       <td id="T_0ee2d_row0_col3" class="data row0 col3" >53.3%</td>
#     </tr>
#     <tr>
#       <th id="T_0ee2d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0ee2d_row1_col0" class="data row1 col0" >59.0%</td>
#       <td id="T_0ee2d_row1_col1" class="data row1 col1" >1.5%</td>
#       <td id="T_0ee2d_row1_col2" class="data row1 col2" >8.4%</td>
#       <td id="T_0ee2d_row1_col3" class="data row1 col3" >31.2%</td>
#     </tr>
#     <tr>
#       <th id="T_0ee2d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0ee2d_row2_col0" class="data row2 col0" >9.6%</td>
#       <td id="T_0ee2d_row2_col1" class="data row2 col1" >3.5%</td>
#       <td id="T_0ee2d_row2_col2" class="data row2 col2" >29.0%</td>
#       <td id="T_0ee2d_row2_col3" class="data row2 col3" >58.0%</td>
#     </tr>
#     <tr>
#       <th id="T_0ee2d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0ee2d_row3_col0" class="data row3 col0" >46.9%</td>
#       <td id="T_0ee2d_row3_col1" class="data row3 col1" >1.2%</td>
#       <td id="T_0ee2d_row3_col2" class="data row3 col2" >8.1%</td>
#       <td id="T_0ee2d_row3_col3" class="data row3 col3" >43.9%</td>
#     </tr>
#     <tr>
#       <th id="T_0ee2d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0ee2d_row4_col0" class="data row4 col0" >15.8%</td>
#       <td id="T_0ee2d_row4_col1" class="data row4 col1" >10.9%</td>
#       <td id="T_0ee2d_row4_col2" class="data row4 col2" >43.2%</td>
#       <td id="T_0ee2d_row4_col3" class="data row4 col3" >30.2%</td>
#     </tr>
#     <tr>
#       <th id="T_0ee2d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0ee2d_row5_col0" class="data row5 col0" >25.8%</td>
#       <td id="T_0ee2d_row5_col1" class="data row5 col1" >10.1%</td>
#       <td id="T_0ee2d_row5_col2" class="data row5 col2" >36.4%</td>
#       <td id="T_0ee2d_row5_col3" class="data row5 col3" >27.6%</td>
#     </tr>
#     <tr>
#       <th id="T_0ee2d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0ee2d_row6_col0" class="data row6 col0" >7.1%</td>
#       <td id="T_0ee2d_row6_col1" class="data row6 col1" >7.8%</td>
#       <td id="T_0ee2d_row6_col2" class="data row6 col2" >58.1%</td>
#       <td id="T_0ee2d_row6_col3" class="data row6 col3" >27.0%</td>
#     </tr>
#     <tr>
#       <th id="T_0ee2d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0ee2d_row7_col0" class="data row7 col0" >7.1%</td>
#       <td id="T_0ee2d_row7_col1" class="data row7 col1" >0.0%</td>
#       <td id="T_0ee2d_row7_col2" class="data row7 col2" >50.0%</td>
#       <td id="T_0ee2d_row7_col3" class="data row7 col3" >42.9%</td>
#     </tr>
#     <tr>
#       <th id="T_0ee2d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0ee2d_row8_col0" class="data row8 col0" >33.1%</td>
#       <td id="T_0ee2d_row8_col1" class="data row8 col1" >3.0%</td>
#       <td id="T_0ee2d_row8_col2" class="data row8 col2" >15.6%</td>
#       <td id="T_0ee2d_row8_col3" class="data row8 col3" >48.3%</td>
#     </tr>
#     <tr>
#       <th id="T_0ee2d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0ee2d_row9_col0" class="data row9 col0" >36.9%</td>
#       <td id="T_0ee2d_row9_col1" class="data row9 col1" >4.8%</td>
#       <td id="T_0ee2d_row9_col2" class="data row9 col2" >30.9%</td>
#       <td id="T_0ee2d_row9_col3" class="data row9 col3" >27.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 17. Number of accidents by Severity vs. Manv
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='manv', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. manv')
plt.xlabel('manv')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'manv')
# Out:
# <style type="text/css">
# #T_db2b6 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_db2b6 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_db2b6 caption {
#   caption-side: top;
# }
# #T_db2b6_row0_col0 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_db2b6_row0_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_db2b6_row0_col2, #T_db2b6_row18_col0 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_db2b6_row0_col3 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_db2b6_row1_col0, #T_db2b6_row13_col3 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_db2b6_row1_col1, #T_db2b6_row4_col1, #T_db2b6_row19_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_db2b6_row1_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_db2b6_row1_col3 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_db2b6_row2_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_db2b6_row2_col1, #T_db2b6_row3_col1, #T_db2b6_row11_col1, #T_db2b6_row16_col1, #T_db2b6_row20_col1, #T_db2b6_row24_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_db2b6_row2_col2 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_db2b6_row2_col3, #T_db2b6_row5_col3 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_db2b6_row3_col0, #T_db2b6_row7_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_db2b6_row3_col2 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_db2b6_row3_col3 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_db2b6_row4_col0 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_db2b6_row4_col2 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_db2b6_row4_col3, #T_db2b6_row13_col2 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_db2b6_row5_col0 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_db2b6_row5_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_db2b6_row5_col2, #T_db2b6_row8_col0 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_db2b6_row6_col0 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_db2b6_row6_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_db2b6_row6_col2, #T_db2b6_row17_col0 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_db2b6_row6_col3 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_db2b6_row7_col0, #T_db2b6_row20_col3 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_db2b6_row7_col1, #T_db2b6_row25_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_db2b6_row7_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_db2b6_row8_col1, #T_db2b6_row22_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_db2b6_row8_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_db2b6_row8_col3 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_db2b6_row9_col0 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_db2b6_row9_col1, #T_db2b6_row10_col1, #T_db2b6_row12_col1, #T_db2b6_row15_col1, #T_db2b6_row22_col2, #T_db2b6_row23_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_db2b6_row9_col2, #T_db2b6_row11_col2, #T_db2b6_row15_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_db2b6_row9_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_db2b6_row10_col0 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_db2b6_row10_col2, #T_db2b6_row24_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_db2b6_row10_col3 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_db2b6_row11_col0 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_db2b6_row11_col3 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_db2b6_row12_col0 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_db2b6_row12_col2, #T_db2b6_row23_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_db2b6_row12_col3, #T_db2b6_row15_col3 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_db2b6_row13_col0 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_db2b6_row13_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_db2b6_row14_col0, #T_db2b6_row25_col0 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_db2b6_row14_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_db2b6_row14_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_db2b6_row14_col3 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_db2b6_row15_col0 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_db2b6_row16_col0 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_db2b6_row16_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_db2b6_row16_col3 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_db2b6_row17_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_db2b6_row17_col2 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_db2b6_row17_col3 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_db2b6_row18_col1, #T_db2b6_row21_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_db2b6_row18_col2, #T_db2b6_row26_col2 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_db2b6_row18_col3 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_db2b6_row19_col0 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_db2b6_row19_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_db2b6_row19_col3, #T_db2b6_row23_col3 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_db2b6_row20_col0 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_db2b6_row20_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_db2b6_row21_col0 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_db2b6_row21_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_db2b6_row21_col3 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_db2b6_row22_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_db2b6_row22_col3 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_db2b6_row23_col0 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_db2b6_row24_col0 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_db2b6_row24_col3 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_db2b6_row25_col2 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_db2b6_row25_col3 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_db2b6_row26_col0 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_db2b6_row26_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_db2b6_row26_col3 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# </style>
# <table id="T_db2b6">
#   <caption>Percentages of Accident Gravity by Manv</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_db2b6_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_db2b6_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_db2b6_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_db2b6_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manv</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db2b6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db2b6_row0_col0" class="data row0 col0" >34.8%</td>
#       <td id="T_db2b6_row0_col1" class="data row0 col1" >4.1%</td>
#       <td id="T_db2b6_row0_col2" class="data row0 col2" >19.8%</td>
#       <td id="T_db2b6_row0_col3" class="data row0 col3" >41.3%</td>
#     </tr>
#     <tr>
#       <th id="T_db2b6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_db2b6_row1_col0" class="data row1 col0" >36.7%</td>
#       <td id="T_db2b6_row1_col1" class="data row1 col1" >2.7%</td>
#       <td id="T_db2b6_row1_col2" class="data row1 col2" >17.8%</td>
#       <td id="T_db2b6_row1_col3" class="data row1 col3" >42.8%</td>
#     </tr>
#     <tr>
#       <th id="T_db2b6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_db2b6_row2_col0" class="data row2 col0" >48.2%</td>
#       <td id="T_db2b6_row2_col1" class="data row2 col1" >1.2%</t

# %%
# 18. Number of accidents by Severity vs. user_category
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='user_category', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. user_category')
plt.xlabel('user_category')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'user_category')
# Out:
# <style type="text/css">
# #T_1bcd4 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_1bcd4 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_1bcd4 caption {
#   caption-side: top;
# }
# #T_1bcd4_row0_col0 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_1bcd4_row0_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_1bcd4_row0_col2, #T_1bcd4_row1_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_1bcd4_row0_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_1bcd4_row1_col0 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_1bcd4_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_1bcd4_row1_col3 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_1bcd4_row2_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_1bcd4_row2_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_1bcd4_row2_col2 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_1bcd4_row2_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1bcd4">
#   <caption>Percentages of Accident Gravity by User_category</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_1bcd4_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_1bcd4_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_1bcd4_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_1bcd4_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >user_category</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bcd4_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_1bcd4_row0_col0" class="data row0 col0" >47.4%</td>
#       <td id="T_1bcd4_row0_col1" class="data row0 col1" >2.4%</td>
#       <td id="T_1bcd4_row0_col2" class="data row0 col2" >14.1%</td>
#       <td id="T_1bcd4_row0_col3" class="data row0 col3" >36.1%</td>
#     </tr>
#     <tr>
#       <th id="T_1bcd4_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_1bcd4_row1_col0" class="data row1 col0" >36.2%</td>
#       <td id="T_1bcd4_row1_col1" class="data row1 col1" >2.0%</td>
#       <td id="T_1bcd4_row1_col2" class="data row1 col2" >14.1%</td>
#       <td id="T_1bcd4_row1_col3" class="data row1 col3" >47.7%</td>
#     </tr>
#     <tr>
#       <th id="T_1bcd4_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_1bcd4_row2_col0" class="data row2 col0" >2.9%</td>
#       <td id="T_1bcd4_row2_col1" class="data row2 col1" >4.8%</td>
#       <td id="T_1bcd4_row2_col2" class="data row2 col2" >27.9%</td>
#       <td id="T_1bcd4_row2_col3" class="data row2 col3" >64.4%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 19. Number of accidents by Severity vs. seat
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='seat', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. seat')
plt.xlabel('seat')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'seat')
# Out:
# <style type="text/css">
# #T_6d7ef th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_6d7ef td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_6d7ef caption {
#   caption-side: top;
# }
# #T_6d7ef_row0_col0, #T_6d7ef_row7_col3 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_6d7ef_row0_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_6d7ef_row0_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_6d7ef_row0_col3 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_6d7ef_row1_col0 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_6d7ef_row1_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_6d7ef_row1_col2 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_6d7ef_row1_col3 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_6d7ef_row2_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_6d7ef_row2_col1, #T_6d7ef_row3_col1, #T_6d7ef_row5_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6d7ef_row2_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_6d7ef_row2_col3 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_6d7ef_row3_col0 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_6d7ef_row3_col2 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_6d7ef_row3_col3 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_6d7ef_row4_col0 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_6d7ef_row4_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_6d7ef_row4_col2 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_6d7ef_row4_col3 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_6d7ef_row5_col0 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_6d7ef_row5_col2 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_6d7ef_row5_col3 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_6d7ef_row6_col0 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_6d7ef_row6_col1, #T_6d7ef_row7_col1, #T_6d7ef_row8_col1, #T_6d7ef_row9_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_6d7ef_row6_col2 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_6d7ef_row6_col3 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_6d7ef_row7_col0 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_6d7ef_row7_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_6d7ef_row8_col0 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_6d7ef_row8_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_6d7ef_row8_col3 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_6d7ef_row9_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_6d7ef_row9_col2 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_6d7ef_row9_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6d7ef">
#   <caption>Percentages of Accident Gravity by Seat</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_6d7ef_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_6d7ef_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_6d7ef_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_6d7ef_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >seat</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d7ef_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_6d7ef_row0_col0" class="data row0 col0" >47.5%</td>
#       <td id="T_6d7ef_row0_col1" class="data row0 col1" >2.4%</td>
#       <td id="T_6d7ef_row0_col2" class="data row0 col2" >14.1%</td>
#       <td id="T_6d7ef_row0_col3" class="data row0 col3" >36.0%</td>
#     </tr>
#     <tr>
#       <th id="T_6d7ef_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_6d7ef_row1_col0" class="data row1 col0" >34.4%</td>
#       <td id="T_6d7ef_row1_col1" class="data row1 col1" >2.0%</td>
#       <td id="T_6d7ef_row1_col2" class="data row1 col2" >15.0%</td>
#       <td id="T_6d7ef_row1_col3" class="data row1 col3" >48.6%</td>
#     </tr>
#     <tr>
#       <th id="T_6d7ef_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_6d7ef_row2_col0" class="data row2 col0" >38.4%</td>
#       <td id="T_6d7ef_row2_col1" class="data row2 col1" >1.4%</td>
#       <td id="T_6d7ef_row2_col2" class="data row2 col2" >8.6%</td>
#       <td id="T_6d7ef_row2_col3" class="data row2 col3" >51.5%</td>
#     </tr>
#     <tr>
#       <th id="T_6d7ef_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_6d7ef_row3_col0" class="data row3 col0" >38.7%</td>
#       <td id="T_6d7ef_row3_col1" class="data row3 col1" >1.2%</td>
#       <td id="T_6d7ef_row3_col2" class="data row3 col2" >8.3%</td>
#       <td id="T_6d7ef_row3_col3" class="data row3 col3" >51.7%</td>
#     </tr>
#     <tr>
#       <th id="T_6d7ef_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_6d7ef_row4_col0" class="data row4 col0" >36.5%</td>
#       <td id="T_6d7ef_row4_col1" class="data row4 col1" >1.8%</td>
#       <td id="T_6d7ef_row4_col2" class="data row4 col2" >10.4%</td>
#       <td id="T_6d7ef_row4_col3" class="data row4 col3" >51.3%</td>
#     </tr>
#     <tr>
#       <th id="T_6d7ef_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_6d7ef_row5_col0" class="data row5 col0" >43.8%</td>
#       <td id="T_6d7ef_row5_col1" class="data row5 col1" >1.5%</td>
#       <td id="T_6d7ef_row5_col2" class="data row5 col2" >11.1%</td>
#       <td id="T_6d7ef_row5_col3" class="data row5 col3" >43.6%</td>
#     </tr>
#     <tr>
#       <th id="T_6d7ef_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_6d7ef_row6_col0" class="data row6 col0" >39.6%</td>
#       <td id="T_6d7ef_row6_col1" class="data row6 col1" >2.9%</td>
#       <td id="T_6d7ef_row6_col2" class="data row6 col2" >20.0%</td>
#       <td id="T_6d7ef_row6_col3" class="data row6 col3" >37.5%</td>
#     </tr>
#     <tr>
#       <th id="T_6d7ef_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_6d7ef_row7_col0" class="data row7 col0" >33.4%</td>
#       <td id="T_6d7ef_row7_col1" class="data row7 col1" >2.9%</td>
#       <td id="T_6d7ef_row7_col2" class="data row7 col2" >16.2%</td>
#       <td id="T_6d7ef_row7_col3" class="data row7 col3" >47.5%</td>
#     </tr>
#     <tr>
#       <th id="T_6d7ef_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_6d7ef_row8_col0" class="data row8 col0" >42.1%</td>
#       <td id="T_6d7ef_row8_col1" class="data row8 col1" >2.9%</td>
#       <td id="T_6d7ef_row8_col2" class="data row8 col2" >19.9%</td>
#       <td id="T_6d7ef_row8_col3" class="data row8 col3" >35.1%</td>
#     </tr>
#     <tr>
#       <th id="T_6d7ef_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_6d7ef_row9_col0" class="data row9 col0" >2.9%</td>
#       <td id="T_6d7ef_row9_col1" class="data row9 col1" >4.8%</td>
#       <td id="T_6d7ef_row9_col2" class="data row9 col2" >27.9%</td>
#       <td id="T_6d7ef_row9_col3" class="data row9 col3" >64.4%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 20. Number of accidents by Severity vs. fixed_obstacle
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='fixed_obstacle', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. fixed_obstacle')
plt.xlabel('fixed_obstacle')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'fixed_obstacle')
# Out:
# <style type="text/css">
# #T_b3ffa th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_b3ffa td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_b3ffa caption {
#   caption-side: top;
# }
# #T_b3ffa_row0_col0, #T_b3ffa_row5_col3 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_b3ffa_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b3ffa_row0_col2, #T_b3ffa_row2_col0 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_b3ffa_row0_col3 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_b3ffa_row1_col0, #T_b3ffa_row2_col3 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_b3ffa_row1_col1, #T_b3ffa_row4_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_b3ffa_row1_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_b3ffa_row1_col3, #T_b3ffa_row12_col3 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_b3ffa_row2_col1 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_b3ffa_row2_col2, #T_b3ffa_row13_col2 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_b3ffa_row3_col0 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_b3ffa_row3_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_b3ffa_row3_col2 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_b3ffa_row3_col3 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_b3ffa_row4_col0, #T_b3ffa_row14_col2, #T_b3ffa_row16_col0 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_b3ffa_row4_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_b3ffa_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b3ffa_row5_col0 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_b3ffa_row5_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_b3ffa_row5_col2 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_b3ffa_row6_col0 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_b3ffa_row6_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_b3ffa_row6_col2 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_b3ffa_row6_col3, #T_b3ffa_row10_col3 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_b3ffa_row7_col0 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_b3ffa_row7_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_b3ffa_row7_col2 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_b3ffa_row7_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_b3ffa_row8_col0 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_b3ffa_row8_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_b3ffa_row8_col2 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_b3ffa_row8_col3 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_b3ffa_row9_col0 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_b3ffa_row9_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_b3ffa_row9_col2, #T_b3ffa_row10_col0 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_b3ffa_row9_col3 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_b3ffa_row10_col1 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_b3ffa_row10_col2 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_b3ffa_row11_col0 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_b3ffa_row11_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_b3ffa_row11_col2 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_b3ffa_row11_col3 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_b3ffa_row12_col0 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_b3ffa_row12_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_b3ffa_row12_col2 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_b3ffa_row13_col0 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_b3ffa_row13_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_b3ffa_row13_col3 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_b3ffa_row14_col0 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_b3ffa_row14_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_b3ffa_row14_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_b3ffa_row15_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_b3ffa_row15_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_b3ffa_row15_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_b3ffa_row15_col3 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_b3ffa_row16_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_b3ffa_row16_col2 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_b3ffa_row16_col3 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_b3ffa_row17_col0 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_b3ffa_row17_col1 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_b3ffa_row17_col2 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_b3ffa_row17_col3 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# </style>
# <table id="T_b3ffa">
#   <caption>Percentages of Accident Gravity by Fixed_obstacle</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_b3ffa_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_b3ffa_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_b3ffa_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_b3ffa_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >fixed_obstacle</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3ffa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3ffa_row0_col0" class="data row0 col0" >45.8%</td>
#       <td id="T_b3ffa_row0_col1" class="data row0 col1" >1.8%</td>
#       <td id="T_b3ffa_row0_col2" class="data row0 col2" >12.9%</td>
#       <td id="T_b3ffa_row0_col3" class="data row0 col3" >39.5%</td>
#     </tr>
#     <tr>
#       <th id="T_b3ffa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b3ffa_row1_col0" class="data row1 col0" >30.8%</td>
#       <td id="T_b3ffa_row1_col1" class="data row1 col1" >2.5%</td>
#       <td id="T_b3ffa_row1_col2" class="data row1 col2" >15.1%</td>
#       <td id="T_b3ffa_row1_col3" class="data row1 col3" >51.7%</td>
#     </tr>
#     <tr>
#       <th id="T_b3ffa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b3ffa_row2_col0" class="data row2 col0" >13.0%</td>
#       <td id="T_b3ffa_row2_col1" class="data row2 col1" >14.9%</td>
#       <td id="T_b3ffa_row2_col2" class="data row2 col2" >41.4%</td>
#       <td id="T_b3ffa_row2_col3" class="data row2 col3" >30.8%</td>
#     </tr>
#     <tr>
#       <th id="T_b3ffa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b3ffa_row3_col0" class="data row3 col0" >21.0%</td>
#       <td id="T_b3ffa_row3_col1" class="data row3 col1" >6.9%</td>
#       <td id="T_b3ffa_row3_col2" class="data row3 col2" >23.4%</td>
#       <td id="T_b3ffa_row3_col3" class="data row3 col3" >48.7%</td>
#     </tr>
#     <tr>
#       <th id="T_b3ffa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b3ffa_row4_col0" class="data row4 col0" >19.3%</td>
#       <td id="T_b3ffa_row4_col1" class="data row4 col1" >2.5%</td>
#       <td id="T_b3ffa_row4_col2" class="data row4 col2" >13.7%</td>
#       <td id="T_b3ffa_row4_col3" class="data row4 col3" >64.6%</td>
#     </tr>
#     <tr>
#       <th id="T_b3ffa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b3ffa_row5_col0" class="data row5 col0" >18.2%</td>
#       <td id="T_b3ffa_row5_col1" class="data row5 col1" >6.6%</td>
#       <td id="T_b3ffa_row5_col2" class="data row5 col2" >29.4%</td>
#       <td id="T_b3ffa_row5_col3" class="data row5 col3" >45.7%</td>
#     </tr>
#     <tr>
#       <th id="T_b3ffa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b3ffa_row6_col0" class="data row6 col0" >16.4%</td>
#       <td id="T_b3ffa_row6_col1" class="data row6 col1" >9.1%</td>
#       <td id="T_b3ffa_

# %%
# 21. Number of accidents by Severity vs. Collision type
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='collision_type', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Collision type')
plt.xlabel('collision_type')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'collision_type')
# Out:
# <style type="text/css">
# #T_d4147 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_d4147 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_d4147 caption {
#   caption-side: top;
# }
# #T_d4147_row0_col0 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_d4147_row0_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_d4147_row0_col2 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_d4147_row0_col3 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_d4147_row1_col0 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_d4147_row1_col1, #T_d4147_row2_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_d4147_row1_col2 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_d4147_row1_col3 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_d4147_row2_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_d4147_row2_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_d4147_row2_col3 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_d4147_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d4147_row3_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d4147_row3_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_d4147_row3_col3 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_d4147_row4_col0 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_d4147_row4_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_d4147_row4_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_d4147_row4_col3 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_d4147_row5_col0 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_d4147_row5_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_d4147_row5_col2 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_d4147_row5_col3 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_d4147_row6_col0 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_d4147_row6_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_d4147_row6_col2 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_d4147_row6_col3 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d4147">
#   <caption>Percentages of Accident Gravity by Collision_type</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_d4147_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_d4147_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_d4147_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_d4147_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >collision_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4147_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d4147_row0_col0" class="data row0 col0" >36.2%</td>
#       <td id="T_d4147_row0_col1" class="data row0 col1" >4.2%</td>
#       <td id="T_d4147_row0_col2" class="data row0 col2" >22.7%</td>
#       <td id="T_d4147_row0_col3" class="data row0 col3" >36.8%</td>
#     </tr>
#     <tr>
#       <th id="T_d4147_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d4147_row1_col0" class="data row1 col0" >47.0%</td>
#       <td id="T_d4147_row1_col1" class="data row1 col1" >1.0%</td>
#       <td id="T_d4147_row1_col2" class="data row1 col2" >7.9%</td>
#       <td id="T_d4147_row1_col3" class="data row1 col3" >44.1%</td>
#     </tr>
#     <tr>
#       <th id="T_d4147_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d4147_row2_col0" class="data row2 col0" >46.8%</td>
#       <td id="T_d4147_row2_col1" class="data row2 col1" >1.1%</td>
#       <td id="T_d4147_row2_col2" class="data row2 col2" >11.7%</td>
#       <td id="T_d4147_row2_col3" class="data row2 col3" >40.5%</td>
#     </tr>
#     <tr>
#       <th id="T_d4147_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_d4147_row3_col0" class="data row3 col0" >57.7%</td>
#       <td id="T_d4147_row3_col1" class="data row3 col1" >0.5%</td>
#       <td id="T_d4147_row3_col2" class="data row3 col2" >3.8%</td>
#       <td id="T_d4147_row3_col3" class="data row3 col3" >37.9%</td>
#     </tr>
#     <tr>
#       <th id="T_d4147_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_d4147_row4_col0" class="data row4 col0" >51.9%</td>
#       <td id="T_d4147_row4_col1" class="data row4 col1" >2.1%</td>
#       <td id="T_d4147_row4_col2" class="data row4 col2" >10.7%</td>
#       <td id="T_d4147_row4_col3" class="data row4 col3" >35.3%</td>
#     </tr>
#     <tr>
#       <th id="T_d4147_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_d4147_row5_col0" class="data row5 col0" >35.7%</td>
#       <td id="T_d4147_row5_col1" class="data row5 col1" >4.6%</td>
#       <td id="T_d4147_row5_col2" class="data row5 col2" >20.4%</td>
#       <td id="T_d4147_row5_col3" class="data row5 col3" >39.4%</td>
#     </tr>
#     <tr>
#       <th id="T_d4147_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_d4147_row6_col0" class="data row6 col0" >15.6%</td>
#       <td id="T_d4147_row6_col1" class="data row6 col1" >5.2%</td>
#       <td id="T_d4147_row6_col2" class="data row6 col2" >31.3%</td>
#       <td id="T_d4147_row6_col3" class="data row6 col3" >47.9%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 22. Number of accidents by Severity vs. plan
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='plan', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. plan')
plt.xlabel('plan')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'plan')
# Out:
# <style type="text/css">
# #T_33f35 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_33f35 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_33f35 caption {
#   caption-side: top;
# }
# #T_33f35_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_33f35_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_33f35_row0_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_33f35_row0_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_33f35_row1_col0 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_33f35_row1_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_33f35_row1_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_33f35_row1_col3 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_33f35_row2_col0 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_33f35_row2_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_33f35_row2_col2 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_33f35_row2_col3 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_33f35_row3_col0 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_33f35_row3_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_33f35_row3_col2 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_33f35_row3_col3 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_33f35">
#   <caption>Percentages of Accident Gravity by Plan</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_33f35_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_33f35_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_33f35_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_33f35_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >plan</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33f35_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_33f35_row0_col0" class="data row0 col0" >43.7%</td>
#       <td id="T_33f35_row0_col1" class="data row0 col1" >2.1%</td>
#       <td id="T_33f35_row0_col2" class="data row0 col2" >13.4%</td>
#       <td id="T_33f35_row0_col3" class="data row0 col3" >40.8%</td>
#     </tr>
#     <tr>
#       <th id="T_33f35_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_33f35_row1_col0" class="data row1 col0" >34.1%</td>
#       <td id="T_33f35_row1_col1" class="data row1 col1" >4.1%</td>
#       <td id="T_33f35_row1_col2" class="data row1 col2" >22.9%</td>
#       <td id="T_33f35_row1_col3" class="data row1 col3" >38.9%</td>
#     </tr>
#     <tr>
#       <th id="T_33f35_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_33f35_row2_col0" class="data row2 col0" >34.5%</td>
#       <td id="T_33f35_row2_col1" class="data row2 col1" >4.6%</td>
#       <td id="T_33f35_row2_col2" class="data row2 col2" >23.1%</td>
#       <td id="T_33f35_row2_col3" class="data row2 col3" >37.8%</td>
#     </tr>
#     <tr>
#       <th id="T_33f35_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_33f35_row3_col0" class="data row3 col0" >31.5%</td>
#       <td id="T_33f35_row3_col1" class="data row3 col1" >4.7%</td>
#       <td id="T_33f35_row3_col2" class="data row3 col2" >27.3%</td>
#       <td id="T_33f35_row3_col3" class="data row3 col3" >36.4%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 23. Number of accidents by Severity vs. accident situation
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='accident_situation', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. accident situation')
plt.xlabel('accident situation')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'accident_situation')
# Out:
# <style type="text/css">
# #T_9a7ca th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_9a7ca td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_9a7ca caption {
#   caption-side: top;
# }
# #T_9a7ca_row0_col0 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_9a7ca_row0_col1, #T_9a7ca_row5_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_9a7ca_row0_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_9a7ca_row0_col3 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_9a7ca_row1_col0 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_9a7ca_row1_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_9a7ca_row1_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_9a7ca_row1_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_9a7ca_row2_col0 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_9a7ca_row2_col1, #T_9a7ca_row5_col2 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_9a7ca_row2_col2 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_9a7ca_row2_col3 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_9a7ca_row3_col0 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_9a7ca_row3_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_9a7ca_row3_col2 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_9a7ca_row3_col3, #T_9a7ca_row5_col3 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_9a7ca_row4_col0 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_9a7ca_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9a7ca_row4_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_9a7ca_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9a7ca_row5_col0 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_9a7ca_row6_col0 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_9a7ca_row6_col1 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_9a7ca_row6_col2 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_9a7ca_row6_col3 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9a7ca">
#   <caption>Percentages of Accident Gravity by Accident_situation</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_9a7ca_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_9a7ca_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_9a7ca_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_9a7ca_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >accident_situation</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a7ca_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_9a7ca_row0_col0" class="data row0 col0" >43.8%</td>
#       <td id="T_9a7ca_row0_col1" class="data row0 col1" >2.0%</td>
#       <td id="T_9a7ca_row0_col2" class="data row0 col2" >13.5%</td>
#       <td id="T_9a7ca_row0_col3" class="data row0 col3" >40.7%</td>
#     </tr>
#     <tr>
#       <th id="T_9a7ca_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_9a7ca_row1_col0" class="data row1 col0" >37.8%</td>
#       <td id="T_9a7ca_row1_col1" class="data row1 col1" >2.8%</td>
#       <td id="T_9a7ca_row1_col2" class="data row1 col2" >14.3%</td>
#       <td id="T_9a7ca_row1_col3" class="data row1 col3" >45.2%</td>
#     </tr>
#     <tr>
#       <th id="T_9a7ca_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_9a7ca_row2_col0" class="data row2 col0" >18.7%</td>
#       <td id="T_9a7ca_row2_col1" class="data row2 col1" >10.2%</td>
#       <td id="T_9a7ca_row2_col2" class="data row2 col2" >39.4%</td>
#       <td id="T_9a7ca_row2_col3" class="data row2 col3" >31.7%</td>
#     </tr>
#     <tr>
#       <th id="T_9a7ca_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_9a7ca_row3_col0" class="data row3 col0" >28.8%</td>
#       <td id="T_9a7ca_row3_col1" class="data row3 col1" >5.0%</td>
#       <td id="T_9a7ca_row3_col2" class="data row3 col2" >22.8%</td>
#       <td id="T_9a7ca_row3_col3" class="data row3 col3" >43.4%</td>
#     </tr>
#     <tr>
#       <th id="T_9a7ca_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_9a7ca_row4_col0" class="data row4 col0" >42.9%</td>
#       <td id="T_9a7ca_row4_col1" class="data row4 col1" >0.9%</td>
#       <td id="T_9a7ca_row4_col2" class="data row4 col2" >7.7%</td>
#       <td id="T_9a7ca_row4_col3" class="data row4 col3" >48.5%</td>
#     </tr>
#     <tr>
#       <th id="T_9a7ca_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_9a7ca_row5_col0" class="data row5 col0" >44.5%</td>
#       <td id="T_9a7ca_row5_col1" class="data row5 col1" >1.9%</td>
#       <td id="T_9a7ca_row5_col2" class="data row5 col2" >10.3%</td>
#       <td id="T_9a7ca_row5_col3" class="data row5 col3" >43.3%</td>
#     </tr>
#     <tr>
#       <th id="T_9a7ca_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_9a7ca_row6_col0" class="data row6 col0" >31.3%</td>
#       <td id="T_9a7ca_row6_col1" class="data row6 col1" >7.4%</td>
#       <td id="T_9a7ca_row6_col2" class="data row6 col2" >27.2%</td>
#       <td id="T_9a7ca_row6_col3" class="data row6 col3" >34.1%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 24. Number of accidents by Severity vs. surface condition
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='surface_condition', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. surface condition')
plt.xlabel('surface condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'surface_condition')
# Out:
# <style type="text/css">
# #T_4a585 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_4a585 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_4a585 caption {
#   caption-side: top;
# }
# #T_4a585_row0_col0 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_4a585_row0_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_4a585_row0_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_4a585_row0_col3, #T_4a585_row2_col3, #T_4a585_row6_col3 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_4a585_row1_col0 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_4a585_row1_col1, #T_4a585_row4_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_4a585_row1_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_4a585_row1_col3 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_4a585_row2_col0 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_4a585_row2_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_4a585_row2_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_4a585_row3_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_4a585_row3_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_4a585_row3_col2 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_4a585_row3_col3 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_4a585_row4_col0 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_4a585_row4_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_4a585_row4_col3 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_4a585_row5_col0 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_4a585_row5_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_4a585_row5_col2 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_4a585_row5_col3, #T_4a585_row6_col0 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_4a585_row6_col1, #T_4a585_row8_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_4a585_row6_col2 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_4a585_row7_col0 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_4a585_row7_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_4a585_row7_col2 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_4a585_row7_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4a585_row8_col0 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_4a585_row8_col2 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_4a585_row8_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4a585">
#   <caption>Percentages of Accident Gravity by Surface_condition</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_4a585_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_4a585_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_4a585_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_4a585_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >surface_condition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a585_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_4a585_row0_col0" class="data row0 col0" >42.4%</td>
#       <td id="T_4a585_row0_col1" class="data row0 col1" >2.5%</td>
#       <td id="T_4a585_row0_col2" class="data row0 col2" >15.3%</td>
#       <td id="T_4a585_row0_col3" class="data row0 col3" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_4a585_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_4a585_row1_col0" class="data row1 col0" >40.5%</td>
#       <td id="T_4a585_row1_col1" class="data row1 col1" >2.7%</td>
#       <td id="T_4a585_row1_col2" class="data row1 col2" >13.9%</td>
#       <td id="T_4a585_row1_col3" class="data row1 col3" >42.9%</td>
#     </tr>
#     <tr>
#       <th id="T_4a585_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_4a585_row2_col0" class="data row2 col0" >37.9%</td>
#       <td id="T_4a585_row2_col1" class="data row2 col1" >3.3%</td>
#       <td id="T_4a585_row2_col2" class="data row2 col2" >19.0%</td>
#       <td id="T_4a585_row2_col3" class="data row2 col3" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_4a585_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_4a585_row3_col0" class="data row3 col0" >38.4%</td>
#       <td id="T_4a585_row3_col1" class="data row3 col1" >2.8%</td>
#       <td id="T_4a585_row3_col2" class="data row3 col2" >17.5%</td>
#       <td id="T_4a585_row3_col3" class="data row3 col3" >41.2%</td>
#     </tr>
#     <tr>
#       <th id="T_4a585_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_4a585_row4_col0" class="data row4 col0" >44.3%</td>
#       <td id="T_4a585_row4_col1" class="data row4 col1" >2.7%</td>
#       <td id="T_4a585_row4_col2" class="data row4 col2" >16.4%</td>
#       <td id="T_4a585_row4_col3" class="data row4 col3" >36.6%</td>
#     </tr>
#     <tr>
#       <th id="T_4a585_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_4a585_row5_col0" class="data row5 col0" >24.1%</td>
#       <td id="T_4a585_row5_col1" class="data row5 col1" >8.8%</td>
#       <td id="T_4a585_row5_col2" class="data row5 col2" >36.4%</td>
#       <td id="T_4a585_row5_col3" class="data row5 col3" >30.7%</td>
#     </tr>
#     <tr>
#       <th id="T_4a585_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_4a585_row6_col0" class="data row6 col0" >30.8%</td>
#       <td id="T_4a585_row6_col1" class="data row6 col1" >5.1%</td>
#       <td id="T_4a585_row6_col2" class="data row6 col2" >24.5%</td>
#       <td id="T_4a585_row6_col3" class="data row6 col3" >39.7%</td>
#     </tr>
#     <tr>
#       <th id="T_4a585_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_4a585_row7_col0" class="data row7 col0" >25.7%</td>
#       <td id="T_4a585_row7_col1" class="data row7 col1" >1.8%</td>
#       <td id="T_4a585_row7_col2" class="data row7 col2" >22.4%</td>
#       <td id="T_4a585_row7_col3" class="data row7 col3" >50.1%</td>
#     </tr>
#     <tr>
#       <th id="T_4a585_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_4a585_row8_col0" class="data row8 col0" >28.0%</td>
#       <td id="T_4a585_row8_col1" class="data row8 col1" >5.0%</td>
#       <td id="T_4a585_row8_col2" class="data row8 col2" >29.2%</td>
#       <td id="T_4a585_row8_col3" class="data row8 col3" >37.8%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 25. Number of accidents by Severity vs. longitudinal profile
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='longitudinal_profile', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. longitudinal profile')
plt.xlabel('longitudinal profile')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'longitudinal_profile')
# Out:
# <style type="text/css">
# #T_dd261 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_dd261 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_dd261 caption {
#   caption-side: top;
# }
# #T_dd261_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_dd261_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_dd261_row0_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_dd261_row0_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_dd261_row1_col0 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_dd261_row1_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_dd261_row1_col2 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_dd261_row1_col3 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_dd261_row2_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_dd261_row2_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_dd261_row2_col2 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_dd261_row2_col3 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_dd261_row3_col0, #T_dd261_row3_col3 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_dd261_row3_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_dd261_row3_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# </style>
# <table id="T_dd261">
#   <caption>Percentages of Accident Gravity by Longitudinal_profile</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_dd261_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_dd261_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_dd261_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_dd261_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >longitudinal_profile</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd261_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_dd261_row0_col0" class="data row0 col0" >42.8%</td>
#       <td id="T_dd261_row0_col1" class="data row0 col1" >2.3%</td>
#       <td id="T_dd261_row0_col2" class="data row0 col2" >14.2%</td>
#       <td id="T_dd261_row0_col3" class="data row0 col3" >40.8%</td>
#     </tr>
#     <tr>
#       <th id="T_dd261_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_dd261_row1_col0" class="data row1 col0" >38.4%</td>
#       <td id="T_dd261_row1_col1" class="data row1 col1" >3.5%</td>
#       <td id="T_dd261_row1_col2" class="data row1 col2" >19.5%</td>
#       <td id="T_dd261_row1_col3" class="data row1 col3" >38.6%</td>
#     </tr>
#     <tr>
#       <th id="T_dd261_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_dd261_row2_col0" class="data row2 col0" >37.8%</td>
#       <td id="T_dd261_row2_col1" class="data row2 col1" >4.6%</td>
#       <td id="T_dd261_row2_col2" class="data row2 col2" >20.1%</td>
#       <td id="T_dd261_row2_col3" class="data row2 col3" >37.5%</td>
#     </tr>
#     <tr>
#       <th id="T_dd261_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_dd261_row3_col0" class="data row3 col0" >37.7%</td>
#       <td id="T_dd261_row3_col1" class="data row3 col1" >4.2%</td>
#       <td id="T_dd261_row3_col2" class="data row3 col2" >20.4%</td>
#       <td id="T_dd261_row3_col3" class="data row3 col3" >37.6%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 26. Number of accidents by Severity vs. route_category
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='route_category', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. route category')
plt.xlabel('route category')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'route_category')
# Out:
# <style type="text/css">
# #T_c6653 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_c6653 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_c6653 caption {
#   caption-side: top;
# }
# #T_c6653_row0_col0, #T_c6653_row0_col3 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_c6653_row0_col1, #T_c6653_row3_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c6653_row0_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_c6653_row1_col0 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_c6653_row1_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_c6653_row1_col2 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_c6653_row1_col3 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_c6653_row2_col0, #T_c6653_row7_col3 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_c6653_row2_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_c6653_row2_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_c6653_row2_col3 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_c6653_row3_col0 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_c6653_row3_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_c6653_row3_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_c6653_row4_col0 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_c6653_row4_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_c6653_row4_col2 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_c6653_row4_col3 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_c6653_row5_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c6653_row5_col1, #T_c6653_row6_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_c6653_row5_col2 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_c6653_row5_col3 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_c6653_row6_col0 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_c6653_row6_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_c6653_row6_col3 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_c6653_row7_col0 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_c6653_row7_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_c6653_row7_col2 {
#   background-color: #91c3de;
#   color: #000000;
# }
# </style>
# <table id="T_c6653">
#   <caption>Percentages of Accident Gravity by Route_category</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_c6653_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_c6653_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_c6653_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_c6653_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >route_category</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6653_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_c6653_row0_col0" class="data row0 col0" >46.6%</td>
#       <td id="T_c6653_row0_col1" class="data row0 col1" >1.1%</td>
#       <td id="T_c6653_row0_col2" class="data row0 col2" >5.6%</td>
#       <td id="T_c6653_row0_col3" class="data row0 col3" >46.6%</td>
#     </tr>
#     <tr>
#       <th id="T_c6653_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_c6653_row1_col0" class="data row1 col0" >41.3%</td>
#       <td id="T_c6653_row1_col1" class="data row1 col1" >3.7%</td>
#       <td id="T_c6653_row1_col2" class="data row1 col2" >15.0%</td>
#       <td id="T_c6653_row1_col3" class="data row1 col3" >40.1%</td>
#     </tr>
#     <tr>
#       <th id="T_c6653_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_c6653_row2_col0" class="data row2 col0" >38.4%</td>
#       <td id="T_c6653_row2_col1" class="data row2 col1" >4.2%</td>
#       <td id="T_c6653_row2_col2" class="data row2 col2" >22.6%</td>
#       <td id="T_c6653_row2_col3" class="data row2 col3" >34.9%</td>
#     </tr>
#     <tr>
#       <th id="T_c6653_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_c6653_row3_col0" class="data row3 col0" >44.2%</td>
#       <td id="T_c6653_row3_col1" class="data row3 col1" >1.2%</td>
#       <td id="T_c6653_row3_col2" class="data row3 col2" >10.6%</td>
#       <td id="T_c6653_row3_col3" class="data row3 col3" >44.0%</td>
#     </tr>
#     <tr>
#       <th id="T_c6653_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_c6653_row4_col0" class="data row4 col0" >36.6%</td>
#       <td id="T_c6653_row4_col1" class="data row4 col1" >4.3%</td>
#       <td id="T_c6653_row4_col2" class="data row4 col2" >23.9%</td>
#       <td id="T_c6653_row4_col3" class="data row4 col3" >35.2%</td>
#     </tr>
#     <tr>
#       <th id="T_c6653_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_c6653_row5_col0" class="data row5 col0" >47.1%</td>
#       <td id="T_c6653_row5_col1" class="data row5 col1" >2.2%</td>
#       <td id="T_c6653_row5_col2" class="data row5 col2" >17.2%</td>
#       <td id="T_c6653_row5_col3" class="data row5 col3" >33.5%</td>
#     </tr>
#     <tr>
#       <th id="T_c6653_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_c6653_row6_col0" class="data row6 col0" >41.6%</td>
#       <td id="T_c6653_row6_col1" class="data row6 col1" >2.2%</td>
#       <td id="T_c6653_row6_col2" class="data row6 col2" >14.2%</td>
#       <td id="T_c6653_row6_col3" class="data row6 col3" >41.9%</td>
#     </tr>
#     <tr>
#       <th id="T_c6653_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_c6653_row7_col0" class="data row7 col0" >39.3%</td>
#       <td id="T_c6653_row7_col1" class="data row7 col1" >2.5%</td>
#       <td id="T_c6653_row7_col2" class="data row7 col2" >19.8%</td>
#       <td id="T_c6653_row7_col3" class="data row7 col3" >38.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 27. Number of accidents by Severity vs. reason travel
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='reason_travel', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. reason_travel')
plt.xlabel('reason_travel')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'reason_travel')
# Out:
# <style type="text/css">
# #T_d8e35 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_d8e35 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_d8e35 caption {
#   caption-side: top;
# }
# #T_d8e35_row0_col0 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_d8e35_row0_col1, #T_d8e35_row1_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_d8e35_row0_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_d8e35_row0_col3 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_d8e35_row1_col0 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_d8e35_row1_col2 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_d8e35_row1_col3 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_d8e35_row2_col0 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_d8e35_row2_col1, #T_d8e35_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d8e35_row2_col2 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_d8e35_row2_col3 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_d8e35_row3_col0 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_d8e35_row3_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_d8e35_row3_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_d8e35_row3_col3 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_d8e35_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d8e35_row4_col2 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_d8e35_row4_col3 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_d8e35_row5_col0 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_d8e35_row5_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_d8e35_row5_col2 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_d8e35_row5_col3 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_d8e35_row6_col0 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_d8e35_row6_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_d8e35_row6_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_d8e35_row6_col3 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d8e35">
#   <caption>Percentages of Accident Gravity by Reason_travel</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_d8e35_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_d8e35_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_d8e35_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_d8e35_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >reason_travel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8e35_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d8e35_row0_col0" class="data row0 col0" >42.8%</td>
#       <td id="T_d8e35_row0_col1" class="data row0 col1" >1.9%</td>
#       <td id="T_d8e35_row0_col2" class="data row0 col2" >12.5%</td>
#       <td id="T_d8e35_row0_col3" class="data row0 col3" >42.8%</td>
#     </tr>
#     <tr>
#       <th id="T_d8e35_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d8e35_row1_col0" class="data row1 col0" >41.0%</td>
#       <td id="T_d8e35_row1_col1" class="data row1 col1" >1.9%</td>
#       <td id="T_d8e35_row1_col2" class="data row1 col2" >13.6%</td>
#       <td id="T_d8e35_row1_col3" class="data row1 col3" >43.4%</td>
#     </tr>
#     <tr>
#       <th id="T_d8e35_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d8e35_row2_col0" class="data row2 col0" >28.6%</td>
#       <td id="T_d8e35_row2_col1" class="data row2 col1" >1.1%</td>
#       <td id="T_d8e35_row2_col2" class="data row2 col2" >15.9%</td>
#       <td id="T_d8e35_row2_col3" class="data row2 col3" >54.4%</td>
#     </tr>
#     <tr>
#       <th id="T_d8e35_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d8e35_row3_col0" class="data row3 col0" >43.3%</td>
#       <td id="T_d8e35_row3_col1" class="data row3 col1" >4.1%</td>
#       <td id="T_d8e35_row3_col2" class="data row3 col2" >20.3%</td>
#       <td id="T_d8e35_row3_col3" class="data row3 col3" >32.4%</td>
#     </tr>
#     <tr>
#       <th id="T_d8e35_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d8e35_row4_col0" class="data row4 col0" >64.7%</td>
#       <td id="T_d8e35_row4_col1" class="data row4 col1" >1.0%</td>
#       <td id="T_d8e35_row4_col2" class="data row4 col2" >5.7%</td>
#       <td id="T_d8e35_row4_col3" class="data row4 col3" >28.6%</td>
#     </tr>
#     <tr>
#       <th id="T_d8e35_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d8e35_row5_col0" class="data row5 col0" >36.9%</td>
#       <td id="T_d8e35_row5_col1" class="data row5 col1" >3.7%</td>
#       <td id="T_d8e35_row5_col2" class="data row5 col2" >20.5%</td>
#       <td id="T_d8e35_row5_col3" class="data row5 col3" >38.9%</td>
#     </tr>
#     <tr>
#       <th id="T_d8e35_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_d8e35_row6_col0" class="data row6 col0" >40.2%</td>
#       <td id="T_d8e35_row6_col1" class="data row6 col1" >2.2%</td>
#       <td id="T_d8e35_row6_col2" class="data row6 col2" >11.9%</td>
#       <td id="T_d8e35_row6_col3" class="data row6 col3" >45.6%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 28. Accidents Severity vs. geographical location
fig = px.scatter_mapbox(
    data, 
    lat="lat", 
    lon="long", 
    color="gravity", 
    color_continuous_scale=px.colors.cyclical.IceFire, 
    zoom=3, 
    height=1000, 
    width=2000, 
    labels={"gravity": "Severity"}
)

# Update the layout for mapbox style
fig.update_layout(
    mapbox_style="open-street-map",
    mapbox_center={"lat": data["lat"].mean(), "lon": data["long"].mean()}, 
    title={'x': 0.5} 
)

# Add hover data for more information on each point
fig.update_traces(marker=dict(size=8), 
                  hovertemplate="<br>".join([
                      "Latitude: %{lat}",
                      "Longitude: %{lon}",
                      "Severity: %{marker.color}"
                  ])
)

# Save the map as an HTML file
fig.write_html("accidents_severity_map.html")
