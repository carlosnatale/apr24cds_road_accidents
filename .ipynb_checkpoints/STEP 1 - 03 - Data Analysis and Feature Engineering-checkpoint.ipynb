# %%
# Import libraries needed to execute the code
import os
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import scipy.cluster.hierarchy as shc
from sklearn.decomposition import PCA
from IPython.display import display, HTML
from scipy.cluster.hierarchy import dendrogram, linkage
from pandas.plotting import andrews_curves, parallel_coordinates, lag_plot, autocorrelation_plot, radviz

# %%
# Import the clean data
data = pd.read_csv('source/data.csv')

# %%
# List of columns to convert to object type
columns_to_convert = [
    'AccID', 'accident_situation', 'atm_condition', 'collision_type', 'com_code', 'dep_code', 
    'fixed_obstacle', 'gender', 'gravity', 'infra', 'initial_impact_point', 'int', 'location', 
    'longitudinal_profile', 'lum', 'manv', 'mobile_obstacle', 'motor', 'num_veh_x', 'num_veh_y',
    'plan', 'reason_travel', 'reserved_lane_code', 'route_category', 'safety_equipment1', 'seat', 
    'surface_condition', 'traffic_direction', 'traffic_regime', 'user_category', 
    'vehicle_category', 'vehicleID_x', 'vehicleID_y'
]

# Convert specified columns to object type
data[columns_to_convert] = data[columns_to_convert].astype('object')

# %%
# Identifying correlations with the target variable 'gravity'

# Identifying non-numeric columns again
non_numeric_columns = data.select_dtypes(include=['object']).columns

# Copy the original dataframe
data_numeric = data.copy()

# Convert columns to numeric where appropriate, errors='coerce' will convert non-convertible values to NaN
for col in non_numeric_columns:
    data_numeric[col] = pd.to_numeric(data_numeric[col], errors='coerce')

# Identifying and dropping problematic columns specifically
problematic_columns = ['time', 'vehicleID_x', 'num_veh_x', 'vehicleID_y', 'num_veh_y', 'year']

# Drop the problematic columns and recalculate the correlation matrix
data_cleaned = data_numeric.drop(columns=problematic_columns)

# Calculate correlation matrix
correlation_matrix = data_cleaned.corr()

# Extract correlations with the target variable 'gravity'
correlation_with_gravity = correlation_matrix['gravity'].sort_values(ascending=False)

correlation_with_gravity
# Out:
# gravity                     1.000000
# user_category               0.171793
# seat                        0.154686
# safety_equipment1           0.105336
# birth_year                  0.091158
# gender                      0.081346
# fixed_obstacle              0.067671
# accident_situation          0.031767
# lum                         0.030721
# route_category              0.027054
# plan                        0.024560
# collision_type              0.016856
# surface_condition           0.009426
# location                    0.007797
# longitudinal_profile        0.007339
# lat                         0.005728
# vehicle_category            0.005540
# reserved_lane_code          0.003713
# AccID                       0.002297
# manv                        0.002147
# day                         0.000689
# long                        0.000542
# atm_condition               0.000097
# month                      -0.000112
# motor                      -0.000275
# int                        -0.001500
# traffic_direction          -0.002992
# infra                      -0.003074
# dep_code                   -0.006966
# upstream_terminal_number   -0.007399
# com_code                   -0.009091
# traffic_regime             -0.013229
# reason_travel              -0.014734
# maximum_speed              -0.020056
# initial_impact_point       -0.020873
# total_number_lanes         -0.024373
# mobile_obstacle            -0.054536
# age                        -0.091158
# Name: gravity, dtype: float64

# %% [markdown]
# <font size="6">
#     Visualizations Preparation
# </font>

# %%
# Set up the figure size and style
sns.set_style("darkgrid")

# %%
# Ignore specific warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn")

# %%
# Replace the values in gravity field
data['gravity'] = data['gravity'].replace({
     1: '1 - Uninjured',
     2: '2 - Fatal',
     3: '3 - Hospitalized',
     4: '4 - Minor injury'
})
# Define custom colors
custom_colors = {
    '1 - Uninjured': '#66B2FF',      
    '2 - Fatal': '#FF9999',       
    '3 - Hospitalized': '#FFCC99',   
    '4 - Minor injury': '#99FF99' 
}

# Sort gravity levels alphabetically
gravity_order = sorted(custom_colors.keys())

# %%
# Function to calculate and display percentages in a separated table 
def calculate_and_display_percentages(data, group_by_col):
    counts = data.groupby([group_by_col, 'gravity']).size().reset_index(name='count')
    total_counts = data[group_by_col].value_counts().reset_index(name='total')
    total_counts.columns = [group_by_col, 'total']
    counts = counts.merge(total_counts, on=group_by_col)
    counts['percentage'] = counts['count'] / counts['total'] * 100

    # Pivot the table to show only percentages
    percentage_table = counts.pivot(index=group_by_col, columns='gravity', values='percentage').fillna(0)
    
    styled_table = percentage_table.style.format("{:.1f}%").set_table_styles(
        [{'selector': 'th', 'props': [('font-size', '12pt'), ('font-weight', 'bold'), ('text-align', 'center')]},
         {'selector': 'td', 'props': [('font-size', '10pt'), ('text-align', 'center')]},
         {'selector': 'caption', 'props': [('caption-side', 'top')]}]
    ).set_caption(f'Percentages of Accident Gravity by {group_by_col.capitalize()}').background_gradient(cmap='Blues', axis=None)

    # Display the styled table
    html = styled_table.to_html()
    display(HTML(html))

# %% [markdown]
# <font size="6">
# Graph Visualization
# </font>

# %%
# 1. Number of accidents by Severity Category

# Calculate counts and sort them
counts = data['gravity'].value_counts().sort_values(ascending=False)

# Calculate percentages
total = counts.sum()
percentages = counts / total * 100

plt.figure(figsize=(18, 12))
ax = sns.countplot(data=data, x='gravity', order=counts.index, palette=custom_colors)

for p, percentage in zip(ax.patches, percentages):
    height = p.get_height()
    ax.annotate(f'{percentage:.1f}%', 
                (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='center', 
                xytext=(0, 8), 
                textcoords='offset points')

plt.title('Number of accidents by Severity Category')
plt.xlabel('Severity')
plt.ylabel('Number of Accidents')
plt.show()

# %%
# 2. Number of accidents by Severity vs.Year
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='year', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Year of Accident')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

# Call function to show the percentage Gravity vs. Year
calculate_and_display_percentages(data, 'year')
# Out:
# <style type="text/css">
# #T_7f471 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_7f471 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_7f471 caption {
#   caption-side: top;
# }
# #T_7f471_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7f471_row0_col1, #T_7f471_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7f471_row0_col2, #T_7f471_row3_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_7f471_row0_col3, #T_7f471_row1_col3 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_7f471_row1_col0 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_7f471_row1_col1, #T_7f471_row3_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_7f471_row1_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_7f471_row2_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_7f471_row2_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_7f471_row2_col3 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_7f471_row3_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_7f471_row3_col3 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7f471">
#   <caption>Percentages of Accident Gravity by Year</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_7f471_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_7f471_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_7f471_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_7f471_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f471_level0_row0" class="row_heading level0 row0" >2019</th>
#       <td id="T_7f471_row0_col0" class="data row0 col0" >44.7%</td>
#       <td id="T_7f471_row0_col1" class="data row0 col1" >2.1%</td>
#       <td id="T_7f471_row0_col2" class="data row0 col2" >13.5%</td>
#       <td id="T_7f471_row0_col3" class="data row0 col3" >39.7%</td>
#     </tr>
#     <tr>
#       <th id="T_7f471_level0_row1" class="row_heading level0 row1" >2020</th>
#       <td id="T_7f471_row1_col0" class="data row1 col0" >44.2%</td>
#       <td id="T_7f471_row1_col1" class="data row1 col1" >2.2%</td>
#       <td id="T_7f471_row1_col2" class="data row1 col2" >13.9%</td>
#       <td id="T_7f471_row1_col3" class="data row1 col3" >39.7%</td>
#     </tr>
#     <tr>
#       <th id="T_7f471_level0_row2" class="row_heading level0 row2" >2021</th>
#       <td id="T_7f471_row2_col0" class="data row2 col0" >44.5%</td>
#       <td id="T_7f471_row2_col1" class="data row2 col1" >2.0%</td>
#       <td id="T_7f471_row2_col2" class="data row2 col2" >13.0%</td>
#       <td id="T_7f471_row2_col3" class="data row2 col3" >40.5%</td>
#     </tr>
#     <tr>
#       <th id="T_7f471_level0_row3" class="row_heading level0 row3" >2022</th>
#       <td id="T_7f471_row3_col0" class="data row3 col0" >44.3%</td>
#       <td id="T_7f471_row3_col1" class="data row3 col1" >2.3%</td>
#       <td id="T_7f471_row3_col2" class="data row3 col2" >13.5%</td>
#       <td id="T_7f471_row3_col3" class="data row3 col3" >39.8%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 2.1 Number of accidents by Severity vs.Year
years = data['year'].unique()
n_years = len(years)

fig, axes = plt.subplots(1, n_years, figsize=(18, 6))
fig.suptitle('Severity Distribution per Year', fontsize=16)

custom_colors_mat = ['#66B2FF', '#99FF99', '#FFCC99', '#FF9999']

for i, year in enumerate(years):
    yearly_data = data[data['year'] == year]['gravity'].value_counts()
    colors = custom_colors_mat[:len(yearly_data)]  
    axes[i].pie(yearly_data, labels=yearly_data.index, autopct='%1.1f%%', colors=colors)
    axes[i].set_title(f'Year {year}')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# 3. Number of accidents by Severity vs. Month
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='month', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'month')
# Out:
# <style type="text/css">
# #T_be749 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_be749 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_be749 caption {
#   caption-side: top;
# }
# #T_be749_row0_col0, #T_be749_row3_col0, #T_be749_row8_col0, #T_be749_row9_col0 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_be749_row0_col1, #T_be749_row1_col1, #T_be749_row6_col1, #T_be749_row8_col1, #T_be749_row10_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_be749_row0_col2, #T_be749_row11_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_be749_row0_col3 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_be749_row1_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_be749_row1_col2, #T_be749_row2_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_be749_row1_col3 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_be749_row2_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_be749_row2_col1, #T_be749_row4_col1, #T_be749_row5_col1, #T_be749_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_be749_row2_col3, #T_be749_row10_col3, #T_be749_row11_col3 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_be749_row3_col1, #T_be749_row7_col1, #T_be749_row11_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_be749_row3_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_be749_row3_col3, #T_be749_row5_col3 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_be749_row4_col0 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_be749_row4_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_be749_row4_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_be749_row5_col0 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_be749_row5_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_be749_row6_col0, #T_be749_row7_col0 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_be749_row6_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_be749_row6_col3, #T_be749_row8_col3 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_be749_row7_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_be749_row7_col3 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_be749_row8_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_be749_row9_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_be749_row9_col3 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_be749_row10_col0, #T_be749_row11_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_be749_row10_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# </style>
# <table id="T_be749">
#   <caption>Percentages of Accident Gravity by Month</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_be749_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_be749_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_be749_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_be749_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be749_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_be749_row0_col0" class="data row0 col0" >44.6%</td>
#       <td id="T_be749_row0_col1" class="data row0 col1" >2.3%</td>
#       <td id="T_be749_row0_col2" class="data row0 col2" >12.3%</td>
#       <td id="T_be749_row0_col3" class="data row0 col3" >40.9%</td>
#     </tr>
#     <tr>
#       <th id="T_be749_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_be749_row1_col0" class="data row1 col0" >45.2%</td>
#       <td id="T_be749_row1_col1" class="data row1 col1" >2.2%</td>
#       <td id="T_be749_row1_col2" class="data row1 col2" >12.6%</td>
#       <td id="T_be749_row1_col3" class="data row1 col3" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_be749_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_be749_row2_col0" class="data row2 col0" >44.7%</td>
#       <td id="T_be749_row2_col1" class="data row2 col1" >2.0%</td>
#       <td id="T_be749_row2_col2" class="data row2 col2" >12.6%</td>
#       <td id="T_be749_row2_col3" class="data row2 col3" >40.6%</td>
#     </tr>
#     <tr>
#       <th id="T_be749_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_be749_row3_col0" class="data row3 col0" >44.6%</td>
#       <td id="T_be749_row3_col1" class="data row3 col1" >2.3%</td>
#       <td id="T_be749_row3_col2" class="data row3 col2" >13.4%</td>
#       <td id="T_be749_row3_col3" class="data row3 col3" >39.7%</td>
#     </tr>
#     <tr>
#       <th id="T_be749_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_be749_row4_col0" class="data row4 col0" >44.4%</td>
#       <td id="T_be749_row4_col1" class="data row4 col1" >2.1%</td>
#       <td id="T_be749_row4_col2" class="data row4 col2" >14.2%</td>
#       <td id="T_be749_row4_col3" class="data row4 col3" >39.4%</td>
#     </tr>
#     <tr>
#       <th id="T_be749_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_be749_row5_col0" class="data row5 col0" >44.2%</td>
#       <td id="T_be749_row5_col1" class="data row5 col1" >2.1%</td>
#       <td id="T_be749_row5_col2" class="data row5 col2" >14.0%</td>
#       <td id="T_be749_row5_col3" class="data row5 col3" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_be749_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_be749_row6_col0" class="data row6 col0" >43.5%</td>
#       <td id="T_be749_row6_col1" class="data row6 col1" >2.3%</td>
#       <td id="T_be749_row6_col2" class="data row6 col2" >14.6%</td>
#       <td id="T_be749_row6_col3" class="data row6 col3" >39.6%</td>
#     </tr>
#     <tr>
#       <th id="T_be749_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_be749_row7_col0" class="data row7 col0" >43.4%</td>
#       <td id="T_be749_row7_col1" class="data row7 col1" >2.4%</td>
#       <td id="T_be749_row7_col2" class="data row7 col2" >15.9%</td>
#       <td id="T_be749_row7_col3" class="data row7 col3" >38.3%</td>
#     </tr>
#     <tr>
#       <th id="T_be749_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_be749_row8_col0" class="data row8 col0" >44.7%</td>
#       <td id="T_be749_row8_col1" class="data row8 col1" >2.1%</td>
#       <td id="T_be749_row8_col2" class="data row8 col2" >13.6%</td>
#       <td id="T_be749_row8_col3" class="data row8 col3" >39.6%</td>
#     </tr>
#     <tr>
#       <th id="T_be749_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_be749_row9_col0" class="data row9 col0" >44.7%</td>
#       <td id="T_be749_row9_col1" class="data row9 col1" >2.0%</td>
#       <td id="T_be749_row9_col2" class="data row9 col2" >12.9%</td>
#       <td id="T_be749_row9_col3" class="data row9 col3" >40.4%</td>
#     </tr>
#     <tr>
#       <th id="T_be749_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_be749_row10_col0" class="data row10 col0" >45.0%</td>
#       <td id="T_be749_row10_col1" class="data row10 col1" >2.2%</td>
#       <td id="T_be749_row10_col2" class="data row10 col2" >12.2%</td>
#       <td id="T_be749_row10_col3" class="data row10 col3" >40.6%</td>
#     </tr>
#     <tr>
#       <th id="T_be749_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_be749_row11_col0" class="data row11 col0" >44.9%</td>
#       <td id="T_be749_row11_col1" class="data row11 col1" >2.3%</td>
#       <td id="T_be749_row11_col2" class="data row11 col2" >12.3%</td>
#       <td id="T_be749_row11_col3" class="data row11 col3" >40.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 4. Number of accidents by Severity vs. Day
aggregated_data = data.groupby(['day', 'gravity']).size().reset_index(name='count')

plt.figure(figsize=(18, 12))
sns.lineplot(data=aggregated_data, x='day', y='count', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Number of Accidents by Severity vs. Day')
plt.xlabel('Day')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'day')
# Out:
# <style type="text/css">
# #T_72708 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_72708 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_72708 caption {
#   caption-side: top;
# }
# #T_72708_row0_col0, #T_72708_row14_col0, #T_72708_row17_col0, #T_72708_row20_col0, #T_72708_row21_col0 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_72708_row0_col1, #T_72708_row1_col1, #T_72708_row3_col1, #T_72708_row5_col1, #T_72708_row6_col1, #T_72708_row10_col1, #T_72708_row11_col1, #T_72708_row17_col1, #T_72708_row19_col1, #T_72708_row20_col1, #T_72708_row21_col1, #T_72708_row22_col1, #T_72708_row24_col1, #T_72708_row26_col1, #T_72708_row28_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_72708_row0_col2, #T_72708_row3_col2, #T_72708_row4_col2, #T_72708_row14_col2, #T_72708_row18_col2, #T_72708_row21_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_72708_row0_col3, #T_72708_row21_col3, #T_72708_row27_col3, #T_72708_row30_col3 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_72708_row1_col0, #T_72708_row3_col0, #T_72708_row19_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_72708_row1_col2, #T_72708_row2_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_72708_row1_col3, #T_72708_row4_col3, #T_72708_row25_col3 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_72708_row2_col0, #T_72708_row5_col0, #T_72708_row8_col0, #T_72708_row24_col0, #T_72708_row26_col0, #T_72708_row27_col0, #T_72708_row29_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_72708_row2_col1, #T_72708_row4_col1, #T_72708_row9_col1, #T_72708_row23_col1, #T_72708_row27_col1, #T_72708_row29_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_72708_row2_col3, #T_72708_row16_col3 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_72708_row3_col3, #T_72708_row7_col3, #T_72708_row28_col3 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_72708_row4_col0, #T_72708_row11_col0 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_72708_row5_col2, #T_72708_row11_col2, #T_72708_row24_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_72708_row5_col3 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_72708_row6_col0, #T_72708_row9_col0, #T_72708_row18_col0, #T_72708_row23_col0, #T_72708_row28_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_72708_row6_col2, #T_72708_row16_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_72708_row6_col3, #T_72708_row12_col3, #T_72708_row13_col3, #T_72708_row14_col3, #T_72708_row15_col3, #T_72708_row17_col3, #T_72708_row20_col3 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_72708_row7_col0, #T_72708_row15_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_72708_row7_col1, #T_72708_row8_col1, #T_72708_row12_col1, #T_72708_row13_col1, #T_72708_row14_col1, #T_72708_row15_col1, #T_72708_row16_col1, #T_72708_row30_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_72708_row7_col2, #T_72708_row8_col2, #T_72708_row10_col2, #T_72708_row17_col2, #T_72708_row19_col2, #T_72708_row20_col2, #T_72708_row23_col2, #T_72708_row25_col2, #T_72708_row26_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_72708_row8_col3, #T_72708_row26_col3 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_72708_row9_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_72708_row9_col3, #T_72708_row10_col3, #T_72708_row11_col3, #T_72708_row22_col3, #T_72708_row29_col3 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_72708_row10_col0, #T_72708_row12_col0 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_72708_row12_col2, #T_72708_row27_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_72708_row13_col0 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_72708_row13_col2, #T_72708_row30_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_72708_row15_col2, #T_72708_row28_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_72708_row16_col0, #T_72708_row22_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_72708_row18_col1, #T_72708_row25_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_72708_row18_col3 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_72708_row19_col3 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_72708_row22_col2, #T_72708_row29_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_72708_row23_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_72708_row24_col3 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_72708_row25_col0, #T_72708_row30_col0 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_72708">
#   <caption>Percentages of Accident Gravity by Day</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_72708_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_72708_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_72708_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_72708_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >day</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72708_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_72708_row0_col0" class="data row0 col0" >44.5%</td>
#       <td id="T_72708_row0_col1" class="data row0 col1" >2.2%</td>
#       <td id="T_72708_row0_col2" class="data row0 col2" >13.4%</td>
#       <td id="T_72708_row0_col3" class="data row0 col3" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_72708_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_72708_row1_col0" class="data row1 col0" >44.9%</td>
#       <td id="T_72708_row1_col1" class="data row1 col1" >2.1%</td>
#       <td id="T_72708_row1_col2" class="data row1 col2" >12.7%</td>
#       <td id="T_72708_row1_col3" class="data row1 col3" >40.3%</td>
#     </tr>
#     <tr>
#       <th id="T_72708_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_72708_row2_col0" class="data row2 col0" >44.3%</td>
#       <td id="T_72708_row2_col1" class="data row2 col1" >2.1%</td>
#       <td id="T_72708_row2_col2" class="data row2 col2" >12.7%</td>
#       <td id="T_72708_row2_col3" class="data row2 col3" >40.9%</td>
#     </tr>
#     <tr>
#       <th id="T_72708_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_72708_row3_col0" class="data row3 col0" >44.9%</td>
#       <td id="T_72708_row3_col1" class="data row3 col1" >2.1%</td>
#       <td id="T_72708_row3_col2" class="data row3 col2" >13.5%</td>
#       <td id="T_72708_row3_col3" class="data row3 col3" >39.5%</td>
#     </tr>
#     <tr>
#       <th id="T_72708_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_72708_row4_col0" class="data row4 col0" >44.4%</td>
#       <td id="T_72708_row4_col1" class="data row4 col1" >1.9%</td>
#       <td id="T_72708_row4_col2" class="data row4 col2" >13.5%</td>
#       <td id="T_72708_row4_col3" class="data row4 col3" >40.3%</td>
#     </tr>
#     <tr>
#       <th id="T_72708_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_72708_row5_col0" class="data row5 col0" >44.2%</td>
#       <td id="T_72708_row5_col1" class="data row5 col1" >2.1%</td>
#       <td id="T_72708_row5_col2" class="data row5 col2" >13.1%</td>
#       <td id="T_72708_row5_col3" class="data row5 col3" >40.6%</td>
#     </tr>
#     <tr>
#       <th id="T_72708_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_72708_row6_col0" class="data row6 col0" >45.0%</td>
#       <td id="T_72708_row6_col1" class="data row6 col1" >2.2%</td>
#       <td id="T_72708_row6_col2" class="data row6 col2" >13.0%</td>
#       <td id="T_72708_row6_col3" class="data row6 col3" >39.7%</td>
#     </tr>
#     <tr>
#       <th id="T_72708_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_72708_r

# %%
# 5. Number of accidents by Severity vs. Weather Conditions
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='atm_condition', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Weather Conditions')
plt.xlabel('Weather Condition')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'atm_condition')
# Out:
# <style type="text/css">
# #T_9893f th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_9893f td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_9893f caption {
#   caption-side: top;
# }
# #T_9893f_row0_col0 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_9893f_row0_col1, #T_9893f_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9893f_row0_col2 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_9893f_row0_col3 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_9893f_row1_col0 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_9893f_row1_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_9893f_row1_col3 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_9893f_row2_col0 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_9893f_row2_col1, #T_9893f_row3_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_9893f_row2_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_9893f_row2_col3 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_9893f_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9893f_row3_col2 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_9893f_row3_col3 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_9893f_row4_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_9893f_row4_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_9893f_row4_col2 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_9893f_row4_col3 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_9893f_row5_col0 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_9893f_row5_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_9893f_row5_col2 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_9893f_row5_col3 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_9893f_row6_col0 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_9893f_row6_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_9893f_row6_col2 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_9893f_row6_col3 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_9893f_row7_col0 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_9893f_row7_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_9893f_row7_col2 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_9893f_row7_col3 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_9893f_row8_col0 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_9893f_row8_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_9893f_row8_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_9893f_row8_col3 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9893f">
#   <caption>Percentages of Accident Gravity by Atm_condition</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_9893f_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_9893f_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_9893f_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_9893f_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >atm_condition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9893f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_9893f_row0_col0" class="data row0 col0" >44.6%</td>
#       <td id="T_9893f_row0_col1" class="data row0 col1" >2.1%</td>
#       <td id="T_9893f_row0_col2" class="data row0 col2" >13.5%</td>
#       <td id="T_9893f_row0_col3" class="data row0 col3" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_9893f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_9893f_row1_col0" class="data row1 col0" >44.0%</td>
#       <td id="T_9893f_row1_col1" class="data row1 col1" >1.9%</td>
#       <td id="T_9893f_row1_col2" class="data row1 col2" >11.2%</td>
#       <td id="T_9893f_row1_col3" class="data row1 col3" >42.9%</td>
#     </tr>
#     <tr>
#       <th id="T_9893f_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_9893f_row2_col0" class="data row2 col0" >43.9%</td>
#       <td id="T_9893f_row2_col1" class="data row2 col1" >2.3%</td>
#       <td id="T_9893f_row2_col2" class="data row2 col2" >13.7%</td>
#       <td id="T_9893f_row2_col3" class="data row2 col3" >40.1%</td>
#     </tr>
#     <tr>
#       <th id="T_9893f_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_9893f_row3_col0" class="data row3 col0" >51.5%</td>
#       <td id="T_9893f_row3_col1" class="data row3 col1" >2.2%</td>
#       <td id="T_9893f_row3_col2" class="data row3 col2" >12.6%</td>
#       <td id="T_9893f_row3_col3" class="data row3 col3" >33.7%</td>
#     </tr>
#     <tr>
#       <th id="T_9893f_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_9893f_row4_col0" class="data row4 col0" >37.7%</td>
#       <td id="T_9893f_row4_col1" class="data row4 col1" >5.2%</td>
#       <td id="T_9893f_row4_col2" class="data row4 col2" >20.5%</td>
#       <td id="T_9893f_row4_col3" class="data row4 col3" >36.5%</td>
#     </tr>
#     <tr>
#       <th id="T_9893f_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_9893f_row5_col0" class="data row5 col0" >35.5%</td>
#       <td id="T_9893f_row5_col1" class="data row5 col1" >4.4%</td>
#       <td id="T_9893f_row5_col2" class="data row5 col2" >24.2%</td>
#       <td id="T_9893f_row5_col3" class="data row5 col3" >36.0%</td>
#     </tr>
#     <tr>
#       <th id="T_9893f_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_9893f_row6_col0" class="data row6 col0" >46.0%</td>
#       <td id="T_9893f_row6_col1" class="data row6 col1" >3.2%</td>
#       <td id="T_9893f_row6_col2" class="data row6 col2" >20.8%</td>
#       <td id="T_9893f_row6_col3" class="data row6 col3" >29.9%</td>
#     </tr>
#     <tr>
#       <th id="T_9893f_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_9893f_row7_col0" class="data row7 col0" >43.3%</td>
#       <td id="T_9893f_row7_col1" class="data row7 col1" >2.8%</td>
#       <td id="T_9893f_row7_col2" class="data row7 col2" >12.8%</td>
#       <td id="T_9893f_row7_col3" class="data row7 col3" >41.0%</td>
#     </tr>
#     <tr>
#       <th id="T_9893f_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_9893f_row8_col0" class="data row8 col0" >37.7%</td>
#       <td id="T_9893f_row8_col1" class="data row8 col1" >4.9%</td>
#       <td id="T_9893f_row8_col2" class="data row8 col2" >17.8%</td>
#       <td id="T_9893f_row8_col3" class="data row8 col3" >39.6%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 6. Number of accidents by Severity vs. Lighting Conditions
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='lum', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Lighting Conditions')
plt.xlabel('Lighting Condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'lum')
# Out:
# <style type="text/css">
# #T_27397 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_27397 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_27397 caption {
#   caption-side: top;
# }
# #T_27397_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_27397_row0_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_27397_row0_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_27397_row0_col3, #T_27397_row1_col3 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_27397_row1_col0 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_27397_row1_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_27397_row1_col2 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_27397_row2_col0 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_27397_row2_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_27397_row2_col2 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_27397_row2_col3 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_27397_row3_col0 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_27397_row3_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_27397_row3_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_27397_row3_col3 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_27397_row4_col0 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_27397_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_27397_row4_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_27397_row4_col3 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_27397">
#   <caption>Percentages of Accident Gravity by Lum</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_27397_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_27397_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_27397_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_27397_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >lum</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27397_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_27397_row0_col0" class="data row0 col0" >45.7%</td>
#       <td id="T_27397_row0_col1" class="data row0 col1" >1.9%</td>
#       <td id="T_27397_row0_col2" class="data row0 col2" >13.1%</td>
#       <td id="T_27397_row0_col3" class="data row0 col3" >39.3%</td>
#     </tr>
#     <tr>
#       <th id="T_27397_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_27397_row1_col0" class="data row1 col0" >42.9%</td>
#       <td id="T_27397_row1_col1" class="data row1 col1" >2.5%</td>
#       <td id="T_27397_row1_col2" class="data row1 col2" >15.3%</td>
#       <td id="T_27397_row1_col3" class="data row1 col3" >39.3%</td>
#     </tr>
#     <tr>
#       <th id="T_27397_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_27397_row2_col0" class="data row2 col0" >38.2%</td>
#       <td id="T_27397_row2_col1" class="data row2 col1" >5.4%</td>
#       <td id="T_27397_row2_col2" class="data row2 col2" >19.0%</td>
#       <td id="T_27397_row2_col3" class="data row2 col3" >37.3%</td>
#     </tr>
#     <tr>
#       <th id="T_27397_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_27397_row3_col0" class="data row3 col0" >41.7%</td>
#       <td id="T_27397_row3_col1" class="data row3 col1" >3.1%</td>
#       <td id="T_27397_row3_col2" class="data row3 col2" >13.7%</td>
#       <td id="T_27397_row3_col3" class="data row3 col3" >41.5%</td>
#     </tr>
#     <tr>
#       <th id="T_27397_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_27397_row4_col0" class="data row4 col0" >43.2%</td>
#       <td id="T_27397_row4_col1" class="data row4 col1" >1.4%</td>
#       <td id="T_27397_row4_col2" class="data row4 col2" >10.9%</td>
#       <td id="T_27397_row4_col3" class="data row4 col3" >44.6%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 7. Number of accidents by Severity vs. Vehicle Category
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='vehicle_category', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Vehicle Category')
plt.xlabel('Vehicle Category')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'vehicle_category')
# Out:
# <style type="text/css">
# #T_334fc th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_334fc td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_334fc caption {
#   caption-side: top;
# }
# #T_334fc_row0_col0 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_334fc_row0_col1, #T_334fc_row9_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_334fc_row0_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_334fc_row0_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_334fc_row1_col0, #T_334fc_row20_col3 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_334fc_row1_col1, #T_334fc_row4_col1, #T_334fc_row5_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_334fc_row1_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_334fc_row1_col3 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_334fc_row2_col0, #T_334fc_row3_col3, #T_334fc_row15_col0, #T_334fc_row17_col0 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_334fc_row2_col1, #T_334fc_row17_col1, #T_334fc_row20_col1, #T_334fc_row23_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_334fc_row2_col2 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_334fc_row2_col3 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_334fc_row3_col0, #T_334fc_row14_col0, #T_334fc_row27_col0 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_334fc_row3_col1, #T_334fc_row14_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_334fc_row3_col2, #T_334fc_row11_col2 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_334fc_row4_col0, #T_334fc_row23_col0 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_334fc_row4_col2, #T_334fc_row7_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_334fc_row4_col3 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_334fc_row5_col0 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_334fc_row5_col2, #T_334fc_row13_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_334fc_row5_col3 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_334fc_row6_col0 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_334fc_row6_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_334fc_row6_col2 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_334fc_row6_col3 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_334fc_row7_col0 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_334fc_row7_col1 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_334fc_row7_col3 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_334fc_row8_col0, #T_334fc_row13_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_334fc_row8_col1, #T_334fc_row19_col1 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_334fc_row8_col2, #T_334fc_row17_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_334fc_row8_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_334fc_row9_col0, #T_334fc_row12_col0 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_334fc_row9_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_334fc_row9_col3 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_334fc_row10_col0 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_334fc_row10_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_334fc_row10_col2, #T_334fc_row30_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_334fc_row10_col3 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_334fc_row11_col0 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_334fc_row11_col1, #T_334fc_row21_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_334fc_row11_col3 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_334fc_row12_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_334fc_row12_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_334fc_row12_col3 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_334fc_row13_col0 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_334fc_row13_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_334fc_row14_col2 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_334fc_row14_col3 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_334fc_row15_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_334fc_row15_col2 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_334fc_row15_col3, #T_334fc_row28_col0 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_334fc_row16_col0, #T_334fc_row24_col3 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_334fc_row16_col1, #T_334fc_row29_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_334fc_row16_col2 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_334fc_row16_col3 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_334fc_row17_col3 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_334fc_row18_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_334fc_row18_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_334fc_row18_col2 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_334fc_row18_col3 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_334fc_row19_col0, #T_334fc_row19_col3 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_334fc_row19_col2 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_334fc_row20_col0 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_334fc_row20_col2 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_334fc_row21_col0 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_334fc_row21_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_334fc_row21_col3 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_334fc_row22_col0 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_334fc_row22_col1 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_334fc_row22_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_334fc_row22_col3 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_334fc_row23_col2, #T_334fc_row27_col2 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_334fc_row23_col3 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_334fc_row24_col0 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_334fc_row24_col1, #T_334fc_row26_col1, #T_334fc_row30_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_334fc_row24_col2 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_334fc_row25_col0 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_334fc_row25_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_334fc_row25_col2, #T_334fc_row26_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_334fc_row25_col3, #T_334fc_row29_col0 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_334fc_row26_col0 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_334fc_row26_col3 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_334fc_row27_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_334fc_row27_col3 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_334fc_row28_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_334fc_row28_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_334fc_row28_col3 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_334fc_row29_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_334fc_row29_col3 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_334fc_row30_col0 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_334fc_row30_col3 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_334fc">
#   <caption>Percentages of Accident Gravity by Vehicle_category</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_334fc_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_334fc_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_334fc_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_334fc_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >vehicle_category</th>
#       <th class="blank col0" >&nbsp

# %%
# 7.1 Number of accidents by Severity vs.Year
genders = data['gender'].unique()
n_genders = len(genders)

fig, axes = plt.subplots(1, n_genders, figsize=(18, 6))
fig.suptitle('Severity Distribution per gender', fontsize=16)

custom_colors_mat = ['#66B2FF', '#99FF99', '#FFCC99', '#FF9999']

for i, gender in enumerate(genders):
    genderly_data = data[data['gender'] == gender]['gravity'].value_counts()
    colors = custom_colors_mat[:len(genderly_data)]  
    axes[i].pie(genderly_data, labels=genderly_data.index, autopct='%1.1f%%', colors=colors)
    axes[i].set_title(f'gender {gender}')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# 8. Number of accidents by Severity vs. Gender
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='gender', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.show()

calculate_and_display_percentages(data, 'gender')
# Out:
# <style type="text/css">
# #T_58726 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_58726 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_58726 caption {
#   caption-side: top;
# }
# #T_58726_row0_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_58726_row0_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_58726_row0_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_58726_row0_col3 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_58726_row1_col0 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_58726_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_58726_row1_col2 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_58726_row1_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_58726">
#   <caption>Percentages of Accident Gravity by Gender</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_58726_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_58726_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_58726_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_58726_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58726_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_58726_row0_col0" class="data row0 col0" >46.6%</td>
#       <td id="T_58726_row0_col1" class="data row0 col1" >2.5%</td>
#       <td id="T_58726_row0_col2" class="data row0 col2" >14.2%</td>
#       <td id="T_58726_row0_col3" class="data row0 col3" >36.8%</td>
#     </tr>
#     <tr>
#       <th id="T_58726_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_58726_row1_col0" class="data row1 col0" >39.9%</td>
#       <td id="T_58726_row1_col1" class="data row1 col1" >1.5%</td>
#       <td id="T_58726_row1_col2" class="data row1 col2" >11.9%</td>
#       <td id="T_58726_row1_col3" class="data row1 col3" >46.8%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 9. Number of accidents by Severity vs. Surface Condition
plt.figure(figsize=(18,12))
sns.countplot(data=data, x='surface_condition', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Surface Condition')
plt.xlabel('Surface Condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'surface_condition')
# Out:
# <style type="text/css">
# #T_07da4 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_07da4 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_07da4 caption {
#   caption-side: top;
# }
# #T_07da4_row0_col0 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_07da4_row0_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_07da4_row0_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_07da4_row0_col3 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_07da4_row1_col0 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_07da4_row1_col1, #T_07da4_row2_col1, #T_07da4_row4_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_07da4_row1_col2 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_07da4_row1_col3 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_07da4_row2_col0 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_07da4_row2_col2 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_07da4_row2_col3 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_07da4_row3_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_07da4_row3_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_07da4_row3_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_07da4_row3_col3 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_07da4_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_07da4_row4_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_07da4_row4_col3 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_07da4_row5_col0 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_07da4_row5_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_07da4_row5_col2 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_07da4_row5_col3, #T_07da4_row6_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_07da4_row6_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_07da4_row6_col2 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_07da4_row6_col3 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_07da4_row7_col0 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_07da4_row7_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_07da4_row7_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_07da4_row7_col3 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_07da4_row8_col0 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_07da4_row8_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_07da4_row8_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_07da4_row8_col3 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_07da4">
#   <caption>Percentages of Accident Gravity by Surface_condition</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_07da4_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_07da4_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_07da4_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_07da4_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >surface_condition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07da4_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_07da4_row0_col0" class="data row0 col0" >44.7%</td>
#       <td id="T_07da4_row0_col1" class="data row0 col1" >2.1%</td>
#       <td id="T_07da4_row0_col2" class="data row0 col2" >13.7%</td>
#       <td id="T_07da4_row0_col3" class="data row0 col3" >39.5%</td>
#     </tr>
#     <tr>
#       <th id="T_07da4_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_07da4_row1_col0" class="data row1 col0" >43.6%</td>
#       <td id="T_07da4_row1_col1" class="data row1 col1" >2.3%</td>
#       <td id="T_07da4_row1_col2" class="data row1 col2" >12.1%</td>
#       <td id="T_07da4_row1_col3" class="data row1 col3" >42.0%</td>
#     </tr>
#     <tr>
#       <th id="T_07da4_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_07da4_row2_col0" class="data row2 col0" >43.7%</td>
#       <td id="T_07da4_row2_col1" class="data row2 col1" >2.3%</td>
#       <td id="T_07da4_row2_col2" class="data row2 col2" >16.8%</td>
#       <td id="T_07da4_row2_col3" class="data row2 col3" >37.2%</td>
#     </tr>
#     <tr>
#       <th id="T_07da4_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_07da4_row3_col0" class="data row3 col0" >42.9%</td>
#       <td id="T_07da4_row3_col1" class="data row3 col1" >4.0%</td>
#       <td id="T_07da4_row3_col2" class="data row3 col2" >14.3%</td>
#       <td id="T_07da4_row3_col3" class="data row3 col3" >38.9%</td>
#     </tr>
#     <tr>
#       <th id="T_07da4_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_07da4_row4_col0" class="data row4 col0" >48.7%</td>
#       <td id="T_07da4_row4_col1" class="data row4 col1" >2.3%</td>
#       <td id="T_07da4_row4_col2" class="data row4 col2" >13.8%</td>
#       <td id="T_07da4_row4_col3" class="data row4 col3" >35.2%</td>
#     </tr>
#     <tr>
#       <th id="T_07da4_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_07da4_row5_col0" class="data row5 col0" >27.8%</td>
#       <td id="T_07da4_row5_col1" class="data row5 col1" >5.7%</td>
#       <td id="T_07da4_row5_col2" class="data row5 col2" >29.2%</td>
#       <td id="T_07da4_row5_col3" class="data row5 col3" >37.3%</td>
#     </tr>
#     <tr>
#       <th id="T_07da4_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_07da4_row6_col0" class="data row6 col0" >37.3%</td>
#       <td id="T_07da4_row6_col1" class="data row6 col1" >4.4%</td>
#       <td id="T_07da4_row6_col2" class="data row6 col2" >20.4%</td>
#       <td id="T_07da4_row6_col3" class="data row6 col3" >37.8%</td>
#     </tr>
#     <tr>
#       <th id="T_07da4_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_07da4_row7_col0" class="data row7 col0" >40.6%</td>
#       <td id="T_07da4_row7_col1" class="data row7 col1" >1.3%</td>
#       <td id="T_07da4_row7_col2" class="data row7 col2" >17.2%</td>
#       <td id="T_07da4_row7_col3" class="data row7 col3" >41.0%</td>
#     </tr>
#     <tr>
#       <th id="T_07da4_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_07da4_row8_col0" class="data row8 col0" >38.6%</td>
#       <td id="T_07da4_row8_col1" class="data row8 col1" >4.4%</td>
#       <td id="T_07da4_row8_col2" class="data row8 col2" >22.6%</td>
#       <td id="T_07da4_row8_col3" class="data row8 col3" >34.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 10. Number of accidents by Severity vs. Maximum Speed
# Define the bins and corresponding labels
bins = [0, 49, 59, 69, 79, 89, 99, 109, float('inf')]
labels = ['0-49', '50-59', '60-69', '70-79', '80-89', '90-99', '100-109', '110-119']

# Create a new column for the binned speeds
data['speed_group'] = pd.cut(data['maximum_speed'], bins=bins, labels=labels, right=False)

plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='speed_group', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Maximum Speed')
plt.xlabel('Maximum Speed Group')
plt.ylabel('Gravity')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

calculate_and_display_percentages(data, 'maximum_speed')
# Out:
# <style type="text/css">
# #T_6aa13 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_6aa13 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_6aa13 caption {
#   caption-side: top;
# }
# #T_6aa13_row0_col0 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_6aa13_row0_col1, #T_6aa13_row9_col1, #T_6aa13_row10_col1, #T_6aa13_row15_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_6aa13_row0_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_6aa13_row0_col3, #T_6aa13_row5_col0, #T_6aa13_row23_col3 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_6aa13_row1_col0 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_6aa13_row1_col1, #T_6aa13_row2_col1, #T_6aa13_row3_col0, #T_6aa13_row3_col1, #T_6aa13_row3_col2, #T_6aa13_row4_col1, #T_6aa13_row4_col2, #T_6aa13_row6_col1, #T_6aa13_row6_col2, #T_6aa13_row11_col1, #T_6aa13_row13_col1, #T_6aa13_row13_col2, #T_6aa13_row16_col1, #T_6aa13_row18_col1, #T_6aa13_row18_col3, #T_6aa13_row20_col1, #T_6aa13_row20_col3, #T_6aa13_row25_col1, #T_6aa13_row25_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6aa13_row1_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_6aa13_row1_col3, #T_6aa13_row22_col0 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_6aa13_row2_col0 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_6aa13_row2_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_6aa13_row2_col3 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_6aa13_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6aa13_row4_col0, #T_6aa13_row18_col2 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_6aa13_row4_col3, #T_6aa13_row18_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_6aa13_row5_col1, #T_6aa13_row14_col1, #T_6aa13_row22_col1, #T_6aa13_row24_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_6aa13_row5_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_6aa13_row5_col3, #T_6aa13_row8_col3 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_6aa13_row6_col0 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_6aa13_row6_col3 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_6aa13_row7_col0 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_6aa13_row7_col1, #T_6aa13_row8_col1, #T_6aa13_row23_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_6aa13_row7_col2, #T_6aa13_row17_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_6aa13_row7_col3 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_6aa13_row8_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_6aa13_row8_col2 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_6aa13_row9_col0 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_6aa13_row9_col2 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_6aa13_row9_col3 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_6aa13_row10_col0, #T_6aa13_row14_col0 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_6aa13_row10_col2 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_6aa13_row10_col3 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_6aa13_row11_col0 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_6aa13_row11_col2 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_6aa13_row11_col3 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_6aa13_row12_col0 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_6aa13_row12_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_6aa13_row12_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_6aa13_row12_col3 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_6aa13_row13_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_6aa13_row13_col3 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_6aa13_row14_col2 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_6aa13_row14_col3 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_6aa13_row15_col0, #T_6aa13_row19_col0 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_6aa13_row15_col2 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_6aa13_row15_col3 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_6aa13_row16_col0, #T_6aa13_row16_col3, #T_6aa13_row20_col0 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_6aa13_row16_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_6aa13_row17_col0, #T_6aa13_row22_col3 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_6aa13_row17_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_6aa13_row17_col3, #T_6aa13_row23_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_6aa13_row19_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_6aa13_row19_col2 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_6aa13_row19_col3 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_6aa13_row20_col2 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_6aa13_row21_col0 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_6aa13_row21_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_6aa13_row21_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_6aa13_row21_col3 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_6aa13_row22_col2 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_6aa13_row23_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_6aa13_row24_col0, #T_6aa13_row25_col0, #T_6aa13_row25_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_6aa13_row24_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_6aa13_row24_col3 {
#   background-color: #95c5df;
#   color: #000000;
# }
# </style>
# <table id="T_6aa13">
#   <caption>Percentages of Accident Gravity by Maximum_speed</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_6aa13_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_6aa13_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_6aa13_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_6aa13_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >maximum_speed</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6aa13_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_6aa13_row0_col0" class="data row0 col0" >46.8%</td>
#       <td id="T_6aa13_row0_col1" class="data row0 col1" >1.0%</td>
#       <td id="T_6aa13_row0_col2" class="data row0 col2" >7.8%</td>
#       <td id="T_6aa13_row0_col3" class="data row0 col3" >44.4%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa13_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_6aa13_row1_col0" class="data row1 col0" >38.1%</td>
#       <td id="T_6aa13_row1_col1" class="data row1 col1" >0.0%</td>
#       <td id="T_6aa13_row1_col2" class="data row1 col2" >14.3%</td>
#       <td id="T_6aa13_row1_col3" class="data row1 col3" >47.6%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa13_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_6aa13_row2_col0" class="data row2 col0" >54.5%</td>
#       <td id="T_6aa13_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_6aa13_row2_col2" class="data row2 col2" >18.2%</td>
#       <td id="T_6aa13_row2_col3" class="data row2 col3" >27.3%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa13_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_6aa13_row3_col0" class="data row3 col0" >0.0%</td>
#       <td id="T_6aa13_row3_col1" class="data row3 col1" >0.0%</td>
#       <td id="T_6aa13_row3_col2" class="data row3 col2" >0.0%</td>
#       <td id="T_6aa13_row3_col3" class="data row3 col3" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa13_level0_row4" class="row_heading level0 row4" >9</th>
#       <td id="T_6aa13_row4_col0" class="data row4 col0" >66.7%</td>
#       <td id="T_6aa13_row4_col1" class="data row4 col1" >0.0%</td>
#       <td id="T_6aa13_row4_col2" cl

# %%
# 11. Number of accidents by Severity vs. Age
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='gravity', y='age', hue_order=gravity_order, palette=custom_colors)
plt.title('Age Distribution by Accident Gravity Category')
plt.show()

calculate_and_display_percentages(data, 'age')
# Out:
# <style type="text/css">
# #T_74a82 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_74a82 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_74a82 caption {
#   caption-side: top;
# }
# #T_74a82_row0_col0, #T_74a82_row24_col3, #T_74a82_row31_col3 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_74a82_row0_col1, #T_74a82_row15_col1, #T_74a82_row17_col1, #T_74a82_row28_col1, #T_74a82_row29_col1, #T_74a82_row30_col1, #T_74a82_row33_col1, #T_74a82_row34_col1, #T_74a82_row35_col1, #T_74a82_row36_col1, #T_74a82_row38_col1, #T_74a82_row39_col1, #T_74a82_row40_col1, #T_74a82_row47_col1, #T_74a82_row48_col1, #T_74a82_row50_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_74a82_row0_col2, #T_74a82_row77_col1, #T_74a82_row80_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_74a82_row0_col3, #T_74a82_row45_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_74a82_row1_col0 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_74a82_row1_col1, #T_74a82_row8_col1, #T_74a82_row9_col1, #T_74a82_row13_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_74a82_row1_col2 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_74a82_row1_col3, #T_74a82_row42_col0 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_74a82_row2_col0, #T_74a82_row4_col0, #T_74a82_row28_col0, #T_74a82_row72_col0 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_74a82_row2_col1, #T_74a82_row3_col1, #T_74a82_row19_col1, #T_74a82_row20_col1, #T_74a82_row22_col1, #T_74a82_row24_col1, #T_74a82_row25_col1, #T_74a82_row52_col1, #T_74a82_row56_col1, #T_74a82_row57_col1, #T_74a82_row58_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_74a82_row2_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_74a82_row2_col3, #T_74a82_row19_col3, #T_74a82_row57_col0, #T_74a82_row62_col0 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_74a82_row3_col0, #T_74a82_row22_col3, #T_74a82_row23_col0, #T_74a82_row28_col3 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_74a82_row3_col2, #T_74a82_row84_col1 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_74a82_row3_col3, #T_74a82_row35_col0, #T_74a82_row58_col0, #T_74a82_row65_col0, #T_74a82_row70_col0 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_74a82_row4_col1, #T_74a82_row11_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_74a82_row4_col2 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_74a82_row4_col3, #T_74a82_row32_col0, #T_74a82_row67_col0 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_74a82_row5_col0, #T_74a82_row86_col0 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_74a82_row5_col1, #T_74a82_row12_col1, #T_74a82_row14_col1, #T_74a82_row16_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_74a82_row5_col2 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_74a82_row5_col3, #T_74a82_row40_col0 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_74a82_row6_col0, #T_74a82_row41_col3, #T_74a82_row46_col3 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_74a82_row6_col1, #T_74a82_row7_col1, #T_74a82_row10_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_74a82_row6_col2, #T_74a82_row33_col2, #T_74a82_row35_col2, #T_74a82_row37_col2, #T_74a82_row40_col2, #T_74a82_row45_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_74a82_row6_col3, #T_74a82_row7_col3 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_74a82_row7_col0, #T_74a82_row50_col3 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_74a82_row7_col2, #T_74a82_row28_col2, #T_74a82_row34_col2, #T_74a82_row46_col2, #T_74a82_row48_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_74a82_row8_col0, #T_74a82_row10_col0, #T_74a82_row89_col0 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_74a82_row8_col2, #T_74a82_row39_col2, #T_74a82_row90_col1 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_74a82_row8_col3 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_74a82_row9_col0, #T_74a82_row72_col3 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_74a82_row9_col2, #T_74a82_row26_col2, #T_74a82_row49_col2, #T_74a82_row52_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_74a82_row9_col3 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_74a82_row10_col2, #T_74a82_row56_col2, #T_74a82_row59_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_74a82_row10_col3 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_74a82_row11_col0, #T_74a82_row68_col3, #T_74a82_row69_col3, #T_74a82_row93_col0 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_74a82_row11_col2 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_74a82_row11_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_74a82_row12_col0, #T_74a82_row70_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_74a82_row12_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_74a82_row12_col3, #T_74a82_row13_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_74a82_row13_col0, #T_74a82_row91_col3 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_74a82_row13_col2, #T_74a82_row55_col2 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_74a82_row14_col0 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_74a82_row14_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_74a82_row14_col3, #T_74a82_row16_col3 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_74a82_row15_col0, #T_74a82_row18_col2, #T_74a82_row80_col2 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_74a82_row15_col2, #T_74a82_row17_col0, #T_74a82_row19_col2 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_74a82_row15_col3 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_74a82_row16_col0 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_74a82_row16_col2, #T_74a82_row91_col2 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_74a82_row17_col2 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_74a82_row17_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_74a82_row18_col0, #T_74a82_row92_col2, #T_74a82_row94_col2 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_74a82_row18_col1, #T_74a82_row23_col1, #T_74a82_row26_col1, #T_74a82_row27_col1, #T_74a82_row31_col1, #T_74a82_row32_col1, #T_74a82_row37_col1, #T_74a82_row41_col1, #T_74a82_row42_col1, #T_74a82_row43_col1, #T_74a82_row44_col1, #T_74a82_row45_col1, #T_74a82_row46_col1, #T_74a82_row49_col1, #T_74a82_row54_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_74a82_row18_col3 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_74a82_row19_col0, #T_74a82_row85_col3, #T_74a82_row94_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_74a82_row20_col0, #T_74a82_row62_col3 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_74a82_row20_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_74a82_row20_col3, #T_74a82_row66_col0 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_74a82_row21_col0, #T_74a82_row88_col0 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_74a82_row21_col1, #T_74a82_row51_col1, #T_74a82_row55_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_74a82_row21_col2, #T_74a82_row62_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_74a82_row21_col3 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_74a82_row22_col0, #T_74a82_row25_col0, #T_74a82_row26_col3 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_74a82_row22_col2, #T_74a82_row50_col2, #T_74a82_row54_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_74a82_row23_col2, #T_74a82_row53_col2, #T_74a82_row93_col1 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_74a82_row23_col3, #T_74a82_row25_col3, #T_74a82_row29_col3, #T_74a82_row82_col0 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_74a82_row24_col0, #T_74a82_row27_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_74a82_row24_col2 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_74a82_row25_col2, #T_74a82_row91_col1 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_74a82_row26_col

# %%
# 12. Number of accidents by Severity vs. Age
plt.figure(figsize=(10, 6))
sns.kdeplot(data=data, x='age', hue='gravity', fill=True, hue_order=gravity_order, palette=custom_colors)
plt.title('Density of Age Distribution by Accident Gravity Category')
plt.show()

# %%
# 13. Number of accidents by Severity vs. Age
plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='age', y='maximum_speed', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Age vs. Maximum Speed by Accident Gravity')
plt.show()

# %%
# 14. Number of accidents by Severity vs. motor
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='motor', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. motor')
plt.xlabel('motor')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'motor')
# Out:
# <style type="text/css">
# #T_7ac4c th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_7ac4c td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_7ac4c caption {
#   caption-side: top;
# }
# #T_7ac4c_row0_col0, #T_7ac4c_row2_col3 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_7ac4c_row0_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_7ac4c_row0_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_7ac4c_row0_col3, #T_7ac4c_row3_col0, #T_7ac4c_row5_col0 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_7ac4c_row1_col0 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_7ac4c_row1_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_7ac4c_row1_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_7ac4c_row1_col3 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_7ac4c_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7ac4c_row2_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_7ac4c_row2_col2 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_7ac4c_row3_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_7ac4c_row3_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_7ac4c_row3_col3 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_7ac4c_row4_col0 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_7ac4c_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7ac4c_row4_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_7ac4c_row4_col3 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_7ac4c_row5_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_7ac4c_row5_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_7ac4c_row5_col3 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_7ac4c_row6_col0 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_7ac4c_row6_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_7ac4c_row6_col2 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_7ac4c_row6_col3 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7ac4c">
#   <caption>Percentages of Accident Gravity by Motor</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_7ac4c_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_7ac4c_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_7ac4c_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_7ac4c_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >motor</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ac4c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7ac4c_row0_col0" class="data row0 col0" >41.5%</td>
#       <td id="T_7ac4c_row0_col1" class="data row0 col1" >1.7%</td>
#       <td id="T_7ac4c_row0_col2" class="data row0 col2" >13.3%</td>
#       <td id="T_7ac4c_row0_col3" class="data row0 col3" >43.5%</td>
#     </tr>
#     <tr>
#       <th id="T_7ac4c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7ac4c_row1_col0" class="data row1 col0" >44.7%</td>
#       <td id="T_7ac4c_row1_col1" class="data row1 col1" >2.3%</td>
#       <td id="T_7ac4c_row1_col2" class="data row1 col2" >13.6%</td>
#       <td id="T_7ac4c_row1_col3" class="data row1 col3" >39.5%</td>
#     </tr>
#     <tr>
#       <th id="T_7ac4c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7ac4c_row2_col0" class="data row2 col0" >48.8%</td>
#       <td id="T_7ac4c_row2_col1" class="data row2 col1" >1.2%</td>
#       <td id="T_7ac4c_row2_col2" class="data row2 col2" >8.5%</td>
#       <td id="T_7ac4c_row2_col3" class="data row2 col3" >41.6%</td>
#     </tr>
#     <tr>
#       <th id="T_7ac4c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7ac4c_row3_col0" class="data row3 col0" >43.6%</td>
#       <td id="T_7ac4c_row3_col1" class="data row3 col1" >1.5%</td>
#       <td id="T_7ac4c_row3_col2" class="data row3 col2" >9.5%</td>
#       <td id="T_7ac4c_row3_col3" class="data row3 col3" >45.4%</td>
#     </tr>
#     <tr>
#       <th id="T_7ac4c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7ac4c_row4_col0" class="data row4 col0" >42.4%</td>
#       <td id="T_7ac4c_row4_col1" class="data row4 col1" >0.6%</td>
#       <td id="T_7ac4c_row4_col2" class="data row4 col2" >10.8%</td>
#       <td id="T_7ac4c_row4_col3" class="data row4 col3" >46.2%</td>
#     </tr>
#     <tr>
#       <th id="T_7ac4c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7ac4c_row5_col0" class="data row5 col0" >43.7%</td>
#       <td id="T_7ac4c_row5_col1" class="data row5 col1" >2.1%</td>
#       <td id="T_7ac4c_row5_col2" class="data row5 col2" >14.5%</td>
#       <td id="T_7ac4c_row5_col3" class="data row5 col3" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_7ac4c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7ac4c_row6_col0" class="data row6 col0" >42.0%</td>
#       <td id="T_7ac4c_row6_col1" class="data row6 col1" >2.7%</td>
#       <td id="T_7ac4c_row6_col2" class="data row6 col2" >17.1%</td>
#       <td id="T_7ac4c_row6_col3" class="data row6 col3" >38.2%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 15. Number of accidents by Severity vs. Impact point
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='initial_impact_point', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Impact point')
plt.xlabel('Impact point')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'initial_impact_point')
# Out:
# <style type="text/css">
# #T_19479 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_19479 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_19479 caption {
#   caption-side: top;
# }
# #T_19479_row0_col0 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_19479_row0_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_19479_row0_col2 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_19479_row0_col3 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_19479_row1_col0 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_19479_row1_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_19479_row1_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_19479_row1_col3, #T_19479_row7_col3 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_19479_row2_col0 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_19479_row2_col1, #T_19479_row8_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_19479_row2_col2, #T_19479_row8_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_19479_row2_col3 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_19479_row3_col0, #T_19479_row9_col3 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_19479_row3_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_19479_row3_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_19479_row3_col3 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_19479_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_19479_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_19479_row4_col2 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_19479_row4_col3 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_19479_row5_col0 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_19479_row5_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_19479_row5_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_19479_row5_col3, #T_19479_row6_col3 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_19479_row6_col0 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_19479_row6_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_19479_row6_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_19479_row7_col0 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_19479_row7_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_19479_row7_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_19479_row8_col0 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_19479_row8_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_19479_row9_col0 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_19479_row9_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_19479_row9_col2 {
#   background-color: #97c6df;
#   color: #000000;
# }
# </style>
# <table id="T_19479">
#   <caption>Percentages of Accident Gravity by Initial_impact_point</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_19479_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_19479_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_19479_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_19479_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >initial_impact_point</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19479_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_19479_row0_col0" class="data row0 col0" >36.3%</td>
#       <td id="T_19479_row0_col1" class="data row0 col1" >3.2%</td>
#       <td id="T_19479_row0_col2" class="data row0 col2" >16.7%</td>
#       <td id="T_19479_row0_col3" class="data row0 col3" >43.8%</td>
#     </tr>
#     <tr>
#       <th id="T_19479_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_19479_row1_col0" class="data row1 col0" >42.3%</td>
#       <td id="T_19479_row1_col1" class="data row1 col1" >2.6%</td>
#       <td id="T_19479_row1_col2" class="data row1 col2" >15.2%</td>
#       <td id="T_19479_row1_col3" class="data row1 col3" >39.9%</td>
#     </tr>
#     <tr>
#       <th id="T_19479_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_19479_row2_col0" class="data row2 col0" >45.0%</td>
#       <td id="T_19479_row2_col1" class="data row2 col1" >2.1%</td>
#       <td id="T_19479_row2_col2" class="data row2 col2" >13.8%</td>
#       <td id="T_19479_row2_col3" class="data row2 col3" >39.1%</td>
#     </tr>
#     <tr>
#       <th id="T_19479_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_19479_row3_col0" class="data row3 col0" >43.4%</td>
#       <td id="T_19479_row3_col1" class="data row3 col1" >2.5%</td>
#       <td id="T_19479_row3_col2" class="data row3 col2" >15.6%</td>
#       <td id="T_19479_row3_col3" class="data row3 col3" >38.4%</td>
#     </tr>
#     <tr>
#       <th id="T_19479_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_19479_row4_col0" class="data row4 col0" >52.7%</td>
#       <td id="T_19479_row4_col1" class="data row4 col1" >0.7%</td>
#       <td id="T_19479_row4_col2" class="data row4 col2" >5.1%</td>
#       <td id="T_19479_row4_col3" class="data row4 col3" >41.5%</td>
#     </tr>
#     <tr>
#       <th id="T_19479_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_19479_row5_col0" class="data row5 col0" >50.2%</td>
#       <td id="T_19479_row5_col1" class="data row5 col1" >1.2%</td>
#       <td id="T_19479_row5_col2" class="data row5 col2" >9.8%</td>
#       <td id="T_19479_row5_col3" class="data row5 col3" >38.9%</td>
#     </tr>
#     <tr>
#       <th id="T_19479_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_19479_row6_col0" class="data row6 col0" >49.6%</td>
#       <td id="T_19479_row6_col1" class="data row6 col1" >1.4%</td>
#       <td id="T_19479_row6_col2" class="data row6 col2" >10.0%</td>
#       <td id="T_19479_row6_col3" class="data row6 col3" >38.9%</td>
#     </tr>
#     <tr>
#       <th id="T_19479_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_19479_row7_col0" class="data row7 col0" >44.5%</td>
#       <td id="T_19479_row7_col1" class="data row7 col1" >1.9%</td>
#       <td id="T_19479_row7_col2" class="data row7 col2" >13.7%</td>
#       <td id="T_19479_row7_col3" class="data row7 col3" >39.9%</td>
#     </tr>
#     <tr>
#       <th id="T_19479_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_19479_row8_col0" class="data row8 col0" >44.7%</td>
#       <td id="T_19479_row8_col1" class="data row8 col1" >2.0%</td>
#       <td id="T_19479_row8_col2" class="data row8 col2" >13.8%</td>
#       <td id="T_19479_row8_col3" class="data row8 col3" >39.5%</td>
#     </tr>
#     <tr>
#       <th id="T_19479_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_19479_row9_col0" class="data row9 col0" >30.5%</td>
#       <td id="T_19479_row9_col1" class="data row9 col1" >4.8%</td>
#       <td id="T_19479_row9_col2" class="data row9 col2" >21.2%</td>
#       <td id="T_19479_row9_col3" class="data row9 col3" >43.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 16. Number of accidents by Severity vs. Safety equipment
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='safety_equipment1', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. Safety equipment')
plt.xlabel('Safety equipment')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'safety_equipment1')
# Out:
# <style type="text/css">
# #T_a1e6c th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_a1e6c td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_a1e6c caption {
#   caption-side: top;
# }
# #T_a1e6c_row0_col0 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_a1e6c_row0_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_a1e6c_row0_col2 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_a1e6c_row0_col3 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_a1e6c_row1_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_a1e6c_row1_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_a1e6c_row1_col2 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_a1e6c_row1_col3 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_a1e6c_row2_col0, #T_a1e6c_row6_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_a1e6c_row2_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_a1e6c_row2_col2 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_a1e6c_row2_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a1e6c_row3_col0 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_a1e6c_row3_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_a1e6c_row3_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_a1e6c_row3_col3 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_a1e6c_row4_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_a1e6c_row4_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_a1e6c_row4_col2 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_a1e6c_row4_col3 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_a1e6c_row5_col0 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_a1e6c_row5_col1 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_a1e6c_row5_col2 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_a1e6c_row5_col3 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_a1e6c_row6_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_a1e6c_row6_col2 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_a1e6c_row6_col3 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_a1e6c_row7_col0 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_a1e6c_row7_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a1e6c_row7_col2 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_a1e6c_row7_col3 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_a1e6c_row8_col0 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_a1e6c_row8_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_a1e6c_row8_col2 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_a1e6c_row8_col3 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_a1e6c_row9_col0 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_a1e6c_row9_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_a1e6c_row9_col2 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_a1e6c_row9_col3 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# </style>
# <table id="T_a1e6c">
#   <caption>Percentages of Accident Gravity by Safety_equipment1</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_a1e6c_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_a1e6c_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_a1e6c_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_a1e6c_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >safety_equipment1</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1e6c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1e6c_row0_col0" class="data row0 col0" >9.0%</td>
#       <td id="T_a1e6c_row0_col1" class="data row0 col1" >8.4%</td>
#       <td id="T_a1e6c_row0_col2" class="data row0 col2" >32.1%</td>
#       <td id="T_a1e6c_row0_col3" class="data row0 col3" >50.5%</td>
#     </tr>
#     <tr>
#       <th id="T_a1e6c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1e6c_row1_col0" class="data row1 col0" >59.3%</td>
#       <td id="T_a1e6c_row1_col1" class="data row1 col1" >1.2%</td>
#       <td id="T_a1e6c_row1_col2" class="data row1 col2" >7.3%</td>
#       <td id="T_a1e6c_row1_col3" class="data row1 col3" >32.2%</td>
#     </tr>
#     <tr>
#       <th id="T_a1e6c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a1e6c_row2_col0" class="data row2 col0" >7.8%</td>
#       <td id="T_a1e6c_row2_col1" class="data row2 col1" >3.5%</td>
#       <td id="T_a1e6c_row2_col2" class="data row2 col2" >29.0%</td>
#       <td id="T_a1e6c_row2_col3" class="data row2 col3" >59.7%</td>
#     </tr>
#     <tr>
#       <th id="T_a1e6c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a1e6c_row3_col0" class="data row3 col0" >47.8%</td>
#       <td id="T_a1e6c_row3_col1" class="data row3 col1" >0.9%</td>
#       <td id="T_a1e6c_row3_col2" class="data row3 col2" >7.0%</td>
#       <td id="T_a1e6c_row3_col3" class="data row3 col3" >44.2%</td>
#     </tr>
#     <tr>
#       <th id="T_a1e6c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a1e6c_row4_col0" class="data row4 col0" >18.0%</td>
#       <td id="T_a1e6c_row4_col1" class="data row4 col1" >10.6%</td>
#       <td id="T_a1e6c_row4_col2" class="data row4 col2" >42.9%</td>
#       <td id="T_a1e6c_row4_col3" class="data row4 col3" >28.6%</td>
#     </tr>
#     <tr>
#       <th id="T_a1e6c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a1e6c_row5_col0" class="data row5 col0" >30.4%</td>
#       <td id="T_a1e6c_row5_col1" class="data row5 col1" >8.0%</td>
#       <td id="T_a1e6c_row5_col2" class="data row5 col2" >32.7%</td>
#       <td id="T_a1e6c_row5_col3" class="data row5 col3" >28.9%</td>
#     </tr>
#     <tr>
#       <th id="T_a1e6c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a1e6c_row6_col0" class="data row6 col0" >6.7%</td>
#       <td id="T_a1e6c_row6_col1" class="data row6 col1" >7.8%</td>
#       <td id="T_a1e6c_row6_col2" class="data row6 col2" >58.4%</td>
#       <td id="T_a1e6c_row6_col3" class="data row6 col3" >27.0%</td>
#     </tr>
#     <tr>
#       <th id="T_a1e6c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a1e6c_row7_col0" class="data row7 col0" >11.8%</td>
#       <td id="T_a1e6c_row7_col1" class="data row7 col1" >0.0%</td>
#       <td id="T_a1e6c_row7_col2" class="data row7 col2" >29.4%</td>
#       <td id="T_a1e6c_row7_col3" class="data row7 col3" >58.8%</td>
#     </tr>
#     <tr>
#       <th id="T_a1e6c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a1e6c_row8_col0" class="data row8 col0" >35.3%</td>
#       <td id="T_a1e6c_row8_col1" class="data row8 col1" >2.7%</td>
#       <td id="T_a1e6c_row8_col2" class="data row8 col2" >14.5%</td>
#       <td id="T_a1e6c_row8_col3" class="data row8 col3" >47.4%</td>
#     </tr>
#     <tr>
#       <th id="T_a1e6c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a1e6c_row9_col0" class="data row9 col0" >41.7%</td>
#       <td id="T_a1e6c_row9_col1" class="data row9 col1" >4.2%</td>
#       <td id="T_a1e6c_row9_col2" class="data row9 col2" >27.6%</td>
#       <td id="T_a1e6c_row9_col3" class="data row9 col3" >26.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 17. Number of accidents by Severity vs. Manv
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='manv', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. manv')
plt.xlabel('manv')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'manv')
# Out:
# <style type="text/css">
# #T_c0c26 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_c0c26 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_c0c26 caption {
#   caption-side: top;
# }
# #T_c0c26_row0_col0 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_c0c26_row0_col1, #T_c0c26_row17_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_c0c26_row0_col2, #T_c0c26_row21_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_c0c26_row0_col3 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_c0c26_row1_col0, #T_c0c26_row8_col0 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_c0c26_row1_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_c0c26_row1_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_c0c26_row1_col3, #T_c0c26_row24_col3 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_c0c26_row2_col0 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_c0c26_row2_col1, #T_c0c26_row9_col1, #T_c0c26_row10_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_c0c26_row2_col2 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_c0c26_row2_col3, #T_c0c26_row21_col0, #T_c0c26_row25_col0 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_c0c26_row3_col0, #T_c0c26_row23_col0 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_c0c26_row3_col1, #T_c0c26_row12_col1, #T_c0c26_row23_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_c0c26_row3_col2 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_c0c26_row3_col3 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_c0c26_row4_col0, #T_c0c26_row24_col0 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_c0c26_row4_col1, #T_c0c26_row19_col1, #T_c0c26_row24_col1, #T_c0c26_row26_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_c0c26_row4_col2 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_c0c26_row4_col3 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_c0c26_row5_col0 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_c0c26_row5_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_c0c26_row5_col2 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_c0c26_row5_col3 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_c0c26_row6_col0 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_c0c26_row6_col1, #T_c0c26_row14_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_c0c26_row6_col2 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_c0c26_row6_col3 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_c0c26_row7_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_c0c26_row7_col1, #T_c0c26_row18_col1, #T_c0c26_row25_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_c0c26_row7_col2 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_c0c26_row7_col3 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_c0c26_row8_col1, #T_c0c26_row22_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c0c26_row8_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_c0c26_row8_col3, #T_c0c26_row9_col0, #T_c0c26_row15_col0 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_c0c26_row9_col2, #T_c0c26_row16_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_c0c26_row9_col3 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_c0c26_row10_col0 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_c0c26_row10_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_c0c26_row10_col3 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_c0c26_row11_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_c0c26_row11_col1, #T_c0c26_row15_col1, #T_c0c26_row16_col1, #T_c0c26_row20_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_c0c26_row11_col2, #T_c0c26_row18_col2 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_c0c26_row11_col3 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_c0c26_row12_col0, #T_c0c26_row18_col0 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_c0c26_row12_col2 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_c0c26_row12_col3 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_c0c26_row13_col0 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_c0c26_row13_col1 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_c0c26_row13_col2 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_c0c26_row13_col3 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_c0c26_row14_col0 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_c0c26_row14_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_c0c26_row14_col3 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_c0c26_row15_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_c0c26_row15_col3 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_c0c26_row16_col0 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_c0c26_row16_col3 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_c0c26_row17_col0 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_c0c26_row17_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_c0c26_row17_col3 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_c0c26_row18_col3, #T_c0c26_row20_col3 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_c0c26_row19_col0 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_c0c26_row19_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_c0c26_row19_col3 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_c0c26_row20_col0 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_c0c26_row20_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_c0c26_row21_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_c0c26_row21_col3, #T_c0c26_row22_col3, #T_c0c26_row26_col0 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_c0c26_row22_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c0c26_row22_col2 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_c0c26_row23_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_c0c26_row23_col3 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_c0c26_row24_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_c0c26_row25_col2 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_c0c26_row25_col3 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_c0c26_row26_col2 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_c0c26_row26_col3 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c0c26">
#   <caption>Percentages of Accident Gravity by Manv</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_c0c26_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_c0c26_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_c0c26_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_c0c26_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manv</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0c26_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0c26_row0_col0" class="data row0 col0" >40.0%</td>
#       <td id="T_c0c26_row0_col1" class="data row0 col1" >3.0%</td>
#       <td id="T_c0c26_row0_col2" class="data row0 col2" >15.3%</td>
#       <td id="T_c0c26_row0_col3" class="data row0 col3" >41.6%</td>
#     </tr>
#     <tr>
#       <th id="T_c0c26_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c0c26_row1_col0" class="data row1 col0" >43.0%</td>
#       <td id="T_c0c26_row1_col1" class="data row1 col1" >2.6%</td>
#       <td id="T_c0c26_row1_col2" class="data row1 col2" >15.1%</td>
#       <td id="T_c0c26_row1_col3" class="data row1 col3" >39.3%</td>
#     </tr>
#     <tr>
#       <th id="T_c0c26_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c0c26_row2_col0" class="data row2 col0" >51.7%</td>
#       <td id="

# %%
# 18. Number of accidents by Severity vs. user_category
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='user_category', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. user_category')
plt.xlabel('user_category')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'user_category')
# Out:
# <style type="text/css">
# #T_e7824 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_e7824 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_e7824 caption {
#   caption-side: top;
# }
# #T_e7824_row0_col0 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_e7824_row0_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_e7824_row0_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_e7824_row0_col3 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_e7824_row1_col0 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_e7824_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e7824_row1_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_e7824_row1_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_e7824_row2_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_e7824_row2_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_e7824_row2_col2 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_e7824_row2_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e7824">
#   <caption>Percentages of Accident Gravity by User_category</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_e7824_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_e7824_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_e7824_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_e7824_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >user_category</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7824_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e7824_row0_col0" class="data row0 col0" >48.2%</td>
#       <td id="T_e7824_row0_col1" class="data row0 col1" >2.1%</td>
#       <td id="T_e7824_row0_col2" class="data row0 col2" >12.9%</td>
#       <td id="T_e7824_row0_col3" class="data row0 col3" >36.7%</td>
#     </tr>
#     <tr>
#       <th id="T_e7824_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e7824_row1_col0" class="data row1 col0" >38.0%</td>
#       <td id="T_e7824_row1_col1" class="data row1 col1" >1.8%</td>
#       <td id="T_e7824_row1_col2" class="data row1 col2" >12.4%</td>
#       <td id="T_e7824_row1_col3" class="data row1 col3" >47.9%</td>
#     </tr>
#     <tr>
#       <th id="T_e7824_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_e7824_row2_col0" class="data row2 col0" >3.3%</td>
#       <td id="T_e7824_row2_col1" class="data row2 col1" >5.1%</td>
#       <td id="T_e7824_row2_col2" class="data row2 col2" >27.9%</td>
#       <td id="T_e7824_row2_col3" class="data row2 col3" >63.8%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 19. Number of accidents by Severity vs. seat
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='seat', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Severity vs. seat')
plt.xlabel('seat')
plt.ylabel('Count')
plt.legend(title='Severity')
plt.show()

calculate_and_display_percentages(data, 'seat')
# Out:
# <style type="text/css">
# #T_e171d th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_e171d td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_e171d caption {
#   caption-side: top;
# }
# #T_e171d_row0_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_e171d_row0_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_e171d_row0_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_e171d_row0_col3, #T_e171d_row6_col3 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_e171d_row1_col0, #T_e171d_row7_col0 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_e171d_row1_col1, #T_e171d_row4_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_e171d_row1_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_e171d_row1_col3 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_e171d_row2_col0 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_e171d_row2_col1, #T_e171d_row3_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e171d_row2_col2, #T_e171d_row3_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_e171d_row2_col3 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_e171d_row3_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_e171d_row3_col3 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_e171d_row4_col0 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_e171d_row4_col2 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_e171d_row4_col3 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_e171d_row5_col0 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_e171d_row5_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_e171d_row5_col2 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_e171d_row5_col3 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_e171d_row6_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_e171d_row6_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_e171d_row6_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_e171d_row7_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_e171d_row7_col2 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_e171d_row7_col3 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_e171d_row8_col0 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_e171d_row8_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_e171d_row8_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_e171d_row8_col3 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_e171d_row9_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_e171d_row9_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_e171d_row9_col2 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_e171d_row9_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e171d">
#   <caption>Percentages of Accident Gravity by Seat</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_e171d_level0_col0" class="col_heading level0 col0" >1 - Uninjured</th>
#       <th id="T_e171d_level0_col1" class="col_heading level0 col1" >2 - Fatal</th>
#       <th id="T_e171d_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_e171d_level0_col3" class="col_heading level0 col3" >4 - Minor injury</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >seat</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e171d_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e171d_row0_col0" class="data row0 col0" >48.3%</td>
#       <td id="T_e171d_row0_col1" class="data row0 col1" >2.1%</td>
#       <td id="T_e171d_row0_col2" class="data row0 col2" >12.9%</td>
#       <td id="T_e171d_row0_col3" class="data row0 col3" >36.7%</td>
#     </tr>
#     <tr>
#       <th id="T_e171d_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e171d_row1_col0" class="data row1 col0" >36.0%</td>
#       <td id="T_e171d_row1_col1" class="data row1 col1" >1.8%</td>
#       <td id="T_e171d_row1_col2" class="data row1 col2" >13.3%</td>
#       <td id="T_e171d_row1_col3" class="data row1 col3" >49.0%</td>
#     </tr>
#     <tr>
#       <th id="T_e171d_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_e171d_row2_col0" class="data row2 col0" >40.4%</td>
#       <td id="T_e171d_row2_col1" class="data row2 col1" >1.3%</td>
#       <td id="T_e171d_row2_col2" class="data row2 col2" >7.3%</td>
#       <td id="T_e171d_row2_col3" class="data row2 col3" >51.1%</td>
#     </tr>
#     <tr>
#       <th id="T_e171d_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_e171d_row3_col0" class="data row3 col0" >40.0%</td>
#       <td id="T_e171d_row3_col1" class="data row3 col1" >1.1%</td>
#       <td id="T_e171d_row3_col2" class="data row3 col2" >7.4%</td>
#       <td id="T_e171d_row3_col3" class="data row3 col3" >51.5%</td>
#     </tr>
#     <tr>
#       <th id="T_e171d_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_e171d_row4_col0" class="data row4 col0" >38.2%</td>
#       <td id="T_e171d_row4_col1" class="data row4 col1" >1.6%</td>
#       <td id="T_e171d_row4_col2" class="data row4 col2" >9.1%</td>
#       <td id="T_e171d_row4_col3" class="data row4 col3" >51.1%</td>
#     </tr>
#     <tr>
#       <th id="T_e171d_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_e171d_row5_col0" class="data row5 col0" >46.9%</td>
#       <td id="T_e171d_row5_col1" class="data row5 col1" >1.4%</td>
#       <td id="T_e171d_row5_col2" class="data row5 col2" >9.4%</td>
#       <td id="T_e171d_row5_col3" class="data row5 col3" >42.2%</td>
#     </tr>
#     <tr>
#       <th id="T_e171d_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_e171d_row6_col0" class="data row6 col0" >43.0%</td>
#       <td id="T_e171d_row6_col1" class="data row6 col1" >2.8%</td>
#       <td id="T_e171d_row6_col2" class="data row6 col2" >17.5%</td>
#       <td id="T_e171d_row6_col3" class="data row6 col3" >36.7%</td>
#     </tr>
#     <tr>
#       <th id="T_e171d_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_e171d_row7_col0" class="data row7 col0" >36.0%</td>
#       <td id="T_e171d_row7_col1" class="data row7 col1" >2.7%</td>
#       <td id="T_e171d_row7_col2" class="data row7 col2" >14.8%</td>
#       <td id="T_e171d_row7_col3" class="data row7 col3" >46.5%</td>
#     </tr>
#     <tr>
#       <th id="T_e171d_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_e171d_row8_col0" class="data row8 col0" >45.8%</td>
#       <td id="T_e171d_row8_col1" class="data row8 col1" >2.4%</td>
#       <td id="T_e171d_row8_col2" class="data row8 col2" >17.0%</td>
#       <td id="T_e171d_row8_col3" class="data row8 col3" >34.8%</td>
#     </tr>
#     <tr>
#       <th id="T_e171d_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_e171d_row9_col0" class="data row9 col0" >3.3%</td>
#       <td id="T_e171d_row9_col1" class="data row9 col1" >5.1%</td>
#       <td id="T_e171d_row9_col2" class="data row9 col2" >27.9%</td>
#       <td id="T_e171d_row9_col3" class="data row9 col3" >63.8%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 20. Accidents Severity vs. geographical location
fig = px.scatter_mapbox(
    data, 
    lat="lat", 
    lon="long", 
    color="gravity", 
    color_continuous_scale=px.colors.cyclical.IceFire, 
    zoom=3, 
    height=1000, 
    width=2000, 
    labels={"gravity": "Severity"}
)

# Update the layout for mapbox style
fig.update_layout(
    mapbox_style="open-street-map",
    mapbox_center={"lat": data["lat"].mean(), "lon": data["long"].mean()}, 
    title={'x': 0.5} 
)

# Add hover data for more information on each point
fig.update_traces(marker=dict(size=8), 
                  hovertemplate="<br>".join([
                      "Latitude: %{lat}",
                      "Longitude: %{lon}",
                      "Severity: %{marker.color}"
                  ])
)

# Save the map as an HTML file
fig.write_html("accidents_severity_map.html")
