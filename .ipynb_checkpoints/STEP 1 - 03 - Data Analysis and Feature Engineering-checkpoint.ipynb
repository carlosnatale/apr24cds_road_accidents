# %%
import os
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import scipy.cluster.hierarchy as shc
from sklearn.decomposition import PCA
from IPython.display import display, HTML
from scipy.cluster.hierarchy import dendrogram, linkage
from pandas.plotting import andrews_curves, parallel_coordinates, lag_plot, autocorrelation_plot, radviz

#import geopandas as gpd
#from shapely.geometry import Point

# %%
data = pd.read_csv('source/data.csv')

# %% [markdown]
# <font size="6">
#     Visualizations
# </font>

# %%
data['gravity'].head()
# Out:
# 0    4 - Slightly injured
# 1    4 - Slightly injured
# 2    4 - Slightly injured
# 3    4 - Slightly injured
# 4            1 - Unharmed
# Name: gravity, dtype: object

# %%
# Set up the figure size and style
sns.set_style("darkgrid")
plt.figure(figsize=(12, 8))

# %%
# Ignore specific warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn")

# %%
# Replace the values
data['gravity'] = data['gravity'].replace({
     0: '1 - Unknown',
     1: '1 - Unharmed',
     2: '2 - Killed',
     3: '3 - Hospitalized',
     4: '4 - Slightly injured'
})

# %%
# Function to calculate and display percentages
def calculate_and_display_percentages(data, group_by_col):
    counts = data.groupby([group_by_col, 'gravity']).size().reset_index(name='count')
    total_counts = data[group_by_col].value_counts().reset_index(name='total')
    total_counts.columns = [group_by_col, 'total']
    counts = counts.merge(total_counts, on=group_by_col)
    counts['percentage'] = counts['count'] / counts['total'] * 100
    
    # Pivot the table to show only percentages
    percentage_table = counts.pivot(index=group_by_col, columns='gravity', values='percentage').fillna(0)
    
    # Improve table visualization
    styled_table = percentage_table.style.format("{:.1f}%").set_table_styles(
        [{'selector': 'th', 'props': [('font-size', '12pt'), ('font-weight', 'bold'), ('text-align', 'center')]},
         {'selector': 'td', 'props': [('font-size', '10pt'), ('text-align', 'center')]},
         {'selector': 'caption', 'props': [('caption-side', 'top')]}]
    ).set_caption(f'Percentages of Accident Gravity by {group_by_col.capitalize()}').background_gradient(cmap='Blues', axis=None)
    
    # Display the styled table
    html = styled_table.to_html()
    display(HTML(html))

# %%
data.head()
# Out:
#           AccID  day  month  year      time  lum dep_code com_code  location  \
# 0  201900000001   30     11  2019  01:30:00    4       93    93053         1
# 1  201900000001   30     11  2019  01:30:00    4       93    93053         1
# 2  201900000001   30     11  2019  01:30:00    4       93    93053         1
# 3  201900000001   30     11  2019  01:30:00    4       93    93053         1
# 4  201900000001   30     11  2019  01:30:00    4       93    93053         1
#
#    int  ...  age  vehicleID_y num_veh_y  traffic_direction  vehicle_category  \
# 0    1  ...   22  138 306 524       B01                  2                 7
# 1    1  ...   22  138 306 525       A01                  2                17
# 2    1  ...   31  138 306 524       B01                  2                 7
# 3    1  ...   31  138 306 525       A01                  2                17
# 4    1  ...   65  138 306 524       B01                  2                 7
#
#    fixed_obstacle  mobile_obstacle  initial_impact_point  manv  motor
# 0               0                2                     5    23      1
# 1               1                0                     3    11      1
# 2               0                2                     5    23      1
# 3               1                0                     3    11      1
# 4               0                2                     5    23      1
#
# [5 rows x 50 columns]

# %%
# Gravity vs. Year
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='year', hue='gravity')
plt.title('Gravity vs. Year of Accident')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.show()

# Gravity vs. Year
calculate_and_display_percentages(data, 'year')
# Out:
# <style type="text/css">
# #T_9536a th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_9536a td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_9536a caption {
#   caption-side: top;
# }
# #T_9536a_row0_col0, #T_9536a_row1_col0, #T_9536a_row2_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9536a_row0_col1 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_9536a_row0_col2, #T_9536a_row1_col2, #T_9536a_row3_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_9536a_row0_col3 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_9536a_row0_col4, #T_9536a_row1_col4 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_9536a_row1_col1 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_9536a_row1_col3 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_9536a_row2_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9536a_row2_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_9536a_row2_col3 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_9536a_row2_col4 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_9536a_row3_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_9536a_row3_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_9536a_row3_col3 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_9536a_row3_col4 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9536a">
#   <caption>Percentages of Accident Gravity by Year</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_9536a_level0_col0" class="col_heading level0 col0" >-1</th>
#       <th id="T_9536a_level0_col1" class="col_heading level0 col1" >1 - Unharmed</th>
#       <th id="T_9536a_level0_col2" class="col_heading level0 col2" >2 - Killed</th>
#       <th id="T_9536a_level0_col3" class="col_heading level0 col3" >3 - Hospitalized</th>
#       <th id="T_9536a_level0_col4" class="col_heading level0 col4" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9536a_level0_row0" class="row_heading level0 row0" >2019</th>
#       <td id="T_9536a_row0_col0" class="data row0 col0" >0.0%</td>
#       <td id="T_9536a_row0_col1" class="data row0 col1" >44.8%</td>
#       <td id="T_9536a_row0_col2" class="data row0 col2" >2.0%</td>
#       <td id="T_9536a_row0_col3" class="data row0 col3" >13.2%</td>
#       <td id="T_9536a_row0_col4" class="data row0 col4" >39.9%</td>
#     </tr>
#     <tr>
#       <th id="T_9536a_level0_row1" class="row_heading level0 row1" >2020</th>
#       <td id="T_9536a_row1_col0" class="data row1 col0" >0.0%</td>
#       <td id="T_9536a_row1_col1" class="data row1 col1" >44.4%</td>
#       <td id="T_9536a_row1_col2" class="data row1 col2" >2.0%</td>
#       <td id="T_9536a_row1_col3" class="data row1 col3" >13.5%</td>
#       <td id="T_9536a_row1_col4" class="data row1 col4" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_9536a_level0_row2" class="row_heading level0 row2" >2021</th>
#       <td id="T_9536a_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_9536a_row2_col1" class="data row2 col1" >45.8%</td>
#       <td id="T_9536a_row2_col2" class="data row2 col2" >1.9%</td>
#       <td id="T_9536a_row2_col3" class="data row2 col3" >12.4%</td>
#       <td id="T_9536a_row2_col4" class="data row2 col4" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_9536a_level0_row3" class="row_heading level0 row3" >2022</th>
#       <td id="T_9536a_row3_col0" class="data row3 col0" >0.2%</td>
#       <td id="T_9536a_row3_col1" class="data row3 col1" >45.4%</td>
#       <td id="T_9536a_row3_col2" class="data row3 col2" >2.2%</td>
#       <td id="T_9536a_row3_col3" class="data row3 col3" >12.9%</td>
#       <td id="T_9536a_row3_col4" class="data row3 col4" >39.2%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Gravity vs. Month
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='month', hue='gravity')
plt.title('Gravity vs. Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.show()

# Gravity vs. Month
calculate_and_display_percentages(data, 'month')
# Out:
# <style type="text/css">
# #T_035ef th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_035ef td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_035ef caption {
#   caption-side: top;
# }
# #T_035ef_row0_col0, #T_035ef_row1_col0, #T_035ef_row2_col0, #T_035ef_row3_col0, #T_035ef_row4_col0, #T_035ef_row5_col0, #T_035ef_row6_col0, #T_035ef_row7_col0, #T_035ef_row8_col0, #T_035ef_row9_col0, #T_035ef_row10_col0, #T_035ef_row11_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_035ef_row0_col1, #T_035ef_row8_col1, #T_035ef_row9_col1 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_035ef_row0_col2, #T_035ef_row1_col2, #T_035ef_row3_col2, #T_035ef_row6_col2, #T_035ef_row7_col2, #T_035ef_row10_col2, #T_035ef_row11_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_035ef_row0_col3 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_035ef_row0_col4 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_035ef_row1_col1, #T_035ef_row10_col1, #T_035ef_row11_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_035ef_row1_col3, #T_035ef_row2_col3 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_035ef_row1_col4 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_035ef_row2_col1, #T_035ef_row3_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_035ef_row2_col2, #T_035ef_row4_col2, #T_035ef_row5_col2, #T_035ef_row8_col2, #T_035ef_row9_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_035ef_row2_col4, #T_035ef_row9_col4, #T_035ef_row10_col4, #T_035ef_row11_col4 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_035ef_row3_col3 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_035ef_row3_col4, #T_035ef_row6_col4 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_035ef_row4_col1 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_035ef_row4_col3 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_035ef_row4_col4 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_035ef_row5_col1 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_035ef_row5_col3 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_035ef_row5_col4, #T_035ef_row8_col4 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_035ef_row6_col1 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_035ef_row6_col3 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_035ef_row7_col1 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_035ef_row7_col3 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_035ef_row7_col4 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_035ef_row8_col3 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_035ef_row9_col3 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_035ef_row10_col3, #T_035ef_row11_col3 {
#   background-color: #c3daee;
#   color: #000000;
# }
# </style>
# <table id="T_035ef">
#   <caption>Percentages of Accident Gravity by Month</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_035ef_level0_col0" class="col_heading level0 col0" >-1</th>
#       <th id="T_035ef_level0_col1" class="col_heading level0 col1" >1 - Unharmed</th>
#       <th id="T_035ef_level0_col2" class="col_heading level0 col2" >2 - Killed</th>
#       <th id="T_035ef_level0_col3" class="col_heading level0 col3" >3 - Hospitalized</th>
#       <th id="T_035ef_level0_col4" class="col_heading level0 col4" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_035ef_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_035ef_row0_col0" class="data row0 col0" >0.0%</td>
#       <td id="T_035ef_row0_col1" class="data row0 col1" >45.4%</td>
#       <td id="T_035ef_row0_col2" class="data row0 col2" >2.1%</td>
#       <td id="T_035ef_row0_col3" class="data row0 col3" >11.8%</td>
#       <td id="T_035ef_row0_col4" class="data row0 col4" >40.7%</td>
#     </tr>
#     <tr>
#       <th id="T_035ef_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_035ef_row1_col0" class="data row1 col0" >0.1%</td>
#       <td id="T_035ef_row1_col1" class="data row1 col1" >45.8%</td>
#       <td id="T_035ef_row1_col2" class="data row1 col2" >2.0%</td>
#       <td id="T_035ef_row1_col3" class="data row1 col3" >12.3%</td>
#       <td id="T_035ef_row1_col4" class="data row1 col4" >39.9%</td>
#     </tr>
#     <tr>
#       <th id="T_035ef_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_035ef_row2_col0" class="data row2 col0" >0.1%</td>
#       <td id="T_035ef_row2_col1" class="data row2 col1" >45.4%</td>
#       <td id="T_035ef_row2_col2" class="data row2 col2" >1.9%</td>
#       <td id="T_035ef_row2_col3" class="data row2 col3" >12.2%</td>
#       <td id="T_035ef_row2_col4" class="data row2 col4" >40.3%</td>
#     </tr>
#     <tr>
#       <th id="T_035ef_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_035ef_row3_col0" class="data row3 col0" >0.0%</td>
#       <td id="T_035ef_row3_col1" class="data row3 col1" >45.5%</td>
#       <td id="T_035ef_row3_col2" class="data row3 col2" >2.2%</td>
#       <td id="T_035ef_row3_col3" class="data row3 col3" >13.0%</td>
#       <td id="T_035ef_row3_col4" class="data row3 col4" >39.4%</td>
#     </tr>
#     <tr>
#       <th id="T_035ef_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_035ef_row4_col0" class="data row4 col0" >0.0%</td>
#       <td id="T_035ef_row4_col1" class="data row4 col1" >45.0%</td>
#       <td id="T_035ef_row4_col2" class="data row4 col2" >2.0%</td>
#       <td id="T_035ef_row4_col3" class="data row4 col3" >13.8%</td>
#       <td id="T_035ef_row4_col4" class="data row4 col4" >39.2%</td>
#     </tr>
#     <tr>
#       <th id="T_035ef_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_035ef_row5_col0" class="data row5 col0" >0.1%</td>
#       <td id="T_035ef_row5_col1" class="data row5 col1" >44.9%</td>
#       <td id="T_035ef_row5_col2" class="data row5 col2" >2.0%</td>
#       <td id="T_035ef_row5_col3" class="data row5 col3" >13.5%</td>
#       <td id="T_035ef_row5_col4" class="data row5 col4" >39.5%</td>
#     </tr>
#     <tr>
#       <th id="T_035ef_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_035ef_row6_col0" class="data row6 col0" >0.1%</td>
#       <td id="T_035ef_row6_col1" class="data row6 col1" >44.2%</td>
#       <td id="T_035ef_row6_col2" class="data row6 col2" >2.2%</td>
#       <td id="T_035ef_row6_col3" class="data row6 col3" >14.2%</td>
#       <td id="T_035ef_row6_col4" class="data row6 col4" >39.4%</td>
#     </tr>
#     <tr>
#       <th id="T_035ef_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_035ef_row7_col0" class="data row7 col0" >0.0%</td>
#       <td id="T_035ef_row7_col1" class="data row7 col1" >44.1%</td>
#       <td id="T_035ef_row7_col2" class="data row7 col2" >2.3%</td>
#       <td id="T_035ef_row7_col3" class="data row7 col3" >15.4%</td>
#       <td id="T_035ef_row7_col4" class="data row7 col4" >38.2%</td>
#     </tr>
#     <tr>
#       <th id="T_035ef_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_035ef_row8_col0" class="data row8 col0" >0.1%</td>
#       <td id="T_035ef_row8_col1" class="data row8 col1" >45.2%</td>
#       <td id="T_035ef_row8_col2" class="data row8 col2" >2.0%</td>
#       <td id="T_035ef_row8_col3" class="data row8 col3" >13.2%</td>
#       <td id="T_035ef_row8_col4" class="data row8 col4" >39.5%</td>
#     </tr>
#     <tr>
#       <th id="T_035ef_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_035ef_row9_col0" class="data row9 col0" >0.1%</td>
#       <td id="T_035ef_row9_col1" class="data row9 col1" >45.3%</td>
#       <td id="T_035ef_row9_col2" class="data row9 col2" >1.8%</td>
#       <td id="T_035ef_row9_col3" class="data row9 col3" >12.4%</td>
#       <td id="T_035ef_row9_col4" class="data row9 col4" >40.3%</td>
#     </tr>
#     <tr>
#       <th

# %%
# Aggregate the data by vehicle_category and gravity
agg_dataday = data.groupby(['day', 'gravity']).size().unstack(fill_value=0)

# Gravity vs. Day
plt.figure(figsize=(18, 12))
for gravity in agg_dataday.columns:
    plt.plot(agg_dataday.index, agg_dataday[gravity], marker='o', label=f'Gravity: {gravity}')

plt.title('Gravity vs. day')
plt.xlabel('day')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Gravity vs. Day
calculate_and_display_percentages(data, 'day')
# Out:
# <style type="text/css">
# #T_0405a th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_0405a td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_0405a caption {
#   caption-side: top;
# }
# #T_0405a_row0_col0, #T_0405a_row1_col0, #T_0405a_row2_col0, #T_0405a_row3_col0, #T_0405a_row4_col0, #T_0405a_row5_col0, #T_0405a_row6_col0, #T_0405a_row7_col0, #T_0405a_row8_col0, #T_0405a_row9_col0, #T_0405a_row10_col0, #T_0405a_row11_col0, #T_0405a_row12_col0, #T_0405a_row13_col0, #T_0405a_row14_col0, #T_0405a_row15_col0, #T_0405a_row16_col0, #T_0405a_row17_col0, #T_0405a_row18_col0, #T_0405a_row19_col0, #T_0405a_row20_col0, #T_0405a_row21_col0, #T_0405a_row22_col0, #T_0405a_row23_col0, #T_0405a_row24_col0, #T_0405a_row25_col0, #T_0405a_row26_col0, #T_0405a_row27_col0, #T_0405a_row28_col0, #T_0405a_row29_col0, #T_0405a_row30_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0405a_row0_col1, #T_0405a_row7_col1, #T_0405a_row11_col1, #T_0405a_row14_col1, #T_0405a_row15_col1, #T_0405a_row17_col1 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_0405a_row0_col2, #T_0405a_row1_col2, #T_0405a_row5_col2, #T_0405a_row6_col2, #T_0405a_row7_col2, #T_0405a_row8_col2, #T_0405a_row10_col2, #T_0405a_row12_col2, #T_0405a_row13_col2, #T_0405a_row14_col2, #T_0405a_row15_col2, #T_0405a_row16_col2, #T_0405a_row17_col2, #T_0405a_row18_col2, #T_0405a_row19_col2, #T_0405a_row20_col2, #T_0405a_row21_col2, #T_0405a_row22_col2, #T_0405a_row25_col2, #T_0405a_row26_col2, #T_0405a_row27_col2, #T_0405a_row30_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_0405a_row0_col3, #T_0405a_row3_col3, #T_0405a_row11_col3 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_0405a_row0_col4, #T_0405a_row12_col4, #T_0405a_row13_col4, #T_0405a_row14_col4, #T_0405a_row15_col4, #T_0405a_row27_col4 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_0405a_row1_col1, #T_0405a_row3_col1, #T_0405a_row9_col1, #T_0405a_row19_col1, #T_0405a_row23_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_0405a_row1_col3, #T_0405a_row2_col3 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_0405a_row1_col4, #T_0405a_row4_col4, #T_0405a_row22_col4, #T_0405a_row25_col4, #T_0405a_row29_col4 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_0405a_row2_col1, #T_0405a_row4_col1, #T_0405a_row24_col1 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_0405a_row2_col2, #T_0405a_row3_col2, #T_0405a_row9_col2, #T_0405a_row11_col2, #T_0405a_row23_col2, #T_0405a_row24_col2, #T_0405a_row28_col2, #T_0405a_row29_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_0405a_row2_col4, #T_0405a_row16_col4 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_0405a_row3_col4, #T_0405a_row6_col4, #T_0405a_row7_col4, #T_0405a_row17_col4, #T_0405a_row21_col4 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_0405a_row4_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_0405a_row4_col3, #T_0405a_row14_col3, #T_0405a_row15_col3, #T_0405a_row18_col3, #T_0405a_row21_col3, #T_0405a_row28_col3 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_0405a_row5_col1, #T_0405a_row8_col1, #T_0405a_row12_col1, #T_0405a_row20_col1, #T_0405a_row27_col1, #T_0405a_row29_col1 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_0405a_row5_col3, #T_0405a_row6_col3, #T_0405a_row9_col3 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_0405a_row5_col4 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_0405a_row6_col1, #T_0405a_row18_col1, #T_0405a_row28_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0405a_row7_col3, #T_0405a_row8_col3, #T_0405a_row10_col3, #T_0405a_row17_col3, #T_0405a_row19_col3, #T_0405a_row20_col3, #T_0405a_row23_col3, #T_0405a_row26_col3, #T_0405a_row29_col3 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_0405a_row8_col4, #T_0405a_row20_col4, #T_0405a_row30_col4 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_0405a_row9_col4, #T_0405a_row11_col4, #T_0405a_row26_col4 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_0405a_row10_col1, #T_0405a_row30_col1 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_0405a_row10_col4, #T_0405a_row24_col4 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_0405a_row12_col3, #T_0405a_row22_col3, #T_0405a_row25_col3, #T_0405a_row27_col3 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_0405a_row13_col1, #T_0405a_row22_col1, #T_0405a_row25_col1 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_0405a_row13_col3, #T_0405a_row30_col3 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_0405a_row16_col1, #T_0405a_row26_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_0405a_row16_col3, #T_0405a_row24_col3 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_0405a_row18_col4 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_0405a_row19_col4 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_0405a_row21_col1 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_0405a_row23_col4, #T_0405a_row28_col4 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0405a">
#   <caption>Percentages of Accident Gravity by Day</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_0405a_level0_col0" class="col_heading level0 col0" >-1</th>
#       <th id="T_0405a_level0_col1" class="col_heading level0 col1" >1 - Unharmed</th>
#       <th id="T_0405a_level0_col2" class="col_heading level0 col2" >2 - Killed</th>
#       <th id="T_0405a_level0_col3" class="col_heading level0 col3" >3 - Hospitalized</th>
#       <th id="T_0405a_level0_col4" class="col_heading level0 col4" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >day</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0405a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_0405a_row0_col0" class="data row0 col0" >0.1%</td>
#       <td id="T_0405a_row0_col1" class="data row0 col1" >45.3%</td>
#       <td id="T_0405a_row0_col2" class="data row0 col2" >2.1%</td>
#       <td id="T_0405a_row0_col3" class="data row0 col3" >12.9%</td>
#       <td id="T_0405a_row0_col4" class="data row0 col4" >39.6%</td>
#     </tr>
#     <tr>
#       <th id="T_0405a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_0405a_row1_col0" class="data row1 col0" >0.1%</td>
#       <td id="T_0405a_row1_col1" class="data row1 col1" >45.6%</td>
#       <td id="T_0405a_row1_col2" class="data row1 col2" >2.0%</td>
#       <td id="T_0405a_row1_col3" class="data row1 col3" >12.4%</td>
#       <td id="T_0405a_row1_col4" class="data row1 col4" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_0405a_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_0405a_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_0405a_row2_col1" class="data row2 col1" >45.1%</td>
#       <td id="T_0405a_row2_col2" class="data row2 col2" >1.9%</td>
#       <td id="T_0405a_row2_col3" class="data row2 col3" >12.3%</td>
#       <td id="T_0405a_row2_col4" class="data row2 col4" >40.6%</td>
#     </tr>
#     <tr>
#       <th id="T_0405a_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_0405a_row3_col0" class="data row3 col0" >0.1%</td>
#       <td id="T_0405a_row3_col1" class="data row3 col1" >45.7%</td>
#       <td id="T_0405a_row3_col2" class="data row3 col2" >1.9%</td>
#       <td id="T_0405a_row3_col3" class="data row3 col3" >12.9%</td>
#       <td id="T_0405a_row3_col4" class="data row3 col4" >39.4%</td>
#     </tr>
#     <tr>
#       <th id="T_0405a_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_0405a_row4_col0" class="data row4 col0" >0.0%</td>
#       <td id="T_0405a_row4_col1" class="data row4 col1" >45.0%</td>
#       <td id="T_0405a_row4_col2" class="data row4 col2" >1.8%</td>
#       <td id="T_0405a_row4_col3" class="data row4 col3" >13.0%</td>
#       <td id="T_0

# %%
# Gravity vs. Weather Conditions (atm_condition)
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='atm_condition', hue='gravity')
plt.title('Gravity vs. Weather Conditions')
plt.xlabel('Weather Condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

# Gravity vs. Weather Conditions (atm_condition)
calculate_and_display_percentages(data, 'atm_condition')
# Out:
# <style type="text/css">
# #T_6a2e0 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_6a2e0 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_6a2e0 caption {
#   caption-side: top;
# }
# #T_6a2e0_row0_col0, #T_6a2e0_row1_col0, #T_6a2e0_row2_col0, #T_6a2e0_row3_col0, #T_6a2e0_row4_col0, #T_6a2e0_row5_col0, #T_6a2e0_row6_col0, #T_6a2e0_row7_col0, #T_6a2e0_row8_col0, #T_6a2e0_row9_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6a2e0_row0_col1 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_6a2e0_row0_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_6a2e0_row0_col3 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_6a2e0_row0_col4 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_6a2e0_row1_col1 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_6a2e0_row1_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_6a2e0_row1_col3 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_6a2e0_row1_col4 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_6a2e0_row2_col1 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_6a2e0_row2_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_6a2e0_row2_col3 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_6a2e0_row2_col4 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_6a2e0_row3_col1 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_6a2e0_row3_col2, #T_6a2e0_row4_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_6a2e0_row3_col3 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_6a2e0_row3_col4, #T_6a2e0_row9_col4 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_6a2e0_row4_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6a2e0_row4_col3 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_6a2e0_row4_col4 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_6a2e0_row5_col1 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_6a2e0_row5_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_6a2e0_row5_col3 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_6a2e0_row5_col4, #T_6a2e0_row6_col1 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_6a2e0_row6_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_6a2e0_row6_col3 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_6a2e0_row6_col4 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_6a2e0_row7_col1 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_6a2e0_row7_col2 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_6a2e0_row7_col3 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_6a2e0_row7_col4 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_6a2e0_row8_col1 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_6a2e0_row8_col2 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_6a2e0_row8_col3 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_6a2e0_row8_col4 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_6a2e0_row9_col1 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_6a2e0_row9_col2 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_6a2e0_row9_col3 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# </style>
# <table id="T_6a2e0">
#   <caption>Percentages of Accident Gravity by Atm_condition</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_6a2e0_level0_col0" class="col_heading level0 col0" >-1</th>
#       <th id="T_6a2e0_level0_col1" class="col_heading level0 col1" >1 - Unharmed</th>
#       <th id="T_6a2e0_level0_col2" class="col_heading level0 col2" >2 - Killed</th>
#       <th id="T_6a2e0_level0_col3" class="col_heading level0 col3" >3 - Hospitalized</th>
#       <th id="T_6a2e0_level0_col4" class="col_heading level0 col4" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >atm_condition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a2e0_level0_row0" class="row_heading level0 row0" >-1</th>
#       <td id="T_6a2e0_row0_col0" class="data row0 col0" >0.0%</td>
#       <td id="T_6a2e0_row0_col1" class="data row0 col1" >35.3%</td>
#       <td id="T_6a2e0_row0_col2" class="data row0 col2" >5.9%</td>
#       <td id="T_6a2e0_row0_col3" class="data row0 col3" >11.8%</td>
#       <td id="T_6a2e0_row0_col4" class="data row0 col4" >47.1%</td>
#     </tr>
#     <tr>
#       <th id="T_6a2e0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a2e0_row1_col0" class="data row1 col0" >0.1%</td>
#       <td id="T_6a2e0_row1_col1" class="data row1 col1" >45.3%</td>
#       <td id="T_6a2e0_row1_col2" class="data row1 col2" >2.0%</td>
#       <td id="T_6a2e0_row1_col3" class="data row1 col3" >13.0%</td>
#       <td id="T_6a2e0_row1_col4" class="data row1 col4" >39.6%</td>
#     </tr>
#     <tr>
#       <th id="T_6a2e0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6a2e0_row2_col0" class="data row2 col0" >0.1%</td>
#       <td id="T_6a2e0_row2_col1" class="data row2 col1" >44.7%</td>
#       <td id="T_6a2e0_row2_col2" class="data row2 col2" >1.8%</td>
#       <td id="T_6a2e0_row2_col3" class="data row2 col3" >10.9%</td>
#       <td id="T_6a2e0_row2_col4" class="data row2 col4" >42.5%</td>
#     </tr>
#     <tr>
#       <th id="T_6a2e0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6a2e0_row3_col0" class="data row3 col0" >0.0%</td>
#       <td id="T_6a2e0_row3_col1" class="data row3 col1" >44.5%</td>
#       <td id="T_6a2e0_row3_col2" class="data row3 col2" >2.2%</td>
#       <td id="T_6a2e0_row3_col3" class="data row3 col3" >13.4%</td>
#       <td id="T_6a2e0_row3_col4" class="data row3 col4" >39.9%</td>
#     </tr>
#     <tr>
#       <th id="T_6a2e0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6a2e0_row4_col0" class="data row4 col0" >0.1%</td>
#       <td id="T_6a2e0_row4_col1" class="data row4 col1" >51.7%</td>
#       <td id="T_6a2e0_row4_col2" class="data row4 col2" >2.2%</td>
#       <td id="T_6a2e0_row4_col3" class="data row4 col3" >12.5%</td>
#       <td id="T_6a2e0_row4_col4" class="data row4 col4" >33.5%</td>
#     </tr>
#     <tr>
#       <th id="T_6a2e0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6a2e0_row5_col0" class="data row5 col0" >0.1%</td>
#       <td id="T_6a2e0_row5_col1" class="data row5 col1" >38.6%</td>
#       <td id="T_6a2e0_row5_col2" class="data row5 col2" >4.9%</td>
#       <td id="T_6a2e0_row5_col3" class="data row5 col3" >19.9%</td>
#       <td id="T_6a2e0_row5_col4" class="data row5 col4" >36.4%</td>
#     </tr>
#     <tr>
#       <th id="T_6a2e0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6a2e0_row6_col0" class="data row6 col0" >0.0%</td>
#       <td id="T_6a2e0_row6_col1" class="data row6 col1" >36.4%</td>
#       <td id="T_6a2e0_row6_col2" class="data row6 col2" >4.0%</td>
#       <td id="T_6a2e0_row6_col3" class="data row6 col3" >23.9%</td>
#       <td id="T_6a2e0_row6_col4" class="data row6 col4" >35.7%</td>
#     </tr>
#     <tr>
#       <th id="T_6a2e0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6a2e0_row7_col0" class="data row7 col0" >0.0%</td>
#       <td id="T_6a2e0_row7_col1" class="data row7 col1" >46.3%</td>
#       <td id="T_6a2e0_row7_col2" class="data row7 col2" >3.0%</td>
#       <td id="T_6a2e0_row7_col3" class="data row7 col3" >20.7%</td>
#       <td id="T_6a2e0_row7_col4" class="data row7 col4" >29.9%</td>
#     </tr>
#     <tr>
#       <th id="T_6a2e0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6a2e0_row8_col0" class="data row8 col0" >0.0%</td>
#       <td id="T_6a2e0_row8_col1" class="data row8 col1" >44.1%</td>
#       <td id="T_6a2e0_row8_col2" class="data row8 col2" >2.6%</td>
#       <td id="T_6a2e0_row8_col3" class="data row8 col3" >12.4%</td>
#       <td id="T_6a2e0_row8_col4" class="data row8 col4" >40.9%</td>
#     </tr>
#     <tr>
#       <th id="T_6a2e0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td i

# %%
# Gravity vs. Lighting Conditions (lum)
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='lum', hue='gravity')
plt.title('Gravity vs. Lighting Conditions')
plt.xlabel('Lighting Condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

# Gravity vs. Lighting Conditions (lum)
calculate_and_display_percentages(data, 'lum')
# Out:
# <style type="text/css">
# #T_d603d th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_d603d td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_d603d caption {
#   caption-side: top;
# }
# #T_d603d_row0_col0, #T_d603d_row0_col2, #T_d603d_row0_col3, #T_d603d_row1_col0, #T_d603d_row2_col0, #T_d603d_row3_col0, #T_d603d_row4_col0, #T_d603d_row5_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d603d_row0_col1, #T_d603d_row0_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d603d_row1_col1 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_d603d_row1_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_d603d_row1_col3 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_d603d_row1_col4 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_d603d_row2_col1 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_d603d_row2_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_d603d_row2_col3 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_d603d_row2_col4, #T_d603d_row3_col1 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_d603d_row3_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_d603d_row3_col3 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_d603d_row3_col4 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_d603d_row4_col1 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_d603d_row4_col2 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_d603d_row4_col3 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_d603d_row4_col4 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_d603d_row5_col1 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_d603d_row5_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_d603d_row5_col3 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_d603d_row5_col4 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d603d">
#   <caption>Percentages of Accident Gravity by Lum</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_d603d_level0_col0" class="col_heading level0 col0" >-1</th>
#       <th id="T_d603d_level0_col1" class="col_heading level0 col1" >1 - Unharmed</th>
#       <th id="T_d603d_level0_col2" class="col_heading level0 col2" >2 - Killed</th>
#       <th id="T_d603d_level0_col3" class="col_heading level0 col3" >3 - Hospitalized</th>
#       <th id="T_d603d_level0_col4" class="col_heading level0 col4" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >lum</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d603d_level0_row0" class="row_heading level0 row0" >-1</th>
#       <td id="T_d603d_row0_col0" class="data row0 col0" >0.0%</td>
#       <td id="T_d603d_row0_col1" class="data row0 col1" >50.0%</td>
#       <td id="T_d603d_row0_col2" class="data row0 col2" >0.0%</td>
#       <td id="T_d603d_row0_col3" class="data row0 col3" >0.0%</td>
#       <td id="T_d603d_row0_col4" class="data row0 col4" >50.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d603d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d603d_row1_col0" class="data row1 col0" >0.1%</td>
#       <td id="T_d603d_row1_col1" class="data row1 col1" >46.3%</td>
#       <td id="T_d603d_row1_col2" class="data row1 col2" >1.8%</td>
#       <td id="T_d603d_row1_col3" class="data row1 col3" >12.7%</td>
#       <td id="T_d603d_row1_col4" class="data row1 col4" >39.2%</td>
#     </tr>
#     <tr>
#       <th id="T_d603d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d603d_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_d603d_row2_col1" class="data row2 col1" >43.8%</td>
#       <td id="T_d603d_row2_col2" class="data row2 col2" >2.4%</td>
#       <td id="T_d603d_row2_col3" class="data row2 col3" >14.8%</td>
#       <td id="T_d603d_row2_col4" class="data row2 col4" >39.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d603d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d603d_row3_col0" class="data row3 col0" >0.0%</td>
#       <td id="T_d603d_row3_col1" class="data row3 col1" >39.1%</td>
#       <td id="T_d603d_row3_col2" class="data row3 col2" >5.2%</td>
#       <td id="T_d603d_row3_col3" class="data row3 col3" >18.5%</td>
#       <td id="T_d603d_row3_col4" class="data row3 col4" >37.3%</td>
#     </tr>
#     <tr>
#       <th id="T_d603d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d603d_row4_col0" class="data row4 col0" >0.1%</td>
#       <td id="T_d603d_row4_col1" class="data row4 col1" >42.7%</td>
#       <td id="T_d603d_row4_col2" class="data row4 col2" >3.0%</td>
#       <td id="T_d603d_row4_col3" class="data row4 col3" >13.2%</td>
#       <td id="T_d603d_row4_col4" class="data row4 col4" >41.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d603d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d603d_row5_col0" class="data row5 col0" >0.1%</td>
#       <td id="T_d603d_row5_col1" class="data row5 col1" >44.3%</td>
#       <td id="T_d603d_row5_col2" class="data row5 col2" >1.3%</td>
#       <td id="T_d603d_row5_col3" class="data row5 col3" >10.5%</td>
#       <td id="T_d603d_row5_col4" class="data row5 col4" >43.7%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Gravity vs. Vehicle Category
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='vehicle_category', hue='gravity')
plt.title('Gravity vs. Vehicle Category')
plt.xlabel('Vehicle Category')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

# Gravity vs. Vehicle Category
calculate_and_display_percentages(data, 'vehicle_category')
# Out:
# <style type="text/css">
# #T_ae708 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_ae708 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_ae708 caption {
#   caption-side: top;
# }
# #T_ae708_row0_col0, #T_ae708_row2_col0, #T_ae708_row3_col0, #T_ae708_row4_col0, #T_ae708_row5_col0, #T_ae708_row6_col0, #T_ae708_row7_col0, #T_ae708_row8_col0, #T_ae708_row9_col0, #T_ae708_row11_col0, #T_ae708_row12_col0, #T_ae708_row13_col0, #T_ae708_row14_col0, #T_ae708_row15_col0, #T_ae708_row16_col0, #T_ae708_row17_col0, #T_ae708_row18_col0, #T_ae708_row20_col0, #T_ae708_row21_col0, #T_ae708_row22_col0, #T_ae708_row23_col0, #T_ae708_row24_col0, #T_ae708_row25_col0, #T_ae708_row26_col0, #T_ae708_row26_col2, #T_ae708_row27_col0, #T_ae708_row28_col0, #T_ae708_row30_col0, #T_ae708_row31_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ae708_row0_col1, #T_ae708_row24_col4, #T_ae708_row30_col1 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_ae708_row0_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_ae708_row0_col3 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_ae708_row0_col4 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_ae708_row1_col0, #T_ae708_row7_col2 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_ae708_row1_col1 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_ae708_row1_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_ae708_row1_col3 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_ae708_row1_col4, #T_ae708_row4_col1, #T_ae708_row21_col4 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_ae708_row2_col1 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_ae708_row2_col2, #T_ae708_row5_col2, #T_ae708_row6_col2, #T_ae708_row15_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_ae708_row2_col3 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_ae708_row2_col4 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_ae708_row3_col1 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_ae708_row3_col2, #T_ae708_row18_col2, #T_ae708_row21_col2 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_ae708_row3_col3 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_ae708_row3_col4 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_ae708_row4_col2, #T_ae708_row24_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_ae708_row4_col3, #T_ae708_row5_col3 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_ae708_row4_col4, #T_ae708_row17_col1 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_ae708_row5_col1 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_ae708_row5_col4, #T_ae708_row18_col4 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_ae708_row6_col1 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_ae708_row6_col3, #T_ae708_row14_col3 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_ae708_row6_col4, #T_ae708_row25_col4 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_ae708_row7_col1, #T_ae708_row14_col4, #T_ae708_row26_col1 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_ae708_row7_col3, #T_ae708_row23_col3 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_ae708_row7_col4 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_ae708_row8_col1 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_ae708_row8_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_ae708_row8_col3 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_ae708_row8_col4, #T_ae708_row10_col4 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_ae708_row9_col1 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_ae708_row9_col2, #T_ae708_row20_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_ae708_row9_col3, #T_ae708_row18_col3 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_ae708_row9_col4 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_ae708_row10_col0, #T_ae708_row29_col0, #T_ae708_row29_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_ae708_row10_col1 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_ae708_row10_col2 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_ae708_row10_col3 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_ae708_row11_col1, #T_ae708_row12_col1 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_ae708_row11_col2 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_ae708_row11_col3, #T_ae708_row30_col3 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_ae708_row11_col4 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_ae708_row12_col2, #T_ae708_row22_col2 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_ae708_row12_col3 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_ae708_row12_col4 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_ae708_row13_col1, #T_ae708_row24_col1 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_ae708_row13_col2 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_ae708_row13_col3 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_ae708_row13_col4 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_ae708_row14_col1 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_ae708_row14_col2, #T_ae708_row28_col2 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_ae708_row15_col1, #T_ae708_row18_col1, #T_ae708_row26_col4 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_ae708_row15_col3, #T_ae708_row23_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_ae708_row15_col4 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_ae708_row16_col1, #T_ae708_row16_col4 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_ae708_row16_col2, #T_ae708_row19_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_ae708_row16_col3 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_ae708_row17_col2 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_ae708_row17_col3 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_ae708_row17_col4 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_ae708_row19_col1, #T_ae708_row19_col4 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_ae708_row19_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_ae708_row19_col3 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_ae708_row20_col1 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_ae708_row20_col3 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_ae708_row20_col4 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_ae708_row21_col1, #T_ae708_row27_col1 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_ae708_row21_col3 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_ae708_row22_col1, #T_ae708_row23_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ae708_row22_col3, #T_ae708_row27_col3, #T_ae708_row29_col3 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_ae708_row22_col4 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_ae708_row23_col4 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_ae708_row24_col3 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_ae708_row25_col1 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_ae708_row25_col2 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_ae708_row25_col3 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_ae708_row26_col3 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_ae708_row27_col2, #T_ae708_row31_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_ae708_row27_col4 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_ae708_row28_col1 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_ae708_row28_col3 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_ae708_row28_col4 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_ae708_row29_col1, #T_ae708_row29_col4 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_ae708_row30_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_ae708_row30_col4 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_ae708_row31_col1 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_ae708_row31_col3 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_ae708_r

# %%
# Gravity vs. Gender
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='gender', hue='gravity')
plt.title('Gravity vs. Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.show()

# Gravity vs. Gender
calculate_and_display_percentages(data, 'gender')
# Out:
# <style type="text/css">
# #T_562cc th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_562cc td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_562cc caption {
#   caption-side: top;
# }
# #T_562cc_row0_col0 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_562cc_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_562cc_row0_col2, #T_562cc_row0_col3, #T_562cc_row0_col4, #T_562cc_row1_col0, #T_562cc_row2_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_562cc_row1_col1 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_562cc_row1_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_562cc_row1_col3 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_562cc_row1_col4 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_562cc_row2_col1 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_562cc_row2_col2 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_562cc_row2_col3 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_562cc_row2_col4 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_562cc">
#   <caption>Percentages of Accident Gravity by Gender</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_562cc_level0_col0" class="col_heading level0 col0" >-1</th>
#       <th id="T_562cc_level0_col1" class="col_heading level0 col1" >1 - Unharmed</th>
#       <th id="T_562cc_level0_col2" class="col_heading level0 col2" >2 - Killed</th>
#       <th id="T_562cc_level0_col3" class="col_heading level0 col3" >3 - Hospitalized</th>
#       <th id="T_562cc_level0_col4" class="col_heading level0 col4" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_562cc_level0_row0" class="row_heading level0 row0" >-1</th>
#       <td id="T_562cc_row0_col0" class="data row0 col0" >5.2%</td>
#       <td id="T_562cc_row0_col1" class="data row0 col1" >94.8%</td>
#       <td id="T_562cc_row0_col2" class="data row0 col2" >0.0%</td>
#       <td id="T_562cc_row0_col3" class="data row0 col3" >0.0%</td>
#       <td id="T_562cc_row0_col4" class="data row0 col4" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_562cc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_562cc_row1_col0" class="data row1 col0" >0.0%</td>
#       <td id="T_562cc_row1_col1" class="data row1 col1" >46.7%</td>
#       <td id="T_562cc_row1_col2" class="data row1 col2" >2.4%</td>
#       <td id="T_562cc_row1_col3" class="data row1 col3" >13.9%</td>
#       <td id="T_562cc_row1_col4" class="data row1 col4" >37.1%</td>
#     </tr>
#     <tr>
#       <th id="T_562cc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_562cc_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_562cc_row2_col1" class="data row2 col1" >39.9%</td>
#       <td id="T_562cc_row2_col2" class="data row2 col2" >1.4%</td>
#       <td id="T_562cc_row2_col3" class="data row2 col3" >11.6%</td>
#       <td id="T_562cc_row2_col4" class="data row2 col4" >47.1%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Gravity vs. Surface Condition
plt.figure(figsize=(18,12))
sns.countplot(data=data, x='surface_condition', hue='gravity')
plt.title('Gravity vs. Surface Condition')
plt.xlabel('Surface Condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

# Gravity vs. Surface Condition
calculate_and_display_percentages(data, 'surface_condition')
# Out:
# <style type="text/css">
# #T_cdbbd th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_cdbbd td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_cdbbd caption {
#   caption-side: top;
# }
# #T_cdbbd_row0_col0, #T_cdbbd_row1_col0, #T_cdbbd_row2_col0, #T_cdbbd_row3_col0, #T_cdbbd_row4_col0, #T_cdbbd_row6_col0, #T_cdbbd_row7_col0, #T_cdbbd_row8_col0, #T_cdbbd_row9_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_cdbbd_row0_col1 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_cdbbd_row0_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_cdbbd_row0_col3 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_cdbbd_row0_col4 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_cdbbd_row1_col1 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_cdbbd_row1_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_cdbbd_row1_col3 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_cdbbd_row1_col4 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_cdbbd_row2_col1 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_cdbbd_row2_col2, #T_cdbbd_row3_col2, #T_cdbbd_row5_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_cdbbd_row2_col3 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_cdbbd_row2_col4, #T_cdbbd_row8_col4 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_cdbbd_row3_col1 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_cdbbd_row3_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_cdbbd_row3_col4 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_cdbbd_row4_col1 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_cdbbd_row4_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_cdbbd_row4_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_cdbbd_row4_col4, #T_cdbbd_row9_col1 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_cdbbd_row5_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_cdbbd_row5_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_cdbbd_row5_col3 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_cdbbd_row5_col4 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_cdbbd_row6_col1 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_cdbbd_row6_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_cdbbd_row6_col3 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_cdbbd_row6_col4 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_cdbbd_row7_col1 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_cdbbd_row7_col2 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_cdbbd_row7_col3 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_cdbbd_row7_col4 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_cdbbd_row8_col1 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_cdbbd_row8_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_cdbbd_row8_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_cdbbd_row9_col2 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_cdbbd_row9_col3 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_cdbbd_row9_col4 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cdbbd">
#   <caption>Percentages of Accident Gravity by Surface_condition</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_cdbbd_level0_col0" class="col_heading level0 col0" >-1</th>
#       <th id="T_cdbbd_level0_col1" class="col_heading level0 col1" >1 - Unharmed</th>
#       <th id="T_cdbbd_level0_col2" class="col_heading level0 col2" >2 - Killed</th>
#       <th id="T_cdbbd_level0_col3" class="col_heading level0 col3" >3 - Hospitalized</th>
#       <th id="T_cdbbd_level0_col4" class="col_heading level0 col4" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >surface_condition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdbbd_level0_row0" class="row_heading level0 row0" >-1</th>
#       <td id="T_cdbbd_row0_col0" class="data row0 col0" >0.0%</td>
#       <td id="T_cdbbd_row0_col1" class="data row0 col1" >46.9%</td>
#       <td id="T_cdbbd_row0_col2" class="data row0 col2" >12.5%</td>
#       <td id="T_cdbbd_row0_col3" class="data row0 col3" >6.2%</td>
#       <td id="T_cdbbd_row0_col4" class="data row0 col4" >34.4%</td>
#     </tr>
#     <tr>
#       <th id="T_cdbbd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cdbbd_row1_col0" class="data row1 col0" >0.1%</td>
#       <td id="T_cdbbd_row1_col1" class="data row1 col1" >45.4%</td>
#       <td id="T_cdbbd_row1_col2" class="data row1 col2" >2.0%</td>
#       <td id="T_cdbbd_row1_col3" class="data row1 col3" >13.2%</td>
#       <td id="T_cdbbd_row1_col4" class="data row1 col4" >39.4%</td>
#     </tr>
#     <tr>
#       <th id="T_cdbbd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cdbbd_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_cdbbd_row2_col1" class="data row2 col1" >44.3%</td>
#       <td id="T_cdbbd_row2_col2" class="data row2 col2" >2.2%</td>
#       <td id="T_cdbbd_row2_col3" class="data row2 col3" >11.7%</td>
#       <td id="T_cdbbd_row2_col4" class="data row2 col4" >41.7%</td>
#     </tr>
#     <tr>
#       <th id="T_cdbbd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cdbbd_row3_col0" class="data row3 col0" >0.0%</td>
#       <td id="T_cdbbd_row3_col1" class="data row3 col1" >43.8%</td>
#       <td id="T_cdbbd_row3_col2" class="data row3 col2" >2.3%</td>
#       <td id="T_cdbbd_row3_col3" class="data row3 col3" >16.4%</td>
#       <td id="T_cdbbd_row3_col4" class="data row3 col4" >37.5%</td>
#     </tr>
#     <tr>
#       <th id="T_cdbbd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cdbbd_row4_col0" class="data row4 col0" >0.0%</td>
#       <td id="T_cdbbd_row4_col1" class="data row4 col1" >42.3%</td>
#       <td id="T_cdbbd_row4_col2" class="data row4 col2" >3.7%</td>
#       <td id="T_cdbbd_row4_col3" class="data row4 col3" >15.6%</td>
#       <td id="T_cdbbd_row4_col4" class="data row4 col4" >38.3%</td>
#     </tr>
#     <tr>
#       <th id="T_cdbbd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cdbbd_row5_col0" class="data row5 col0" >0.3%</td>
#       <td id="T_cdbbd_row5_col1" class="data row5 col1" >49.2%</td>
#       <td id="T_cdbbd_row5_col2" class="data row5 col2" >2.1%</td>
#       <td id="T_cdbbd_row5_col3" class="data row5 col3" >13.4%</td>
#       <td id="T_cdbbd_row5_col4" class="data row5 col4" >35.0%</td>
#     </tr>
#     <tr>
#       <th id="T_cdbbd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cdbbd_row6_col0" class="data row6 col0" >0.0%</td>
#       <td id="T_cdbbd_row6_col1" class="data row6 col1" >28.4%</td>
#       <td id="T_cdbbd_row6_col2" class="data row6 col2" >5.2%</td>
#       <td id="T_cdbbd_row6_col3" class="data row6 col3" >30.3%</td>
#       <td id="T_cdbbd_row6_col4" class="data row6 col4" >36.2%</td>
#     </tr>
#     <tr>
#       <th id="T_cdbbd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cdbbd_row7_col0" class="data row7 col0" >0.1%</td>
#       <td id="T_cdbbd_row7_col1" class="data row7 col1" >37.1%</td>
#       <td id="T_cdbbd_row7_col2" class="data row7 col2" >4.3%</td>
#       <td id="T_cdbbd_row7_col3" class="data row7 col3" >20.7%</td>
#       <td id="T_cdbbd_row7_col4" class="data row7 col4" >37.8%</td>
#     </tr>
#     <tr>
#       <th id="T_cdbbd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cdbbd_row8_col0" class="data row8 col0" >0.0%</td>
#       <td id="T_cdbbd_row8_col1" class="data row8 col1" >40.1%</td>
#       <td id="T_cdbbd_row8_col2" class="data row8 col2" >1.3%</td>
#       <td id="T_cdbbd_row8_col3" class="data row8 col3" >16.9%</td>
#       <td id="T_cdbbd_row8_col4" class="data row8 col4" >41.8%</td>
#     </tr>
#     <tr>
#       <th id="T_cdbbd_level0_row9" class="row_heading level0 row9" >9</th>

# %%
# Define the bins and corresponding labels
bins = [0, 49, 59, 69, 79, 89, 99, 109, 119, 129, float('inf')]
labels = ['0-49', '50-59', '60-69', '70-79', '80-89', '90-99', '100-109', '110-119', '120-129']

# Create a new column for the binned speeds
data['speed_group'] = pd.cut(data['maximum_speed'], bins=bins, labels=labels, right=False)

# Gravity vs. Maximum Speed
plt.figure(figsize=(10, 6))
#sns.scatterplot(data=data, x='speed_group', y='gravity', hue='gravity', palette='viridis')
sns.countplot(data=data, x='speed_group', hue='gravity')

plt.title('Gravity vs. Maximum Speed')
plt.xlabel('Maximum Speed Group')
plt.ylabel('Gravity')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

# Gravity vs. Maximum Speed
calculate_and_display_percentages(data, 'speed_group')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 6
#       3 labels = ['0-49', '50-59', '60-69', '70-79', '80-89', '90-99', '100-109', '110-119', '120-129']
#       5 # Create a new column for the binned speeds
# ----> 6 data['speed_group'] = pd.cut(data['maximum_speed'], bins=bins, labels=labels, right=False)
#       8 # Gravity vs. Maximum Speed
#       9 plt.figure(figsize=(10, 6))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\reshape\tile.py:293, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     290     if (np.diff(bins.astype("float64")) < 0).any():
#     291         raise ValueError("bins must increase monotonically.")
# --> 293 fac, bins = _bins_to_cuts(
#     294     x,
#     295     bins,
#     296     right=right,
#     297     labels=labels,
#     298     precision=precision,
#     299     include_lowest=include_lowest,
#     300     dtype=dtype,
#     301     duplicates=duplicates,
#     302     ordered=ordered,
#     303 )
#     305 return _postprocess_for_cut(fac, bins, retbins, dtype, original)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\reshape\tile.py:454, in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     452 else:
#     453     if len(labels) != len(bins) - 1:
# --> 454         raise ValueError(
#     455             "Bin labels must be one fewer than the number of bin edges"
#     456         )
#     458 if not isinstance(getattr(labels, "dtype", None), CategoricalDtype):
#     459     labels = Categorical(
#     460         labels,
#     461         categories=labels if len(set(labels)) == len(labels) else None,
#     462         ordered=ordered,
#     463     )
#
# ValueError: Bin labels must be one fewer than the number of bin edges
