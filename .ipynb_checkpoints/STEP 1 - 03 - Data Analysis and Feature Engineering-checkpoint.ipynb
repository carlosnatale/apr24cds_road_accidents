# %%
import os
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import scipy.cluster.hierarchy as shc
from sklearn.decomposition import PCA
from IPython.display import display, HTML
from scipy.cluster.hierarchy import dendrogram, linkage
from pandas.plotting import andrews_curves, parallel_coordinates, lag_plot, autocorrelation_plot, radviz

#import geopandas as gpd
#from shapely.geometry import Point

# %%
data = pd.read_csv('source/data.csv')

# %% [markdown]
# <font size="6">
#     Visualizations
# </font>

# %%
# Set up the figure size and style
sns.set_style("darkgrid")
plt.figure(figsize=(12, 8))

# %%
# Ignore specific warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn")

# %%
# Replace the values
data['gravity'] = data['gravity'].replace({
     1: '1 - Unharmed',
     2: '2 - Killed',
     3: '3 - Hospitalized',
     4: '4 - Slightly injured'
})

# Define custom colors
custom_colors = {
    '1 - Unharmed': '#2ECCFA',      
    '2 - Killed': '#FE2E2E',       
    '3 - Hospitalized': '#FFBF00',   
    '4 - Slightly injured': '#81F7BE' 
}

# Sort gravity levels alphabetically
gravity_order = sorted(custom_colors.keys())

# %%
# Function to calculate and display percentages
def calculate_and_display_percentages(data, group_by_col):
    counts = data.groupby([group_by_col, 'gravity']).size().reset_index(name='count')
    total_counts = data[group_by_col].value_counts().reset_index(name='total')
    total_counts.columns = [group_by_col, 'total']
    counts = counts.merge(total_counts, on=group_by_col)
    counts['percentage'] = counts['count'] / counts['total'] * 100
    
    # Pivot the table to show only percentages
    percentage_table = counts.pivot(index=group_by_col, columns='gravity', values='percentage').fillna(0)
    
    # Improve table visualization
    styled_table = percentage_table.style.format("{:.1f}%").set_table_styles(
        [{'selector': 'th', 'props': [('font-size', '12pt'), ('font-weight', 'bold'), ('text-align', 'center')]},
         {'selector': 'td', 'props': [('font-size', '10pt'), ('text-align', 'center')]},
         {'selector': 'caption', 'props': [('caption-side', 'top')]}]
    ).set_caption(f'Percentages of Accident Gravity by {group_by_col.capitalize()}').background_gradient(cmap='Blues', axis=None)
    
    # Display the styled table
    html = styled_table.to_html()
    display(HTML(html))

# %%
data.head()
# Out:
#           AccID  day  month  year      time  lum dep_code com_code  location  \
# 0  201900000001   30     11  2019  01:30:00    4       93    93053         1
# 1  201900000001   30     11  2019  01:30:00    4       93    93053         1
# 2  201900000001   30     11  2019  01:30:00    4       93    93053         1
# 3  201900000001   30     11  2019  01:30:00    4       93    93053         1
# 4  201900000001   30     11  2019  01:30:00    4       93    93053         1
#
#    int  ...  age  vehicleID_y num_veh_y  traffic_direction  vehicle_category  \
# 0    1  ...   22  138 306 524       B01                  2                 7
# 1    1  ...   22  138 306 525       A01                  2                17
# 2    1  ...   31  138 306 524       B01                  2                 7
# 3    1  ...   31  138 306 525       A01                  2                17
# 4    1  ...   65  138 306 524       B01                  2                 7
#
#    fixed_obstacle  mobile_obstacle  initial_impact_point  manv  motor
# 0               0                2                     5    23      1
# 1               1                0                     3    11      1
# 2               0                2                     5    23      1
# 3               1                0                     3    11      1
# 4               0                2                     5    23      1
#
# [5 rows x 50 columns]

# %%
# Gravity vs. Year
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='year', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Year of Accident')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.show()

# Gravity vs. Year
calculate_and_display_percentages(data, 'year')
# Out:
# <style type="text/css">
# #T_9e167 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_9e167 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_9e167 caption {
#   caption-side: top;
# }
# #T_9e167_row0_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_9e167_row0_col1, #T_9e167_row1_col1, #T_9e167_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9e167_row0_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_9e167_row0_col3, #T_9e167_row2_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_9e167_row1_col0 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_9e167_row1_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_9e167_row1_col3 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_9e167_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9e167_row2_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_9e167_row3_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_9e167_row3_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_9e167_row3_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_9e167_row3_col3 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9e167">
#   <caption>Percentages of Accident Gravity by Year</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_9e167_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_9e167_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_9e167_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_9e167_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e167_level0_row0" class="row_heading level0 row0" >2019</th>
#       <td id="T_9e167_row0_col0" class="data row0 col0" >44.8%</td>
#       <td id="T_9e167_row0_col1" class="data row0 col1" >2.0%</td>
#       <td id="T_9e167_row0_col2" class="data row0 col2" >13.2%</td>
#       <td id="T_9e167_row0_col3" class="data row0 col3" >39.9%</td>
#     </tr>
#     <tr>
#       <th id="T_9e167_level0_row1" class="row_heading level0 row1" >2020</th>
#       <td id="T_9e167_row1_col0" class="data row1 col0" >44.4%</td>
#       <td id="T_9e167_row1_col1" class="data row1 col1" >2.0%</td>
#       <td id="T_9e167_row1_col2" class="data row1 col2" >13.5%</td>
#       <td id="T_9e167_row1_col3" class="data row1 col3" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_9e167_level0_row2" class="row_heading level0 row2" >2021</th>
#       <td id="T_9e167_row2_col0" class="data row2 col0" >45.8%</td>
#       <td id="T_9e167_row2_col1" class="data row2 col1" >1.9%</td>
#       <td id="T_9e167_row2_col2" class="data row2 col2" >12.5%</td>
#       <td id="T_9e167_row2_col3" class="data row2 col3" >39.8%</td>
#     </tr>
#     <tr>
#       <th id="T_9e167_level0_row3" class="row_heading level0 row3" >2022</th>
#       <td id="T_9e167_row3_col0" class="data row3 col0" >45.5%</td>
#       <td id="T_9e167_row3_col1" class="data row3 col1" >2.2%</td>
#       <td id="T_9e167_row3_col2" class="data row3 col2" >13.0%</td>
#       <td id="T_9e167_row3_col3" class="data row3 col3" >39.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Gravity vs. Month
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='month', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.show()

# Gravity vs. Month
calculate_and_display_percentages(data, 'month')
# Out:
# <style type="text/css">
# #T_11eab th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_11eab td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_11eab caption {
#   caption-side: top;
# }
# #T_11eab_row0_col0, #T_11eab_row9_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_11eab_row0_col1, #T_11eab_row1_col1, #T_11eab_row3_col1, #T_11eab_row10_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_11eab_row0_col2, #T_11eab_row10_col2, #T_11eab_row11_col2 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_11eab_row0_col3 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_11eab_row1_col0, #T_11eab_row10_col0, #T_11eab_row11_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_11eab_row1_col2, #T_11eab_row2_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_11eab_row1_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_11eab_row2_col0, #T_11eab_row3_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_11eab_row2_col1, #T_11eab_row4_col1, #T_11eab_row5_col1, #T_11eab_row8_col1, #T_11eab_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_11eab_row2_col3, #T_11eab_row9_col3, #T_11eab_row10_col3, #T_11eab_row11_col3 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_11eab_row3_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_11eab_row3_col3, #T_11eab_row6_col3 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_11eab_row4_col0 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_11eab_row4_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_11eab_row4_col3 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_11eab_row5_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_11eab_row5_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_11eab_row5_col3, #T_11eab_row8_col3 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_11eab_row6_col0, #T_11eab_row7_col0 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_11eab_row6_col1, #T_11eab_row7_col1, #T_11eab_row11_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_11eab_row6_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_11eab_row7_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_11eab_row7_col3 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_11eab_row8_col0 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_11eab_row8_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_11eab_row9_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# </style>
# <table id="T_11eab">
#   <caption>Percentages of Accident Gravity by Month</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_11eab_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_11eab_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_11eab_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_11eab_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11eab_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_11eab_row0_col0" class="data row0 col0" >45.4%</td>
#       <td id="T_11eab_row0_col1" class="data row0 col1" >2.1%</td>
#       <td id="T_11eab_row0_col2" class="data row0 col2" >11.8%</td>
#       <td id="T_11eab_row0_col3" class="data row0 col3" >40.7%</td>
#     </tr>
#     <tr>
#       <th id="T_11eab_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_11eab_row1_col0" class="data row1 col0" >45.8%</td>
#       <td id="T_11eab_row1_col1" class="data row1 col1" >2.0%</td>
#       <td id="T_11eab_row1_col2" class="data row1 col2" >12.3%</td>
#       <td id="T_11eab_row1_col3" class="data row1 col3" >39.9%</td>
#     </tr>
#     <tr>
#       <th id="T_11eab_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_11eab_row2_col0" class="data row2 col0" >45.4%</td>
#       <td id="T_11eab_row2_col1" class="data row2 col1" >1.9%</td>
#       <td id="T_11eab_row2_col2" class="data row2 col2" >12.3%</td>
#       <td id="T_11eab_row2_col3" class="data row2 col3" >40.4%</td>
#     </tr>
#     <tr>
#       <th id="T_11eab_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_11eab_row3_col0" class="data row3 col0" >45.5%</td>
#       <td id="T_11eab_row3_col1" class="data row3 col1" >2.2%</td>
#       <td id="T_11eab_row3_col2" class="data row3 col2" >13.0%</td>
#       <td id="T_11eab_row3_col3" class="data row3 col3" >39.4%</td>
#     </tr>
#     <tr>
#       <th id="T_11eab_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_11eab_row4_col0" class="data row4 col0" >45.0%</td>
#       <td id="T_11eab_row4_col1" class="data row4 col1" >2.0%</td>
#       <td id="T_11eab_row4_col2" class="data row4 col2" >13.8%</td>
#       <td id="T_11eab_row4_col3" class="data row4 col3" >39.2%</td>
#     </tr>
#     <tr>
#       <th id="T_11eab_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_11eab_row5_col0" class="data row5 col0" >44.9%</td>
#       <td id="T_11eab_row5_col1" class="data row5 col1" >2.0%</td>
#       <td id="T_11eab_row5_col2" class="data row5 col2" >13.6%</td>
#       <td id="T_11eab_row5_col3" class="data row5 col3" >39.6%</td>
#     </tr>
#     <tr>
#       <th id="T_11eab_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_11eab_row6_col0" class="data row6 col0" >44.2%</td>
#       <td id="T_11eab_row6_col1" class="data row6 col1" >2.2%</td>
#       <td id="T_11eab_row6_col2" class="data row6 col2" >14.2%</td>
#       <td id="T_11eab_row6_col3" class="data row6 col3" >39.4%</td>
#     </tr>
#     <tr>
#       <th id="T_11eab_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_11eab_row7_col0" class="data row7 col0" >44.1%</td>
#       <td id="T_11eab_row7_col1" class="data row7 col1" >2.3%</td>
#       <td id="T_11eab_row7_col2" class="data row7 col2" >15.4%</td>
#       <td id="T_11eab_row7_col3" class="data row7 col3" >38.2%</td>
#     </tr>
#     <tr>
#       <th id="T_11eab_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_11eab_row8_col0" class="data row8 col0" >45.3%</td>
#       <td id="T_11eab_row8_col1" class="data row8 col1" >2.0%</td>
#       <td id="T_11eab_row8_col2" class="data row8 col2" >13.2%</td>
#       <td id="T_11eab_row8_col3" class="data row8 col3" >39.6%</td>
#     </tr>
#     <tr>
#       <th id="T_11eab_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_11eab_row9_col0" class="data row9 col0" >45.4%</td>
#       <td id="T_11eab_row9_col1" class="data row9 col1" >1.8%</td>
#       <td id="T_11eab_row9_col2" class="data row9 col2" >12.4%</td>
#       <td id="T_11eab_row9_col3" class="data row9 col3" >40.4%</td>
#     </tr>
#     <tr>
#       <th id="T_11eab_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_11eab_row10_col0" class="data row10 col0" >45.8%</td>
#       <td id="T_11eab_row10_col1" class="data row10 col1" >2.1%</td>
#       <td id="T_11eab_row10_col2" class="data row10 col2" >11.9%</td>
#       <td id="T_11eab_row10_col3" class="data row10 col3" >40.3%</td>
#     </tr>
#     <tr>
#       <th id="T_11eab_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_11eab_row11_col0" class="data row11 col0" >45.7%</td>
#       <td id="T_11eab_row11_col1" class="data row11 col1" >2.2%</td>
#       <td id="T_11eab_row11_col2" class="data row11 col2" >11.9%</td>
#       <td id="T_11eab_row11_col3" class="data row11 col3" >40.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Aggregate the data by vehicle_category and gravity
agg_dataday = data.groupby(['day', 'gravity']).size().unstack(fill_value=0)

# Gravity vs. Day
plt.figure(figsize=(18, 12))
for gravity in agg_dataday.columns:
    plt.plot(agg_dataday.index, agg_dataday[gravity], marker='o', label=f'Gravity: {gravity}')

plt.title('Gravity vs. day')
plt.xlabel('day')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Gravity vs. Day
calculate_and_display_percentages(data, 'day')
# Out:
# <style type="text/css">
# #T_09e79 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_09e79 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_09e79 caption {
#   caption-side: top;
# }
# #T_09e79_row0_col0, #T_09e79_row7_col0, #T_09e79_row11_col0, #T_09e79_row14_col0, #T_09e79_row15_col0, #T_09e79_row17_col0 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_09e79_row0_col1, #T_09e79_row13_col1, #T_09e79_row14_col1, #T_09e79_row16_col1, #T_09e79_row25_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_09e79_row0_col2, #T_09e79_row3_col2, #T_09e79_row11_col2, #T_09e79_row15_col2, #T_09e79_row28_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_09e79_row0_col3, #T_09e79_row12_col3, #T_09e79_row13_col3, #T_09e79_row15_col3, #T_09e79_row27_col3 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_09e79_row1_col0, #T_09e79_row3_col0, #T_09e79_row9_col0, #T_09e79_row19_col0, #T_09e79_row23_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_09e79_row1_col1, #T_09e79_row5_col1, #T_09e79_row6_col1, #T_09e79_row7_col1, #T_09e79_row8_col1, #T_09e79_row10_col1, #T_09e79_row11_col1, #T_09e79_row12_col1, #T_09e79_row15_col1, #T_09e79_row17_col1, #T_09e79_row19_col1, #T_09e79_row20_col1, #T_09e79_row21_col1, #T_09e79_row22_col1, #T_09e79_row24_col1, #T_09e79_row26_col1, #T_09e79_row27_col1, #T_09e79_row30_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_09e79_row1_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_09e79_row1_col3, #T_09e79_row9_col3, #T_09e79_row11_col3, #T_09e79_row29_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_09e79_row2_col0, #T_09e79_row24_col0 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_09e79_row2_col1, #T_09e79_row3_col1, #T_09e79_row4_col1, #T_09e79_row9_col1, #T_09e79_row23_col1, #T_09e79_row28_col1, #T_09e79_row29_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_09e79_row2_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_09e79_row2_col3 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_09e79_row3_col3, #T_09e79_row6_col3, #T_09e79_row7_col3, #T_09e79_row14_col3, #T_09e79_row17_col3, #T_09e79_row21_col3 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_09e79_row4_col0, #T_09e79_row5_col0, #T_09e79_row8_col0, #T_09e79_row12_col0, #T_09e79_row27_col0, #T_09e79_row29_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_09e79_row4_col2, #T_09e79_row7_col2, #T_09e79_row8_col2, #T_09e79_row14_col2, #T_09e79_row17_col2, #T_09e79_row18_col2, #T_09e79_row21_col2, #T_09e79_row23_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_09e79_row4_col3, #T_09e79_row10_col3, #T_09e79_row22_col3, #T_09e79_row25_col3 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_09e79_row5_col2, #T_09e79_row6_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_09e79_row5_col3, #T_09e79_row24_col3 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_09e79_row6_col0, #T_09e79_row18_col0, #T_09e79_row28_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_09e79_row8_col3, #T_09e79_row20_col3, #T_09e79_row26_col3, #T_09e79_row30_col3 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_09e79_row9_col2, #T_09e79_row16_col2, #T_09e79_row24_col2 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_09e79_row10_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_09e79_row10_col2, #T_09e79_row19_col2, #T_09e79_row20_col2, #T_09e79_row25_col2, #T_09e79_row26_col2, #T_09e79_row29_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_09e79_row12_col2, #T_09e79_row22_col2, #T_09e79_row27_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_09e79_row13_col0, #T_09e79_row22_col0, #T_09e79_row30_col0 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_09e79_row13_col2, #T_09e79_row30_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_09e79_row16_col0, #T_09e79_row20_col0, #T_09e79_row26_col0 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_09e79_row16_col3 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_09e79_row18_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_09e79_row18_col3 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_09e79_row19_col3, #T_09e79_row28_col3 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_09e79_row21_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_09e79_row23_col3 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_09e79_row25_col0 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_09e79">
#   <caption>Percentages of Accident Gravity by Day</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_09e79_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_09e79_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_09e79_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_09e79_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >day</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09e79_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_09e79_row0_col0" class="data row0 col0" >45.4%</td>
#       <td id="T_09e79_row0_col1" class="data row0 col1" >2.2%</td>
#       <td id="T_09e79_row0_col2" class="data row0 col2" >12.9%</td>
#       <td id="T_09e79_row0_col3" class="data row0 col3" >39.6%</td>
#     </tr>
#     <tr>
#       <th id="T_09e79_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_09e79_row1_col0" class="data row1 col0" >45.6%</td>
#       <td id="T_09e79_row1_col1" class="data row1 col1" >2.0%</td>
#       <td id="T_09e79_row1_col2" class="data row1 col2" >12.4%</td>
#       <td id="T_09e79_row1_col3" class="data row1 col3" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_09e79_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_09e79_row2_col0" class="data row2 col0" >45.1%</td>
#       <td id="T_09e79_row2_col1" class="data row2 col1" >1.9%</td>
#       <td id="T_09e79_row2_col2" class="data row2 col2" >12.3%</td>
#       <td id="T_09e79_row2_col3" class="data row2 col3" >40.6%</td>
#     </tr>
#     <tr>
#       <th id="T_09e79_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_09e79_row3_col0" class="data row3 col0" >45.7%</td>
#       <td id="T_09e79_row3_col1" class="data row3 col1" >1.9%</td>
#       <td id="T_09e79_row3_col2" class="data row3 col2" >12.9%</td>
#       <td id="T_09e79_row3_col3" class="data row3 col3" >39.4%</td>
#     </tr>
#     <tr>
#       <th id="T_09e79_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_09e79_row4_col0" class="data row4 col0" >45.1%</td>
#       <td id="T_09e79_row4_col1" class="data row4 col1" >1.8%</td>
#       <td id="T_09e79_row4_col2" class="data row4 col2" >13.0%</td>
#       <td id="T_09e79_row4_col3" class="data row4 col3" >40.1%</td>
#     </tr>
#     <tr>
#       <th id="T_09e79_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_09e79_row5_col0" class="data row5 col0" >44.9%</td>
#       <td id="T_09e79_row5_col1" class="data row5 col1" >2.0%</td>
#       <td id="T_09e79_row5_col2" class="data row5 col2" >12.7%</td>
#       <td id="T_09e79_row5_col3" class="data row5 col3" >40.4%</td>
#     </tr>
#     <tr>
#       <th id="T_09e79_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_09e79_row6_col0" class="data row6 col0" >45.8%</td>
#       <td id="T_09e79_row6_col1" class="data row6 col1" >2.1%</td>
#       <td id="T_09e79_row6_col2" class="data row6 col2" >12.7%</td>
#       <td id="T_09e79_row6_col3" class="data row6 col3" >39.5%</td>
#     </tr>
#     <tr>
#       <th id="T_09e79_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_09e79_row7_col0" class="data row7 col0" >45.3%</td>
#       <td id="T_09e79_row7_col1" class="data row7 c

# %%
# Gravity vs. Weather Conditions (atm_condition)
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='atm_condition', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Weather Conditions')
plt.xlabel('Weather Condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

# Gravity vs. Weather Conditions (atm_condition)
calculate_and_display_percentages(data, 'atm_condition')
# Out:
# <style type="text/css">
# #T_1f167 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_1f167 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_1f167 caption {
#   caption-side: top;
# }
# #T_1f167_row0_col0 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_1f167_row0_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_1f167_row0_col2 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_1f167_row0_col3 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_1f167_row1_col0 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_1f167_row1_col1, #T_1f167_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_1f167_row1_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_1f167_row1_col3 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_1f167_row2_col0 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_1f167_row2_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_1f167_row2_col3 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_1f167_row3_col0 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_1f167_row3_col1, #T_1f167_row4_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_1f167_row3_col2 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_1f167_row3_col3, #T_1f167_row9_col3 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_1f167_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_1f167_row4_col2 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_1f167_row4_col3 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_1f167_row5_col0 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_1f167_row5_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_1f167_row5_col2 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_1f167_row5_col3, #T_1f167_row6_col0 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_1f167_row6_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_1f167_row6_col2 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_1f167_row6_col3 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_1f167_row7_col0 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_1f167_row7_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_1f167_row7_col2 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_1f167_row7_col3 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_1f167_row8_col0 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_1f167_row8_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_1f167_row8_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_1f167_row8_col3 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_1f167_row9_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_1f167_row9_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_1f167_row9_col2 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# </style>
# <table id="T_1f167">
#   <caption>Percentages of Accident Gravity by Atm_condition</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_1f167_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_1f167_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_1f167_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_1f167_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >atm_condition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f167_level0_row0" class="row_heading level0 row0" >-1</th>
#       <td id="T_1f167_row0_col0" class="data row0 col0" >35.3%</td>
#       <td id="T_1f167_row0_col1" class="data row0 col1" >5.9%</td>
#       <td id="T_1f167_row0_col2" class="data row0 col2" >11.8%</td>
#       <td id="T_1f167_row0_col3" class="data row0 col3" >47.1%</td>
#     </tr>
#     <tr>
#       <th id="T_1f167_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1f167_row1_col0" class="data row1 col0" >45.3%</td>
#       <td id="T_1f167_row1_col1" class="data row1 col1" >2.0%</td>
#       <td id="T_1f167_row1_col2" class="data row1 col2" >13.0%</td>
#       <td id="T_1f167_row1_col3" class="data row1 col3" >39.6%</td>
#     </tr>
#     <tr>
#       <th id="T_1f167_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1f167_row2_col0" class="data row2 col0" >44.7%</td>
#       <td id="T_1f167_row2_col1" class="data row2 col1" >1.8%</td>
#       <td id="T_1f167_row2_col2" class="data row2 col2" >10.9%</td>
#       <td id="T_1f167_row2_col3" class="data row2 col3" >42.6%</td>
#     </tr>
#     <tr>
#       <th id="T_1f167_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1f167_row3_col0" class="data row3 col0" >44.5%</td>
#       <td id="T_1f167_row3_col1" class="data row3 col1" >2.2%</td>
#       <td id="T_1f167_row3_col2" class="data row3 col2" >13.4%</td>
#       <td id="T_1f167_row3_col3" class="data row3 col3" >39.9%</td>
#     </tr>
#     <tr>
#       <th id="T_1f167_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1f167_row4_col0" class="data row4 col0" >51.8%</td>
#       <td id="T_1f167_row4_col1" class="data row4 col1" >2.2%</td>
#       <td id="T_1f167_row4_col2" class="data row4 col2" >12.6%</td>
#       <td id="T_1f167_row4_col3" class="data row4 col3" >33.5%</td>
#     </tr>
#     <tr>
#       <th id="T_1f167_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1f167_row5_col0" class="data row5 col0" >38.6%</td>
#       <td id="T_1f167_row5_col1" class="data row5 col1" >5.0%</td>
#       <td id="T_1f167_row5_col2" class="data row5 col2" >20.0%</td>
#       <td id="T_1f167_row5_col3" class="data row5 col3" >36.5%</td>
#     </tr>
#     <tr>
#       <th id="T_1f167_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1f167_row6_col0" class="data row6 col0" >36.4%</td>
#       <td id="T_1f167_row6_col1" class="data row6 col1" >4.0%</td>
#       <td id="T_1f167_row6_col2" class="data row6 col2" >23.9%</td>
#       <td id="T_1f167_row6_col3" class="data row6 col3" >35.7%</td>
#     </tr>
#     <tr>
#       <th id="T_1f167_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1f167_row7_col0" class="data row7 col0" >46.3%</td>
#       <td id="T_1f167_row7_col1" class="data row7 col1" >3.1%</td>
#       <td id="T_1f167_row7_col2" class="data row7 col2" >20.7%</td>
#       <td id="T_1f167_row7_col3" class="data row7 col3" >29.9%</td>
#     </tr>
#     <tr>
#       <th id="T_1f167_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1f167_row8_col0" class="data row8 col0" >44.1%</td>
#       <td id="T_1f167_row8_col1" class="data row8 col1" >2.6%</td>
#       <td id="T_1f167_row8_col2" class="data row8 col2" >12.4%</td>
#       <td id="T_1f167_row8_col3" class="data row8 col3" >40.9%</td>
#     </tr>
#     <tr>
#       <th id="T_1f167_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1f167_row9_col0" class="data row9 col0" >38.0%</td>
#       <td id="T_1f167_row9_col1" class="data row9 col1" >4.6%</td>
#       <td id="T_1f167_row9_col2" class="data row9 col2" >17.6%</td>
#       <td id="T_1f167_row9_col3" class="data row9 col3" >39.9%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Gravity vs. Lighting Conditions (lum)
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='lum', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Lighting Conditions')
plt.xlabel('Lighting Condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

# Gravity vs. Lighting Conditions (lum)
calculate_and_display_percentages(data, 'lum')
# Out:
# <style type="text/css">
# #T_f96c0 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_f96c0 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_f96c0 caption {
#   caption-side: top;
# }
# #T_f96c0_row0_col0, #T_f96c0_row0_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f96c0_row0_col1, #T_f96c0_row0_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f96c0_row1_col0 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_f96c0_row1_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_f96c0_row1_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_f96c0_row1_col3 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_f96c0_row2_col0, #T_f96c0_row5_col3 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_f96c0_row2_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_f96c0_row2_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_f96c0_row2_col3 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_f96c0_row3_col0 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_f96c0_row3_col1 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_f96c0_row3_col2 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_f96c0_row3_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_f96c0_row4_col0 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_f96c0_row4_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_f96c0_row4_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_f96c0_row4_col3 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_f96c0_row5_col0 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_f96c0_row5_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_f96c0_row5_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# </style>
# <table id="T_f96c0">
#   <caption>Percentages of Accident Gravity by Lum</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_f96c0_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_f96c0_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_f96c0_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_f96c0_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >lum</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f96c0_level0_row0" class="row_heading level0 row0" >-1</th>
#       <td id="T_f96c0_row0_col0" class="data row0 col0" >50.0%</td>
#       <td id="T_f96c0_row0_col1" class="data row0 col1" >0.0%</td>
#       <td id="T_f96c0_row0_col2" class="data row0 col2" >0.0%</td>
#       <td id="T_f96c0_row0_col3" class="data row0 col3" >50.0%</td>
#     </tr>
#     <tr>
#       <th id="T_f96c0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f96c0_row1_col0" class="data row1 col0" >46.3%</td>
#       <td id="T_f96c0_row1_col1" class="data row1 col1" >1.8%</td>
#       <td id="T_f96c0_row1_col2" class="data row1 col2" >12.7%</td>
#       <td id="T_f96c0_row1_col3" class="data row1 col3" >39.3%</td>
#     </tr>
#     <tr>
#       <th id="T_f96c0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f96c0_row2_col0" class="data row2 col0" >43.8%</td>
#       <td id="T_f96c0_row2_col1" class="data row2 col1" >2.4%</td>
#       <td id="T_f96c0_row2_col2" class="data row2 col2" >14.8%</td>
#       <td id="T_f96c0_row2_col3" class="data row2 col3" >39.0%</td>
#     </tr>
#     <tr>
#       <th id="T_f96c0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f96c0_row3_col0" class="data row3 col0" >39.1%</td>
#       <td id="T_f96c0_row3_col1" class="data row3 col1" >5.2%</td>
#       <td id="T_f96c0_row3_col2" class="data row3 col2" >18.5%</td>
#       <td id="T_f96c0_row3_col3" class="data row3 col3" >37.3%</td>
#     </tr>
#     <tr>
#       <th id="T_f96c0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f96c0_row4_col0" class="data row4 col0" >42.7%</td>
#       <td id="T_f96c0_row4_col1" class="data row4 col1" >3.0%</td>
#       <td id="T_f96c0_row4_col2" class="data row4 col2" >13.2%</td>
#       <td id="T_f96c0_row4_col3" class="data row4 col3" >41.0%</td>
#     </tr>
#     <tr>
#       <th id="T_f96c0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f96c0_row5_col0" class="data row5 col0" >44.3%</td>
#       <td id="T_f96c0_row5_col1" class="data row5 col1" >1.3%</td>
#       <td id="T_f96c0_row5_col2" class="data row5 col2" >10.6%</td>
#       <td id="T_f96c0_row5_col3" class="data row5 col3" >43.8%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Gravity vs. Vehicle Category
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='vehicle_category', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Vehicle Category')
plt.xlabel('Vehicle Category')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

# Gravity vs. Vehicle Category
calculate_and_display_percentages(data, 'vehicle_category')
# Out:
# <style type="text/css">
# #T_75cc7 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_75cc7 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_75cc7 caption {
#   caption-side: top;
# }
# #T_75cc7_row0_col0, #T_75cc7_row4_col0, #T_75cc7_row24_col3, #T_75cc7_row30_col0 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_75cc7_row0_col1 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_75cc7_row0_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_75cc7_row0_col3 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_75cc7_row1_col0 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_75cc7_row1_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_75cc7_row1_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_75cc7_row1_col3, #T_75cc7_row29_col3 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_75cc7_row2_col0 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_75cc7_row2_col1, #T_75cc7_row5_col1, #T_75cc7_row6_col1, #T_75cc7_row15_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_75cc7_row2_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_75cc7_row2_col3 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_75cc7_row3_col0 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_75cc7_row3_col1, #T_75cc7_row18_col1, #T_75cc7_row21_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_75cc7_row3_col2 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_75cc7_row3_col3 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_75cc7_row4_col1, #T_75cc7_row24_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_75cc7_row4_col2, #T_75cc7_row5_col2 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_75cc7_row4_col3, #T_75cc7_row17_col0 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_75cc7_row5_col0, #T_75cc7_row10_col0 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_75cc7_row5_col3, #T_75cc7_row18_col3, #T_75cc7_row20_col2 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_75cc7_row6_col0 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_75cc7_row6_col2, #T_75cc7_row14_col2 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_75cc7_row6_col3, #T_75cc7_row25_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_75cc7_row7_col0, #T_75cc7_row14_col3, #T_75cc7_row26_col0 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_75cc7_row7_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_75cc7_row7_col2, #T_75cc7_row23_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_75cc7_row7_col3 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_75cc7_row8_col0 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_75cc7_row8_col1 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_75cc7_row8_col2 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_75cc7_row8_col3 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_75cc7_row9_col0 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_75cc7_row9_col1, #T_75cc7_row20_col1 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_75cc7_row9_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_75cc7_row9_col3 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_75cc7_row10_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_75cc7_row10_col2 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_75cc7_row10_col3 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_75cc7_row11_col0, #T_75cc7_row12_col0 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_75cc7_row11_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_75cc7_row11_col2, #T_75cc7_row30_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_75cc7_row11_col3 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_75cc7_row12_col1, #T_75cc7_row22_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_75cc7_row12_col2 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_75cc7_row12_col3 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_75cc7_row13_col0, #T_75cc7_row24_col0 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_75cc7_row13_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_75cc7_row13_col2 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_75cc7_row13_col3 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_75cc7_row14_col0 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_75cc7_row14_col1, #T_75cc7_row28_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_75cc7_row15_col0, #T_75cc7_row26_col3 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_75cc7_row15_col2, #T_75cc7_row23_col1 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_75cc7_row15_col3 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_75cc7_row16_col0, #T_75cc7_row16_col3, #T_75cc7_row21_col3 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_75cc7_row16_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_75cc7_row16_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_75cc7_row17_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_75cc7_row17_col2 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_75cc7_row17_col3 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_75cc7_row18_col0 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_75cc7_row18_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_75cc7_row19_col0, #T_75cc7_row19_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_75cc7_row19_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_75cc7_row19_col2 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_75cc7_row20_col0 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_75cc7_row20_col3 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_75cc7_row21_col0, #T_75cc7_row27_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_75cc7_row21_col2 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_75cc7_row22_col0, #T_75cc7_row23_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_75cc7_row22_col2, #T_75cc7_row27_col2, #T_75cc7_row29_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_75cc7_row22_col3 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_75cc7_row23_col3 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_75cc7_row24_col2 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_75cc7_row25_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_75cc7_row25_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_75cc7_row25_col2 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_75cc7_row26_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_75cc7_row26_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_75cc7_row27_col1, #T_75cc7_row31_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_75cc7_row27_col3 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_75cc7_row28_col0 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_75cc7_row28_col2 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_75cc7_row28_col3 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_75cc7_row29_col0, #T_75cc7_row31_col0 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_75cc7_row29_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_75cc7_row30_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_75cc7_row30_col3 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_75cc7_row31_col2 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_75cc7_row31_col3 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_75cc7">
#   <caption>Percentages of Accident Gravity by Vehicle_category</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_75cc7_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_75cc7_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_75cc7_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_75cc7_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >vehicle_category</t

# %%
# Gravity vs. Gender
plt.figure(figsize=(18, 12))
sns.countplot(data=data, x='gender', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.show()

# Gravity vs. Gender
calculate_and_display_percentages(data, 'gender')
# Out:
# <style type="text/css">
# #T_68ce5 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_68ce5 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_68ce5 caption {
#   caption-side: top;
# }
# #T_68ce5_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_68ce5_row0_col1, #T_68ce5_row0_col2, #T_68ce5_row0_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_68ce5_row1_col0 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_68ce5_row1_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_68ce5_row1_col2 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_68ce5_row1_col3 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_68ce5_row2_col0 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_68ce5_row2_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_68ce5_row2_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_68ce5_row2_col3 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# </style>
# <table id="T_68ce5">
#   <caption>Percentages of Accident Gravity by Gender</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_68ce5_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_68ce5_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_68ce5_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_68ce5_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68ce5_level0_row0" class="row_heading level0 row0" >-1</th>
#       <td id="T_68ce5_row0_col0" class="data row0 col0" >100.0%</td>
#       <td id="T_68ce5_row0_col1" class="data row0 col1" >0.0%</td>
#       <td id="T_68ce5_row0_col2" class="data row0 col2" >0.0%</td>
#       <td id="T_68ce5_row0_col3" class="data row0 col3" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_68ce5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_68ce5_row1_col0" class="data row1 col0" >46.7%</td>
#       <td id="T_68ce5_row1_col1" class="data row1 col1" >2.4%</td>
#       <td id="T_68ce5_row1_col2" class="data row1 col2" >13.9%</td>
#       <td id="T_68ce5_row1_col3" class="data row1 col3" >37.1%</td>
#     </tr>
#     <tr>
#       <th id="T_68ce5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_68ce5_row2_col0" class="data row2 col0" >39.9%</td>
#       <td id="T_68ce5_row2_col1" class="data row2 col1" >1.4%</td>
#       <td id="T_68ce5_row2_col2" class="data row2 col2" >11.6%</td>
#       <td id="T_68ce5_row2_col3" class="data row2 col3" >47.1%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Gravity vs. Surface Condition
plt.figure(figsize=(18,12))
sns.countplot(data=data, x='surface_condition', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Gravity vs. Surface Condition')
plt.xlabel('Surface Condition')
plt.ylabel('Count')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

# Gravity vs. Surface Condition
calculate_and_display_percentages(data, 'surface_condition')
# Out:
# <style type="text/css">
# #T_90652 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_90652 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_90652 caption {
#   caption-side: top;
# }
# #T_90652_row0_col0 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_90652_row0_col1 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_90652_row0_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_90652_row0_col3 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_90652_row1_col0 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_90652_row1_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_90652_row1_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_90652_row1_col3 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_90652_row2_col0 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_90652_row2_col1, #T_90652_row5_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_90652_row2_col2 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_90652_row2_col3, #T_90652_row8_col3 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_90652_row3_col0 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_90652_row3_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_90652_row3_col2 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_90652_row3_col3 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_90652_row4_col0 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_90652_row4_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_90652_row4_col2 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_90652_row4_col3 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_90652_row5_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_90652_row5_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_90652_row5_col3 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_90652_row6_col0 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_90652_row6_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_90652_row6_col2 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_90652_row6_col3 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_90652_row7_col0 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_90652_row7_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_90652_row7_col2 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_90652_row7_col3 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_90652_row8_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_90652_row8_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_90652_row8_col2 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_90652_row9_col0 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_90652_row9_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_90652_row9_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_90652_row9_col3 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_90652">
#   <caption>Percentages of Accident Gravity by Surface_condition</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_90652_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_90652_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_90652_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_90652_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >surface_condition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90652_level0_row0" class="row_heading level0 row0" >-1</th>
#       <td id="T_90652_row0_col0" class="data row0 col0" >46.9%</td>
#       <td id="T_90652_row0_col1" class="data row0 col1" >12.5%</td>
#       <td id="T_90652_row0_col2" class="data row0 col2" >6.2%</td>
#       <td id="T_90652_row0_col3" class="data row0 col3" >34.4%</td>
#     </tr>
#     <tr>
#       <th id="T_90652_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_90652_row1_col0" class="data row1 col0" >45.4%</td>
#       <td id="T_90652_row1_col1" class="data row1 col1" >2.0%</td>
#       <td id="T_90652_row1_col2" class="data row1 col2" >13.2%</td>
#       <td id="T_90652_row1_col3" class="data row1 col3" >39.4%</td>
#     </tr>
#     <tr>
#       <th id="T_90652_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_90652_row2_col0" class="data row2 col0" >44.4%</td>
#       <td id="T_90652_row2_col1" class="data row2 col1" >2.2%</td>
#       <td id="T_90652_row2_col2" class="data row2 col2" >11.7%</td>
#       <td id="T_90652_row2_col3" class="data row2 col3" >41.8%</td>
#     </tr>
#     <tr>
#       <th id="T_90652_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_90652_row3_col0" class="data row3 col0" >43.8%</td>
#       <td id="T_90652_row3_col1" class="data row3 col1" >2.3%</td>
#       <td id="T_90652_row3_col2" class="data row3 col2" >16.4%</td>
#       <td id="T_90652_row3_col3" class="data row3 col3" >37.5%</td>
#     </tr>
#     <tr>
#       <th id="T_90652_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_90652_row4_col0" class="data row4 col0" >42.3%</td>
#       <td id="T_90652_row4_col1" class="data row4 col1" >3.7%</td>
#       <td id="T_90652_row4_col2" class="data row4 col2" >15.6%</td>
#       <td id="T_90652_row4_col3" class="data row4 col3" >38.3%</td>
#     </tr>
#     <tr>
#       <th id="T_90652_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_90652_row5_col0" class="data row5 col0" >49.3%</td>
#       <td id="T_90652_row5_col1" class="data row5 col1" >2.1%</td>
#       <td id="T_90652_row5_col2" class="data row5 col2" >13.4%</td>
#       <td id="T_90652_row5_col3" class="data row5 col3" >35.1%</td>
#     </tr>
#     <tr>
#       <th id="T_90652_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_90652_row6_col0" class="data row6 col0" >28.4%</td>
#       <td id="T_90652_row6_col1" class="data row6 col1" >5.2%</td>
#       <td id="T_90652_row6_col2" class="data row6 col2" >30.3%</td>
#       <td id="T_90652_row6_col3" class="data row6 col3" >36.2%</td>
#     </tr>
#     <tr>
#       <th id="T_90652_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_90652_row7_col0" class="data row7 col0" >37.2%</td>
#       <td id="T_90652_row7_col1" class="data row7 col1" >4.3%</td>
#       <td id="T_90652_row7_col2" class="data row7 col2" >20.7%</td>
#       <td id="T_90652_row7_col3" class="data row7 col3" >37.8%</td>
#     </tr>
#     <tr>
#       <th id="T_90652_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_90652_row8_col0" class="data row8 col0" >40.1%</td>
#       <td id="T_90652_row8_col1" class="data row8 col1" >1.3%</td>
#       <td id="T_90652_row8_col2" class="data row8 col2" >16.9%</td>
#       <td id="T_90652_row8_col3" class="data row8 col3" >41.8%</td>
#     </tr>
#     <tr>
#       <th id="T_90652_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_90652_row9_col0" class="data row9 col0" >38.3%</td>
#       <td id="T_90652_row9_col1" class="data row9 col1" >4.2%</td>
#       <td id="T_90652_row9_col2" class="data row9 col2" >22.7%</td>
#       <td id="T_90652_row9_col3" class="data row9 col3" >34.8%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Define the bins and corresponding labels
bins = [0, 49, 59, 69, 79, 89, 99, 109, float('inf')]
labels = ['0-49', '50-59', '60-69', '70-79', '80-89', '90-99', '100-109', '110-119']

# Create a new column for the binned speeds
data['speed_group'] = pd.cut(data['maximum_speed'], bins=bins, labels=labels, right=False)

# Gravity vs. Maximum Speed
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='speed_group', hue='gravity', hue_order=gravity_order, palette=custom_colors)

plt.title('Gravity vs. Maximum Speed')
plt.xlabel('Maximum Speed Group')
plt.ylabel('Gravity')
plt.legend(title='Gravity')
plt.xticks(rotation=45)
plt.show()

# Gravity vs. Maximum Speed
calculate_and_display_percentages(data, 'maximum_speed')
# Out:
# <style type="text/css">
# #T_39cc6 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_39cc6 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_39cc6 caption {
#   caption-side: top;
# }
# #T_39cc6_row0_col0, #T_39cc6_row7_col0, #T_39cc6_row11_col0 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_39cc6_row0_col1, #T_39cc6_row1_col1, #T_39cc6_row2_col0, #T_39cc6_row2_col1, #T_39cc6_row2_col2, #T_39cc6_row3_col1, #T_39cc6_row3_col2, #T_39cc6_row5_col1, #T_39cc6_row5_col2, #T_39cc6_row10_col1, #T_39cc6_row12_col1, #T_39cc6_row12_col2, #T_39cc6_row15_col1, #T_39cc6_row17_col1, #T_39cc6_row17_col3, #T_39cc6_row19_col1, #T_39cc6_row19_col3, #T_39cc6_row24_col1, #T_39cc6_row24_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_39cc6_row0_col2 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_39cc6_row0_col3 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_39cc6_row1_col0 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_39cc6_row1_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_39cc6_row1_col3 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_39cc6_row2_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_39cc6_row3_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_39cc6_row3_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_39cc6_row4_col0, #T_39cc6_row18_col0 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_39cc6_row4_col1, #T_39cc6_row13_col1, #T_39cc6_row23_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_39cc6_row4_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_39cc6_row4_col3, #T_39cc6_row23_col3 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_39cc6_row5_col0 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_39cc6_row5_col3, #T_39cc6_row8_col0 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_39cc6_row6_col0, #T_39cc6_row14_col0 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_39cc6_row6_col1, #T_39cc6_row9_col1, #T_39cc6_row14_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_39cc6_row6_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_39cc6_row6_col3 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_39cc6_row7_col1, #T_39cc6_row22_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_39cc6_row7_col2 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_39cc6_row7_col3, #T_39cc6_row16_col0 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_39cc6_row8_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_39cc6_row8_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_39cc6_row8_col3 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_39cc6_row9_col0 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_39cc6_row9_col2 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_39cc6_row9_col3 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_39cc6_row10_col0, #T_39cc6_row20_col3 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_39cc6_row10_col2 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_39cc6_row10_col3 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_39cc6_row11_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_39cc6_row11_col2 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_39cc6_row11_col3 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_39cc6_row12_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_39cc6_row12_col3 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_39cc6_row13_col0 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_39cc6_row13_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_39cc6_row13_col3, #T_39cc6_row18_col3 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_39cc6_row14_col2 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_39cc6_row14_col3 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_39cc6_row15_col0, #T_39cc6_row15_col3, #T_39cc6_row19_col0 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_39cc6_row15_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_39cc6_row16_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_39cc6_row16_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_39cc6_row16_col3 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_39cc6_row17_col0 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_39cc6_row17_col2 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_39cc6_row18_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_39cc6_row18_col2 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_39cc6_row19_col2 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_39cc6_row20_col0 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_39cc6_row20_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_39cc6_row20_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_39cc6_row21_col0 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_39cc6_row21_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_39cc6_row21_col2 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_39cc6_row21_col3 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_39cc6_row22_col0 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_39cc6_row22_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_39cc6_row22_col3 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_39cc6_row23_col0 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_39cc6_row23_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_39cc6_row24_col0, #T_39cc6_row24_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_39cc6">
#   <caption>Percentages of Accident Gravity by Maximum_speed</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >gravity</th>
#       <th id="T_39cc6_level0_col0" class="col_heading level0 col0" >1 - Unharmed</th>
#       <th id="T_39cc6_level0_col1" class="col_heading level0 col1" >2 - Killed</th>
#       <th id="T_39cc6_level0_col2" class="col_heading level0 col2" >3 - Hospitalized</th>
#       <th id="T_39cc6_level0_col3" class="col_heading level0 col3" >4 - Slightly injured</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >maximum_speed</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39cc6_level0_row0" class="row_heading level0 row0" >6</th>
#       <td id="T_39cc6_row0_col0" class="data row0 col0" >43.4%</td>
#       <td id="T_39cc6_row0_col1" class="data row0 col1" >0.0%</td>
#       <td id="T_39cc6_row0_col2" class="data row0 col2" >11.3%</td>
#       <td id="T_39cc6_row0_col3" class="data row0 col3" >45.3%</td>
#     </tr>
#     <tr>
#       <th id="T_39cc6_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_39cc6_row1_col0" class="data row1 col0" >54.5%</td>
#       <td id="T_39cc6_row1_col1" class="data row1 col1" >0.0%</td>
#       <td id="T_39cc6_row1_col2" class="data row1 col2" >18.2%</td>
#       <td id="T_39cc6_row1_col3" class="data row1 col3" >27.3%</td>
#     </tr>
#     <tr>
#       <th id="T_39cc6_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_39cc6_row2_col0" class="data row2 col0" >0.0%</td>
#       <td id="T_39cc6_row2_col1" class="data row2 col1" >0.0%</td>
#       <td id="T_39cc6_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_39cc6_row2_col3" class="data row2 col3" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_39cc6_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_39cc6_row3_col0" class="data row3 col0" >66.7%</td>
#       <td id="T_39cc6_row3_col1" class="data row3 col1" >0.0%</td>
#       <td id="T_39cc6_row3_col2" class="data row3 col2" >0.0%</td>
#       <td id="T_39cc6_row3_col3" class="data row3 col3" >33.3%</td>
#     </tr>
#     <tr>
#       <th id="T_39cc6_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_39cc6_row4_col0" class="data row4 col0" >46.5%</td>
#       <td id="T_39cc6_row4_col1" class="data row4 col1" >2.2%</td>
#       <td id="

# %%
# 1. Bar Plot
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Count of Each Gravity Category')
plt.show()

# %%
# 2. Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='gravity', y='age', hue_order=gravity_order, palette=custom_colors)
plt.title('Age Distribution by Gravity Category')
plt.show()

# Gravity
calculate_and_display_percentages(data, 'age')
# Out:
# <style type="text/css">
# #T_c0be8 th {
#   font-size: 12pt;
#   font-weight: bold;
#   text-align: center;
# }
# #T_c0be8 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_c0be8 caption {
#   caption-side: top;
# }
# #T_c0be8_row0_col0, #T_c0be8_row22_col3, #T_c0be8_row25_col0, #T_c0be8_row28_col3, #T_c0be8_row79_col0 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_c0be8_row0_col1, #T_c0be8_row5_col1, #T_c0be8_row12_col1, #T_c0be8_row15_col1, #T_c0be8_row17_col1, #T_c0be8_row28_col1, #T_c0be8_row29_col1, #T_c0be8_row30_col1, #T_c0be8_row31_col1, #T_c0be8_row33_col1, #T_c0be8_row34_col1, #T_c0be8_row35_col1, #T_c0be8_row36_col1, #T_c0be8_row38_col1, #T_c0be8_row39_col1, #T_c0be8_row47_col1, #T_c0be8_row48_col1, #T_c0be8_row50_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_c0be8_row0_col2, #T_c0be8_row75_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_c0be8_row0_col3, #T_c0be8_row1_col3, #T_c0be8_row5_col3, #T_c0be8_row41_col0 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_c0be8_row1_col0, #T_c0be8_row34_col3, #T_c0be8_row35_col3 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_c0be8_row1_col1, #T_c0be8_row14_col1, #T_c0be8_row16_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_c0be8_row1_col2, #T_c0be8_row5_col2 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_c0be8_row2_col0, #T_c0be8_row29_col0 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_c0be8_row2_col1, #T_c0be8_row3_col1, #T_c0be8_row19_col1, #T_c0be8_row20_col1, #T_c0be8_row22_col1, #T_c0be8_row24_col1, #T_c0be8_row25_col1, #T_c0be8_row51_col1, #T_c0be8_row52_col1, #T_c0be8_row55_col1, #T_c0be8_row56_col1, #T_c0be8_row57_col1, #T_c0be8_row58_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_c0be8_row2_col2 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_c0be8_row2_col3, #T_c0be8_row36_col0 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_c0be8_row3_col0, #T_c0be8_row81_col0 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_c0be8_row3_col2, #T_c0be8_row4_col2 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_c0be8_row3_col3, #T_c0be8_row19_col3, #T_c0be8_row37_col0, #T_c0be8_row39_col0, #T_c0be8_row49_col0 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_c0be8_row4_col0, #T_c0be8_row30_col0, #T_c0be8_row76_col0 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_c0be8_row4_col1, #T_c0be8_row8_col1, #T_c0be8_row9_col1, #T_c0be8_row11_col1, #T_c0be8_row13_col1, #T_c0be8_row40_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_c0be8_row4_col3, #T_c0be8_row32_col0, #T_c0be8_row33_col0, #T_c0be8_row66_col0 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_c0be8_row5_col0, #T_c0be8_row36_col3, #T_c0be8_row86_col0 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_c0be8_row6_col0, #T_c0be8_row50_col3, #T_c0be8_row91_col0 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_c0be8_row6_col1, #T_c0be8_row7_col1, #T_c0be8_row10_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c0be8_row6_col2, #T_c0be8_row8_col2, #T_c0be8_row30_col2, #T_c0be8_row31_col2, #T_c0be8_row39_col2 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_c0be8_row6_col3, #T_c0be8_row44_col0, #T_c0be8_row47_col0 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_c0be8_row7_col0, #T_c0be8_row53_col3 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_c0be8_row7_col2, #T_c0be8_row48_col2 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_c0be8_row7_col3 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_c0be8_row8_col0 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_c0be8_row8_col3, #T_c0be8_row11_col3 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_c0be8_row9_col0, #T_c0be8_row11_col0, #T_c0be8_row69_col3 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_c0be8_row9_col2, #T_c0be8_row26_col2, #T_c0be8_row49_col2, #T_c0be8_row52_col2, #T_c0be8_row91_col1 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_c0be8_row9_col3 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_c0be8_row10_col0, #T_c0be8_row62_col3, #T_c0be8_row90_col0 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_c0be8_row10_col2, #T_c0be8_row13_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_c0be8_row10_col3 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_c0be8_row11_col2, #T_c0be8_row55_col2, #T_c0be8_row56_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_c0be8_row12_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_c0be8_row12_col2, #T_c0be8_row51_col2 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_c0be8_row12_col3, #T_c0be8_row13_col3 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_c0be8_row13_col0 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_c0be8_row14_col0 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_c0be8_row14_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_c0be8_row14_col3 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_c0be8_row15_col0, #T_c0be8_row16_col2, #T_c0be8_row83_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_c0be8_row15_col2, #T_c0be8_row74_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_c0be8_row15_col3 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_c0be8_row16_col0, #T_c0be8_row76_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_c0be8_row16_col3 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_c0be8_row17_col0, #T_c0be8_row73_col2, #T_c0be8_row81_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_c0be8_row17_col2 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_c0be8_row17_col3 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_c0be8_row18_col0, #T_c0be8_row40_col3, #T_c0be8_row88_col2, #T_c0be8_row91_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_c0be8_row18_col1, #T_c0be8_row23_col1, #T_c0be8_row26_col1, #T_c0be8_row27_col1, #T_c0be8_row32_col1, #T_c0be8_row37_col1, #T_c0be8_row41_col1, #T_c0be8_row42_col1, #T_c0be8_row43_col1, #T_c0be8_row44_col1, #T_c0be8_row45_col1, #T_c0be8_row46_col1, #T_c0be8_row49_col1, #T_c0be8_row54_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_c0be8_row18_col2, #T_c0be8_row84_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_c0be8_row18_col3 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_c0be8_row19_col0, #T_c0be8_row74_col3, #T_c0be8_row76_col3 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_c0be8_row19_col2, #T_c0be8_row70_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_c0be8_row20_col0 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_c0be8_row20_col2, #T_c0be8_row68_col2 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_c0be8_row20_col3 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_c0be8_row21_col0, #T_c0be8_row42_col3, #T_c0be8_row48_col3 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_c0be8_row21_col1, #T_c0be8_row53_col1, #T_c0be8_row59_col1, #T_c0be8_row60_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_c0be8_row21_col2, #T_c0be8_row57_col2 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_c0be8_row21_col3, #T_c0be8_row28_col0 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_c0be8_row22_col0, #T_c0be8_row24_col0, #T_c0be8_row26_col3, #T_c0be8_row82_col0 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_c0be8_row22_col2, #T_c0be8_row24_col2, #T_c0be8_row54_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_c0be8_row23_col0, #T_c0be8_row24_col3, #T_c0be8_row31_col3 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_c0be8_row23_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_c0be8_row23_col3, #T_c0be8_row25_col3, #T_c0be8_row29_col3 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_c0be8_row25_col2, #T_c0be8_row50_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_c0be8_row26_col0, #T_c0be8_row27_col0, #T_c0be8_row27_col3 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_c0be8_row27_col2 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_c0be8_row28_col2, #T_c0be8_row29_col2, #T_c0be8_row3

# %%
# 5. KDE Plot
plt.figure(figsize=(10, 6))
sns.kdeplot(data=data, x='age', hue='gravity', fill=True, hue_order=gravity_order, palette=custom_colors)
plt.title('Age Distribution by Gravity Category')
plt.show()

# %%
# 12. Line Plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='age', y='maximum_speed', hue='gravity', hue_order=gravity_order, palette=custom_colors)
plt.title('Age vs. Maximum Speed by Gravity')
plt.show()
